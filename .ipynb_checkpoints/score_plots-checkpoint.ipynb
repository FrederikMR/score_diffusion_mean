# %% [markdown]
# # Score Plots

# %%
from jaxgeometry.manifolds import Euclidean, nSphere, S1
from jaxgeometry.setup import dts, jacfwdx
from jaxgeometry.statistics.score_matching import diffusion_mean
import jaxgeometry.statistics as jstat
import jaxgeometry.stochastics as jstoch
import jax.numpy as jnp
import haiku as hk
import jax
from jax import vmap

import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

from jaxgeometry.statistics.score_matching import model_loader
from scores import models

# %% [markdown]
# ## Define Manifolds

# %% [markdown]
# ## R2

# %%
R2 = Euclidean(N=2)
jstoch.Brownian_coords(R2)
jstat.diffusion_mean(R2)
# Out:
# using M.Exp for Logarithm

# %%
theta = jnp.linspace(0,2*jnp.pi, 100)

X_obs = (jnp.array([jnp.cos(theta), jnp.sin(theta)]).T, jnp.zeros(100))
x0 = (jnp.zeros(2), jnp.zeros(1))
t = 0.5

# %% [markdown]
# ### DSM

# %%
file_path = 'scores/R2/dsm/'
state = model_loader.load_model(file_path)

# %%
layers = [50, 100, 100, 50]

s1_model = hk.transform(lambda x: models.MLP_s1(dim=R2.dim, layers=layers)(x))
s2_model = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=R2.dim, r = max(N_dim//2,1))(x))

# %%
model = s1_model
rng_key = jax.random.PRNGKey(2712)
def grady_log_model(x,y,t):
    
    return model.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log_model(x,y,t):
    
    grad_val = grady_log_model(x, y, t)
            
    return 0.5*(jnp.dot(grad_val, grad_val)+M.div(y,lambda y: grady_log_model(x, y, t)))

# %%
#Source: https://stackoverflow.com/questions/2827393/angles-between-two-n-dimensional-vectors-in-python

def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / jnp.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return jnp.arccos(jnp.clip(jnp.dot(v1_u, v2_u), -1.0, 1.0))

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere
#Plotting
# Creating the theta and phi values
intervals = 1000

min_x = -2.0
max_x = 2.0
min_t = 1e-8
max_t = 1.0

x1 = jnp.linspace(min_x, max_x, intervals)
x2 = jnp.linspace(min_x, max_x, intervals)
t1 = jnp.linspace(min_t, max_t, intervals)

# Creating the coordinate grid for the unit sphere.
X1_heat, X2_heat = jnp.meshgrid(x1, x2)
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, intervals, intervals), 
                     X2_heat.reshape(1, intervals, intervals))), axes=(1,2,0))

theoretical_grad = lambda y: R2.grady_log_hk(x0, (y, jnp.zeros(1)), t)[0]
numerical_grad = lambda y: grady_log_model(x0, (y, jnp.zeros(1)), t)
heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
                                                         numerical_grad(x1)))(x2))(X_heat)

# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.imshow(heat_map, cmap=mpl.cm.inferno, interpolation='nearest', aspect='auto',
          extent=[min_x,max_x,min_x,max_x])
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_title(r'$\cos^{-1}\frac{\langle s_{\theta}(x,y,t), \nabla_{y}\ln p(x,y,t) \rangle_{\mathbb{R}^{2}}}{||s_{\theta}(x,y,t)||_{\mathbb{R}^{2}}\cdot||\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}}$',
            fontsize=20)
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
cax = plt.axes([1.0, 0.075, 0.05, 0.825])
fig.colorbar(m, ax=ax, cax=cax)
ax.autoscale(False)
fig.savefig('Figures/r2_angle.pdf', format='pdf', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()

# %% [markdown]
# ### Plotting the Norm Difference in $x$

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere

# Creating the theta and phi values
intervals = 1000

min_x = -2.0
max_x = 2.0
min_t = 1e-8
max_t = 1.0

x1 = jnp.linspace(min_x, max_x, intervals)
x2 = jnp.linspace(min_x, max_x, intervals)
t1 = jnp.linspace(min_t, max_t, intervals)

# Creating the coordinate grid for the unit sphere.
X1_heat, X2_heat = jnp.meshgrid(x1, x2)
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, intervals, intervals), 
                     X2_heat.reshape(1, intervals, intervals))), axes=(1,2,0))

theoretical_grad = lambda y: R2.grady_log_hk(x0, (y, jnp.zeros(1)), t)[0]
numerical_grad = lambda y: grady_log_model(x0, (y, jnp.zeros(1)), t)
heat_map = vmap(lambda x2: vmap(lambda x1: jnp.linalg.norm(theoretical_grad(x1)-numerical_grad(x1))**2)(x2))(X_heat)

# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.imshow(heat_map, cmap=mpl.cm.inferno, interpolation='nearest', aspect='auto',
          extent=[min_x,max_x,min_x,max_x])
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_title(r'$||s_{\theta}(x,y,t)-\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}^{2}$', fontsize=20)
ax.set_ylim((min_x,max_x))
ax.set_xlim((min_x,max_x))
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
cax = plt.axes([1.0, 0.075, 0.05, 0.825])
fig.colorbar(m, ax=ax, cax=cax)
ax.autoscale(False)
fig.savefig('Figures/r2_norm.pdf', format='pdf', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()

# %% [markdown]
# ### Estimate Diffusion Mean

# %%
def s1_grad(x,y,t):
    
    return model.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def s2_grad(x,y,t):
    
    ggrad = jacfwdx(lambda y: model.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

diffusion_mean.initialize(R2, s1_model=s1_grad, s2_model = s2_grad, method="Gradient")

# %%
theta = jnp.linspace(0,2*jnp.pi, 100)

X_obs = (jnp.array([jnp.cos(theta), jnp.sin(theta)]).T, jnp.zeros(100))
x0 = (jnp.zeros(2), jnp.zeros(1))

# %%
mu_sm, T_sm, _, _ = R2.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0].reshape(1)), jnp.array([0.1]))

# %%
# %time (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = R2.diffusion_mean(X_obs,num_steps=1000, N=1)
# Out:
# Step 0 | T: 1.157805e+01 | T: ((Array([0.11074843, 0.12107268], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.042053e+01 | T: ((Array([0.10084385, 0.11116208], dtype=float32), Array(0.21992685, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.438817e+00 | T: ((Array([0.09109786, 0.10139912], dtype=float32), Array(0.22974007, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.603736e+00 | T: ((Array([0.08157159, 0.09183952], dtype=float32), Array(0.23940513, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.891038e+00 | T: ((Array([0.07232282, 0.08253556], dtype=float32), Array(0.24889334, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.280631e+00 | T: ((Array([0.06340458, 0.07353497], dtype=float32), Array(0.25818148, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.755886e+00 | T: ((Array([0.05486419, 0.06488019], dtype=float32), Array(0.26725128, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.303047e+00 | T: ((Array([0.04674234, 0.05660788], dtype=float32), Array(0.27608886, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.910723e+00 | T: ((Array([0.03907268, 0.04874858], dtype=float32), Array(0.2846841, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.569474e+00 | T: ((Array([0.0318815 , 0.04132659], dtype=float32), Array(0.29303017, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.271465e+00 | T: ((Array([0.02518781, 0.0343601 ], dtype=float32), Array(0.301123, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.010183e+00 | T: ((Array([0.01900347, 0.02786128], dtype=float32), Array(0.3089609, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.780193e+00 | T: ((Array([0.01333376, 0.0218368 ], dtype=float32), Array(0.3165442, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.576958e+00 | T: ((Array([0.00817792, 0.01628819], dtype=float32), Array(0.32387477, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.396675e+00 | T: ((Array([0.00352981, 0.01121239], dtype=float32), Array(0.33095583, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.236156e+00 | T: ((Array([-0.00062138,  0.00660225], dtype=float32), Array(0.33779174, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.092710e+00 | T: ((Array([-0.00429038,  0.00244717], dtype=float32), Array(0.3443877, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.964067e+00 | T: ((Array([-0.0074951 , -0.00126639], dtype=float32), Array(0.35074964, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.848305e+00 | T: ((Array([-0.01025606, -0.00455444], dtype=float32), Array(0.356884, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.743790e+00 | T: ((Array([-0.01259572, -0.00743486], dtype=float32), Array(0.36279762, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.649132e+00 | T: ((Array([-0.01453794, -0.00992709], dtype=float32), Array(0.36849764, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.563141e+00 | T: ((Array([-0.01610756, -0.01205162], dtype=float32), Array(0.37399143, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.484798e+00 | T: ((Array([-0.01732994, -0.01382973], dtype=float32), Array(0.3792864, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.413226e+00 | T: ((Array([-0.01823065, -0.01528311], dtype=float32), Array(0.38439012, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.347668e+00 | T: ((Array([-0.01883516, -0.01643368], dtype=float32), Array(0.38931006, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.287469e+00 | T: ((Array([-0.01916864, -0.01730328], dtype=float32), Array(0.3940537, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.232062e+00 | T: ((Array([-0.01925569, -0.01791355], dtype=float32), Array(0.39862835, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.180949e+00 | T: ((Array([-0.01912026, -0.01828574], dtype=float32), Array(0.40304127, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.133698e+00 | T: ((Array([-0.01878549, -0.01844059], dtype=float32), Array(0.40729955, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.089929e+00 | T: ((Array([-0.0182736 , -0.01839821], dtype=float32), Array(0.4114101, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.049307e+00 | T: ((Array([-0.01760583, -0.01817804], dtype=float32), Array(0.4153796, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.011536e+00 | T: ((Array([-0.01680241, -0.01779872], dtype=float32), Array(0.41921464, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.976354e+00 | T: ((Array([-0.01588245, -0.0172781 ], dtype=float32), Array(0.42292145, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.943530e+00 | T: ((Array([-0.01486401, -0.01663316], dtype=float32), Array(0.42650616, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.912855e+00 | T: ((Array([-0.013764  , -0.01588001], dtype=float32), Array(0.42997462, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.884145e+00 | T: ((Array([-0.01259825, -0.01503386], dtype=float32), Array(0.43333244, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.857233e+00 | T: ((Array([-0.01138145, -0.01410902], dtype=float32), Array(0.43658504, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.831969e+00 | T: ((Array([-0.01012721, -0.0131189 ], dtype=float32), Array(0.4397376, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.808220e+00 | T: ((Array([-0.00884806, -0.01207602], dtype=float32), Array(0.44279504, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.785863e+00 | T: ((Array([-0.00755548, -0.01099202], dtype=float32), Array(0.44576213, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.764788e+00 | T: ((Array([-0.00625991, -0.00987764], dtype=float32), Array(0.44864336, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.744896e+00 | T: ((Array([-0.00497081, -0.00874281], dtype=float32), Array(0.45144302, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.726095e+00 | T: ((Array([-0.00369668, -0.00759662], dtype=float32), Array(0.45416522, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.708303e+00 | T: ((Array([-0.00244507, -0.00644734], dtype=float32), Array(0.45681384, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.691444e+00 | T: ((Array([-0.00122267, -0.0053025 ], dtype=float32), Array(0.45939258, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.675450e+00 | T: ((Array([-3.5323435e-05, -4.1688443e-03], dtype=float32), Array(0.46190494, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.660256e+00 | T: ((Array([ 0.00111194, -0.00305244], dtype=float32), Array(0.46435425, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.645807e+00 | T: ((Array([ 0.00221484, -0.00195865], dtype=float32), Array(0.46674362, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.632048e+00 | T: ((Array([ 0.00326981, -0.0008922 ], dtype=float32), Array(0.46907604, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.618932e+00 | T: ((Array([0.00427397, 0.00014282], dtype=float32), Array(0.47135434, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.606413e+00 | T: ((Array([0.00522505, 0.00114288], dtype=float32), Array(0.47358117, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.594451e+00 | T: ((Array([0.00612137, 0.00210501], dtype=float32), Array(0.47575906, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.583009e+00 | T: ((Array([0.00696179, 0.00302677], dtype=float32), Array(0.47789037, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.572052e+00 | T: ((Array([0.00774566, 0.00390618], dtype=float32), Array(0.47997734, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.561549e+00 | T: ((Array([0.0084728 , 0.00474172], dtype=float32), Array(0.48202205, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.551470e+00 | T: ((Array([0.00914341, 0.00553227], dtype=float32), Array(0.48402652, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.541788e+00 | T: ((Array([0.00975811, 0.00627711], dtype=float32), Array(0.4859926, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.532479e+00 | T: ((Array([0.0103178 , 0.00697588], dtype=float32), Array(0.48792207, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.523520e+00 | T: ((Array([0.01082371, 0.00762851], dtype=float32), Array(0.48981658, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.514891e+00 | T: ((Array([0.01127733, 0.00823525], dtype=float32), Array(0.4916777, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.506571e+00 | T: ((Array([0.01168035, 0.0087966 ], dtype=float32), Array(0.49350688, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.498543e+00 | T: ((Array([0.01203467, 0.00931329], dtype=float32), Array(0.49530554, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.490790e+00 | T: ((Array([0.01234236, 0.00978628], dtype=float32), Array(0.49707493, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.483298e+00 | T: ((Array([0.0126056 , 0.01021668], dtype=float32), Array(0.4988163, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.476052e+00 | T: ((Array([0.01282668, 0.01060579], dtype=float32), Array(0.50053084, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.469040e+00 | T: ((Array([0.01300799, 0.01095503], dtype=float32), Array(0.50221956, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.462249e+00 | T: ((Array([0.01315194, 0.01126595], dtype=float32), Array(0.50388354, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.455668e+00 | T: ((Array([0.01326101, 0.01154016], dtype=float32), Array(0.5055237, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.449288e+00 | T: ((Array([0.01333766, 0.0117794 ], dtype=float32), Array(0.50714093, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.443098e+00 | T: ((Array([0.01338437, 0.01198541], dtype=float32), Array(0.5087361, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.437089e+00 | T: ((Array([0.01340359, 0.01216002], dtype=float32), Array(0.51031, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.431253e+00 | T: ((Array([0.01339773, 0.01230505], dtype=float32), Array(0.51186335, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.425583e+00 | T: ((Array([0.01336914, 0.01242237], dtype=float32), Array(0.5133969, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.420071e+00 | T: ((Array([0.01332014, 0.01251381], dtype=float32), Array(0.51491135, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.414711e+00 | T: ((Array([0.01325295, 0.01258122], dtype=float32), Array(0.51640725, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.409496e+00 | T: ((Array([0.01316972, 0.01262641], dtype=float32), Array(0.5178852, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.404420e+00 | T: ((Array([0.01307251, 0.01265117], dtype=float32), Array(0.5193458, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.399478e+00 | T: ((Array([0.01296329, 0.01265725], dtype=float32), Array(0.52078956, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.394664e+00 | T: ((Array([0.01284391, 0.01264634], dtype=float32), Array(0.522217, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.389974e+00 | T: ((Array([0.01271616, 0.0126201 ], dtype=float32), Array(0.5236285, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.385403e+00 | T: ((Array([0.01258168, 0.01258012], dtype=float32), Array(0.52502453, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.380946e+00 | T: ((Array([0.01244204, 0.01252792], dtype=float32), Array(0.5264056, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.376600e+00 | T: ((Array([0.01229866, 0.01246496], dtype=float32), Array(0.527772, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.372360e+00 | T: ((Array([0.0121529 , 0.01239264], dtype=float32), Array(0.5291242, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.368223e+00 | T: ((Array([0.01200597, 0.01231229], dtype=float32), Array(0.5304625, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.364185e+00 | T: ((Array([0.01185901, 0.01222514], dtype=float32), Array(0.5317873, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.360244e+00 | T: ((Array([0.01171303, 0.01213238], dtype=float32), Array(0.53309876, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.356395e+00 | T: ((Array([0.01156894, 0.0120351 ], dtype=float32), Array(0.53439736, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.352635e+00 | T: ((Array([0.01142758, 0.01193433], dtype=float32), Array(0.53568333, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.348962e+00 | T: ((Array([0.01128965, 0.01183102], dtype=float32), Array(0.5369569, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.345373e+00 | T: ((Array([0.01115581, 0.01172606], dtype=float32), Array(0.5382184, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.341866e+00 | T: ((Array([0.01102658, 0.01162025], dtype=float32), Array(0.539468, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.338438e+00 | T: ((Array([0.01090244, 0.01151432], dtype=float32), Array(0.54070604, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.335086e+00 | T: ((Array([0.01078378, 0.01140896], dtype=float32), Array(0.5419327, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.331808e+00 | T: ((Array([0.01067089, 0.01130476], dtype=float32), Array(0.54314816, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.328602e+00 | T: ((Array([0.01056404, 0.01120226], dtype=float32), Array(0.54435265, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.325466e+00 | T: ((Array([0.01046338, 0.01110195], dtype=float32), Array(0.5455464, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.322398e+00 | T: ((Array([0.01036905, 0.01100424], dtype=float32), Array(0.5467296, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.319396e+00 | T: ((Array([0.0102811, 0.0109095], dtype=float32), Array(0.54790246, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.316458e+00 | T: ((Array([0.01019955, 0.01081805], dtype=float32), Array(0.54906505, dtype=float32)), Array([0.], dtype=float32))
# Step 100 | T: 2.313581e+00 | T: ((Array([0.01012436, 0.01073014], dtype=float32), Array(0.5502176, dtype=float32)), Array([0.], dtype=float32))
# Step 101 | T: 2.310766e+00 | T: ((Array([0.01005546, 0.010646  ], dtype=float32), Array(0.5513603, dtype=float32)), Array([0.], dtype=float32))
# Step 102 | T: 2.308009e+00 | T: ((Array([0.00999274, 0.01056579], dtype=float32), Array(0.5524933, dtype=float32)), Array([0.], dtype=float32))
# Step 103 | T: 2.305310e+00 | T: ((Array([0.00993606, 0.01048965], dtype=float32), Array(0.5536167, dtype=float32)), Array([0.], dtype=float32))
# Step 104 | T: 2.302666e+00 | T: ((Array([0.00988524, 0.01041768], dtype=float32), Array(0.5547307, dtype=float32)), Array([0.], dtype=float32))
# Step 105 | T: 2.300077e+00 | T: ((Array([0.00984009, 0.01034993], dtype=float32), Array(0.5558354, dtype=float32)), Array([0.], dtype=float32))
# Step 106 | T: 2.297540e+00 | T: ((Array([0.00980038, 0.01028642], dtype=float32), Array(0.556931, dtype=float32)), Array([0.], dtype=float32))
# Step 107 | T: 2.295055e+00 | T: ((Array([0.00976589, 0.01022717], dtype=float32), Array(0.55801755, dtype=float32)), Array([0.], dtype=float32))
# Step 108 | T: 2.292620e+00 | T: ((Array([0.00973635, 0.01017213], dtype=float32), Array(0.5590952, dtype=float32)), Array([0.], dtype=float32))
# Step 109 | T: 2.290234e+00 | T: ((Array([0.00971152, 0.01012127], dtype=float32), Array(0.5601641, dtype=float32)), Array([0.], dtype=float32))
# Step 110 | T: 2.287896e+00 | T: ((Array([0.00969111, 0.01007449], dtype=float32), Array(0.56122434, dtype=float32)), Array([0.], dtype=float32))
# Step 111 | T: 2.285604e+00 | T: ((Array([0.00967486, 0.01003172], dtype=float32), Array(0.56227607, dtype=float32)), Array([0.], dtype=float32))
# Step 112 | T: 2.283357e+00 | T: ((Array([0.00966248, 0.00999284], dtype=float32), Array(0.5633194, dtype=float32)), Array([0.], dtype=float32))
# Step 113 | T: 2.281155e+00 | T: ((Array([0.0096537 , 0.00995773], dtype=float32), Array(0.5643544, dtype=float32)), Array([0.], dtype=float32))
# Step 114 | T: 2.278995e+00 | T: ((Array([0.00964823, 0.00992626], dtype=float32), Array(0.5653812, dtype=float32)), Array([0.], dtype=float32))
# Step 115 | T: 2.276878e+00 | T: ((Array([0.00964581, 0.00989828], dtype=float32), Array(0.5664, dtype=float32)), Array([0.], dtype=float32))
# Step 116 | T: 2.274801e+00 | T: ((Array([0.00964615, 0.00987363], dtype=float32), Array(0.5674107, dtype=float32)), Array([0.], dtype=float32))
# Step 117 | T: 2.272765e+00 | T: ((Array([0.00964899, 0.00985216], dtype=float32), Array(0.56841356, dtype=float32)), Array([0.], dtype=float32))
# Step 118 | T: 2.270768e+00 | T: ((Array([0.00965407, 0.0098337 ], dtype=float32), Array(0.5694086, dtype=float32)), Array([0.], dtype=float32))
# Step 119 | T: 2.268810e+00 | T: ((Array([0.00966116, 0.00981808], dtype=float32), Array(0.57039595, dtype=float32)), Array([0.], dtype=float32))
# Step 120 | T: 2.266888e+00 | T: ((Array([0.00966999, 0.00980513], dtype=float32), Array(0.57137567, dtype=float32)), Array([0.], dtype=float32))
# Step 121 | T: 2.265003e+00 | T: ((Array([0.00968035, 0.00979468], dtype=float32), Array(0.5723479, dtype=float32)), Array([0.], dtype=float32))
# Step 122 | T: 2.263154e+00 | T: ((Array([0.00969202, 0.00978656], dtype=float32), Array(0.57331264, dtype=float32)), Array([0.], dtype=float32))
# Step 123 | T: 2.261339e+00 | T: ((Array([0.00970478, 0.0097806 ], dtype=float32), Array(0.57427, dtype=float32)), Array([0.], dtype=float32))
# Step 124 | T: 2.259558e+00 | T: ((Array([0.00971844, 0.00977663], dtype=float32), Array(0.5752201, dtype=float32)), Array([0.], dtype=float32))
# Step 125 | T: 2.257812e+00 | T: ((Array([0.00973282, 0.00977449], dtype=float32), Array(0.576163, dtype=float32)), Array([0.], dtype=float32))
# Step 126 | T: 2.256097e+00 | T: ((Array([0.00974775, 0.00977401], dtype=float32), Array(0.5770988, dtype=float32)), Array([0.], dtype=float32))
# Step 127 | T: 2.254414e+00 | T: ((Array([0.00976307, 0.00977505], dtype=float32), Array(0.57802755, dtype=float32)), Array([0.], dtype=float32))
# Step 128 | T: 2.252762e+00 | T: ((Array([0.00977862, 0.00977744], dtype=float32), Array(0.57894933, dtype=float32)), Array([0.], dtype=float32))
# Step 129 | T: 2.251141e+00 | T: ((Array([0.00979428, 0.00978105], dtype=float32), Array(0.57986426, dtype=float32)), Array([0.], dtype=float32))
# Step 130 | T: 2.249549e+00 | T: ((Array([0.00980993, 0.00978573], dtype=float32), Array(0.58077234, dtype=float32)), Array([0.], dtype=float32))
# Step 131 | T: 2.247987e+00 | T: ((Array([0.00982545, 0.00979136], dtype=float32), Array(0.5816737, dtype=float32)), Array([0.], dtype=float32))
# Step 132 | T: 2.246453e+00 | T: ((Array([0.00984074, 0.0097978 ], dtype=float32), Array(0.58256835, dtype=float32)), Array([0.], dtype=float32))
# Step 133 | T: 2.244946e+00 | T: ((Array([0.00985571, 0.00980494], dtype=float32), Array(0.5834564, dtype=float32)), Array([0.], dtype=float32))
# Step 134 | T: 2.243468e+00 | T: ((Array([0.00987029, 0.00981267], dtype=float32), Array(0.58433795, dtype=float32)), Array([0.], dtype=float32))
# Step 135 | T: 2.242016e+00 | T: ((Array([0.00988441, 0.00982087], dtype=float32), Array(0.585213, dtype=float32)), Array([0.], dtype=float32))
# Step 136 | T: 2.240590e+00 | T: ((Array([0.00989801, 0.00982945], dtype=float32), Array(0.5860817, dtype=float32)), Array([0.], dtype=float32))
# Step 137 | T: 2.239189e+00 | T: ((Array([0.00991105, 0.00983832], dtype=float32), Array(0.586944, dtype=float32)), Array([0.], dtype=float32))
# Step 138 | T: 2.237814e+00 | T: ((Array([0.00992347, 0.00984739], dtype=float32), Array(0.5878, dtype=float32)), Array([0.], dtype=float32))
# Step 139 | T: 2.236463e+00 | T: ((Array([0.00993526, 0.00985659], dtype=float32), Array(0.58864987, dtype=float32)), Array([0.], dtype=float32))
# Step 140 | T: 2.235136e+00 | T: ((Array([0.00994638, 0.00986583], dtype=float32), Array(0.5894935, dtype=float32)), Array([0.], dtype=float32))
# Step 141 | T: 2.233833e+00 | T: ((Array([0.00995682, 0.00987507], dtype=float32), Array(0.5903311, dtype=float32)), Array([0.], dtype=float32))
# Step 142 | T: 2.232552e+00 | T: ((Array([0.00996656, 0.00988424], dtype=float32), Array(0.5911626, dtype=float32)), Array([0.], dtype=float32))
# Step 143 | T: 2.231294e+00 | T: ((Array([0.00997561, 0.00989328], dtype=float32), Array(0.59198815, dtype=float32)), Array([0.], dtype=float32))
# Step 144 | T: 2.230059e+00 | T: ((Array([0.00998397, 0.00990215], dtype=float32), Array(0.59280777, dtype=float32)), Array([0.], dtype=float32))
# Step 145 | T: 2.228845e+00 | T: ((Array([0.00999164, 0.00991081], dtype=float32), Array(0.5936215, dtype=float32)), Array([0.], dtype=float32))
# Step 146 | T: 2.227652e+00 | T: ((Array([0.00999862, 0.00991921], dtype=float32), Array(0.59442943, dtype=float32)), Array([0.], dtype=float32))
# Step 147 | T: 2.226480e+00 | T: ((Array([0.01000494, 0.00992734], dtype=float32), Array(0.5952316, dtype=float32)), Array([0.], dtype=float32))
# Step 148 | T: 2.225328e+00 | T: ((Array([0.01001062, 0.00993517], dtype=float32), Array(0.59602803, dtype=float32)), Array([0.], dtype=float32))
# Step 149 | T: 2.224197e+00 | T: ((Array([0.01001566, 0.00994266], dtype=float32), Array(0.59681886, dtype=float32)), Array([0.], dtype=float32))
# Step 150 | T: 2.223085e+00 | T: ((Array([0.0100201 , 0.00994981], dtype=float32), Array(0.5976041, dtype=float32)), Array([0.], dtype=float32))
# Step 151 | T: 2.221992e+00 | T: ((Array([0.01002397, 0.0099566 ], dtype=float32), Array(0.5983837, dtype=float32)), Array([0.], dtype=float32))
# Step 152 | T: 2.220918e+00 | T: ((Array([0.01002728, 0.00996302], dtype=float32), Array(0.59915787, dtype=float32)), Array([0.], dtype=float32))
# Step 153 | T: 2.219862e+00 | T: ((Array([0.01003007, 0.00996907], dtype=float32), Array(0.5999266, dtype=float32)), Array([0.], dtype=float32))
# Step 154 | T: 2.218824e+00 | T: ((Array([0.01003237, 0.00997473], dtype=float32), Array(0.6006899, dtype=float32)), Array([0.], dtype=float32))
# Step 155 | T: 2.217804e+00 | T: ((Array([0.0100342 , 0.00998001], dtype=float32), Array(0.6014478, dtype=float32)), Array([0.], dtype=float32))
# Step 156 | T: 2.216802e+00 | T: ((Array([0.0100356 , 0.00998492], dtype=float32), Array(0.60220045, dtype=float32)), Array([0.], dtype=float32))
# Step 157 | T: 2.215816e+00 | T: ((Array([0.0100366 , 0.00998945], dtype=float32), Array(0.60294783, dtype=float32)), Array([0.], dtype=float32))
# Step 158 | T: 2.214848e+00 | T: ((Array([0.01003724, 0.00999361], dtype=float32), Array(0.60368997, dtype=float32)), Array([0.], dtype=float32))
# Step 159 | T: 2.213895e+00 | T: ((Array([0.01003753, 0.00999741], dtype=float32), Array(0.604427, dtype=float32)), Array([0.], dtype=float32))
# Step 160 | T: 2.212959e+00 | T: ((Array([0.01003752, 0.01000086], dtype=float32), Array(0.60515887, dtype=float32)), Array([0.], dtype=float32))
# Step 161 | T: 2.212038e+00 | T: ((Array([0.01003722, 0.01000397], dtype=float32), Array(0.6058857, dtype=float32)), Array([0.], dtype=float32))
# Step 162 | T: 2.211133e+00 | T: ((Array([0.01003668, 0.01000675], dtype=float32), Array(0.60660744, dtype=float32)), Array([0.], dtype=float32))
# Step 163 | T: 2.210243e+00 | T: ((Array([0.01003592, 0.01000922], dtype=float32), Array(0.6073242, dtype=float32)), Array([0.], dtype=float32))
# Step 164 | T: 2.209368e+00 | T: ((Array([0.01003496, 0.01001139], dtype=float32), Array(0.608036, dtype=float32)), Array([0.], dtype=float32))
# Step 165 | T: 2.208508e+00 | T: ((Array([0.01003383, 0.01001327], dtype=float32), Array(0.6087429, dtype=float32)), Array([0.], dtype=float32))
# Step 166 | T: 2.207662e+00 | T: ((Array([0.01003256, 0.01001487], dtype=float32), Array(0.6094449, dtype=float32)), Array([0.], dtype=float32))
# Step 167 | T: 2.206830e+00 | T: ((Array([0.01003117, 0.01001622], dtype=float32), Array(0.6101421, dtype=float32)), Array([0.], dtype=float32))
# Step 168 | T: 2.206012e+00 | T: ((Array([0.01002967, 0.01001734], dtype=float32), Array(0.61083454, dtype=float32)), Array([0.], dtype=float32))
# Step 169 | T: 2.205207e+00 | T: ((Array([0.01002811, 0.01001822], dtype=float32), Array(0.6115222, dtype=float32)), Array([0.], dtype=float32))
# Step 170 | T: 2.204415e+00 | T: ((Array([0.01002648, 0.0100189 ], dtype=float32), Array(0.61220515, dtype=float32)), Array([0.], dtype=float32))
# Step 171 | T: 2.203637e+00 | T: ((Array([0.01002481, 0.01001938], dtype=float32), Array(0.61288345, dtype=float32)), Array([0.], dtype=float32))
# Step 172 | T: 2.202872e+00 | T: ((Array([0.01002311, 0.01001969], dtype=float32), Array(0.6135571, dtype=float32)), Array([0.], dtype=float32))
# Step 173 | T: 2.202119e+00 | T: ((Array([0.01002141, 0.01001983], dtype=float32), Array(0.61422616, dtype=float32)), Array([0.], dtype=float32))
# Step 174 | T: 2.201378e+00 | T: ((Array([0.01001971, 0.01001983], dtype=float32), Array(0.6148907, dtype=float32)), Array([0.], dtype=float32))
# Step 175 | T: 2.200650e+00 | T: ((Array([0.01001802, 0.01001969], dtype=float32), Array(0.6155507, dtype=float32)), Array([0.], dtype=float32))
# Step 176 | T: 2.199933e+00 | T: ((Array([0.01001637, 0.01001943], dtype=float32), Array(0.6162062, dtype=float32)), Array([0.], dtype=float32))
# Step 177 | T: 2.199229e+00 | T: ((Array([0.01001475, 0.01001907], dtype=float32), Array(0.61685735, dtype=float32)), Array([0.], dtype=float32))
# Step 178 | T: 2.198535e+00 | T: ((Array([0.01001318, 0.01001861], dtype=float32), Array(0.61750406, dtype=float32)), Array([0.], dtype=float32))
# Step 179 | T: 2.197853e+00 | T: ((Array([0.01001166, 0.01001807], dtype=float32), Array(0.61814636, dtype=float32)), Array([0.], dtype=float32))
# Step 180 | T: 2.197182e+00 | T: ((Array([0.01001019, 0.01001745], dtype=float32), Array(0.6187843, dtype=float32)), Array([0.], dtype=float32))
# Step 181 | T: 2.196522e+00 | T: ((Array([0.0100088 , 0.01001678], dtype=float32), Array(0.61941797, dtype=float32)), Array([0.], dtype=float32))
# Step 182 | T: 2.195872e+00 | T: ((Array([0.01000747, 0.01001606], dtype=float32), Array(0.6200474, dtype=float32)), Array([0.], dtype=float32))
# Step 183 | T: 2.195233e+00 | T: ((Array([0.01000622, 0.0100153 ], dtype=float32), Array(0.6206725, dtype=float32)), Array([0.], dtype=float32))
# Step 184 | T: 2.194604e+00 | T: ((Array([0.01000504, 0.01001451], dtype=float32), Array(0.6212935, dtype=float32)), Array([0.], dtype=float32))
# Step 185 | T: 2.193985e+00 | T: ((Array([0.01000393, 0.0100137 ], dtype=float32), Array(0.6219103, dtype=float32)), Array([0.], dtype=float32))
# Step 186 | T: 2.193377e+00 | T: ((Array([0.01000291, 0.01001287], dtype=float32), Array(0.62252295, dtype=float32)), Array([0.], dtype=float32))
# Step 187 | T: 2.192778e+00 | T: ((Array([0.01000196, 0.01001204], dtype=float32), Array(0.6231315, dtype=float32)), Array([0.], dtype=float32))
# Step 188 | T: 2.192189e+00 | T: ((Array([0.01000108, 0.0100112 ], dtype=float32), Array(0.62373596, dtype=float32)), Array([0.], dtype=float32))
# Step 189 | T: 2.191609e+00 | T: ((Array([0.01000029, 0.01001037], dtype=float32), Array(0.6243364, dtype=float32)), Array([0.], dtype=float32))
# Step 190 | T: 2.191038e+00 | T: ((Array([0.00999957, 0.01000955], dtype=float32), Array(0.6249328, dtype=float32)), Array([0.], dtype=float32))
# Step 191 | T: 2.190477e+00 | T: ((Array([0.00999893, 0.01000874], dtype=float32), Array(0.62552524, dtype=float32)), Array([0.], dtype=float32))
# Step 192 | T: 2.189924e+00 | T: ((Array([0.00999835, 0.01000795], dtype=float32), Array(0.6261137, dtype=float32)), Array([0.], dtype=float32))
# Step 193 | T: 2.189380e+00 | T: ((Array([0.00999785, 0.01000719], dtype=float32), Array(0.62669826, dtype=float32)), Array([0.], dtype=float32))
# Step 194 | T: 2.188845e+00 | T: ((Array([0.00999741, 0.01000644], dtype=float32), Array(0.6272789, dtype=float32)), Array([0.], dtype=float32))
# Step 195 | T: 2.188318e+00 | T: ((Array([0.00999703, 0.01000573], dtype=float32), Array(0.6278557, dtype=float32)), Array([0.], dtype=float32))
# Step 196 | T: 2.187800e+00 | T: ((Array([0.00999671, 0.01000505], dtype=float32), Array(0.6284287, dtype=float32)), Array([0.], dtype=float32))
# Step 197 | T: 2.187290e+00 | T: ((Array([0.00999645, 0.0100044 ], dtype=float32), Array(0.62899786, dtype=float32)), Array([0.], dtype=float32))
# Step 198 | T: 2.186788e+00 | T: ((Array([0.00999624, 0.01000378], dtype=float32), Array(0.6295633, dtype=float32)), Array([0.], dtype=float32))
# Step 199 | T: 2.186294e+00 | T: ((Array([0.00999609, 0.01000319], dtype=float32), Array(0.6301249, dtype=float32)), Array([0.], dtype=float32))
# Step 200 | T: 2.185807e+00 | T: ((Array([0.00999597, 0.01000264], dtype=float32), Array(0.6306829, dtype=float32)), Array([0.], dtype=float32))
# Step 201 | T: 2.185328e+00 | T: ((Array([0.0099959 , 0.01000213], dtype=float32), Array(0.63123715, dtype=float32)), Array([0.], dtype=float32))
# Step 202 | T: 2.184857e+00 | T: ((Array([0.00999587, 0.01000165], dtype=float32), Array(0.6317877, dtype=float32)), Array([0.], dtype=float32))
# Step 203 | T: 2.184393e+00 | T: ((Array([0.00999587, 0.01000121], dtype=float32), Array(0.63233465, dtype=float32)), Array([0.], dtype=float32))
# Step 204 | T: 2.183937e+00 | T: ((Array([0.00999591, 0.0100008 ], dtype=float32), Array(0.632878, dtype=float32)), Array([0.], dtype=float32))
# Step 205 | T: 2.183487e+00 | T: ((Array([0.00999597, 0.01000042], dtype=float32), Array(0.6334177, dtype=float32)), Array([0.], dtype=float32))
# Step 206 | T: 2.183045e+00 | T: ((Array([0.00999606, 0.01000008], dtype=float32), Array(0.6339539, dtype=float32)), Array([0.], dtype=float32))
# Step 207 | T: 2.182609e+00 | T: ((Array([0.00999617, 0.00999977], dtype=float32), Array(0.63448656, dtype=float32)), Array([0.], dtype=float32))
# Step 208 | T: 2.182181e+00 | T: ((Array([0.0099963, 0.0099995], dtype=float32), Array(0.6350157, dtype=float32)), Array([0.], dtype=float32))
# Step 209 | T: 2.181758e+00 | T: ((Array([0.00999645, 0.00999925], dtype=float32), Array(0.6355414, dtype=float32)), Array([0.], dtype=float32))
# Step 210 | T: 2.181343e+00 | T: ((Array([0.00999661, 0.00999903], dtype=float32), Array(0.6360636, dtype=float32)), Array([0.], dtype=float32))
# Step 211 | T: 2.180934e+00 | T: ((Array([0.00999678, 0.00999885], dtype=float32), Array(0.6365824, dtype=float32)), Array([0.], dtype=float32))
# Step 212 | T: 2.180531e+00 | T: ((Array([0.00999696, 0.00999868], dtype=float32), Array(0.6370977, dtype=float32)), Array([0.], dtype=float32))
# Step 213 | T: 2.180135e+00 | T: ((Array([0.00999715, 0.00999855], dtype=float32), Array(0.6376097, dtype=float32)), Array([0.], dtype=float32))
# Step 214 | T: 2.179744e+00 | T: ((Array([0.00999734, 0.00999843], dtype=float32), Array(0.6381183, dtype=float32)), Array([0.], dtype=float32))
# Step 215 | T: 2.179360e+00 | T: ((Array([0.00999753, 0.00999834], dtype=float32), Array(0.6386236, dtype=float32)), Array([0.], dtype=float32))
# Step 216 | T: 2.178982e+00 | T: ((Array([0.00999772, 0.00999827], dtype=float32), Array(0.6391256, dtype=float32)), Array([0.], dtype=float32))
# Step 217 | T: 2.178610e+00 | T: ((Array([0.00999791, 0.00999822], dtype=float32), Array(0.6396243, dtype=float32)), Array([0.], dtype=float32))
# Step 218 | T: 2.178243e+00 | T: ((Array([0.0099981 , 0.00999819], dtype=float32), Array(0.64011973, dtype=float32)), Array([0.], dtype=float32))
# Step 219 | T: 2.177882e+00 | T: ((Array([0.00999829, 0.00999817], dtype=float32), Array(0.6406119, dtype=float32)), Array([0.], dtype=float32))
# Step 220 | T: 2.177526e+00 | T: ((Array([0.00999847, 0.00999817], dtype=float32), Array(0.6411008, dtype=float32)), Array([0.], dtype=float32))
# Step 221 | T: 2.177176e+00 | T: ((Array([0.00999865, 0.00999818], dtype=float32), Array(0.6415866, dtype=float32)), Array([0.], dtype=float32))
# Step 222 | T: 2.176832e+00 | T: ((Array([0.00999882, 0.0099982 ], dtype=float32), Array(0.6420692, dtype=float32)), Array([0.], dtype=float32))
# Step 223 | T: 2.176492e+00 | T: ((Array([0.00999898, 0.00999823], dtype=float32), Array(0.6425487, dtype=float32)), Array([0.], dtype=float32))
# Step 224 | T: 2.176158e+00 | T: ((Array([0.00999914, 0.00999828], dtype=float32), Array(0.643025, dtype=float32)), Array([0.], dtype=float32))
# Step 225 | T: 2.175829e+00 | T: ((Array([0.00999928, 0.00999833], dtype=float32), Array(0.6434982, dtype=float32)), Array([0.], dtype=float32))
# Step 226 | T: 2.175505e+00 | T: ((Array([0.00999942, 0.00999839], dtype=float32), Array(0.6439683, dtype=float32)), Array([0.], dtype=float32))
# Step 227 | T: 2.175186e+00 | T: ((Array([0.00999955, 0.00999845], dtype=float32), Array(0.64443535, dtype=float32)), Array([0.], dtype=float32))
# Step 228 | T: 2.174872e+00 | T: ((Array([0.00999967, 0.00999852], dtype=float32), Array(0.64489937, dtype=float32)), Array([0.], dtype=float32))
# Step 229 | T: 2.174563e+00 | T: ((Array([0.00999978, 0.00999859], dtype=float32), Array(0.64536035, dtype=float32)), Array([0.], dtype=float32))
# Step 230 | T: 2.174258e+00 | T: ((Array([0.00999988, 0.00999867], dtype=float32), Array(0.6458183, dtype=float32)), Array([0.], dtype=float32))
# Step 231 | T: 2.173958e+00 | T: ((Array([0.00999998, 0.00999874], dtype=float32), Array(0.64627326, dtype=float32)), Array([0.], dtype=float32))
# Step 232 | T: 2.173663e+00 | T: ((Array([0.01000006, 0.00999882], dtype=float32), Array(0.6467253, dtype=float32)), Array([0.], dtype=float32))
# Step 233 | T: 2.173372e+00 | T: ((Array([0.01000014, 0.0099989 ], dtype=float32), Array(0.64717436, dtype=float32)), Array([0.], dtype=float32))
# Step 234 | T: 2.173086e+00 | T: ((Array([0.0100002 , 0.00999898], dtype=float32), Array(0.6476205, dtype=float32)), Array([0.], dtype=float32))
# Step 235 | T: 2.172804e+00 | T: ((Array([0.01000026, 0.00999906], dtype=float32), Array(0.6480638, dtype=float32)), Array([0.], dtype=float32))
# Step 236 | T: 2.172526e+00 | T: ((Array([0.01000031, 0.00999914], dtype=float32), Array(0.64850414, dtype=float32)), Array([0.], dtype=float32))
# Step 237 | T: 2.172252e+00 | T: ((Array([0.01000036, 0.00999922], dtype=float32), Array(0.64894164, dtype=float32)), Array([0.], dtype=float32))
# Step 238 | T: 2.171983e+00 | T: ((Array([0.01000039, 0.0099993 ], dtype=float32), Array(0.6493763, dtype=float32)), Array([0.], dtype=float32))
# Step 239 | T: 2.171717e+00 | T: ((Array([0.01000042, 0.00999937], dtype=float32), Array(0.6498081, dtype=float32)), Array([0.], dtype=float32))
# Step 240 | T: 2.171456e+00 | T: ((Array([0.01000045, 0.00999944], dtype=float32), Array(0.65023714, dtype=float32)), Array([0.], dtype=float32))
# Step 241 | T: 2.171199e+00 | T: ((Array([0.01000047, 0.00999951], dtype=float32), Array(0.6506634, dtype=float32)), Array([0.], dtype=float32))
# Step 242 | T: 2.170945e+00 | T: ((Array([0.01000048, 0.00999957], dtype=float32), Array(0.65108687, dtype=float32)), Array([0.], dtype=float32))
# Step 243 | T: 2.170696e+00 | T: ((Array([0.01000049, 0.00999963], dtype=float32), Array(0.6515076, dtype=float32)), Array([0.], dtype=float32))
# Step 244 | T: 2.170450e+00 | T: ((Array([0.01000049, 0.00999969], dtype=float32), Array(0.6519256, dtype=float32)), Array([0.], dtype=float32))
# Step 245 | T: 2.170208e+00 | T: ((Array([0.01000049, 0.00999975], dtype=float32), Array(0.6523409, dtype=float32)), Array([0.], dtype=float32))
# Step 246 | T: 2.169969e+00 | T: ((Array([0.01000048, 0.0099998 ], dtype=float32), Array(0.6527535, dtype=float32)), Array([0.], dtype=float32))
# Step 247 | T: 2.169734e+00 | T: ((Array([0.01000048, 0.00999985], dtype=float32), Array(0.6531634, dtype=float32)), Array([0.], dtype=float32))
# Step 248 | T: 2.169503e+00 | T: ((Array([0.01000047, 0.00999989], dtype=float32), Array(0.6535706, dtype=float32)), Array([0.], dtype=float32))
# Step 249 | T: 2.169275e+00 | T: ((Array([0.01000045, 0.00999993], dtype=float32), Array(0.6539752, dtype=float32)), Array([0.], dtype=float32))
# Step 250 | T: 2.169051e+00 | T: ((Array([0.01000044, 0.00999997], dtype=float32), Array(0.65437716, dtype=float32)), Array([0.], dtype=float32))
# Step 251 | T: 2.168830e+00 | T: ((Array([0.01000042, 0.01000001], dtype=float32), Array(0.6547765, dtype=float32)), Array([0.], dtype=float32))
# Step 252 | T: 2.168612e+00 | T: ((Array([0.0100004 , 0.01000004], dtype=float32), Array(0.6551733, dtype=float32)), Array([0.], dtype=float32))
# Step 253 | T: 2.168398e+00 | T: ((Array([0.01000038, 0.01000007], dtype=float32), Array(0.65556747, dtype=float32)), Array([0.], dtype=float32))
# Step 254 | T: 2.168187e+00 | T: ((Array([0.01000036, 0.01000009], dtype=float32), Array(0.65595907, dtype=float32)), Array([0.], dtype=float32))
# Step 255 | T: 2.167979e+00 | T: ((Array([0.01000034, 0.01000011], dtype=float32), Array(0.65634817, dtype=float32)), Array([0.], dtype=float32))
# Step 256 | T: 2.167774e+00 | T: ((Array([0.01000031, 0.01000013], dtype=float32), Array(0.6567347, dtype=float32)), Array([0.], dtype=float32))
# Step 257 | T: 2.167572e+00 | T: ((Array([0.01000029, 0.01000015], dtype=float32), Array(0.65711874, dtype=float32)), Array([0.], dtype=float32))
# Step 258 | T: 2.167374e+00 | T: ((Array([0.01000027, 0.01000016], dtype=float32), Array(0.6575003, dtype=float32)), Array([0.], dtype=float32))
# Step 259 | T: 2.167178e+00 | T: ((Array([0.01000024, 0.01000017], dtype=float32), Array(0.6578794, dtype=float32)), Array([0.], dtype=float32))
# Step 260 | T: 2.166985e+00 | T: ((Array([0.01000022, 0.01000018], dtype=float32), Array(0.65825605, dtype=float32)), Array([0.], dtype=float32))
# Step 261 | T: 2.166795e+00 | T: ((Array([0.0100002 , 0.01000019], dtype=float32), Array(0.65863025, dtype=float32)), Array([0.], dtype=float32))
# Step 262 | T: 2.166608e+00 | T: ((Array([0.01000018, 0.01000019], dtype=float32), Array(0.659002, dtype=float32)), Array([0.], dtype=float32))
# Step 263 | T: 2.166424e+00 | T: ((Array([0.01000016, 0.0100002 ], dtype=float32), Array(0.6593713, dtype=float32)), Array([0.], dtype=float32))
# Step 264 | T: 2.166242e+00 | T: ((Array([0.01000014, 0.0100002 ], dtype=float32), Array(0.65973824, dtype=float32)), Array([0.], dtype=float32))
# Step 265 | T: 2.166064e+00 | T: ((Array([0.01000012, 0.0100002 ], dtype=float32), Array(0.6601028, dtype=float32)), Array([0.], dtype=float32))
# Step 266 | T: 2.165887e+00 | T: ((Array([0.0100001, 0.0100002], dtype=float32), Array(0.66046494, dtype=float32)), Array([0.], dtype=float32))
# Step 267 | T: 2.165714e+00 | T: ((Array([0.01000008, 0.01000019], dtype=float32), Array(0.6608248, dtype=float32)), Array([0.], dtype=float32))
# Step 268 | T: 2.165543e+00 | T: ((Array([0.01000007, 0.01000019], dtype=float32), Array(0.6611823, dtype=float32)), Array([0.], dtype=float32))
# Step 269 | T: 2.165375e+00 | T: ((Array([0.01000005, 0.01000018], dtype=float32), Array(0.66153747, dtype=float32)), Array([0.], dtype=float32))
# Step 270 | T: 2.165209e+00 | T: ((Array([0.01000004, 0.01000018], dtype=float32), Array(0.6618903, dtype=float32)), Array([0.], dtype=float32))
# Step 271 | T: 2.165046e+00 | T: ((Array([0.01000002, 0.01000017], dtype=float32), Array(0.6622409, dtype=float32)), Array([0.], dtype=float32))
# Step 272 | T: 2.164885e+00 | T: ((Array([0.01000001, 0.01000017], dtype=float32), Array(0.6625892, dtype=float32)), Array([0.], dtype=float32))
# Step 273 | T: 2.164726e+00 | T: ((Array([0.01      , 0.01000016], dtype=float32), Array(0.6629352, dtype=float32)), Array([0.], dtype=float32))
# Step 274 | T: 2.164571e+00 | T: ((Array([0.00999999, 0.01000015], dtype=float32), Array(0.663279, dtype=float32)), Array([0.], dtype=float32))
# Step 275 | T: 2.164417e+00 | T: ((Array([0.00999998, 0.01000015], dtype=float32), Array(0.66362053, dtype=float32)), Array([0.], dtype=float32))
# Step 276 | T: 2.164266e+00 | T: ((Array([0.00999998, 0.01000014], dtype=float32), Array(0.66395986, dtype=float32)), Array([0.], dtype=float32))
# Step 277 | T: 2.164116e+00 | T: ((Array([0.00999997, 0.01000013], dtype=float32), Array(0.664297, dtype=float32)), Array([0.], dtype=float32))
# Step 278 | T: 2.163969e+00 | T: ((Array([0.00999997, 0.01000012], dtype=float32), Array(0.6646319, dtype=float32)), Array([0.], dtype=float32))
# Step 279 | T: 2.163825e+00 | T: ((Array([0.00999996, 0.01000011], dtype=float32), Array(0.6649646, dtype=float32)), Array([0.], dtype=float32))
# Step 280 | T: 2.163682e+00 | T: ((Array([0.00999996, 0.0100001 ], dtype=float32), Array(0.6652952, dtype=float32)), Array([0.], dtype=float32))
# Step 281 | T: 2.163542e+00 | T: ((Array([0.00999995, 0.0100001 ], dtype=float32), Array(0.6656236, dtype=float32)), Array([0.], dtype=float32))
# Step 282 | T: 2.163403e+00 | T: ((Array([0.00999995, 0.01000009], dtype=float32), Array(0.6659499, dtype=float32)), Array([0.], dtype=float32))
# Step 283 | T: 2.163267e+00 | T: ((Array([0.00999995, 0.01000008], dtype=float32), Array(0.666274, dtype=float32)), Array([0.], dtype=float32))
# Step 284 | T: 2.163133e+00 | T: ((Array([0.00999995, 0.01000007], dtype=float32), Array(0.66659606, dtype=float32)), Array([0.], dtype=float32))
# Step 285 | T: 2.163001e+00 | T: ((Array([0.00999995, 0.01000007], dtype=float32), Array(0.666916, dtype=float32)), Array([0.], dtype=float32))
# Step 286 | T: 2.162870e+00 | T: ((Array([0.00999995, 0.01000006], dtype=float32), Array(0.6672339, dtype=float32)), Array([0.], dtype=float32))
# Step 287 | T: 2.162742e+00 | T: ((Array([0.00999995, 0.01000005], dtype=float32), Array(0.66754967, dtype=float32)), Array([0.], dtype=float32))
# Step 288 | T: 2.162616e+00 | T: ((Array([0.00999996, 0.01000005], dtype=float32), Array(0.66786337, dtype=float32)), Array([0.], dtype=float32))
# Step 289 | T: 2.162491e+00 | T: ((Array([0.00999996, 0.01000004], dtype=float32), Array(0.66817504, dtype=float32)), Array([0.], dtype=float32))
# Step 290 | T: 2.162369e+00 | T: ((Array([0.00999996, 0.01000004], dtype=float32), Array(0.6684847, dtype=float32)), Array([0.], dtype=float32))
# Step 291 | T: 2.162248e+00 | T: ((Array([0.00999996, 0.01000003], dtype=float32), Array(0.6687923, dtype=float32)), Array([0.], dtype=float32))
# Step 292 | T: 2.162128e+00 | T: ((Array([0.00999997, 0.01000003], dtype=float32), Array(0.6690979, dtype=float32)), Array([0.], dtype=float32))
# Step 293 | T: 2.162012e+00 | T: ((Array([0.00999997, 0.01000002], dtype=float32), Array(0.6694015, dtype=float32)), Array([0.], dtype=float32))
# Step 294 | T: 2.161896e+00 | T: ((Array([0.00999997, 0.01000002], dtype=float32), Array(0.6697031, dtype=float32)), Array([0.], dtype=float32))
# Step 295 | T: 2.161783e+00 | T: ((Array([0.00999998, 0.01000001], dtype=float32), Array(0.67000276, dtype=float32)), Array([0.], dtype=float32))
# Step 296 | T: 2.161670e+00 | T: ((Array([0.00999998, 0.01000001], dtype=float32), Array(0.6703004, dtype=float32)), Array([0.], dtype=float32))
# Step 297 | T: 2.161560e+00 | T: ((Array([0.00999998, 0.01000001], dtype=float32), Array(0.6705961, dtype=float32)), Array([0.], dtype=float32))
# Step 298 | T: 2.161451e+00 | T: ((Array([0.00999999, 0.01      ], dtype=float32), Array(0.6708899, dtype=float32)), Array([0.], dtype=float32))
# Step 299 | T: 2.161344e+00 | T: ((Array([0.00999999, 0.01      ], dtype=float32), Array(0.6711818, dtype=float32)), Array([0.], dtype=float32))
# Step 300 | T: 2.161238e+00 | T: ((Array([0.00999999, 0.01      ], dtype=float32), Array(0.6714718, dtype=float32)), Array([0.], dtype=float32))
# Step 301 | T: 2.161134e+00 | T: ((Array([0.01, 0.01], dtype=float32), Array(0.67175984, dtype=float32)), Array([0.], dtype=float32))
# Step 302 | T: 2.161032e+00 | T: ((Array([0.01, 0.01], dtype=float32), Array(0.672046, dtype=float32)), Array([0.], dtype=float32))
# Step 303 | T: 2.160931e+00 | T: ((Array([0.01, 0.01], dtype=float32), Array(0.67233026, dtype=float32)), Array([0.], dtype=float32))
# Step 304 | T: 2.160832e+00 | T: ((Array([0.01, 0.01], dtype=float32), Array(0.67261267, dtype=float32)), Array([0.], dtype=float32))
# Step 305 | T: 2.160734e+00 | T: ((Array([0.01000001, 0.01      ], dtype=float32), Array(0.6728932, dtype=float32)), Array([0.], dtype=float32))
# Step 306 | T: 2.160638e+00 | T: ((Array([0.01000001, 0.00999999], dtype=float32), Array(0.67317194, dtype=float32)), Array([0.], dtype=float32))
# Step 307 | T: 2.160543e+00 | T: ((Array([0.01000001, 0.00999999], dtype=float32), Array(0.6734488, dtype=float32)), Array([0.], dtype=float32))
# Step 308 | T: 2.160450e+00 | T: ((Array([0.01000001, 0.00999999], dtype=float32), Array(0.6737239, dtype=float32)), Array([0.], dtype=float32))
# Step 309 | T: 2.160357e+00 | T: ((Array([0.01000001, 0.00999999], dtype=float32), Array(0.6739971, dtype=float32)), Array([0.], dtype=float32))
# Step 310 | T: 2.160266e+00 | T: ((Array([0.01000001, 0.00999999], dtype=float32), Array(0.67426854, dtype=float32)), Array([0.], dtype=float32))
# Step 311 | T: 2.160177e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.6745382, dtype=float32)), Array([0.], dtype=float32))
# Step 312 | T: 2.160089e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67480606, dtype=float32)), Array([0.], dtype=float32))
# Step 313 | T: 2.160002e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.6750722, dtype=float32)), Array([0.], dtype=float32))
# Step 314 | T: 2.159917e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67533654, dtype=float32)), Array([0.], dtype=float32))
# Step 315 | T: 2.159832e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67559916, dtype=float32)), Array([0.], dtype=float32))
# Step 316 | T: 2.159750e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67586005, dtype=float32)), Array([0.], dtype=float32))
# Step 317 | T: 2.159668e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.6761192, dtype=float32)), Array([0.], dtype=float32))
# Step 318 | T: 2.159588e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67637664, dtype=float32)), Array([0.], dtype=float32))
# Step 319 | T: 2.159508e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67663234, dtype=float32)), Array([0.], dtype=float32))
# Step 320 | T: 2.159430e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.6768864, dtype=float32)), Array([0.], dtype=float32))
# Step 321 | T: 2.159353e+00 | T: ((Array([0.01000002, 0.01      ], dtype=float32), Array(0.67713875, dtype=float32)), Array([0.], dtype=float32))
# Step 322 | T: 2.159278e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.67738944, dtype=float32)), Array([0.], dtype=float32))
# Step 323 | T: 2.159203e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.6776385, dtype=float32)), Array([0.], dtype=float32))
# Step 324 | T: 2.159130e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.67788583, dtype=float32)), Array([0.], dtype=float32))
# Step 325 | T: 2.159057e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.6781315, dtype=float32)), Array([0.], dtype=float32))
# Step 326 | T: 2.158986e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.6783756, dtype=float32)), Array([0.], dtype=float32))
# Step 327 | T: 2.158916e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.6786181, dtype=float32)), Array([0.], dtype=float32))
# Step 328 | T: 2.158847e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.67885894, dtype=float32)), Array([0.], dtype=float32))
# Step 329 | T: 2.158779e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.6790982, dtype=float32)), Array([0.], dtype=float32))
# Step 330 | T: 2.158711e+00 | T: ((Array([0.01000002, 0.01000001], dtype=float32), Array(0.67933583, dtype=float32)), Array([0.], dtype=float32))
# Step 331 | T: 2.158646e+00 | T: ((Array([0.01000001, 0.01000001], dtype=float32), Array(0.67957187, dtype=float32)), Array([0.], dtype=float32))
# Step 332 | T: 2.158581e+00 | T: ((Array([0.01000001, 0.01000001], dtype=float32), Array(0.67980635, dtype=float32)), Array([0.], dtype=float32))
# ...
# Step 891 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104692, dtype=float32)), Array([0.], dtype=float32))
# Step 892 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71047044, dtype=float32)), Array([0.], dtype=float32))
# Step 893 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104717, dtype=float32)), Array([0.], dtype=float32))
# Step 894 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71047294, dtype=float32)), Array([0.], dtype=float32))
# Step 895 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104742, dtype=float32)), Array([0.], dtype=float32))
# Step 896 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104754, dtype=float32)), Array([0.], dtype=float32))
# Step 897 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104766, dtype=float32)), Array([0.], dtype=float32))
# Step 898 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71047777, dtype=float32)), Array([0.], dtype=float32))
# Step 899 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71047896, dtype=float32)), Array([0.], dtype=float32))
# Step 900 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104801, dtype=float32)), Array([0.], dtype=float32))
# Step 901 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104812, dtype=float32)), Array([0.], dtype=float32))
# Step 902 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71048236, dtype=float32)), Array([0.], dtype=float32))
# Step 903 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104835, dtype=float32)), Array([0.], dtype=float32))
# Step 904 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71048456, dtype=float32)), Array([0.], dtype=float32))
# Step 905 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71048564, dtype=float32)), Array([0.], dtype=float32))
# Step 906 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104867, dtype=float32)), Array([0.], dtype=float32))
# Step 907 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104878, dtype=float32)), Array([0.], dtype=float32))
# Step 908 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104888, dtype=float32)), Array([0.], dtype=float32))
# Step 909 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104898, dtype=float32)), Array([0.], dtype=float32))
# Step 910 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104908, dtype=float32)), Array([0.], dtype=float32))
# Step 911 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71049184, dtype=float32)), Array([0.], dtype=float32))
# Step 912 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71049285, dtype=float32)), Array([0.], dtype=float32))
# Step 913 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104938, dtype=float32)), Array([0.], dtype=float32))
# Step 914 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71049476, dtype=float32)), Array([0.], dtype=float32))
# Step 915 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104957, dtype=float32)), Array([0.], dtype=float32))
# Step 916 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71049666, dtype=float32)), Array([0.], dtype=float32))
# Step 917 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104976, dtype=float32)), Array([0.], dtype=float32))
# Step 918 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104985, dtype=float32)), Array([0.], dtype=float32))
# Step 919 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7104994, dtype=float32)), Array([0.], dtype=float32))
# Step 920 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105003, dtype=float32)), Array([0.], dtype=float32))
# Step 921 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105012, dtype=float32)), Array([0.], dtype=float32))
# Step 922 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105021, dtype=float32)), Array([0.], dtype=float32))
# Step 923 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105029, dtype=float32)), Array([0.], dtype=float32))
# Step 924 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71050376, dtype=float32)), Array([0.], dtype=float32))
# Step 925 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105046, dtype=float32)), Array([0.], dtype=float32))
# Step 926 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105054, dtype=float32)), Array([0.], dtype=float32))
# Step 927 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71050626, dtype=float32)), Array([0.], dtype=float32))
# Step 928 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71050704, dtype=float32)), Array([0.], dtype=float32))
# Step 929 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105078, dtype=float32)), Array([0.], dtype=float32))
# Step 930 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105086, dtype=float32)), Array([0.], dtype=float32))
# Step 931 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71050936, dtype=float32)), Array([0.], dtype=float32))
# Step 932 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051013, dtype=float32)), Array([0.], dtype=float32))
# Step 933 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105109, dtype=float32)), Array([0.], dtype=float32))
# Step 934 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105116, dtype=float32)), Array([0.], dtype=float32))
# Step 935 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051234, dtype=float32)), Array([0.], dtype=float32))
# Step 936 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051306, dtype=float32)), Array([0.], dtype=float32))
# Step 937 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105138, dtype=float32)), Array([0.], dtype=float32))
# Step 938 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105145, dtype=float32)), Array([0.], dtype=float32))
# Step 939 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105152, dtype=float32)), Array([0.], dtype=float32))
# Step 940 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051586, dtype=float32)), Array([0.], dtype=float32))
# Step 941 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105165, dtype=float32)), Array([0.], dtype=float32))
# Step 942 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051717, dtype=float32)), Array([0.], dtype=float32))
# Step 943 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105178, dtype=float32)), Array([0.], dtype=float32))
# Step 944 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105185, dtype=float32)), Array([0.], dtype=float32))
# Step 945 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71051913, dtype=float32)), Array([0.], dtype=float32))
# Step 946 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105198, dtype=float32)), Array([0.], dtype=float32))
# Step 947 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105204, dtype=float32)), Array([0.], dtype=float32))
# Step 948 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.710521, dtype=float32)), Array([0.], dtype=float32))
# Step 949 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105216, dtype=float32)), Array([0.], dtype=float32))
# Step 950 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105222, dtype=float32)), Array([0.], dtype=float32))
# Step 951 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105228, dtype=float32)), Array([0.], dtype=float32))
# Step 952 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052337, dtype=float32)), Array([0.], dtype=float32))
# Step 953 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052396, dtype=float32)), Array([0.], dtype=float32))
# Step 954 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052456, dtype=float32)), Array([0.], dtype=float32))
# Step 955 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105251, dtype=float32)), Array([0.], dtype=float32))
# Step 956 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052563, dtype=float32)), Array([0.], dtype=float32))
# Step 957 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052617, dtype=float32)), Array([0.], dtype=float32))
# Step 958 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105267, dtype=float32)), Array([0.], dtype=float32))
# Step 959 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052724, dtype=float32)), Array([0.], dtype=float32))
# Step 960 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105278, dtype=float32)), Array([0.], dtype=float32))
# Step 961 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105283, dtype=float32)), Array([0.], dtype=float32))
# Step 962 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71052885, dtype=float32)), Array([0.], dtype=float32))
# Step 963 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105293, dtype=float32)), Array([0.], dtype=float32))
# Step 964 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105298, dtype=float32)), Array([0.], dtype=float32))
# Step 965 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105303, dtype=float32)), Array([0.], dtype=float32))
# Step 966 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053076, dtype=float32)), Array([0.], dtype=float32))
# Step 967 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053123, dtype=float32)), Array([0.], dtype=float32))
# Step 968 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105317, dtype=float32)), Array([0.], dtype=float32))
# Step 969 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105322, dtype=float32)), Array([0.], dtype=float32))
# Step 970 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053267, dtype=float32)), Array([0.], dtype=float32))
# Step 971 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053314, dtype=float32)), Array([0.], dtype=float32))
# Step 972 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053356, dtype=float32)), Array([0.], dtype=float32))
# Step 973 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.710534, dtype=float32)), Array([0.], dtype=float32))
# Step 974 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105344, dtype=float32)), Array([0.], dtype=float32))
# Step 975 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105348, dtype=float32)), Array([0.], dtype=float32))
# Step 976 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105352, dtype=float32)), Array([0.], dtype=float32))
# Step 977 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053565, dtype=float32)), Array([0.], dtype=float32))
# Step 978 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053606, dtype=float32)), Array([0.], dtype=float32))
# Step 979 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105365, dtype=float32)), Array([0.], dtype=float32))
# Step 980 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105369, dtype=float32)), Array([0.], dtype=float32))
# Step 981 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105373, dtype=float32)), Array([0.], dtype=float32))
# Step 982 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105377, dtype=float32)), Array([0.], dtype=float32))
# Step 983 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.710538, dtype=float32)), Array([0.], dtype=float32))
# Step 984 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105384, dtype=float32)), Array([0.], dtype=float32))
# Step 985 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053874, dtype=float32)), Array([0.], dtype=float32))
# Step 986 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105391, dtype=float32)), Array([0.], dtype=float32))
# Step 987 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71053946, dtype=float32)), Array([0.], dtype=float32))
# Step 988 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105398, dtype=float32)), Array([0.], dtype=float32))
# Step 989 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105402, dtype=float32)), Array([0.], dtype=float32))
# Step 990 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71054053, dtype=float32)), Array([0.], dtype=float32))
# Step 991 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105409, dtype=float32)), Array([0.], dtype=float32))
# Step 992 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.71054125, dtype=float32)), Array([0.], dtype=float32))
# Step 993 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105416, dtype=float32)), Array([0.], dtype=float32))
# Step 994 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105419, dtype=float32)), Array([0.], dtype=float32))
# Step 995 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105422, dtype=float32)), Array([0.], dtype=float32))
# Step 996 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105425, dtype=float32)), Array([0.], dtype=float32))
# Step 997 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105428, dtype=float32)), Array([0.], dtype=float32))
# Step 998 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105431, dtype=float32)), Array([0.], dtype=float32))
# Step 999 | T: 2.154482e+00 | T: ((Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105434, dtype=float32)), Array([0.], dtype=float32))
# Final 999 | T: 2.154482e+00 | T: (Array([0.01000002, 0.01000002], dtype=float32), Array(0.7105434, dtype=float32))
# CPU times: user 31.8 s, sys: 807 ms, total: 32.7 s
# Wall time: 31.2 s

# %%
mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
T_bridge = jnp.stack(T_bridge)

# %%
mu_opt, T_opt = R2.mlxt_hk(X_obs)

# %%
# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.scatter(X_obs[0][:,0], X_obs[0][:,1], s=10, color='black', label='Observations')
#ax.scatter(mu_true_est[0][:,0], mu_true_est[0][:,1], s=20*t_true_est, color='orange', label=r'$\nabla_{y}\ln p(x,y,t)$')
ax.scatter(mu_sm[0][:,0], mu_sm[0][:,1], color='blue', label='Score Matching', alpha=.1)
ax.scatter(mu_bridgex[-1][0], mu_bridgex[-1][1], color='red', label=r'Bridge Sampling',alpha=.5)
ax.scatter(mu_opt[0][0], mu_opt[0][1], color='purple', label=r'Diffusion Mean',alpha=.5)
ax.set_title(r'$\mathbb{R}^{2}$', fontsize=20)
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
#ax.set_title(r'Diffusion Mean Estimates')
ax.legend(loc='lower center', fontsize=20)
ax.grid()
fig.savefig('Figures/r2_xestimates.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(jnp.arange(0,len(T_sm),1), T_sm, color='blue', label='Score Matching', alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), jnp.append(T_bridge, T_bridge[-1]*jnp.ones(len(T_sm)-len(T_bridge))), color='red', label=r'Bridge Sampling',alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), T_opt*jnp.ones(len(T_sm)), color='purple', label=r't-Diffusion',alpha=.5)
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_title(r'$\mathbb{R}^{2}$', fontsize=20)
#ax.set_title(r'Diffusion Mean Estimates')
ax.legend(loc='lower center', fontsize=20)
ax.grid()
fig.savefig('Figures/r2_testimates.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## S2

# %%
S2 = nSphere(N=2)
jstoch.Brownian_coords(S2)
jstat.diffusion_mean(S2)

x0 = S2.coords([0.]*2)
t = 0.5
# Out:
# using M.Exp for Logarithm

# %%
def get_coords(Fx):
    chart = S2.centered_chart(Fx)
    return (S2.invF((Fx,chart)),chart)

def to_TM(Fx,v):
    x = get_coords(Fx)
#     return jnp.dot(M.JF(x),jnp.dot(M.invJF((Fx,x[1])),v))
    JFx = S2.JF(x)
    return jnp.dot(JFx,jnp.linalg.lstsq(JFx,v)[0])

def to_TMx(Fx,v):

    x = get_coords(Fx)

    return jnp.dot(S2.invJF((Fx,x[1])),v)

# %%
# Creating the theta and phi values.
N_points = 100
theta = jnp.pi/4
phi = jnp.linspace(0.0, jnp.pi*2, N_points)
X1_circle = jnp.sin(theta)*jnp.cos(phi)
X2_circle = jnp.sin(theta)*jnp.sin(phi)
X3_circle = jnp.cos(theta)*jnp.ones(N_points)
X_circle = jnp.concatenate((X1_circle.reshape(1,-1), X2_circle.reshape(1,-1), X3_circle.reshape(1,-1))).T
X_circle = X_circle[:-1]

X_obs = vmap(lambda x: get_coords(x))(X_circle)

# %% [markdown]
# ### DSM

# %%
file_path = 'scores/S2/vsm/'
state = model_loader.load_model(file_path)

# %%
layers = [50, 100, 100, 50]#[50,100,200,400,400,200,100,50]

s1_model = hk.transform(lambda x: models.MLP_s1(dim=S2.emb_dim, layers=layers)(x))
s2_model = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=S2.emb_dim, r = max(S2.emb_dim//2,1))(x))

# %%
model = s1_model
rng_key = jax.random.PRNGKey(2712)
def grady_log_model(x,y,t):
    
    return to_TMx(y[1], model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))

def gradt_log_model(x,y,t):
    
    grad_val = grady_log_model(x, y, t)
            
    return 0.5*(jnp.dot(grad_val, grad_val)+M.div(y,lambda y: grady_log_model(x, y, t)))

# %%
#Source: https://stackoverflow.com/questions/2827393/angles-between-two-n-dimensional-vectors-in-python

def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / jnp.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return jnp.arccos(jnp.clip(jnp.dot(v1_u, v2_u), -1.0, 1.0))

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

min_t = 0.1
max_t = 0.9

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)
t1 = jnp.linspace(min_t, max_t, intervals+1)




# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)

# Creating the coordinate grid for the unit sphere.
X1_heat = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_heat = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_heat = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, ntheta+1, nphi+1), 
                     X2_heat.reshape(1, ntheta+1, nphi+1), 
                     X3_heat.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

# Creating the coordinate grid for the unit sphere.
X1_vec = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_vec = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_vec = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_vec = jnp.transpose(jnp.concatenate((X1_vec.reshape(1, ntheta+1, nphi+1), 
                     X2_vec.reshape(1, ntheta+1, nphi+1), 
                     X3_vec.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
                                                         numerical_grad(x1)))(x2))(X_heat)

# Creating the plot.
#fig, ax = plt.subplots(1,3)
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(X1_heat, X2_heat, X3_heat, rstride=1, cstride=1, facecolors=plt.cm.inferno(heat_map*10), alpha=0.5)
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
#ax.set_xlabel(r'$x^{1}$')
#ax.set_ylabel(r'$x^{2}$')
#ax.set_zlabel(r'$x^{3}$')
#ax.set_title(r'$\cos^{-1}\frac{\langle s_{\theta}^{t}(x,y,t), \nabla_{y}\ln p(x,y,t) \rangle_{\mathbb{R}^{2}}}{||s_{\theta}^{t}(x,y,t)||_{\mathbb{R}^{2}}\cdot||\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}}$')
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
cax = plt.axes([0.75, 0.32, 0.02, 0.36])
fig.colorbar(m, ax=ax, cax=cax)
fig.savefig('Figures/s2_angle.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Plotting the Norm Difference in $x$

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

min_t = 0.1
max_t = 0.9

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)
t1 = jnp.linspace(min_t, max_t, intervals+1)

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)

print(S2.Exp((jnp.zeros(2), jnp.array([0.0,0.0,1.0])), jnp.array([0.0,1.0])))

# Creating the coordinate grid for the unit sphere.
X1_heat = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_heat = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_heat = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, ntheta+1, nphi+1), 
                     X2_heat.reshape(1, ntheta+1, nphi+1), 
                     X3_heat.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

# Creating the coordinate grid for the unit sphere.
X1_vec = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_vec = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_vec = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_vec = jnp.transpose(jnp.concatenate((X1_vec.reshape(1, ntheta+1, nphi+1), 
                     X2_vec.reshape(1, ntheta+1, nphi+1), 
                     X3_vec.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
heat_map = vmap(lambda x2: vmap(lambda x1: jnp.linalg.norm(theoretical_grad(x1)-numerical_grad(x1))**2)(x2))(X_heat)

# Creating the plot.
#fig, ax = plt.subplots(1,3)
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(X1_heat, X2_heat, X3_heat, rstride=1, cstride=1, facecolors=plt.cm.inferno(heat_map*10), alpha=0.5)
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
#ax.set_xlabel(r'$x^{1}$')
#ax.set_ylabel(r'$x^{2}$')
#ax.set_zlabel(r'$x^{3}$')
#ax.set_title(r'$\cos^{-1}\frac{\langle s_{\theta}^{t}(x,y,t), \nabla_{y}\ln p(x,y,t) \rangle_{\mathbb{R}^{2}}}{||s_{\theta}^{t}(x,y,t)||_{\mathbb{R}^{2}}\cdot||\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}}$')
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
cax = plt.axes([0.75, 0.32, 0.02, 0.36])
fig.colorbar(m, ax=ax, cax=cax)
fig.savefig('Figures/s2_angle.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
# Out:
# (Array([ 0.        , -0.03962836], dtype=float32), Array([-0.94303066,  0.        , -0.33270544], dtype=float32))
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Estimate Diffusion Mean

# %%
def s1_grad(x,y,t):
    
    return to_TMx(y[1], model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))

def s2_grad(x,y,t):
    
    ggrad = jacfwdx(lambda y: model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))(y)
    
    return ggrad

# %%
diffusion_mean.initialize(S2, s1_model=s1_grad, s2_model = s2_grad, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = S2.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.5]))

# %%
gradx_sm
# Out:
# Array([[ 2.0594047e-02, -4.7019798e-01],
#        [ 2.2922631e-02, -3.9075696e-01],
#        [ 2.6103694e-02, -3.2869023e-01],
#        ...,
#        [ 2.8899223e-08, -4.8165369e-09],
#        [ 3.1307490e-08,  4.8165369e-09],
#        [ 2.8899223e-08, -4.8165369e-09]], dtype=float32)

# %%
plt.figure(figsize=(8,8))
plt.plot(jnp.linalg.norm(gradx_sm, axis=1))

# %%
diffusion_mean.initialize(S2, s1_model=lambda x,y,t: S2.grady_log_hk(x,y,t)[0], s2_model = lambda x,y,t: jacfwdx(lambda y: S2.grady_log_hk(x,y,t)[0])(y), method="Gradient")
mu_opt, T_opt, _, _ = S2.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.5]))

# %%
# run once to compile
# %time (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = S2.diffusion_mean(X_obs,num_steps=2)
# run MLE
# %time (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = S2.diffusion_mean(X_obs,num_steps=30)
# Out:
# Step 0 | T: 6.887799e+00 | T: ((Array([-4.4718167e-09,  6.9081292e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 1 | T: 5.799889e+00 | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Final 1 | T: 5.799889e+00 | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# CPU times: user 341 ms, sys: 924 µs, total: 342 ms
# Wall time: 339 ms
# Step 0 | T: 6.886695e+00 | T: ((Array([-4.4718167e-09,  6.9081292e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 1 | T: 5.799729e+00 | T: ((Array([0.00970699, 0.00147822], dtype=float32), Array(0.21990886, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 2 | T: 5.040082e+00 | T: ((Array([0.01921101, 0.00606249], dtype=float32), Array(0.2296851, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 3 | T: 4.377378e+00 | T: ((Array([0.02849546, 0.01203372], dtype=float32), Array(0.23928696, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 4 | T: 3.810262e+00 | T: ((Array([0.03752801, 0.01873265], dtype=float32), Array(0.24867892, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 5 | T: 3.329710e+00 | T: ((Array([0.04627392, 0.02582595], dtype=float32), Array(0.25783226, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 6 | T: 2.922419e+00 | T: ((Array([0.05470094, 0.03311412], dtype=float32), Array(0.2667248, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 7 | T: 2.579157e+00 | T: ((Array([0.06278052, 0.04046409], dtype=float32), Array(0.27534032, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 8 | T: 2.290001e+00 | T: ((Array([0.07048863, 0.04778063], dtype=float32), Array(0.2836681, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 9 | T: 2.044775e+00 | T: ((Array([0.07780532, 0.0549924 ], dtype=float32), Array(0.29170167, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 10 | T: 1.837500e+00 | T: ((Array([1.0518493e-09, 7.3260957e-09], dtype=float32), Array(0.29943836, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 11 | T: 1.641130e+00 | T: ((Array([0.00664291, 0.00683512], dtype=float32), Array(0.30687872, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 12 | T: 1.485990e+00 | T: ((Array([0.01299382, 0.01342202], dtype=float32), Array(0.31402522, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 13 | T: 1.353567e+00 | T: ((Array([0.01903336, 0.01973584], dtype=float32), Array(0.32088235, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 14 | T: 1.240841e+00 | T: ((Array([0.02474739, 0.02575651], dtype=float32), Array(0.3274564, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 15 | T: 1.144199e+00 | T: ((Array([0.03012553, 0.03146883], dtype=float32), Array(0.33375487, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 16 | T: 1.061364e+00 | T: ((Array([0.03516117, 0.03686223], dtype=float32), Array(0.33978617, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 17 | T: 9.897366e-01 | T: ((Array([0.0398512 , 0.04192922], dtype=float32), Array(0.34555942, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 18 | T: 9.282408e-01 | T: ((Array([0.04419578, 0.04666589], dtype=float32), Array(0.35108414, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 19 | T: 8.739411e-01 | T: ((Array([0.04819716, 0.05107076], dtype=float32), Array(0.3563701, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 20 | T: 8.282411e-01 | T: ((Array([0.05185959, 0.0551448 ], dtype=float32), Array(0.36142734, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 21 | T: 7.870855e-01 | T: ((Array([0.05519013, 0.05889176], dtype=float32), Array(0.3662658, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 22 | T: 7.510980e-01 | T: ((Array([0.0581972 , 0.06231724], dtype=float32), Array(0.3708954, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 23 | T: 7.208537e-01 | T: ((Array([0.06088992, 0.06542784], dtype=float32), Array(0.37532604, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 24 | T: 6.927651e-01 | T: ((Array([0.06327926, 0.06823185], dtype=float32), Array(0.3795673, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 25 | T: 6.674358e-01 | T: ((Array([0.06537722, 0.07073933], dtype=float32), Array(0.3836284, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 26 | T: 6.455357e-01 | T: ((Array([0.06719608, 0.07296131], dtype=float32), Array(0.38751835, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 27 | T: 6.252311e-01 | T: ((Array([ 5.5321520e-10, -2.3277709e-10], dtype=float32), Array(0.39124578, dtype=float32)), Array([0.0064543 , 0.02045278, 0.99977005], dtype=float32))
# Step 28 | T: 5.863803e-01 | T: ((Array([0.00136069, 0.00179208], dtype=float32), Array(0.3948191, dtype=float32)), Array([0.0064543 , 0.02045278, 0.99977005], dtype=float32))
# Step 29 | T: 5.682050e-01 | T: ((Array([0.00253806, 0.00343198], dtype=float32), Array(0.39824623, dtype=float32)), Array([0.0064543 , 0.02045278, 0.99977005], dtype=float32))
# Final 29 | T: 5.682050e-01 | T: (Array([0.00253806, 0.00343198], dtype=float32), Array(0.39824623, dtype=float32))
# CPU times: user 4.92 s, sys: 41.2 ms, total: 4.96 s
# Wall time: 4.91 s

# %%
mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)

# %%
# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)

# Creating the coordinate grid for the unit sphere.
X1 = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2 = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3 = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))

#rot_mat = lambda v: jnp.array([[1.0, 0.0, 0.0],
#                     [0.0, jnp.cos(v), -jnp.sin(v)],
#                    [0.0, jnp.sin(v), -jnp.cos(v)]])
#X_circle = jnp.vstack((X_circle[0].reshape(1,-1),
#                       jnp.array([-X_circle[0][0], -X_circle[0][1], X_circle[0][2]]).reshape(1,-1))) #delete this

#X_circle = jnp.vstack((jnp.array([1.0, 0.0, 0.0]).reshape(1,-1),
#                      jnp.array([0.0, 1.0, 0.0]).reshape(1,-1)))

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, X3, rstride=1, cstride=1, alpha=0.2)
ax.scatter(X_obs[1][:,0], X_obs[1][:,1], X_obs[1][:,2], s=10, color='black', label='Observations')
ax.scatter(mu_sm[1][:,0], mu_sm[1][:,1], mu_sm[1][:,2], s=10, color='blue', label=r'Score Matching')
ax.scatter(mu_bridgechart[-1][0], mu_bridgechart[-1][1], mu_bridgechart[-1][2], s=10, color='red', label=r'Diffusion Bridge')
ax.scatter(mu_opt[1][-1,0], mu_opt[1][-1,1], mu_opt[1][-1,2], s=10, color='purple', label=r'Diffusion Mean')
#ax.scatter(mu_bridge[1][:,0], mu_bridge[1][:,1], mu_bridge[1][:,2], s=20*t_bridge, color='red', label=r'Bridge Sampling')
ax.set_xlim(-1.0,1.0)
ax.set_ylim(-1.0,1.0)
ax.set_zlim(-1.0,1.0)
ax.legend(loc='lower center', fontsize=18)
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
ax.view_init(20, 180)
fig.savefig('Figures/s2_equator_lower.pdf', format='pdf', pad_inches=0.1, bbox_inches='tight')
#plt.show()

# %%
# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(jnp.arange(0,len(T_sm),1), T_sm, color='blue', label='Score Matching', alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), jnp.append(T_bridge, T_bridge[-1]*jnp.ones(len(T_sm)-len(T_bridge))), color='red', label=r'Bridge Sampling',alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), T_opt, color='purple', label=r't-Diffusion',alpha=.5)
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_title(r'$\mathbb{R}^{2}$', fontsize=20)
#ax.set_title(r'Diffusion Mean Estimates')
ax.legend(loc='lower center', fontsize=20)
ax.grid()
fig.savefig('Figures/r2_testimates.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## S1

# %%
S1M = S1(use_spherical_coords=True)
jstoch.Brownian_coords(S2)
jstat.diffusion_mean(S2)

x0 = S2.coords([0.])
t = 0.5
# Out:
# using M.Exp for Logarithm

# %%
def get_coords(Fx):
    chart = S1M.centered_chart(Fx)
    return (S1M.invF((Fx,chart)),chart)

def to_TM(Fx,v):
    x = get_coords(Fx)
#     return jnp.dot(M.JF(x),jnp.dot(M.invJF((Fx,x[1])),v))
    JFx = S1M.JF(x)
    return jnp.dot(JFx,jnp.linalg.lstsq(JFx,v)[0])

def to_TMx(Fx,v):

    x = get_coords(Fx)

    return jnp.dot(S1M.invJF((Fx,x[1])),v)

# %%
# Creating the theta and phi values.
N_points = 100
phi = jnp.linspace(0.0, jnp.pi, N_points)
X1_circle = jnp.sin(phi)
X2_circle = jnp.cos(phi)
X_circle = jnp.concatenate((X1_circle.reshape(1,-1), X2_circle.reshape(1,-1))).T
X_circle = X_circle[:-1]

X_obs = vmap(lambda x: get_coords(x))(X_circle)

# %% [markdown]
# ### DSM

# %%
file_path = 'scores/S1/vsm/'
state = model_loader.load_model(file_path)

# %%
layers = [50, 100, 50]#[50,100,200,400,400,200,100,50]

s1_model = hk.transform(lambda x: models.MLP_s1(dim=S1M.emb_dim, layers=layers)(x))
s2_model = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=S1M.emb_dim, r = max(S1M.emb_dim//2,1))(x))

# %%
model = s1_model
rng_key = jax.random.PRNGKey(2712)
def grady_log_model(x,y,t):
    
    return to_TMx(y[1], model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))

def gradt_log_model(x,y,t):
    
    grad_val = grady_log_model(x, y, t)
            
    return 0.5*(jnp.dot(grad_val, grad_val)+M.div(y,lambda y: grady_log_model(x, y, t)))

# %%
#Source: https://stackoverflow.com/questions/2827393/angles-between-two-n-dimensional-vectors-in-python

def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / jnp.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return jnp.arccos(jnp.clip(jnp.dot(v1_u, v2_u), -1.0, 1.0))

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

min_t = 0.1
max_t = 0.9

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)
t1 = jnp.linspace(min_t, max_t, intervals+1)




# Creating the theta and phi values.
phi_heat   = jnp.linspace(0.0, jnp.pi*2, 100)

# Creating the coordinate grid for the unit sphere.
X1_heat = jnp.cos(phi_heat)
X2_heat = jnp.sin(phi_heat)
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, 100), 
                     X2_heat.reshape(1, 100))))

# Creating the coordinate grid for the unit sphere.
X1_vec = jnp.cos(phi_heat)
X2_vec = jnp.sin(phi_heat)
X_vec = jnp.transpose(jnp.concatenate((X1_vec.reshape(1, 100), 
                     X2_vec.reshape(1, 100))))

theoretical_grad = lambda y: S1M.grady_log_hk(x0, get_coords(y), t)[0]
numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
                                                         numerical_grad(x1)))(x2))(X_heat)

# Creating the plot.
#fig, ax = plt.subplots(1,3)
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(X1_heat, X2_heat, X3_heat, rstride=1, cstride=1, facecolors=plt.cm.inferno(heat_map*10), alpha=0.5)
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
#ax.set_xlabel(r'$x^{1}$')
#ax.set_ylabel(r'$x^{2}$')
#ax.set_zlabel(r'$x^{3}$')
#ax.set_title(r'$\cos^{-1}\frac{\langle s_{\theta}^{t}(x,y,t), \nabla_{y}\ln p(x,y,t) \rangle_{\mathbb{R}^{2}}}{||s_{\theta}^{t}(x,y,t)||_{\mathbb{R}^{2}}\cdot||\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}}$')
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
cax = plt.axes([0.75, 0.32, 0.02, 0.36])
fig.colorbar(m, ax=ax, cax=cax)
fig.savefig('Figures/s2_angle.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
# Out:
# (100, 2)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_209215/1800070333.py in <module>
#      36 #theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
#      37 numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
# ---> 38 heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
#      39                                                          numerical_grad(x1)))(x2))(X_heat)
#      40
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_209215/1800070333.py in <lambda>(x2)
#      36 #theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
#      37 numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
# ---> 38 heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
#      39                                                          numerical_grad(x1)))(x2))(X_heat)
#      40
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_209215/1800070333.py in <lambda>(x1)
#      36 #theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
#      37 numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
# ---> 38 heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
#      39                                                          numerical_grad(x1)))(x2))(X_heat)
#      40
#
# /tmp/ipykernel_209215/305859236.py in <lambda>(y)
#      40                      X3_vec.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))
#      41
# ---> 42 theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
#      43 numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
#      44 heat_map = vmap(lambda x2: vmap(lambda x1: angle_between(theoretical_grad(x1),
#
# /tmp/ipykernel_209215/4066001094.py in get_coords(Fx)
#       1 def get_coords(Fx):
#       2     chart = S1M.centered_chart(Fx)
# ----> 3     return (S1M.invF((Fx,chart)),chart)
#       4
#       5 def to_TM(Fx,v):
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/S1.py in <lambda>(x)
#      41         self.angle_shift = angle_shift
#      42
# ---> 43         self.F_spherical_inv = lambda x: (jnp.arctan2(x[1][1],x[1][0]) % self.angle_shift).reshape(1)
#      44         self.F_spherical = lambda x: jnp.array([jnp.cos(x[0]), jnp.sin(x[0])]).reshape(2)
#      45
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in op(self, *args)
#     721 def _forward_operator_to_aval(name):
#     722   def op(self, *args):
# --> 723     return getattr(self.aval, f"_{name}")(self, *args)
#     724   return op
#     725
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4151
#    4152   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 4153   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    4154                  unique_indices, mode, fill_value)
#    4155
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4160             unique_indices, mode, fill_value):
#    4161   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 4162   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    4163   y = arr
#    4164
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in _index_to_gather(x_shape, idx, normalize_indices)
#    4261                      normalize_indices: bool = True) -> _Indexer:
#    4262   # Remove ellipses and add trailing slice(None)s.
# -> 4263   idx = _canonicalize_tuple_index(len(x_shape), idx)
#    4264
#    4265   # Check for advanced indexing:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in _canonicalize_tuple_index(arr_ndim, idx, array_name)
#    4594   len_without_none = sum(1 for e in idx if e is not None and e is not Ellipsis)
#    4595   if len_without_none > arr_ndim:
# -> 4596     raise IndexError(
#    4597         f"Too many indices for {array_name}: {len_without_none} "
#    4598         f"non-None/Ellipsis indices for dim {arr_ndim}.")
#
# IndexError: Too many indices for array: 1 non-None/Ellipsis indices for dim 0.

# %% [markdown]
# ### Plotting the Norm Difference in $x$

# %%
#Plot source: https://stackoverflow.com/questions/44594011/heat-map-on-unit-sphere

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

min_t = 0.1
max_t = 0.9

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)
t1 = jnp.linspace(min_t, max_t, intervals+1)

# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)

print(S2.Exp((jnp.zeros(2), jnp.array([0.0,0.0,1.0])), jnp.array([0.0,1.0])))

# Creating the coordinate grid for the unit sphere.
X1_heat = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_heat = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_heat = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_heat = jnp.transpose(jnp.concatenate((X1_heat.reshape(1, ntheta+1, nphi+1), 
                     X2_heat.reshape(1, ntheta+1, nphi+1), 
                     X3_heat.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

# Creating the coordinate grid for the unit sphere.
X1_vec = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2_vec = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3_vec = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))
X_vec = jnp.transpose(jnp.concatenate((X1_vec.reshape(1, ntheta+1, nphi+1), 
                     X2_vec.reshape(1, ntheta+1, nphi+1), 
                     X3_vec.reshape(1, ntheta+1, nphi+1))), axes=(1,2,0))

theoretical_grad = lambda y: S2.grady_log_hk(x0, get_coords(y), t)[0]
numerical_grad = lambda y: grady_log_model(x0, get_coords(y), t)
heat_map = vmap(lambda x2: vmap(lambda x1: jnp.linalg.norm(theoretical_grad(x1)-numerical_grad(x1))**2)(x2))(X_heat)

# Creating the plot.
#fig, ax = plt.subplots(1,3)
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(X1_heat, X2_heat, X3_heat, rstride=1, cstride=1, facecolors=plt.cm.inferno(heat_map*10), alpha=0.5)
m = mpl.cm.ScalarMappable(cmap=mpl.cm.inferno)
m.set_array(heat_map)
#ax.set_xlabel(r'$x^{1}$')
#ax.set_ylabel(r'$x^{2}$')
#ax.set_zlabel(r'$x^{3}$')
#ax.set_title(r'$\cos^{-1}\frac{\langle s_{\theta}^{t}(x,y,t), \nabla_{y}\ln p(x,y,t) \rangle_{\mathbb{R}^{2}}}{||s_{\theta}^{t}(x,y,t)||_{\mathbb{R}^{2}}\cdot||\nabla_{y}\ln p(x,y,t)||_{\mathbb{R}^{2}}}$')
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
cax = plt.axes([0.75, 0.32, 0.02, 0.36])
fig.colorbar(m, ax=ax, cax=cax)
fig.savefig('Figures/s2_angle.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
# Out:
# (Array([ 0.        , -0.03962836], dtype=float32), Array([-0.94303066,  0.        , -0.33270544], dtype=float32))
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Estimate Diffusion Mean

# %%
def s1_grad(x,y,t):
    
    return to_TMx(y[1], model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))

def s2_grad(x,y,t):
    
    ggrad = jacfwdx(lambda y: model.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t))))(y)
    
    return ggrad

# %%
diffusion_mean.initialize(S2, s1_model=s1_grad, s2_model = s2_grad, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = S2.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.5]))

# %%
gradx_sm
# Out:
# Array([[ 2.0594047e-02, -4.7019798e-01],
#        [ 2.2922631e-02, -3.9075696e-01],
#        [ 2.6103694e-02, -3.2869023e-01],
#        ...,
#        [ 2.8899223e-08, -4.8165369e-09],
#        [ 3.1307490e-08,  4.8165369e-09],
#        [ 2.8899223e-08, -4.8165369e-09]], dtype=float32)

# %%
plt.figure(figsize=(8,8))
plt.plot(jnp.linalg.norm(gradx_sm, axis=1))

# %%
diffusion_mean.initialize(S2, s1_model=lambda x,y,t: S2.grady_log_hk(x,y,t)[0], s2_model = lambda x,y,t: jacfwdx(lambda y: S2.grady_log_hk(x,y,t)[0])(y), method="Gradient")
mu_opt, T_opt, _, _ = S2.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.5]))

# %%
# run once to compile
# %time (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = S2.diffusion_mean(X_obs,num_steps=2)
# run MLE
# %time (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = S2.diffusion_mean(X_obs,num_steps=30)
# Out:
# Step 0 | T: 6.887799e+00 | T: ((Array([-4.4718167e-09,  6.9081292e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 1 | T: 5.799889e+00 | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Final 1 | T: 5.799889e+00 | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# CPU times: user 341 ms, sys: 924 µs, total: 342 ms
# Wall time: 339 ms
# Step 0 | T: 6.886695e+00 | T: ((Array([-4.4718167e-09,  6.9081292e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 1 | T: 5.799729e+00 | T: ((Array([0.00970699, 0.00147822], dtype=float32), Array(0.21990886, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 2 | T: 5.040082e+00 | T: ((Array([0.01921101, 0.00606249], dtype=float32), Array(0.2296851, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 3 | T: 4.377378e+00 | T: ((Array([0.02849546, 0.01203372], dtype=float32), Array(0.23928696, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 4 | T: 3.810262e+00 | T: ((Array([0.03752801, 0.01873265], dtype=float32), Array(0.24867892, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 5 | T: 3.329710e+00 | T: ((Array([0.04627392, 0.02582595], dtype=float32), Array(0.25783226, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 6 | T: 2.922419e+00 | T: ((Array([0.05470094, 0.03311412], dtype=float32), Array(0.2667248, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 7 | T: 2.579157e+00 | T: ((Array([0.06278052, 0.04046409], dtype=float32), Array(0.27534032, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 8 | T: 2.290001e+00 | T: ((Array([0.07048863, 0.04778063], dtype=float32), Array(0.2836681, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 9 | T: 2.044775e+00 | T: ((Array([0.07780532, 0.0549924 ], dtype=float32), Array(0.29170167, dtype=float32)), Array([-0.18722294, -0.3244377 ,  0.9271935 ], dtype=float32))
# Step 10 | T: 1.837500e+00 | T: ((Array([1.0518493e-09, 7.3260957e-09], dtype=float32), Array(0.29943836, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 11 | T: 1.641130e+00 | T: ((Array([0.00664291, 0.00683512], dtype=float32), Array(0.30687872, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 12 | T: 1.485990e+00 | T: ((Array([0.01299382, 0.01342202], dtype=float32), Array(0.31402522, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))
# Step 13 | T: 1.353567e+00 | T: ((Array([0.01903336, 0.01973584], dtype=float32), Array(0.32088235, dtype=float32)), Array([-0.12371089, -0.13353908,  0.983292  ], dtype=float32))

# %%
mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)

# %%
# Creating the theta and phi values.
intervals = 100
ntheta = intervals
nphi = 2*intervals

theta = jnp.linspace(0.0, jnp.pi*1, ntheta+1)
phi   = jnp.linspace(0.0, jnp.pi*2, nphi+1)

# Creating the coordinate grid for the unit sphere.
X1 = jnp.outer(jnp.sin(theta), jnp.cos(phi))
X2 = jnp.outer(jnp.sin(theta), jnp.sin(phi))
X3 = jnp.outer(jnp.cos(theta), jnp.ones(nphi+1))

#rot_mat = lambda v: jnp.array([[1.0, 0.0, 0.0],
#                     [0.0, jnp.cos(v), -jnp.sin(v)],
#                    [0.0, jnp.sin(v), -jnp.cos(v)]])
#X_circle = jnp.vstack((X_circle[0].reshape(1,-1),
#                       jnp.array([-X_circle[0][0], -X_circle[0][1], X_circle[0][2]]).reshape(1,-1))) #delete this

#X_circle = jnp.vstack((jnp.array([1.0, 0.0, 0.0]).reshape(1,-1),
#                      jnp.array([0.0, 1.0, 0.0]).reshape(1,-1)))

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, X3, rstride=1, cstride=1, alpha=0.2)
ax.scatter(X_obs[1][:,0], X_obs[1][:,1], X_obs[1][:,2], s=10, color='black', label='Observations')
ax.scatter(mu_sm[1][:,0], mu_sm[1][:,1], mu_sm[1][:,2], s=10, color='blue', label=r'Score Matching')
ax.scatter(mu_bridgechart[-1][0], mu_bridgechart[-1][1], mu_bridgechart[-1][2], s=10, color='red', label=r'Diffusion Bridge')
ax.scatter(mu_opt[1][-1,0], mu_opt[1][-1,1], mu_opt[1][-1,2], s=10, color='purple', label=r'Diffusion Mean')
#ax.scatter(mu_bridge[1][:,0], mu_bridge[1][:,1], mu_bridge[1][:,2], s=20*t_bridge, color='red', label=r'Bridge Sampling')
ax.set_xlim(-1.0,1.0)
ax.set_ylim(-1.0,1.0)
ax.set_zlim(-1.0,1.0)
ax.legend(loc='lower center', fontsize=18)
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
ax.view_init(20, 180)
fig.savefig('Figures/s2_equator_lower.pdf', format='pdf', pad_inches=0.1, bbox_inches='tight')
#plt.show()

# %%
# Creating the plot.
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(jnp.arange(0,len(T_sm),1), T_sm, color='blue', label='Score Matching', alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), jnp.append(T_bridge, T_bridge[-1]*jnp.ones(len(T_sm)-len(T_bridge))), color='red', label=r'Bridge Sampling',alpha=.5)
ax.plot(jnp.arange(0,len(T_sm),1), T_opt, color='purple', label=r't-Diffusion',alpha=.5)
ax.set_xlabel(r'$x^{1}$', fontsize=20)
ax.set_ylabel(r'$x^{2}$', fontsize=20)
ax.set_title(r'$\mathbb{R}^{2}$', fontsize=20)
#ax.set_title(r'Diffusion Mean Estimates')
ax.legend(loc='lower center', fontsize=20)
ax.grid()
fig.savefig('Figures/r2_testimates.eps', format='eps', pad_inches=0.1, bbox_inches='tight')
#fig.tight_layout()
