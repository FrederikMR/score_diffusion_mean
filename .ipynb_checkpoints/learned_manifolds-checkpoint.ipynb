# %% [markdown]
# # Learned Manifolds

# %%
#Modules

#plotting
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %% [markdown]
# ## VAE MNIST

# %% [markdown]
# ## VAE SVHN

# %%
#Modules

#ManLearn
from ManLearn.initialize import *
from ManLearn.VAE.VAE_SVHN import model, VAEOutput
from ManLearn.train_SVHN import load_dataset
from ManLearn.model_loader import load_model
# Out:
# 2023-08-24 13:32:17.859925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#Loading data
ds = load_dataset()
# Out:
# 2023-08-24 13:32:19.708038: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
#Loading State and loss
state = load_model('ManLearn/models/SVHN/VAE/')
elbo_loss = jnp.array(np.load('ManLearn/models/SVHN/VAE/elbo_loss.npy'))
rec_loss = jnp.array(np.load('ManLearn/models/SVHN/VAE/rec_loss.npy'))
kld_loss = jnp.array(np.load('ManLearn/models/SVHN/VAE/kld_loss.npy'))
# Out:
# WARNING:jax._src.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
plt.figure(figsize=(10,10))
plt.plot(jnp.arange(0,len(elbo_loss),1)*100, rec_loss)

# %%
img = next(ds).image
img_learned = model.apply(state.params, state.state_val, state.rng_key, img)[0].x_hat

# %%
fig = plt.figure(figsize=(12, 12))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(10, 10),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )
for ax, im in zip(grid, img):
    # Iterating over the grid returns the Axes.
    ax.imshow(im, cmap='gray')
    ax.set_axis_off()

# %%
fig = plt.figure(figsize=(12, 12))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(10, 10),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )
for ax, im in zip(grid, img_learned):
    # Iterating over the grid returns the Axes.
    ax.imshow(im, cmap='gray')
    ax.set_axis_off()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
img = next(ds).image
rng_key, next_rng_key = jran.split(state.rng_key)
out, _ = model.apply(state.params, state.state_val, state.rng_key, img)
import matplotlib.pyplot as pltfrom mpl_toolkits.axes_grid1 import ImageGrid
fig = plt.figure(figsize=(8, 8))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(1, 10),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )
for ax, im in zip(grid, img[:10]):
    # Iterating over the grid returns the Axes.
    ax.imshow(im, cmap='gray')
    ax.set_axis_off()

from mpl_toolkits.axes_grid1 import ImageGrid
fig = plt.figure(figsize=(8, 8))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(1, 10),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )
for ax, im in zip(grid, img_learned[:10]):
    # Iterating over the grid returns the Axes.
    ax.imshow(im, cmap='gray')
    ax.set_axis_off()
plt.figure()
plt.imshow(img[0])
plt.figure()
plt.imshow(out.x_hat[0])

# %% [markdown]
# ## VAE CelebA

# %%
#Modules

#ManLearn
from ManLearn.initialize import *
from ManLearn.VAE.VAE_CelebA import model, VAEOutput
from ManLearn.train_CelebA import load_dataset
from ManLearn.model_loader import load_model
# Out:
# 2023-08-23 15:53:33.893241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#Loading data
ds = load_dataset()
# Out:
# 2023-08-23 15:53:35.901082: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
#Loading State
state = load_model('ManLearn/models/CelebA/VAE/')

# %%
img = next(ds).image
rng_key, next_rng_key = jran.split(state.rng_key)
out, _ = model.apply(state.params, state.state_val, rng_key, img)
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(img[0])
plt.figure()
plt.imshow(out.x_hat[0])
plt.figure()
plt.imshow(out.x_hat[1])
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
ds = load_dataset(data_dir='../Funny/', batch_size=1)

# %%
next(ds).image.shape
# Out:
# (1, 64, 64, 3)

# %%
img = next(ds).image
out, _ = model.apply(state.params, state.state_val, state.rng_key, img)
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(img[0])
plt.figure()
plt.imshow(out.x_hat[0])
