# %% [markdown]
# # Score Table

# %% [markdown]
# This notebook estimates the diffusion t-mean for synthetic data compared to the estimation using bridge sampling. Further time-complexity is estimated in this note book

# %%
from jaxgeometry.manifolds import *
from jaxgeometry.integration import dts
from jaxgeometry.autodiff import jacfwdx
from jaxgeometry.statistics.score_matching import diffusion_mean
import jaxgeometry.statistics as jstat
import jaxgeometry.stochastics as jstoch
import jax.numpy as jnp
import haiku as hk
import jax
from jax import vmap

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr

from jaxgeometry.statistics.score_matching import model_loader
from models import models

# %%
loss_type = 'dsm'
s2_approximation = True

# %%
def get_coords(M, Fx):
    chart = M.centered_chart(Fx)
    return (M.invF((Fx,chart)),chart)

def to_TM(M, Fx,v):
    x = get_coords(Fx)
#     return jnp.dot(M.JF(x),jnp.dot(M.invJF((Fx,x[1])),v))
    JFx = M.JF(x)
    return jnp.dot(JFx,jnp.linalg.lstsq(JFx,v)[0])

def to_TMx(M, Fx,v):

    x = get_coords(M, Fx)

    return jnp.dot(M.invJF((Fx,x[1])),v)

# %% [markdown]
# # Euclidean

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2 #Change this for R2, R3, R5, R10, R20, R50

# %%
M = Euclidean(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = (jnp.zeros(N), jnp.zeros(1))
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/R'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/R'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/R'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/R'+str(N)+'/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  1590

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/R'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/R'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                    step_size=0.01, max_iter=1000)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.142622e+01 | T: ((Array([ 0.00431354, -0.01948302], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.032720e+01 | T: ((Array([ 0.00643428, -0.00989969], dtype=float32), Array(0.21992944, dtype=float32)), Array([0.], dtype=float32))
# Final 1 | T: 1.032720e+01 | T: (Array([ 0.00643428, -0.00989969], dtype=float32), Array(0.21992944, dtype=float32))
# Step 0 | T: 1.142622e+01 | T: ((Array([ 0.00431354, -0.01948302], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.032720e+01 | T: ((Array([ 0.00643428, -0.00989969], dtype=float32), Array(0.21992944, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.392080e+00 | T: ((Array([ 0.00410805, -0.00118478], dtype=float32), Array(0.22974923, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.592904e+00 | T: ((Array([0.00051343, 0.00614951], dtype=float32), Array(0.23942587, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.907605e+00 | T: ((Array([-0.0025528 ,  0.01171097], dtype=float32), Array(0.24893129, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.317437e+00 | T: ((Array([-0.00404395,  0.01538073], dtype=float32), Array(0.2582426, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.806722e+00 | T: ((Array([-0.00387775,  0.01729917], dtype=float32), Array(0.2673415, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.362746e+00 | T: ((Array([-0.00252663,  0.0177436 ], dtype=float32), Array(0.27621377, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.975282e+00 | T: ((Array([-0.0005829 ,  0.01702231], dtype=float32), Array(0.28484875, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.635965e+00 | T: ((Array([0.00139435, 0.01542358], dtype=float32), Array(0.293239, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.337826e+00 | T: ((Array([0.00295327, 0.01320108], dtype=float32), Array(0.3013797, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.075002e+00 | T: ((Array([0.00382092, 0.01057428], dtype=float32), Array(0.3092685, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.842539e+00 | T: ((Array([0.00392896, 0.0077324 ], dtype=float32), Array(0.31690493, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.636266e+00 | T: ((Array([0.00337397, 0.00483773], dtype=float32), Array(0.32429025, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.452663e+00 | T: ((Array([0.00235162, 0.00202741], dtype=float32), Array(0.33142707, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.288751e+00 | T: ((Array([ 0.00109982, -0.0005861 ], dtype=float32), Array(0.33831918, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.141982e+00 | T: ((Array([-0.00014419, -0.00291494], dtype=float32), Array(0.34497136, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.010175e+00 | T: ((Array([-0.00117838, -0.00489558], dtype=float32), Array(0.3513891, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.891453e+00 | T: ((Array([-0.00186226, -0.00648779], dtype=float32), Array(0.35757855, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.784199e+00 | T: ((Array([-0.00213025, -0.0076728 ], dtype=float32), Array(0.36354622, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.687028e+00 | T: ((Array([-0.00198979, -0.00845076], dtype=float32), Array(0.3692991, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.598754e+00 | T: ((Array([-0.00150759, -0.00883764], dtype=float32), Array(0.37484434, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.518356e+00 | T: ((Array([-0.00079022, -0.00886208], dtype=float32), Array(0.38018924, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.444957e+00 | T: ((Array([ 3.6334444e-05, -8.5622519e-03], dtype=float32), Array(0.38534123, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.377794e+00 | T: ((Array([ 0.00084595, -0.00798303], dtype=float32), Array(0.39030778, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.316204e+00 | T: ((Array([ 0.00152906, -0.00717344], dtype=float32), Array(0.3950963, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.259602e+00 | T: ((Array([ 0.00200546, -0.00618449], dtype=float32), Array(0.39971414, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.207476e+00 | T: ((Array([ 0.00223174, -0.00506727], dtype=float32), Array(0.40416855, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.159376e+00 | T: ((Array([ 0.00220267, -0.00387139], dtype=float32), Array(0.40846667, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.114902e+00 | T: ((Array([ 0.00194721, -0.00264366], dtype=float32), Array(0.41261542, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.073704e+00 | T: ((Array([ 0.00152059, -0.00142696], dtype=float32), Array(0.41662163, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.035470e+00 | T: ((Array([ 0.00099422, -0.00025941], dtype=float32), Array(0.42049184, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.999921e+00 | T: ((Array([0.00044497, 0.00082631], dtype=float32), Array(0.42423245, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.966810e+00 | T: ((Array([-5.5083248e-05,  1.8034204e-03], dtype=float32), Array(0.42784962, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.935913e+00 | T: ((Array([-0.00044716,  0.00265121], dtype=float32), Array(0.4313493, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.907030e+00 | T: ((Array([-0.00069189,  0.00335509], dtype=float32), Array(0.4347372, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.879980e+00 | T: ((Array([-0.0007723 ,  0.00390646], dtype=float32), Array(0.4380188, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.854604e+00 | T: ((Array([-0.00069363,  0.0043023 ], dtype=float32), Array(0.44119933, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.830757e+00 | T: ((Array([-0.00048046,  0.00454475], dtype=float32), Array(0.44428384, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.808312e+00 | T: ((Array([-0.00017168,  0.00464052], dtype=float32), Array(0.44727713, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.787152e+00 | T: ((Array([0.00018569, 0.0046002 ], dtype=float32), Array(0.45018375, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.767175e+00 | T: ((Array([0.00054304, 0.00443756], dtype=float32), Array(0.45300806, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.748287e+00 | T: ((Array([0.00085633, 0.00416881], dtype=float32), Array(0.45575422, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.730403e+00 | T: ((Array([0.001091 , 0.0038119], dtype=float32), Array(0.45842615, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.713449e+00 | T: ((Array([0.0012254 , 0.00338575], dtype=float32), Array(0.4610276, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.697353e+00 | T: ((Array([0.00125219, 0.00290965], dtype=float32), Array(0.4635621, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.682051e+00 | T: ((Array([0.00117794, 0.00240258], dtype=float32), Array(0.466033, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.667489e+00 | T: ((Array([0.00102097, 0.00188273], dtype=float32), Array(0.4684435, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.653611e+00 | T: ((Array([0.00080808, 0.001367  ], dtype=float32), Array(0.4707966, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.640372e+00 | T: ((Array([0.00057043, 0.0008706 ], dtype=float32), Array(0.47309515, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.627728e+00 | T: ((Array([0.00033937, 0.00040677], dtype=float32), Array(0.4753418, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.615637e+00 | T: ((Array([ 1.4258317e-04, -1.3458746e-05], dtype=float32), Array(0.4775391, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.604064e+00 | T: ((Array([ 1.0262302e-06, -3.8136367e-04], dtype=float32), Array(0.47968942, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.592974e+00 | T: ((Array([-7.3012809e-05, -6.9061463e-04], dtype=float32), Array(0.48179504, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.582335e+00 | T: ((Array([-7.6640288e-05, -9.3723054e-04], dtype=float32), Array(0.48385808, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.572120e+00 | T: ((Array([-1.5851223e-05, -1.1194890e-03], dtype=float32), Array(0.48588055, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.562302e+00 | T: ((Array([ 9.6009302e-05, -1.2377718e-03], dtype=float32), Array(0.48786432, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.552856e+00 | T: ((Array([ 0.00024055, -0.00129436], dtype=float32), Array(0.48981115, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.543761e+00 | T: ((Array([ 0.00039706, -0.0012932 ], dtype=float32), Array(0.49172273, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.534996e+00 | T: ((Array([ 0.00054522, -0.00123962], dtype=float32), Array(0.49360064, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.526543e+00 | T: ((Array([ 0.00066762, -0.00114005], dtype=float32), Array(0.49544635, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.518385e+00 | T: ((Array([ 0.00075156, -0.00100173], dtype=float32), Array(0.49726126, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.510504e+00 | T: ((Array([ 0.00079027, -0.0008324 ], dtype=float32), Array(0.49904665, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.502887e+00 | T: ((Array([ 0.00078313, -0.00064005], dtype=float32), Array(0.50080377, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.495520e+00 | T: ((Array([ 0.00073525, -0.00043262], dtype=float32), Array(0.5025338, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.488389e+00 | T: ((Array([ 0.00065627, -0.00021781], dtype=float32), Array(0.5042378, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.481484e+00 | T: ((Array([ 5.5881770e-04, -2.8061622e-06], dtype=float32), Array(0.5059168, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.474793e+00 | T: ((Array([0.00045662, 0.00020583], dtype=float32), Array(0.50757176, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.468306e+00 | T: ((Array([0.00036275, 0.00040234], dtype=float32), Array(0.5092036, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.462012e+00 | T: ((Array([0.00028806, 0.00058187], dtype=float32), Array(0.5108132, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.455904e+00 | T: ((Array([0.00024001, 0.00074052], dtype=float32), Array(0.5124013, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.449973e+00 | T: ((Array([0.00022211, 0.00087537], dtype=float32), Array(0.5139687, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.444210e+00 | T: ((Array([0.00023377, 0.00098452], dtype=float32), Array(0.5155161, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.438608e+00 | T: ((Array([0.00027082, 0.00106701], dtype=float32), Array(0.5170442, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.433161e+00 | T: ((Array([0.00032628, 0.0011228 ], dtype=float32), Array(0.51855356, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.427862e+00 | T: ((Array([0.00039156, 0.00115266], dtype=float32), Array(0.5200448, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.422705e+00 | T: ((Array([0.0004576 , 0.00115807], dtype=float32), Array(0.5215185, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.417683e+00 | T: ((Array([0.0005161 , 0.00114115], dtype=float32), Array(0.52297527, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.412793e+00 | T: ((Array([0.00056046, 0.0011045 ], dtype=float32), Array(0.5244155, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.408029e+00 | T: ((Array([0.00058645, 0.00105108], dtype=float32), Array(0.5258397, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.403385e+00 | T: ((Array([0.00059254, 0.00098409], dtype=float32), Array(0.5272483, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.398858e+00 | T: ((Array([0.00057982, 0.00090686], dtype=float32), Array(0.52864176, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.394443e+00 | T: ((Array([0.00055164, 0.00082273], dtype=float32), Array(0.5300205, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.390136e+00 | T: ((Array([0.00051297, 0.00073494], dtype=float32), Array(0.5313848, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.385935e+00 | T: ((Array([0.00046966, 0.00064653], dtype=float32), Array(0.53273517, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.381833e+00 | T: ((Array([0.00042758, 0.00056031], dtype=float32), Array(0.5340718, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.377829e+00 | T: ((Array([0.00039191, 0.00047872], dtype=float32), Array(0.5353951, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.373919e+00 | T: ((Array([0.00036654, 0.00040387], dtype=float32), Array(0.5367053, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.370101e+00 | T: ((Array([0.00035371, 0.00033744], dtype=float32), Array(0.53800285, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.366370e+00 | T: ((Array([0.00035386, 0.00028071], dtype=float32), Array(0.53928787, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.362724e+00 | T: ((Array([0.00036575, 0.00023452], dtype=float32), Array(0.5405607, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.359161e+00 | T: ((Array([0.00038678, 0.00019932], dtype=float32), Array(0.5418216, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.355678e+00 | T: ((Array([0.00041343, 0.00017517], dtype=float32), Array(0.5430708, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.352273e+00 | T: ((Array([0.00044179, 0.00016179], dtype=float32), Array(0.5443085, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.348942e+00 | T: ((Array([0.0004681 , 0.00015859], dtype=float32), Array(0.5455349, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.345685e+00 | T: ((Array([0.00048922, 0.00016469], dtype=float32), Array(0.5467503, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.342498e+00 | T: ((Array([0.00050295, 0.00017905], dtype=float32), Array(0.54795486, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.339380e+00 | T: ((Array([0.00050824, 0.00020042], dtype=float32), Array(0.54914874, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.336329e+00 | T: ((Array([0.00050522, 0.00022748], dtype=float32), Array(0.5503322, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.333343e+00 | T: ((Array([0.00049505, 0.00025885], dtype=float32), Array(0.5515053, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.333343e+00 | T: (Array([0.00049505, 0.00025885], dtype=float32), Array(0.5515053, dtype=float32))

# %%
mu_opt, T_opt = M.mlxt_hk(X_obs)

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0027 -0.0165 )
# T = 0.4200

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgex[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_176384/4101060071.py in <module>
#       1 print(f"Bridge Riemannian Diffusion Mean:")
# ----> 2 print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgex[-1]), ")")
#       3 print(f"T = {T_bridge[-1]:.4f}")
#
# NameError: name 'mu_bridgex' is not defined

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[0]), ")")
print(f"T = {T_opt:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -0.0029 0.0159 0.0126 0.0076 0.0259 0.0032 0.0170 -0.0077 0.0008 0.0018 )
# T = 0.5148

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_sm[0][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt):.5f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_bridgex[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt):.5f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.00510
#  -T error = 0.35292
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_176384/3769845863.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_sm[0][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt):.5f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_bridgex[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt):.5f}")
#
# NameError: name 'mu_bridgex' is not defined

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 264 ms ± 2.33 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100, N=1)
# Out:
# Step 0 | T: 1.101120e+01 | T: ((Array([0.05457994, 0.12616831], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 9.925315e+00 | T: ((Array([0.04486996, 0.11626425], dtype=float32), Array(0.21992762, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.004430e+00 | T: ((Array([0.03572655, 0.10651977], dtype=float32), Array(0.22974285, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.221049e+00 | T: ((Array([0.02746652, 0.09699648], dtype=float32), Array(0.23941153, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.552216e+00 | T: ((Array([0.02039011, 0.08775266], dtype=float32), Array(0.24890527, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 6.978842e+00 | T: ((Array([0.01470873, 0.07884187], dtype=float32), Array(0.25820103, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.485114e+00 | T: ((Array([0.01049948, 0.07031186], dtype=float32), Array(0.26728055, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.058035e+00 | T: ((Array([0.00771104, 0.06220369], dtype=float32), Array(0.27612984, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.686961e+00 | T: ((Array([0.00620478, 0.05455128], dtype=float32), Array(0.28473857, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.363182e+00 | T: ((Array([0.00580016, 0.04738107], dtype=float32), Array(0.2930996, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.079543e+00 | T: ((Array([0.00630691, 0.0407121 ], dtype=float32), Array(0.30120856, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 4.830134e+00 | T: ((Array([0.00754235, 0.03455614], dtype=float32), Array(0.30906335, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.610036e+00 | T: ((Array([0.00933853, 0.02891828], dtype=float32), Array(0.31666386, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.415141e+00 | T: ((Array([0.01154417, 0.02379748], dtype=float32), Array(0.32401165, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.241987e+00 | T: ((Array([0.01402435, 0.01918725], dtype=float32), Array(0.3311096, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.087654e+00 | T: ((Array([0.01665968, 0.01507639], dtype=float32), Array(0.33796182, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 3.949661e+00 | T: ((Array([0.01934541, 0.01144975], dtype=float32), Array(0.34457326, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.825896e+00 | T: ((Array([0.02199098, 0.00828896], dtype=float32), Array(0.3509496, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.714557e+00 | T: ((Array([0.02451969, 0.00557308], dtype=float32), Array(0.35709712, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.614095e+00 | T: ((Array([0.02686843, 0.00327923], dtype=float32), Array(0.3630226, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.523184e+00 | T: ((Array([0.02898744, 0.00138313], dtype=float32), Array(0.36873305, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.440681e+00 | T: ((Array([ 0.03083987, -0.00014044], dtype=float32), Array(0.37423578, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.365597e+00 | T: ((Array([ 0.03240108, -0.00131718], dtype=float32), Array(0.3795382, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.297084e+00 | T: ((Array([ 0.03365772, -0.00217299], dtype=float32), Array(0.38464782, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.234403e+00 | T: ((Array([ 0.03460664, -0.00273363], dtype=float32), Array(0.38957214, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.176916e+00 | T: ((Array([ 0.03525361, -0.00302451], dtype=float32), Array(0.39431867, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.124067e+00 | T: ((Array([ 0.03561195, -0.00307047], dtype=float32), Array(0.39889473, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.075374e+00 | T: ((Array([ 0.03570121, -0.00289564], dtype=float32), Array(0.40330765, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.030415e+00 | T: ((Array([ 0.0355458 , -0.00252333], dtype=float32), Array(0.40756452, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 2.988820e+00 | T: ((Array([ 0.03517374, -0.0019759 ], dtype=float32), Array(0.41167232, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 2.950265e+00 | T: ((Array([ 0.03461554, -0.0012747 ], dtype=float32), Array(0.41563782, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 2.914463e+00 | T: ((Array([ 0.0339031 , -0.00044005], dtype=float32), Array(0.41946757, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.881161e+00 | T: ((Array([0.03306882, 0.00050887], dtype=float32), Array(0.42316794, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.850133e+00 | T: ((Array([0.03214474, 0.00155397], dtype=float32), Array(0.4267451, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.821179e+00 | T: ((Array([0.03116187, 0.00267828], dtype=float32), Array(0.43020493, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.794116e+00 | T: ((Array([0.03014953, 0.00386599], dtype=float32), Array(0.43355316, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.768784e+00 | T: ((Array([0.02913489, 0.00510238], dtype=float32), Array(0.43679523, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.745037e+00 | T: ((Array([0.02814251, 0.00637389], dtype=float32), Array(0.4399364, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.722742e+00 | T: ((Array([0.02719408, 0.00766799], dtype=float32), Array(0.44298163, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.701779e+00 | T: ((Array([0.02630818, 0.00897327], dtype=float32), Array(0.44593576, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.682040e+00 | T: ((Array([0.02550011, 0.01027933], dtype=float32), Array(0.4488033, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.663427e+00 | T: ((Array([0.02478191, 0.01157677], dtype=float32), Array(0.45158866, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.645850e+00 | T: ((Array([0.02416234, 0.01285718], dtype=float32), Array(0.45429593, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.629228e+00 | T: ((Array([0.023647  , 0.01411307], dtype=float32), Array(0.45692906, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.613487e+00 | T: ((Array([0.02323852, 0.01533784], dtype=float32), Array(0.4594918, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.598559e+00 | T: ((Array([0.02293675, 0.01652574], dtype=float32), Array(0.46198764, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.584384e+00 | T: ((Array([0.02273902, 0.01767184], dtype=float32), Array(0.46442, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.570907e+00 | T: ((Array([0.02264049, 0.01877196], dtype=float32), Array(0.46679202, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.558077e+00 | T: ((Array([0.0226344 , 0.01982265], dtype=float32), Array(0.4691067, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.545846e+00 | T: ((Array([0.02271246, 0.02082112], dtype=float32), Array(0.4713669, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.534175e+00 | T: ((Array([0.02286516, 0.02176521], dtype=float32), Array(0.47357532, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.523026e+00 | T: ((Array([0.02308213, 0.02265336], dtype=float32), Array(0.47573444, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.512361e+00 | T: ((Array([0.02335243, 0.02348454], dtype=float32), Array(0.47784668, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.502150e+00 | T: ((Array([0.02366488, 0.02425821], dtype=float32), Array(0.4799143, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.492363e+00 | T: ((Array([0.02400833, 0.0249743 ], dtype=float32), Array(0.48193944, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.482974e+00 | T: ((Array([0.02437193, 0.02563312], dtype=float32), Array(0.48392406, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.473957e+00 | T: ((Array([0.02474535, 0.02623538], dtype=float32), Array(0.4858701, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.465291e+00 | T: ((Array([0.02511896, 0.02678211], dtype=float32), Array(0.4877793, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.456952e+00 | T: ((Array([0.02548401, 0.02727463], dtype=float32), Array(0.48965332, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.448922e+00 | T: ((Array([0.02583275, 0.02771452], dtype=float32), Array(0.49149376, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.441184e+00 | T: ((Array([0.02615851, 0.02810358], dtype=float32), Array(0.49330208, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.433720e+00 | T: ((Array([0.02645576, 0.02844379], dtype=float32), Array(0.49507967, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.426516e+00 | T: ((Array([0.02672016, 0.0287373 ], dtype=float32), Array(0.49682784, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.419556e+00 | T: ((Array([0.02694853, 0.02898638], dtype=float32), Array(0.49854785, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.412827e+00 | T: ((Array([0.02713881, 0.02919341], dtype=float32), Array(0.50024086, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.406319e+00 | T: ((Array([0.02729004, 0.02936081], dtype=float32), Array(0.50190794, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.400018e+00 | T: ((Array([0.02740225, 0.0294911 ], dtype=float32), Array(0.5035501, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.393915e+00 | T: ((Array([0.02747641, 0.02958679], dtype=float32), Array(0.5051683, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.388000e+00 | T: ((Array([0.02751427, 0.02965042], dtype=float32), Array(0.50676346, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.382265e+00 | T: ((Array([0.02751829, 0.0296845 ], dtype=float32), Array(0.5083364, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.376699e+00 | T: ((Array([0.0274915 , 0.02969153], dtype=float32), Array(0.509888, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.371297e+00 | T: ((Array([0.02743739, 0.02967397], dtype=float32), Array(0.51141894, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.366051e+00 | T: ((Array([0.02735976, 0.0296342 ], dtype=float32), Array(0.51293, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.360953e+00 | T: ((Array([0.02726262, 0.02957456], dtype=float32), Array(0.51442176, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.355998e+00 | T: ((Array([0.02715008, 0.0294973 ], dtype=float32), Array(0.51589495, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.351179e+00 | T: ((Array([0.02702625, 0.0294046 ], dtype=float32), Array(0.5173501, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.346492e+00 | T: ((Array([0.02689509, 0.02929852], dtype=float32), Array(0.51878774, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.341930e+00 | T: ((Array([0.02676043, 0.02918104], dtype=float32), Array(0.5202085, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.337489e+00 | T: ((Array([0.02662577, 0.02905404], dtype=float32), Array(0.5216128, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.333165e+00 | T: ((Array([0.02649433, 0.02891929], dtype=float32), Array(0.5230012, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.328951e+00 | T: ((Array([0.02636894, 0.02877843], dtype=float32), Array(0.52437407, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.324846e+00 | T: ((Array([0.02625203, 0.02863303], dtype=float32), Array(0.5257318, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.320845e+00 | T: ((Array([0.0261456 , 0.02848452], dtype=float32), Array(0.5270749, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.316942e+00 | T: ((Array([0.02605121, 0.02833422], dtype=float32), Array(0.52840364, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.313137e+00 | T: ((Array([0.02597001, 0.02818334], dtype=float32), Array(0.52971846, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.309424e+00 | T: ((Array([0.0259027, 0.028033 ], dtype=float32), Array(0.5310196, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.305802e+00 | T: ((Array([0.0258496 , 0.02788419], dtype=float32), Array(0.5323075, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.302266e+00 | T: ((Array([0.02581067, 0.02773781], dtype=float32), Array(0.5335824, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.298815e+00 | T: ((Array([0.02578549, 0.02759465], dtype=float32), Array(0.5348446, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.295444e+00 | T: ((Array([0.02577341, 0.02745543], dtype=float32), Array(0.53609437, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.292151e+00 | T: ((Array([0.02577347, 0.02732074], dtype=float32), Array(0.537332, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.288935e+00 | T: ((Array([0.02578453, 0.02719111], dtype=float32), Array(0.53855777, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.285793e+00 | T: ((Array([0.02580531, 0.02706698], dtype=float32), Array(0.53977185, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.282722e+00 | T: ((Array([0.02583437, 0.02694869], dtype=float32), Array(0.5409745, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.279720e+00 | T: ((Array([0.02587025, 0.02683653], dtype=float32), Array(0.54216594, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.276785e+00 | T: ((Array([0.02591143, 0.02673073], dtype=float32), Array(0.5433464, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.273915e+00 | T: ((Array([0.02595641, 0.02663142], dtype=float32), Array(0.5445161, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.271109e+00 | T: ((Array([0.02600375, 0.02653869], dtype=float32), Array(0.54567516, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.268364e+00 | T: ((Array([0.02605208, 0.02645259], dtype=float32), Array(0.5468238, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.265678e+00 | T: ((Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.265678e+00 | T: (Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32))
# Step 0 | T: 1.101120e+01 | T: ((Array([0.05457994, 0.12616831], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 9.925315e+00 | T: ((Array([0.04486996, 0.11626425], dtype=float32), Array(0.21992762, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.004430e+00 | T: ((Array([0.03572655, 0.10651977], dtype=float32), Array(0.22974285, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.221049e+00 | T: ((Array([0.02746652, 0.09699648], dtype=float32), Array(0.23941153, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.552216e+00 | T: ((Array([0.02039011, 0.08775266], dtype=float32), Array(0.24890527, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 6.978842e+00 | T: ((Array([0.01470873, 0.07884187], dtype=float32), Array(0.25820103, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.485114e+00 | T: ((Array([0.01049948, 0.07031186], dtype=float32), Array(0.26728055, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.058035e+00 | T: ((Array([0.00771104, 0.06220369], dtype=float32), Array(0.27612984, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.686961e+00 | T: ((Array([0.00620478, 0.05455128], dtype=float32), Array(0.28473857, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.363182e+00 | T: ((Array([0.00580016, 0.04738107], dtype=float32), Array(0.2930996, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.079543e+00 | T: ((Array([0.00630691, 0.0407121 ], dtype=float32), Array(0.30120856, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 4.830134e+00 | T: ((Array([0.00754235, 0.03455614], dtype=float32), Array(0.30906335, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.610036e+00 | T: ((Array([0.00933853, 0.02891828], dtype=float32), Array(0.31666386, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.415141e+00 | T: ((Array([0.01154417, 0.02379748], dtype=float32), Array(0.32401165, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.241987e+00 | T: ((Array([0.01402435, 0.01918725], dtype=float32), Array(0.3311096, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.087654e+00 | T: ((Array([0.01665968, 0.01507639], dtype=float32), Array(0.33796182, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 3.949661e+00 | T: ((Array([0.01934541, 0.01144975], dtype=float32), Array(0.34457326, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.825896e+00 | T: ((Array([0.02199098, 0.00828896], dtype=float32), Array(0.3509496, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.714557e+00 | T: ((Array([0.02451969, 0.00557308], dtype=float32), Array(0.35709712, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.614095e+00 | T: ((Array([0.02686843, 0.00327923], dtype=float32), Array(0.3630226, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.523184e+00 | T: ((Array([0.02898744, 0.00138313], dtype=float32), Array(0.36873305, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.440681e+00 | T: ((Array([ 0.03083987, -0.00014044], dtype=float32), Array(0.37423578, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.365597e+00 | T: ((Array([ 0.03240108, -0.00131718], dtype=float32), Array(0.3795382, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.297084e+00 | T: ((Array([ 0.03365772, -0.00217299], dtype=float32), Array(0.38464782, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.234403e+00 | T: ((Array([ 0.03460664, -0.00273363], dtype=float32), Array(0.38957214, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.176916e+00 | T: ((Array([ 0.03525361, -0.00302451], dtype=float32), Array(0.39431867, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.124067e+00 | T: ((Array([ 0.03561195, -0.00307047], dtype=float32), Array(0.39889473, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.075374e+00 | T: ((Array([ 0.03570121, -0.00289564], dtype=float32), Array(0.40330765, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.030415e+00 | T: ((Array([ 0.0355458 , -0.00252333], dtype=float32), Array(0.40756452, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 2.988820e+00 | T: ((Array([ 0.03517374, -0.0019759 ], dtype=float32), Array(0.41167232, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 2.950265e+00 | T: ((Array([ 0.03461554, -0.0012747 ], dtype=float32), Array(0.41563782, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 2.914463e+00 | T: ((Array([ 0.0339031 , -0.00044005], dtype=float32), Array(0.41946757, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.881161e+00 | T: ((Array([0.03306882, 0.00050887], dtype=float32), Array(0.42316794, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.850133e+00 | T: ((Array([0.03214474, 0.00155397], dtype=float32), Array(0.4267451, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.821179e+00 | T: ((Array([0.03116187, 0.00267828], dtype=float32), Array(0.43020493, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.794116e+00 | T: ((Array([0.03014953, 0.00386599], dtype=float32), Array(0.43355316, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.768784e+00 | T: ((Array([0.02913489, 0.00510238], dtype=float32), Array(0.43679523, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.745037e+00 | T: ((Array([0.02814251, 0.00637389], dtype=float32), Array(0.4399364, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.722742e+00 | T: ((Array([0.02719408, 0.00766799], dtype=float32), Array(0.44298163, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.701779e+00 | T: ((Array([0.02630818, 0.00897327], dtype=float32), Array(0.44593576, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.682040e+00 | T: ((Array([0.02550011, 0.01027933], dtype=float32), Array(0.4488033, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.663427e+00 | T: ((Array([0.02478191, 0.01157677], dtype=float32), Array(0.45158866, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.645850e+00 | T: ((Array([0.02416234, 0.01285718], dtype=float32), Array(0.45429593, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.629228e+00 | T: ((Array([0.023647  , 0.01411307], dtype=float32), Array(0.45692906, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.613487e+00 | T: ((Array([0.02323852, 0.01533784], dtype=float32), Array(0.4594918, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.598559e+00 | T: ((Array([0.02293675, 0.01652574], dtype=float32), Array(0.46198764, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.584384e+00 | T: ((Array([0.02273902, 0.01767184], dtype=float32), Array(0.46442, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.570907e+00 | T: ((Array([0.02264049, 0.01877196], dtype=float32), Array(0.46679202, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.558077e+00 | T: ((Array([0.0226344 , 0.01982265], dtype=float32), Array(0.4691067, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.545846e+00 | T: ((Array([0.02271246, 0.02082112], dtype=float32), Array(0.4713669, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.534175e+00 | T: ((Array([0.02286516, 0.02176521], dtype=float32), Array(0.47357532, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.523026e+00 | T: ((Array([0.02308213, 0.02265336], dtype=float32), Array(0.47573444, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.512361e+00 | T: ((Array([0.02335243, 0.02348454], dtype=float32), Array(0.47784668, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.502150e+00 | T: ((Array([0.02366488, 0.02425821], dtype=float32), Array(0.4799143, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.492363e+00 | T: ((Array([0.02400833, 0.0249743 ], dtype=float32), Array(0.48193944, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.482974e+00 | T: ((Array([0.02437193, 0.02563312], dtype=float32), Array(0.48392406, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.473957e+00 | T: ((Array([0.02474535, 0.02623538], dtype=float32), Array(0.4858701, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.465291e+00 | T: ((Array([0.02511896, 0.02678211], dtype=float32), Array(0.4877793, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.456952e+00 | T: ((Array([0.02548401, 0.02727463], dtype=float32), Array(0.48965332, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.448922e+00 | T: ((Array([0.02583275, 0.02771452], dtype=float32), Array(0.49149376, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.441184e+00 | T: ((Array([0.02615851, 0.02810358], dtype=float32), Array(0.49330208, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.433720e+00 | T: ((Array([0.02645576, 0.02844379], dtype=float32), Array(0.49507967, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.426516e+00 | T: ((Array([0.02672016, 0.0287373 ], dtype=float32), Array(0.49682784, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.419556e+00 | T: ((Array([0.02694853, 0.02898638], dtype=float32), Array(0.49854785, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.412827e+00 | T: ((Array([0.02713881, 0.02919341], dtype=float32), Array(0.50024086, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.406319e+00 | T: ((Array([0.02729004, 0.02936081], dtype=float32), Array(0.50190794, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.400018e+00 | T: ((Array([0.02740225, 0.0294911 ], dtype=float32), Array(0.5035501, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.393915e+00 | T: ((Array([0.02747641, 0.02958679], dtype=float32), Array(0.5051683, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.388000e+00 | T: ((Array([0.02751427, 0.02965042], dtype=float32), Array(0.50676346, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.382265e+00 | T: ((Array([0.02751829, 0.0296845 ], dtype=float32), Array(0.5083364, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.376699e+00 | T: ((Array([0.0274915 , 0.02969153], dtype=float32), Array(0.509888, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.371297e+00 | T: ((Array([0.02743739, 0.02967397], dtype=float32), Array(0.51141894, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.366051e+00 | T: ((Array([0.02735976, 0.0296342 ], dtype=float32), Array(0.51293, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.360953e+00 | T: ((Array([0.02726262, 0.02957456], dtype=float32), Array(0.51442176, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.355998e+00 | T: ((Array([0.02715008, 0.0294973 ], dtype=float32), Array(0.51589495, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.351179e+00 | T: ((Array([0.02702625, 0.0294046 ], dtype=float32), Array(0.5173501, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.346492e+00 | T: ((Array([0.02689509, 0.02929852], dtype=float32), Array(0.51878774, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.341930e+00 | T: ((Array([0.02676043, 0.02918104], dtype=float32), Array(0.5202085, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.337489e+00 | T: ((Array([0.02662577, 0.02905404], dtype=float32), Array(0.5216128, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.333165e+00 | T: ((Array([0.02649433, 0.02891929], dtype=float32), Array(0.5230012, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.328951e+00 | T: ((Array([0.02636894, 0.02877843], dtype=float32), Array(0.52437407, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.324846e+00 | T: ((Array([0.02625203, 0.02863303], dtype=float32), Array(0.5257318, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.320845e+00 | T: ((Array([0.0261456 , 0.02848452], dtype=float32), Array(0.5270749, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.316942e+00 | T: ((Array([0.02605121, 0.02833422], dtype=float32), Array(0.52840364, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.313137e+00 | T: ((Array([0.02597001, 0.02818334], dtype=float32), Array(0.52971846, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.309424e+00 | T: ((Array([0.0259027, 0.028033 ], dtype=float32), Array(0.5310196, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.305802e+00 | T: ((Array([0.0258496 , 0.02788419], dtype=float32), Array(0.5323075, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.302266e+00 | T: ((Array([0.02581067, 0.02773781], dtype=float32), Array(0.5335824, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.298815e+00 | T: ((Array([0.02578549, 0.02759465], dtype=float32), Array(0.5348446, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.295444e+00 | T: ((Array([0.02577341, 0.02745543], dtype=float32), Array(0.53609437, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.292151e+00 | T: ((Array([0.02577347, 0.02732074], dtype=float32), Array(0.537332, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.288935e+00 | T: ((Array([0.02578453, 0.02719111], dtype=float32), Array(0.53855777, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.285793e+00 | T: ((Array([0.02580531, 0.02706698], dtype=float32), Array(0.53977185, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.282722e+00 | T: ((Array([0.02583437, 0.02694869], dtype=float32), Array(0.5409745, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.279720e+00 | T: ((Array([0.02587025, 0.02683653], dtype=float32), Array(0.54216594, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.276785e+00 | T: ((Array([0.02591143, 0.02673073], dtype=float32), Array(0.5433464, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.273915e+00 | T: ((Array([0.02595641, 0.02663142], dtype=float32), Array(0.5445161, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.271109e+00 | T: ((Array([0.02600375, 0.02653869], dtype=float32), Array(0.54567516, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.268364e+00 | T: ((Array([0.02605208, 0.02645259], dtype=float32), Array(0.5468238, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.265678e+00 | T: ((Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.265678e+00 | T: (Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32))
# Step 0 | T: 1.101120e+01 | T: ((Array([0.05457994, 0.12616831], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 9.925315e+00 | T: ((Array([0.04486996, 0.11626425], dtype=float32), Array(0.21992762, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.004430e+00 | T: ((Array([0.03572655, 0.10651977], dtype=float32), Array(0.22974285, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.221049e+00 | T: ((Array([0.02746652, 0.09699648], dtype=float32), Array(0.23941153, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.552216e+00 | T: ((Array([0.02039011, 0.08775266], dtype=float32), Array(0.24890527, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 6.978842e+00 | T: ((Array([0.01470873, 0.07884187], dtype=float32), Array(0.25820103, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.485114e+00 | T: ((Array([0.01049948, 0.07031186], dtype=float32), Array(0.26728055, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.058035e+00 | T: ((Array([0.00771104, 0.06220369], dtype=float32), Array(0.27612984, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.686961e+00 | T: ((Array([0.00620478, 0.05455128], dtype=float32), Array(0.28473857, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.363182e+00 | T: ((Array([0.00580016, 0.04738107], dtype=float32), Array(0.2930996, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.079543e+00 | T: ((Array([0.00630691, 0.0407121 ], dtype=float32), Array(0.30120856, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 4.830134e+00 | T: ((Array([0.00754235, 0.03455614], dtype=float32), Array(0.30906335, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.610036e+00 | T: ((Array([0.00933853, 0.02891828], dtype=float32), Array(0.31666386, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.415141e+00 | T: ((Array([0.01154417, 0.02379748], dtype=float32), Array(0.32401165, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.241987e+00 | T: ((Array([0.01402435, 0.01918725], dtype=float32), Array(0.3311096, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.087654e+00 | T: ((Array([0.01665968, 0.01507639], dtype=float32), Array(0.33796182, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 3.949661e+00 | T: ((Array([0.01934541, 0.01144975], dtype=float32), Array(0.34457326, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.825896e+00 | T: ((Array([0.02199098, 0.00828896], dtype=float32), Array(0.3509496, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.714557e+00 | T: ((Array([0.02451969, 0.00557308], dtype=float32), Array(0.35709712, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.614095e+00 | T: ((Array([0.02686843, 0.00327923], dtype=float32), Array(0.3630226, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.523184e+00 | T: ((Array([0.02898744, 0.00138313], dtype=float32), Array(0.36873305, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.440681e+00 | T: ((Array([ 0.03083987, -0.00014044], dtype=float32), Array(0.37423578, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.365597e+00 | T: ((Array([ 0.03240108, -0.00131718], dtype=float32), Array(0.3795382, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.297084e+00 | T: ((Array([ 0.03365772, -0.00217299], dtype=float32), Array(0.38464782, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.234403e+00 | T: ((Array([ 0.03460664, -0.00273363], dtype=float32), Array(0.38957214, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.176916e+00 | T: ((Array([ 0.03525361, -0.00302451], dtype=float32), Array(0.39431867, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.124067e+00 | T: ((Array([ 0.03561195, -0.00307047], dtype=float32), Array(0.39889473, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.075374e+00 | T: ((Array([ 0.03570121, -0.00289564], dtype=float32), Array(0.40330765, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.030415e+00 | T: ((Array([ 0.0355458 , -0.00252333], dtype=float32), Array(0.40756452, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 2.988820e+00 | T: ((Array([ 0.03517374, -0.0019759 ], dtype=float32), Array(0.41167232, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 2.950265e+00 | T: ((Array([ 0.03461554, -0.0012747 ], dtype=float32), Array(0.41563782, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 2.914463e+00 | T: ((Array([ 0.0339031 , -0.00044005], dtype=float32), Array(0.41946757, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.881161e+00 | T: ((Array([0.03306882, 0.00050887], dtype=float32), Array(0.42316794, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.850133e+00 | T: ((Array([0.03214474, 0.00155397], dtype=float32), Array(0.4267451, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.821179e+00 | T: ((Array([0.03116187, 0.00267828], dtype=float32), Array(0.43020493, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.794116e+00 | T: ((Array([0.03014953, 0.00386599], dtype=float32), Array(0.43355316, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.768784e+00 | T: ((Array([0.02913489, 0.00510238], dtype=float32), Array(0.43679523, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.745037e+00 | T: ((Array([0.02814251, 0.00637389], dtype=float32), Array(0.4399364, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.722742e+00 | T: ((Array([0.02719408, 0.00766799], dtype=float32), Array(0.44298163, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.701779e+00 | T: ((Array([0.02630818, 0.00897327], dtype=float32), Array(0.44593576, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.682040e+00 | T: ((Array([0.02550011, 0.01027933], dtype=float32), Array(0.4488033, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.663427e+00 | T: ((Array([0.02478191, 0.01157677], dtype=float32), Array(0.45158866, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.645850e+00 | T: ((Array([0.02416234, 0.01285718], dtype=float32), Array(0.45429593, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.629228e+00 | T: ((Array([0.023647  , 0.01411307], dtype=float32), Array(0.45692906, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.613487e+00 | T: ((Array([0.02323852, 0.01533784], dtype=float32), Array(0.4594918, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.598559e+00 | T: ((Array([0.02293675, 0.01652574], dtype=float32), Array(0.46198764, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.584384e+00 | T: ((Array([0.02273902, 0.01767184], dtype=float32), Array(0.46442, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.570907e+00 | T: ((Array([0.02264049, 0.01877196], dtype=float32), Array(0.46679202, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.558077e+00 | T: ((Array([0.0226344 , 0.01982265], dtype=float32), Array(0.4691067, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.545846e+00 | T: ((Array([0.02271246, 0.02082112], dtype=float32), Array(0.4713669, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.534175e+00 | T: ((Array([0.02286516, 0.02176521], dtype=float32), Array(0.47357532, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.523026e+00 | T: ((Array([0.02308213, 0.02265336], dtype=float32), Array(0.47573444, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.512361e+00 | T: ((Array([0.02335243, 0.02348454], dtype=float32), Array(0.47784668, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.502150e+00 | T: ((Array([0.02366488, 0.02425821], dtype=float32), Array(0.4799143, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.492363e+00 | T: ((Array([0.02400833, 0.0249743 ], dtype=float32), Array(0.48193944, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.482974e+00 | T: ((Array([0.02437193, 0.02563312], dtype=float32), Array(0.48392406, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.473957e+00 | T: ((Array([0.02474535, 0.02623538], dtype=float32), Array(0.4858701, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.465291e+00 | T: ((Array([0.02511896, 0.02678211], dtype=float32), Array(0.4877793, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.456952e+00 | T: ((Array([0.02548401, 0.02727463], dtype=float32), Array(0.48965332, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.448922e+00 | T: ((Array([0.02583275, 0.02771452], dtype=float32), Array(0.49149376, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.441184e+00 | T: ((Array([0.02615851, 0.02810358], dtype=float32), Array(0.49330208, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.433720e+00 | T: ((Array([0.02645576, 0.02844379], dtype=float32), Array(0.49507967, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.426516e+00 | T: ((Array([0.02672016, 0.0287373 ], dtype=float32), Array(0.49682784, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.419556e+00 | T: ((Array([0.02694853, 0.02898638], dtype=float32), Array(0.49854785, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.412827e+00 | T: ((Array([0.02713881, 0.02919341], dtype=float32), Array(0.50024086, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.406319e+00 | T: ((Array([0.02729004, 0.02936081], dtype=float32), Array(0.50190794, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.400018e+00 | T: ((Array([0.02740225, 0.0294911 ], dtype=float32), Array(0.5035501, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.393915e+00 | T: ((Array([0.02747641, 0.02958679], dtype=float32), Array(0.5051683, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.388000e+00 | T: ((Array([0.02751427, 0.02965042], dtype=float32), Array(0.50676346, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.382265e+00 | T: ((Array([0.02751829, 0.0296845 ], dtype=float32), Array(0.5083364, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.376699e+00 | T: ((Array([0.0274915 , 0.02969153], dtype=float32), Array(0.509888, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.371297e+00 | T: ((Array([0.02743739, 0.02967397], dtype=float32), Array(0.51141894, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.366051e+00 | T: ((Array([0.02735976, 0.0296342 ], dtype=float32), Array(0.51293, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.360953e+00 | T: ((Array([0.02726262, 0.02957456], dtype=float32), Array(0.51442176, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.355998e+00 | T: ((Array([0.02715008, 0.0294973 ], dtype=float32), Array(0.51589495, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.351179e+00 | T: ((Array([0.02702625, 0.0294046 ], dtype=float32), Array(0.5173501, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.346492e+00 | T: ((Array([0.02689509, 0.02929852], dtype=float32), Array(0.51878774, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.341930e+00 | T: ((Array([0.02676043, 0.02918104], dtype=float32), Array(0.5202085, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.337489e+00 | T: ((Array([0.02662577, 0.02905404], dtype=float32), Array(0.5216128, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.333165e+00 | T: ((Array([0.02649433, 0.02891929], dtype=float32), Array(0.5230012, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.328951e+00 | T: ((Array([0.02636894, 0.02877843], dtype=float32), Array(0.52437407, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.324846e+00 | T: ((Array([0.02625203, 0.02863303], dtype=float32), Array(0.5257318, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.320845e+00 | T: ((Array([0.0261456 , 0.02848452], dtype=float32), Array(0.5270749, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.316942e+00 | T: ((Array([0.02605121, 0.02833422], dtype=float32), Array(0.52840364, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.313137e+00 | T: ((Array([0.02597001, 0.02818334], dtype=float32), Array(0.52971846, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.309424e+00 | T: ((Array([0.0259027, 0.028033 ], dtype=float32), Array(0.5310196, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.305802e+00 | T: ((Array([0.0258496 , 0.02788419], dtype=float32), Array(0.5323075, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.302266e+00 | T: ((Array([0.02581067, 0.02773781], dtype=float32), Array(0.5335824, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.298815e+00 | T: ((Array([0.02578549, 0.02759465], dtype=float32), Array(0.5348446, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.295444e+00 | T: ((Array([0.02577341, 0.02745543], dtype=float32), Array(0.53609437, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.292151e+00 | T: ((Array([0.02577347, 0.02732074], dtype=float32), Array(0.537332, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.288935e+00 | T: ((Array([0.02578453, 0.02719111], dtype=float32), Array(0.53855777, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.285793e+00 | T: ((Array([0.02580531, 0.02706698], dtype=float32), Array(0.53977185, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.282722e+00 | T: ((Array([0.02583437, 0.02694869], dtype=float32), Array(0.5409745, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.279720e+00 | T: ((Array([0.02587025, 0.02683653], dtype=float32), Array(0.54216594, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.276785e+00 | T: ((Array([0.02591143, 0.02673073], dtype=float32), Array(0.5433464, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.273915e+00 | T: ((Array([0.02595641, 0.02663142], dtype=float32), Array(0.5445161, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.271109e+00 | T: ((Array([0.02600375, 0.02653869], dtype=float32), Array(0.54567516, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.268364e+00 | T: ((Array([0.02605208, 0.02645259], dtype=float32), Array(0.5468238, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.265678e+00 | T: ((Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.265678e+00 | T: (Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32))
# Step 0 | T: 1.101120e+01 | T: ((Array([0.05457994, 0.12616831], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 9.925315e+00 | T: ((Array([0.04486996, 0.11626425], dtype=float32), Array(0.21992762, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.004430e+00 | T: ((Array([0.03572655, 0.10651977], dtype=float32), Array(0.22974285, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.221049e+00 | T: ((Array([0.02746652, 0.09699648], dtype=float32), Array(0.23941153, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.552216e+00 | T: ((Array([0.02039011, 0.08775266], dtype=float32), Array(0.24890527, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 6.978842e+00 | T: ((Array([0.01470873, 0.07884187], dtype=float32), Array(0.25820103, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.485114e+00 | T: ((Array([0.01049948, 0.07031186], dtype=float32), Array(0.26728055, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.058035e+00 | T: ((Array([0.00771104, 0.06220369], dtype=float32), Array(0.27612984, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.686961e+00 | T: ((Array([0.00620478, 0.05455128], dtype=float32), Array(0.28473857, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.363182e+00 | T: ((Array([0.00580016, 0.04738107], dtype=float32), Array(0.2930996, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.079543e+00 | T: ((Array([0.00630691, 0.0407121 ], dtype=float32), Array(0.30120856, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 4.830134e+00 | T: ((Array([0.00754235, 0.03455614], dtype=float32), Array(0.30906335, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.610036e+00 | T: ((Array([0.00933853, 0.02891828], dtype=float32), Array(0.31666386, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.415141e+00 | T: ((Array([0.01154417, 0.02379748], dtype=float32), Array(0.32401165, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.241987e+00 | T: ((Array([0.01402435, 0.01918725], dtype=float32), Array(0.3311096, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.087654e+00 | T: ((Array([0.01665968, 0.01507639], dtype=float32), Array(0.33796182, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 3.949661e+00 | T: ((Array([0.01934541, 0.01144975], dtype=float32), Array(0.34457326, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.825896e+00 | T: ((Array([0.02199098, 0.00828896], dtype=float32), Array(0.3509496, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.714557e+00 | T: ((Array([0.02451969, 0.00557308], dtype=float32), Array(0.35709712, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.614095e+00 | T: ((Array([0.02686843, 0.00327923], dtype=float32), Array(0.3630226, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.523184e+00 | T: ((Array([0.02898744, 0.00138313], dtype=float32), Array(0.36873305, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.440681e+00 | T: ((Array([ 0.03083987, -0.00014044], dtype=float32), Array(0.37423578, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.365597e+00 | T: ((Array([ 0.03240108, -0.00131718], dtype=float32), Array(0.3795382, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.297084e+00 | T: ((Array([ 0.03365772, -0.00217299], dtype=float32), Array(0.38464782, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.234403e+00 | T: ((Array([ 0.03460664, -0.00273363], dtype=float32), Array(0.38957214, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.176916e+00 | T: ((Array([ 0.03525361, -0.00302451], dtype=float32), Array(0.39431867, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.124067e+00 | T: ((Array([ 0.03561195, -0.00307047], dtype=float32), Array(0.39889473, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.075374e+00 | T: ((Array([ 0.03570121, -0.00289564], dtype=float32), Array(0.40330765, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.030415e+00 | T: ((Array([ 0.0355458 , -0.00252333], dtype=float32), Array(0.40756452, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 2.988820e+00 | T: ((Array([ 0.03517374, -0.0019759 ], dtype=float32), Array(0.41167232, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 2.950265e+00 | T: ((Array([ 0.03461554, -0.0012747 ], dtype=float32), Array(0.41563782, dtype=float32)), Array([0.], dtype=float32))
# ...
# Step 91 | T: 2.288935e+00 | T: ((Array([0.02578453, 0.02719111], dtype=float32), Array(0.53855777, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.285793e+00 | T: ((Array([0.02580531, 0.02706698], dtype=float32), Array(0.53977185, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.282722e+00 | T: ((Array([0.02583437, 0.02694869], dtype=float32), Array(0.5409745, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.279720e+00 | T: ((Array([0.02587025, 0.02683653], dtype=float32), Array(0.54216594, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.276785e+00 | T: ((Array([0.02591143, 0.02673073], dtype=float32), Array(0.5433464, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.273915e+00 | T: ((Array([0.02595641, 0.02663142], dtype=float32), Array(0.5445161, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.271109e+00 | T: ((Array([0.02600375, 0.02653869], dtype=float32), Array(0.54567516, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.268364e+00 | T: ((Array([0.02605208, 0.02645259], dtype=float32), Array(0.5468238, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.265678e+00 | T: ((Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.265678e+00 | T: (Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32))
# Step 0 | T: 1.101120e+01 | T: ((Array([0.05457994, 0.12616831], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 9.925315e+00 | T: ((Array([0.04486996, 0.11626425], dtype=float32), Array(0.21992762, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.004430e+00 | T: ((Array([0.03572655, 0.10651977], dtype=float32), Array(0.22974285, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.221049e+00 | T: ((Array([0.02746652, 0.09699648], dtype=float32), Array(0.23941153, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.552216e+00 | T: ((Array([0.02039011, 0.08775266], dtype=float32), Array(0.24890527, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 6.978842e+00 | T: ((Array([0.01470873, 0.07884187], dtype=float32), Array(0.25820103, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.485114e+00 | T: ((Array([0.01049948, 0.07031186], dtype=float32), Array(0.26728055, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.058035e+00 | T: ((Array([0.00771104, 0.06220369], dtype=float32), Array(0.27612984, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.686961e+00 | T: ((Array([0.00620478, 0.05455128], dtype=float32), Array(0.28473857, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.363182e+00 | T: ((Array([0.00580016, 0.04738107], dtype=float32), Array(0.2930996, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.079543e+00 | T: ((Array([0.00630691, 0.0407121 ], dtype=float32), Array(0.30120856, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 4.830134e+00 | T: ((Array([0.00754235, 0.03455614], dtype=float32), Array(0.30906335, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.610036e+00 | T: ((Array([0.00933853, 0.02891828], dtype=float32), Array(0.31666386, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.415141e+00 | T: ((Array([0.01154417, 0.02379748], dtype=float32), Array(0.32401165, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.241987e+00 | T: ((Array([0.01402435, 0.01918725], dtype=float32), Array(0.3311096, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.087654e+00 | T: ((Array([0.01665968, 0.01507639], dtype=float32), Array(0.33796182, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 3.949661e+00 | T: ((Array([0.01934541, 0.01144975], dtype=float32), Array(0.34457326, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 3.825896e+00 | T: ((Array([0.02199098, 0.00828896], dtype=float32), Array(0.3509496, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.714557e+00 | T: ((Array([0.02451969, 0.00557308], dtype=float32), Array(0.35709712, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.614095e+00 | T: ((Array([0.02686843, 0.00327923], dtype=float32), Array(0.3630226, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.523184e+00 | T: ((Array([0.02898744, 0.00138313], dtype=float32), Array(0.36873305, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.440681e+00 | T: ((Array([ 0.03083987, -0.00014044], dtype=float32), Array(0.37423578, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.365597e+00 | T: ((Array([ 0.03240108, -0.00131718], dtype=float32), Array(0.3795382, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.297084e+00 | T: ((Array([ 0.03365772, -0.00217299], dtype=float32), Array(0.38464782, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.234403e+00 | T: ((Array([ 0.03460664, -0.00273363], dtype=float32), Array(0.38957214, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.176916e+00 | T: ((Array([ 0.03525361, -0.00302451], dtype=float32), Array(0.39431867, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.124067e+00 | T: ((Array([ 0.03561195, -0.00307047], dtype=float32), Array(0.39889473, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.075374e+00 | T: ((Array([ 0.03570121, -0.00289564], dtype=float32), Array(0.40330765, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.030415e+00 | T: ((Array([ 0.0355458 , -0.00252333], dtype=float32), Array(0.40756452, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 2.988820e+00 | T: ((Array([ 0.03517374, -0.0019759 ], dtype=float32), Array(0.41167232, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 2.950265e+00 | T: ((Array([ 0.03461554, -0.0012747 ], dtype=float32), Array(0.41563782, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 2.914463e+00 | T: ((Array([ 0.0339031 , -0.00044005], dtype=float32), Array(0.41946757, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 2.881161e+00 | T: ((Array([0.03306882, 0.00050887], dtype=float32), Array(0.42316794, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.850133e+00 | T: ((Array([0.03214474, 0.00155397], dtype=float32), Array(0.4267451, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.821179e+00 | T: ((Array([0.03116187, 0.00267828], dtype=float32), Array(0.43020493, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.794116e+00 | T: ((Array([0.03014953, 0.00386599], dtype=float32), Array(0.43355316, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.768784e+00 | T: ((Array([0.02913489, 0.00510238], dtype=float32), Array(0.43679523, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.745037e+00 | T: ((Array([0.02814251, 0.00637389], dtype=float32), Array(0.4399364, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.722742e+00 | T: ((Array([0.02719408, 0.00766799], dtype=float32), Array(0.44298163, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.701779e+00 | T: ((Array([0.02630818, 0.00897327], dtype=float32), Array(0.44593576, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.682040e+00 | T: ((Array([0.02550011, 0.01027933], dtype=float32), Array(0.4488033, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.663427e+00 | T: ((Array([0.02478191, 0.01157677], dtype=float32), Array(0.45158866, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.645850e+00 | T: ((Array([0.02416234, 0.01285718], dtype=float32), Array(0.45429593, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.629228e+00 | T: ((Array([0.023647  , 0.01411307], dtype=float32), Array(0.45692906, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.613487e+00 | T: ((Array([0.02323852, 0.01533784], dtype=float32), Array(0.4594918, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.598559e+00 | T: ((Array([0.02293675, 0.01652574], dtype=float32), Array(0.46198764, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.584384e+00 | T: ((Array([0.02273902, 0.01767184], dtype=float32), Array(0.46442, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.570907e+00 | T: ((Array([0.02264049, 0.01877196], dtype=float32), Array(0.46679202, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.558077e+00 | T: ((Array([0.0226344 , 0.01982265], dtype=float32), Array(0.4691067, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.545846e+00 | T: ((Array([0.02271246, 0.02082112], dtype=float32), Array(0.4713669, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.534175e+00 | T: ((Array([0.02286516, 0.02176521], dtype=float32), Array(0.47357532, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.523026e+00 | T: ((Array([0.02308213, 0.02265336], dtype=float32), Array(0.47573444, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.512361e+00 | T: ((Array([0.02335243, 0.02348454], dtype=float32), Array(0.47784668, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.502150e+00 | T: ((Array([0.02366488, 0.02425821], dtype=float32), Array(0.4799143, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.492363e+00 | T: ((Array([0.02400833, 0.0249743 ], dtype=float32), Array(0.48193944, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.482974e+00 | T: ((Array([0.02437193, 0.02563312], dtype=float32), Array(0.48392406, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.473957e+00 | T: ((Array([0.02474535, 0.02623538], dtype=float32), Array(0.4858701, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.465291e+00 | T: ((Array([0.02511896, 0.02678211], dtype=float32), Array(0.4877793, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.456952e+00 | T: ((Array([0.02548401, 0.02727463], dtype=float32), Array(0.48965332, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.448922e+00 | T: ((Array([0.02583275, 0.02771452], dtype=float32), Array(0.49149376, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.441184e+00 | T: ((Array([0.02615851, 0.02810358], dtype=float32), Array(0.49330208, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.433720e+00 | T: ((Array([0.02645576, 0.02844379], dtype=float32), Array(0.49507967, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.426516e+00 | T: ((Array([0.02672016, 0.0287373 ], dtype=float32), Array(0.49682784, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.419556e+00 | T: ((Array([0.02694853, 0.02898638], dtype=float32), Array(0.49854785, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.412827e+00 | T: ((Array([0.02713881, 0.02919341], dtype=float32), Array(0.50024086, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.406319e+00 | T: ((Array([0.02729004, 0.02936081], dtype=float32), Array(0.50190794, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.400018e+00 | T: ((Array([0.02740225, 0.0294911 ], dtype=float32), Array(0.5035501, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.393915e+00 | T: ((Array([0.02747641, 0.02958679], dtype=float32), Array(0.5051683, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.388000e+00 | T: ((Array([0.02751427, 0.02965042], dtype=float32), Array(0.50676346, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.382265e+00 | T: ((Array([0.02751829, 0.0296845 ], dtype=float32), Array(0.5083364, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.376699e+00 | T: ((Array([0.0274915 , 0.02969153], dtype=float32), Array(0.509888, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.371297e+00 | T: ((Array([0.02743739, 0.02967397], dtype=float32), Array(0.51141894, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.366051e+00 | T: ((Array([0.02735976, 0.0296342 ], dtype=float32), Array(0.51293, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.360953e+00 | T: ((Array([0.02726262, 0.02957456], dtype=float32), Array(0.51442176, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.355998e+00 | T: ((Array([0.02715008, 0.0294973 ], dtype=float32), Array(0.51589495, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.351179e+00 | T: ((Array([0.02702625, 0.0294046 ], dtype=float32), Array(0.5173501, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.346492e+00 | T: ((Array([0.02689509, 0.02929852], dtype=float32), Array(0.51878774, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.341930e+00 | T: ((Array([0.02676043, 0.02918104], dtype=float32), Array(0.5202085, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.337489e+00 | T: ((Array([0.02662577, 0.02905404], dtype=float32), Array(0.5216128, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.333165e+00 | T: ((Array([0.02649433, 0.02891929], dtype=float32), Array(0.5230012, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.328951e+00 | T: ((Array([0.02636894, 0.02877843], dtype=float32), Array(0.52437407, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.324846e+00 | T: ((Array([0.02625203, 0.02863303], dtype=float32), Array(0.5257318, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.320845e+00 | T: ((Array([0.0261456 , 0.02848452], dtype=float32), Array(0.5270749, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.316942e+00 | T: ((Array([0.02605121, 0.02833422], dtype=float32), Array(0.52840364, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.313137e+00 | T: ((Array([0.02597001, 0.02818334], dtype=float32), Array(0.52971846, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.309424e+00 | T: ((Array([0.0259027, 0.028033 ], dtype=float32), Array(0.5310196, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.305802e+00 | T: ((Array([0.0258496 , 0.02788419], dtype=float32), Array(0.5323075, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.302266e+00 | T: ((Array([0.02581067, 0.02773781], dtype=float32), Array(0.5335824, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.298815e+00 | T: ((Array([0.02578549, 0.02759465], dtype=float32), Array(0.5348446, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.295444e+00 | T: ((Array([0.02577341, 0.02745543], dtype=float32), Array(0.53609437, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.292151e+00 | T: ((Array([0.02577347, 0.02732074], dtype=float32), Array(0.537332, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.288935e+00 | T: ((Array([0.02578453, 0.02719111], dtype=float32), Array(0.53855777, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.285793e+00 | T: ((Array([0.02580531, 0.02706698], dtype=float32), Array(0.53977185, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.282722e+00 | T: ((Array([0.02583437, 0.02694869], dtype=float32), Array(0.5409745, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.279720e+00 | T: ((Array([0.02587025, 0.02683653], dtype=float32), Array(0.54216594, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.276785e+00 | T: ((Array([0.02591143, 0.02673073], dtype=float32), Array(0.5433464, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.273915e+00 | T: ((Array([0.02595641, 0.02663142], dtype=float32), Array(0.5445161, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.271109e+00 | T: ((Array([0.02600375, 0.02653869], dtype=float32), Array(0.54567516, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.268364e+00 | T: ((Array([0.02605208, 0.02645259], dtype=float32), Array(0.5468238, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.265678e+00 | T: ((Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.265678e+00 | T: (Array([0.02610011, 0.02637309], dtype=float32), Array(0.5479622, dtype=float32))
# 6.89 s ± 107 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Circle

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = S1()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.])
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/S1/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
layers = [50,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/S1/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/S1/xs.csv', header=None)
charts = pd.read_csv('Data/S1/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[0][0]), jnp.array([0.2]), 
                                     step_size=0.01, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_265361/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      82
#      83     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 84             iterative_mle(samples,\
#      85                 neg_log_p_Ts,\
#      86                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      56
#      57     for i in range(num_steps):
# ---> 58         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      59         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      60         if i % 1 == 0:
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      43
#      44         params = get_params(opt_state)
# ---> 45         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      46         opt_state = opt_update(step, grads, opt_state)
#      47         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     134         T = jnp.sum(dts)
#     135
# --> 136         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     137
#     138         # sample
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63
#      64     # guide function
# ---> 65     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
#      66                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      67                                       (1,0))
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in tensordot(a, b, axes, precision)
#    3180            "of lists/tuples of ints.")
#    3181     raise TypeError(msg)
# -> 3182   return lax.dot_general(a, b, (contracting_dims, ((), ())),
#    3183                          precision=precision)
#    3184
#
#     [... skipping hidden 35 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type)
#    2506     msg = ("dot_general requires contracting dimensions to have the same "
#    2507            "shape, got {} and {}.")
# -> 2508     raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    2509
#    2510   return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (1,) and (2,).

# %%
def gradt_log_opt(x,y,t):
    
    s1_val = M.grady_log_hk(x,y,t)
    s2_val = jacfwdx(lambda y: M.grady_log_hk(x,y,t))(y)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div).squeeze()

# %%
diffusion_mean(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t), s2_model = gradt_log_opt, method="Gradient")
mu_opt, T_opt, _, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_265361/4209498760.py in <module>
#       1 diffusion_mean(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t), s2_model = gradt_log_opt, method="Gradient")
# ----> 2 mu_opt, T_opt, _, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]))
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in <lambda>(X_obs, x0, t, step_size, max_iter)
#      86     elif method == "Gradient":
#      87
# ---> 88         M.sm_dmxt = lambda X_obs, x0, t, step_size=0.1, max_iter=1000: JointGradientDescent(x0,
#      89                                                                                             jnp.array(t),
#      90                                                                                             M,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/optimization/GradientDescent.py in JointGradientDescent(mu_rm, mu_euc, M, grad_fn_rm, grad_fn_euc, step_size_rm, step_size_euc, max_iter, bnds_rm, bnds_euc, max_step)
#     150     grad_euc = grad_fn_euc(mu_rm, mu_euc)
#     151
# --> 152     _, out = lax.scan(update, init=(mu_rm, mu_euc, grad_rm, grad_euc), xs=jnp.arange(0,max_iter,1))
#     153
#     154     mu_rm = out[0]
#
#     [... skipping hidden 2 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py in _check_scan_carry_type(body_fun, in_carry, out_carry_tree, out_avals)
#     316         for path, in_aval, out_aval in zip(paths, in_avals, out_avals)
#     317         if not core.typematch(in_aval, out_aval))
# --> 318     raise TypeError(
#     319         "Scanned function carry input and carry output must have equal types "
#     320         "(e.g. shapes and dtypes of arrays), "
#
# TypeError: Scanned function carry input and carry output must have equal types (e.g. shapes and dtypes of arrays), but they differ:
#   * the input carry component carry[0][1] has type float32[2] but the corresponding output carry component has type float32[1], so the shapes do not match
#
# Revise the scanned function so that all output types (e.g. shapes and dtypes) match the corresponding input types.

# %%
mu_smchart = mu_sm[0][-1]

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_smchart), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 2.0329 )
# T = 1.0000

# %%
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1]):.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.5f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_265361/3996920164.py in <module>
# ----> 1 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1]):.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.5f}")
#
# NameError: name 'mu_opt' is not defined

# %%
mu_bridge = M.F((mu_bridgex[-1], mu_bridgechart[-1]))

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridge), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.9567 0.2912 )
# T = 0.5128

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[1][-1]), ")")
print(f"T = {T_opt[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 1.0000 0.0002 )
# T = 0.0716

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1]):.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.5f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_bridgechart[-1]):.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.5f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.78229
#  -T error = 0.92626
# Bridge Diffusion mean:
#  -mean error = 0.00017
#  -T error = 0.44123

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 337 ms ± 3.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100, N=1)
# Out:
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883113e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032158e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465624e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227062, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398962, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.4656617, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.467289, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.4688735, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041705, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.4719214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832603e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338825, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.47621548, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.4775787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.47891006, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.48021078, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.481482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683385e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.4827248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394015, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.48512906, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.48629236, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743093, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591662e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854554, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574530e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.48963696, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.4917529, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277872, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.4937839, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.494769, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573454, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464089e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.496681, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.49760887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.4985186, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.49941057, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407409e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.5002852, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.50114286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.50198394, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.267695], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.2758596, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507274e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437075, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883111e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.2926175, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334002e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.30059552, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830318, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418879e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.31574082, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.3229106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157136], dtype=float32), Array(0.32981613, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387371e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646217, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572083], dtype=float32), Array(0.34285444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862518e+00 | T: ((Array([-0.07804246], dtype=float32), Array(0.34899938, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637067e+00 | T: ((Array([-0.0705253], dtype=float32), Array(0.35490403, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432304e+00 | T: ((Array([-0.06316626], dtype=float32), Array(0.36057585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245780e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.36602262, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075386e+00 | T: ((Array([-0.04890837], dtype=float32), Array(0.37125227, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200172], dtype=float32), Array(0.3762729, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775929e+00 | T: ((Array([-0.03523772], dtype=float32), Array(0.3810926, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861202], dtype=float32), Array(0.3857195, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522033e+00 | T: ((Array([-0.02212016], dtype=float32), Array(0.39016163, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409250e+00 | T: ((Array([-0.01575764], dtype=float32), Array(0.39442685, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304638e+00 | T: ((Array([-0.00951992], dtype=float32), Array(0.39852297, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207382e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.40245754, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.0025993], dtype=float32), Array(0.4062379, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032158e+00 | T: ((Array([0.00848978], dtype=float32), Array(0.40987122, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427341], dtype=float32), Array(0.41336444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.4167242, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553736], dtype=float32), Array(0.41995695, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306885, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681561e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.4260658, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623114e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895347, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567810e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.43173724, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515391e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442228, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465624e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.4370135, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951556, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373231e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.44193292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330245e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426975, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871765, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083606, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288867, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.4548787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.45680913, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.45868284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.4605025, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227065, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398965, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.46566173, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.46728903, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.46887353, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041708, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.47192144, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832602e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481915, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.4762155, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.47757873, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.4789101, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336694], dtype=float32), Array(0.4802108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734694], dtype=float32), Array(0.48148203, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130283], dtype=float32), Array(0.48272482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523545], dtype=float32), Array(0.48394018, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.17914562], dtype=float32), Array(0.4851291, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303409], dtype=float32), Array(0.4862924, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690157], dtype=float32), Array(0.48743096, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591661e+00 | T: ((Array([0.19074872], dtype=float32), Array(0.48854557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574529e+00 | T: ((Array([0.19457619], dtype=float32), Array(0.489637, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838455], dtype=float32), Array(0.49070588, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217437], dtype=float32), Array(0.49175292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594616], dtype=float32), Array(0.49277875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970044], dtype=float32), Array(0.49378392, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343765], dtype=float32), Array(0.49476904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715823], dtype=float32), Array(0.49573457, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464090e+00 | T: ((Array([0.22086261], dtype=float32), Array(0.49668103, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455117], dtype=float32), Array(0.4976089, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822428], dtype=float32), Array(0.49851862, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188227], dtype=float32), Array(0.4994106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407408e+00 | T: ((Array([0.23552549], dtype=float32), Array(0.50028527, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915423], dtype=float32), Array(0.5011429, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.501984, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.5028088, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354655e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.50361764, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.50441086, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.50518876, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059516, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.50669956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293538e+00 | T: ((Array([0.267695], dtype=float32), Array(0.507433, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281897e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.5081521, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.5088572, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.5095484, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248045e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.510226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.5108901, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.511541, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.51217884, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.5128038, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.5128038, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883113e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848980e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227062, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398962, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.4656617, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.467289, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.4688735, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041705, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.4719214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832603e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338825, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787068e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.47621548, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.4775787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.47891006, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.48021078, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.481482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.4827248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394015, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.48512906, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.48629236, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743093, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591662e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854554, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574530e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.48963696, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.4917529, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277872, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.4937839, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.494769, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573454, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464089e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.496681, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.49760887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.4985186, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.49941057, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407409e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.5002852, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.50114286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.50198394, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.267695], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883114e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.30059552, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848978e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830318, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418879e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.31574082, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.3229106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157136], dtype=float32), Array(0.32981613, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387371e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646217, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.34285444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862518e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899938, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637067e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.35490403, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432304e+00 | T: ((Array([-0.06316626], dtype=float32), Array(0.36057585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245780e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.36602262, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075386e+00 | T: ((Array([-0.04890837], dtype=float32), Array(0.37125227, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200172], dtype=float32), Array(0.3762729, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775929e+00 | T: ((Array([-0.03523773], dtype=float32), Array(0.3810926, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861202], dtype=float32), Array(0.3857195, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522033e+00 | T: ((Array([-0.02212016], dtype=float32), Array(0.39016163, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409250e+00 | T: ((Array([-0.01575765], dtype=float32), Array(0.39442685, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304638e+00 | T: ((Array([-0.00951992], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340245], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259929], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848978], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427341], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995452], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553736], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102605], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642463], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.04173699], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696692], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211806], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719394], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713332], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681053], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155821], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624895], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088534], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546987], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.10000489], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893522], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# ...
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636948], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995649], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.2535301], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709057], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063806], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.26417282], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.26769504], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.2712049], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470258], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818826], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.2816621], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.28512424], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.28857484], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.29201403], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544196], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544196], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883114e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.40987122, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.41336444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.4167242, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995695, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306885, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681561e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.4260658, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623114e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895347, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567810e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.43173724, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515391e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442228, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.4370135, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951556, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373231e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.44193292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330245e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426975, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871765, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083606, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288867, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141594e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.4548787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.45680913, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.45868284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.4605025, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227065, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398965, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.46566173, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.46728903, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.46887353, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041708, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.47192144, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832602e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481915, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.4762155, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.47757873, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.4789101, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.4802108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.48148203, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.48272482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394018, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.4851291, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.4862924, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743096, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591661e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574529e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.489637, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070588, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.49175292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.49378392, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.49476904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573457, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464090e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.49668103, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.4976089, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.49851862, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.4994106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407408e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.50028527, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.5011429, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.24276878], dtype=float32), Array(0.501984, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636944], dtype=float32), Array(0.5028088, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995644], dtype=float32), Array(0.50361764, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353006], dtype=float32), Array(0.50441086, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.2570905], dtype=float32), Array(0.50518876, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.260638], dtype=float32), Array(0.5059516, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.26417276], dtype=float32), Array(0.50669956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293538e+00 | T: ((Array([0.26769498], dtype=float32), Array(0.507433, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120483], dtype=float32), Array(0.5081521, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470252], dtype=float32), Array(0.5088572, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.2781882], dtype=float32), Array(0.5095484, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248045e+00 | T: ((Array([0.28166205], dtype=float32), Array(0.510226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.28512418], dtype=float32), Array(0.5108901, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.28857478], dtype=float32), Array(0.511541, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.29201397], dtype=float32), Array(0.51217884, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.2954419], dtype=float32), Array(0.5128038, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.2954419], dtype=float32), Array(0.5128038, dtype=float32))
# 10.9 s ± 39.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # n-Sphere

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 10 #Change this for S2, S3, S5, S10, S20

# %%
M = nSphere(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*N)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/S'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/S'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/S'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/S'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")

# %%
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.001, max_iter=2000)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.736784e+01 | T: ((Array([-1.8853218e-10, -4.8455567e-10, -7.7671852e-10, -2.1932425e-09,
#        -2.2784818e-09,  2.0860778e-09,  2.6260532e-11, -2.7344151e-09,
#        -1.2368043e-08, -6.5753336e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421244,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 1 | T: 1.320977e+01 | T: ((Array([ 0.00807606,  0.00047359,  0.00916921,  0.0035954 ,  0.00805162,
#        -0.00837327, -0.00967944, -0.00809323,  0.00801484,  0.00445966],      dtype=float32), Array(0.21991752, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421244,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Final 1 | T: 1.320977e+01 | T: (Array([ 0.00807606,  0.00047359,  0.00916921,  0.0035954 ,  0.00805162,
#        -0.00837327, -0.00967944, -0.00809323,  0.00801484,  0.00445966],      dtype=float32), Array(0.21991752, dtype=float32))
# Step 0 | T: 1.736715e+01 | T: ((Array([-1.8853218e-10, -4.8455567e-10, -7.7671852e-10, -2.1932425e-09,
#        -2.2784818e-09,  2.0860778e-09,  8.1238016e-11, -2.7344151e-09,
#        -1.2368043e-08, -6.5753336e-09], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 1 | T: 1.320416e+01 | T: ((Array([ 0.00807896,  0.00058059,  0.0091791 ,  0.00353269,  0.00804747,
#        -0.00837041, -0.00967139, -0.00810198,  0.00801492,  0.00444882],      dtype=float32), Array(0.21991728, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 2 | T: 1.126095e+01 | T: ((Array([ 0.01476704,  0.00427931,  0.01763009,  0.00366447,  0.01514144,
#        -0.01593404, -0.01826107, -0.01520597,  0.01495261,  0.01115168],      dtype=float32), Array(0.22970729, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 3 | T: 9.635538e+00 | T: ((Array([ 0.02008786,  0.0090124 ,  0.02514447,  0.0018576 ,  0.02152081,
#        -0.02287146, -0.0248003 , -0.02151496,  0.02100818,  0.01874361],      dtype=float32), Array(0.23933062, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 4 | T: 8.268813e+00 | T: ((Array([ 0.0239749 ,  0.01362425,  0.03147084, -0.00105049,  0.02725403,
#        -0.02921177, -0.02858475, -0.02707255,  0.02623445,  0.0267222 ],      dtype=float32), Array(0.24875368, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 5 | T: 7.131899e+00 | T: ((Array([ 0.02644658,  0.01730711,  0.03639618, -0.00449179,  0.03235993,
#        -0.0349509 , -0.02969728, -0.03188191,  0.03063741,  0.03481736],      dtype=float32), Array(0.25794965, dtype=float32)), Array([-0.03176528, -0.11440293,  0.05558807, -0.0720636 , -0.11384054,
#        -0.41389784,  0.36698964,  0.00421243,  0.29360557, -0.27199152,
#         0.7060211 ], dtype=float32))
# Step 6 | T: 6.164435e+00 | T: ((Array([-1.4023656e-09, -4.8501703e-10,  8.4388121e-11, -1.4829529e-09,
#        -8.6766363e-09,  4.8574522e-09,  3.3664072e-11,  4.8851221e-09,
#        -5.0945723e-09, -9.0266337e-09], dtype=float32), Array(0.2668965, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 7 | T: 5.243478e+00 | T: ((Array([ 0.00133937,  0.00272728,  0.00374602, -0.00372409,  0.00449597,
#        -0.00514351,  0.00020148, -0.00411577,  0.00364175,  0.00811129],      dtype=float32), Array(0.2755777, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 8 | T: 4.531785e+00 | T: ((Array([ 0.00276837,  0.00547277,  0.0075642 , -0.00727363,  0.00891454,
#        -0.01020775, -0.00024526, -0.00817792,  0.00722164,  0.01616339],      dtype=float32), Array(0.2839809, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 9 | T: 3.925209e+00 | T: ((Array([ 0.00418681,  0.00780189,  0.01122351, -0.01036931,  0.01317321,
#        -0.01510035, -0.00117546, -0.0120856 ,  0.01064452,  0.02403892],      dtype=float32), Array(0.29209748, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 10 | T: 3.407717e+00 | T: ((Array([ 0.00549278,  0.00936545,  0.01453405, -0.01278955,  0.0172081 ,
#        -0.0197464 , -0.00240292, -0.01575375,  0.01383015,  0.03163142],      dtype=float32), Array(0.299922, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 11 | T: 2.968585e+00 | T: ((Array([ 0.00662288,  0.01000725,  0.01734379, -0.0144132 ,  0.02096148,
#        -0.02407868, -0.00373963, -0.01910874,  0.01671795,  0.03884581],      dtype=float32), Array(0.30745202, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 12 | T: 2.594882e+00 | T: ((Array([ 0.00753457,  0.00974098,  0.01952828, -0.01518241,  0.02438988,
#        -0.02804087, -0.00503514, -0.02209423,  0.01924523,  0.04559592],      dtype=float32), Array(0.3146877, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 13 | T: 2.278191e+00 | T: ((Array([ 0.00818125,  0.00865746,  0.02103326, -0.01513315,  0.02745633,
#        -0.03159069, -0.00614017, -0.02466772,  0.02137191,  0.05180684],      dtype=float32), Array(0.3216312, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 14 | T: 2.001046e+00 | T: ((Array([ 0.00854233,  0.00698727,  0.02182878, -0.01435755,  0.03013046,
#        -0.03469523, -0.00694607, -0.02679213,  0.02307332,  0.05741446],      dtype=float32), Array(0.32828617, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 15 | T: 1.762347e+00 | T: ((Array([ 0.00861896,  0.0049421 ,  0.02193966, -0.0129818 ,  0.03239791,
#        -0.03733112, -0.00738131, -0.02845165,  0.02433598,  0.06236612],      dtype=float32), Array(0.33465767, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 16 | T: 1.557803e+00 | T: ((Array([ 0.00842778,  0.00281077,  0.02140269, -0.01115472,  0.03424678,
#        -0.03948157, -0.00742491, -0.02964095,  0.02516308,  0.06662387],      dtype=float32), Array(0.34075204, dtype=float32)), Array([-0.07797064, -0.06258246,  0.09545322,  0.00494467, -0.13251637,
#        -0.35091716,  0.29650685, -0.05243801,  0.22955331, -0.210812  ,
#         0.80768937], dtype=float32))
# Step 17 | T: 1.379640e+00 | T: ((Array([-8.4274010e-10,  2.7083837e-09,  1.4231993e-09, -3.4609933e-09,
#        -2.6594265e-09,  3.2632190e-09, -7.5701312e-10,  0.0000000e+00,
#         0.0000000e+00,  0.0000000e+00], dtype=float32), Array(0.3465764, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 18 | T: 1.123289e+00 | T: ((Array([-2.3337296e-04, -1.5770756e-03, -7.1051187e-04,  1.7978867e-03,
#         1.5802243e-03, -1.8320862e-03,  9.8102835e-05, -9.2957640e-04,
#         6.0585840e-04,  3.6516106e-03], dtype=float32), Array(0.3521386, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 19 | T: 9.812896e-01 | T: ((Array([-2.7946517e-04, -2.6217741e-03, -1.0455619e-03,  3.1630513e-03,
#         3.2689166e-03, -3.7784216e-03,  1.2434466e-06, -2.0149585e-03,
#         1.3764198e-03,  7.3426948e-03], dtype=float32), Array(0.35744685, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 20 | T: 8.563222e-01 | T: ((Array([-0.00015783, -0.00303434, -0.00103536,  0.00405131,  0.00501855,
#        -0.00578877, -0.00026195, -0.00320982,  0.00226945,  0.01100539],      dtype=float32), Array(0.3625098, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 21 | T: 7.429777e-01 | T: ((Array([ 0.00011656, -0.00282994, -0.00072147,  0.00443492,  0.00678963,
#        -0.00781962, -0.00065288, -0.00447349,  0.00324928,  0.0145808 ],      dtype=float32), Array(0.367336, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 22 | T: 6.446353e-01 | T: ((Array([ 0.00050195, -0.00210413, -0.00014638,  0.00434402,  0.00854467,
#        -0.00982606, -0.00111664, -0.00576334,  0.00427706,  0.01801092],      dtype=float32), Array(0.37193438, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 23 | T: 5.627375e-01 | T: ((Array([ 0.00097124, -0.00101295,  0.00062439,  0.00382577,  0.01024939,
#        -0.01177052, -0.00158846, -0.00704276,  0.00531596,  0.02124601],      dtype=float32), Array(0.37631404, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 24 | T: 4.863642e-01 | T: ((Array([ 0.00147965,  0.00025756,  0.00153751,  0.00295609,  0.01187316,
#        -0.01361746, -0.00202388, -0.00827731,  0.00633328,  0.02424484],      dtype=float32), Array(0.38048393, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 25 | T: 4.200930e-01 | T: ((Array([ 0.00198404,  0.00152645,  0.00252978,  0.00183469,  0.01338689,
#        -0.01533418, -0.00237915, -0.00943507,  0.00729921,  0.02696731],      dtype=float32), Array(0.38445288, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 26 | T: 3.620419e-01 | T: ((Array([ 0.00246142,  0.00262289,  0.00353636,  0.00056642,  0.01476904,
#        -0.01689744, -0.00260309, -0.01048727,  0.00818689,  0.02938534],      dtype=float32), Array(0.38822967, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 27 | T: 3.094923e-01 | T: ((Array([ 0.00288456,  0.00339233,  0.00449954, -0.0007373 ,  0.01599887,
#        -0.01828412, -0.00268668, -0.0114133 ,  0.00897302,  0.03147975],      dtype=float32), Array(0.3918229, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 28 | T: 2.653362e-01 | T: ((Array([ 0.00322845,  0.00375386,  0.00536557, -0.00197914,  0.01706578,
#        -0.01948029, -0.00263017, -0.01219512,  0.00964467,  0.03323334],      dtype=float32), Array(0.39524114, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 29 | T: 2.219990e-01 | T: ((Array([ 0.00348202,  0.00370913,  0.0060959 , -0.00305517,  0.01795872,
#        -0.02047433, -0.00243936, -0.01282629,  0.01018343,  0.03464042],      dtype=float32), Array(0.39849246, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 30 | T: 1.865838e-01 | T: ((Array([ 0.00363548,  0.00328359,  0.00665707, -0.00390898,  0.01867168,
#        -0.02126004, -0.00214091, -0.01329751,  0.0105879 ,  0.03569914],      dtype=float32), Array(0.40158495, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 31 | T: 1.578539e-01 | T: ((Array([ 0.00368476,  0.00254985,  0.00703405, -0.00448175,  0.01919793,
#        -0.02183439, -0.00179036, -0.01360863,  0.01085389,  0.03641367],      dtype=float32), Array(0.40452653, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 32 | T: 1.256460e-01 | T: ((Array([ 0.00363294,  0.00163461,  0.00721449, -0.00474881,  0.0195436 ,
#        -0.02220348, -0.00141563, -0.01376062,  0.01097882,  0.03679505],      dtype=float32), Array(0.40732458, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 33 | T: 1.012567e-01 | T: ((Array([ 0.00348422,  0.00068368,  0.00720221, -0.00472051,  0.01971098,
#        -0.02237114, -0.00106725, -0.01375944,  0.0109701 ,  0.03685925],      dtype=float32), Array(0.4099865, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 34 | T: 7.708543e-02 | T: ((Array([ 0.00325895, -0.00016702,  0.00700506, -0.00441847,  0.01970783,
#        -0.02234759, -0.00077144, -0.01361278,  0.0108375 ,  0.03662753],      dtype=float32), Array(0.41251922, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 35 | T: 5.505677e-02 | T: ((Array([ 0.00296932, -0.00080682,  0.00664966, -0.00388548,  0.01954918,
#        -0.02214808, -0.00055561, -0.01333601,  0.01059227,  0.03612525],      dtype=float32), Array(0.41492945, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 36 | T: 3.593082e-02 | T: ((Array([ 0.00265185, -0.00116281,  0.00617091, -0.00319268,  0.01924649,
#        -0.02178699, -0.00045073, -0.01294378,  0.01025217,  0.03538011],      dtype=float32), Array(0.41722363, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 37 | T: 1.598305e-02 | T: ((Array([ 0.00232514, -0.00120211,  0.00560756, -0.00240717,  0.01881563,
#        -0.02128272, -0.00044707, -0.01245352,  0.00982991,  0.03442091],      dtype=float32), Array(0.41940787, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 38 | T: -1.095043e-03 | T: ((Array([ 0.00201034, -0.00094318,  0.00498712, -0.00160121,  0.01827455,
#        -0.02065089, -0.0005496 , -0.01188553,  0.00934866,  0.0332817 ],      dtype=float32), Array(0.42148802, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 39 | T: -1.616275e-02 | T: ((Array([ 0.00172418, -0.00045854,  0.00435991, -0.00083202,  0.01764139,
#        -0.01991197, -0.0007187 , -0.0112606 ,  0.00881909,  0.03199376],      dtype=float32), Array(0.42346978, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 40 | T: -2.891750e-02 | T: ((Array([ 0.0014679 ,  0.00018279,  0.00375686, -0.00017163,  0.01693528,
#        -0.01909162, -0.0009316 , -0.0105973 ,  0.0082587 ,  0.03059084],      dtype=float32), Array(0.42535853, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 41 | T: -4.060308e-02 | T: ((Array([ 0.0012732 ,  0.0008561 ,  0.00320425,  0.00033525,  0.01617512,
#        -0.01820983, -0.00116883, -0.00991329,  0.00769134,  0.02910358],      dtype=float32), Array(0.4271593, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 42 | T: -5.288170e-02 | T: ((Array([ 0.00114554,  0.00146005,  0.00273254,  0.00065397,  0.01538143,
#        -0.01728591, -0.00138905, -0.00923234,  0.00713211,  0.02756576],      dtype=float32), Array(0.42887697, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 43 | T: -6.278218e-02 | T: ((Array([ 0.00107161,  0.00191522,  0.00236396,  0.00078355,  0.01456827,
#        -0.01634469, -0.00156474, -0.00857052,  0.00659271,  0.02600619],      dtype=float32), Array(0.43051606, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 44 | T: -7.058343e-02 | T: ((Array([ 0.0010558 ,  0.00215755,  0.00211167,  0.00071998,  0.01375301,
#        -0.01540619, -0.00169279, -0.0079425 ,  0.00608951,  0.02445481],      dtype=float32), Array(0.43208107, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 45 | T: -8.153146e-02 | T: ((Array([ 0.00109969,  0.00216914,  0.0019852 ,  0.00049059,  0.01295397,
#        -0.01448767, -0.0017594 , -0.00736456,  0.00563365,  0.02293842],      dtype=float32), Array(0.43357596, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 46 | T: -8.974273e-02 | T: ((Array([ 0.00119479,  0.00197778,  0.00198192,  0.00012298,  0.01218244,
#        -0.01360579, -0.00175383, -0.00684716,  0.00523977,  0.02148079],      dtype=float32), Array(0.4350046, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 47 | T: -9.752745e-02 | T: ((Array([ 0.00132696,  0.00163114,  0.00208474, -0.00032941,  0.01145099,
#        -0.01277434, -0.0016831 , -0.0064015 ,  0.00491289,  0.02010346],      dtype=float32), Array(0.43637064, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 48 | T: -1.037143e-01 | T: ((Array([ 0.00148005,  0.00120081,  0.00227327, -0.00081879,  0.01077484,
#        -0.01200933, -0.00155784, -0.00603233,  0.00465762,  0.01882483],      dtype=float32), Array(0.43767753, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 49 | T: -1.095038e-01 | T: ((Array([ 0.00163407,  0.0007577 ,  0.00252954, -0.00130714,  0.01016585,
#        -0.0113202 , -0.00139863, -0.00574651,  0.00447712,  0.01766125],      dtype=float32), Array(0.4389286, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 50 | T: -1.154516e-01 | T: ((Array([ 0.00178425,  0.00037999,  0.00282392, -0.0017364 ,  0.00962846,
#        -0.01071648, -0.00124121, -0.00554449,  0.00436776,  0.01662555],      dtype=float32), Array(0.44012693, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 51 | T: -1.194140e-01 | T: ((Array([ 0.0019194 ,  0.00011406,  0.00314633, -0.0020766 ,  0.0091669 ,
#        -0.01020329, -0.00109837, -0.00542409,  0.00432634,  0.01572715],      dtype=float32), Array(0.44127536, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 52 | T: -1.221796e-01 | T: ((Array([ 2.0325719e-03,  6.8098161e-06,  3.4724809e-03, -2.3043195e-03,
#         8.7839998e-03, -9.7825071e-03, -9.8675163e-04, -5.3806356e-03,
#         4.3508452e-03,  1.4972381e-02], dtype=float32), Array(0.4423768, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 53 | T: -1.278535e-01 | T: ((Array([ 2.1205929e-03,  6.6911853e-05,  3.7792341e-03, -2.4140868e-03,
#         8.4820641e-03, -9.4578518e-03, -9.1610744e-04, -5.4093185e-03,
#         4.4312677e-03,  1.4361480e-02], dtype=float32), Array(0.44343358, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 54 | T: -1.321246e-01 | T: ((Array([ 0.00217432,  0.00027683,  0.00404087, -0.00239645,  0.00826261,
#        -0.00922532, -0.00089581, -0.00550136,  0.00456251,  0.01389667],      dtype=float32), Array(0.44444817, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 55 | T: -1.359244e-01 | T: ((Array([ 0.00219429,  0.00059507,  0.00425054, -0.00226212,  0.00811915,
#        -0.00908265, -0.00091216, -0.00564547,  0.00473227,  0.0135727 ],      dtype=float32), Array(0.44542274, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 56 | T: -1.400611e-01 | T: ((Array([ 0.00218799,  0.00092368,  0.00439383, -0.00204222,  0.00804914,
#        -0.00902465, -0.00097619, -0.00583477,  0.00493212,  0.01338186],      dtype=float32), Array(0.4463594, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 57 | T: -1.431462e-01 | T: ((Array([ 0.00214948,  0.00120336,  0.00446053, -0.0017656 ,  0.00804613,
#        -0.00904146, -0.00108542, -0.00605375,  0.00515087,  0.01331256],      dtype=float32), Array(0.44726008, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 58 | T: -1.432647e-01 | T: ((Array([ 0.00208378,  0.00139607,  0.00446197, -0.00145045,  0.00810476,
#        -0.00912543, -0.00120594, -0.00629131,  0.00537355,  0.01335877],      dtype=float32), Array(0.44812682, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 59 | T: -1.484381e-01 | T: ((Array([ 0.00200433,  0.00146108,  0.00439284, -0.00112938,  0.00821688,
#        -0.00926886, -0.00131185, -0.00654004,  0.00559162,  0.01350829],      dtype=float32), Array(0.44896123, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 60 | T: -1.509447e-01 | T: ((Array([ 0.00191581,  0.00142164,  0.00426626, -0.00084951,  0.0083783 ,
#        -0.00946081, -0.00139431, -0.00679195,  0.00579804,  0.01374793],      dtype=float32), Array(0.44976497, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 61 | T: -1.542636e-01 | T: ((Array([ 0.00182729,  0.00128237,  0.00408876, -0.00063332,  0.00857594,
#        -0.00969267, -0.00144286, -0.00703412,  0.00598713,  0.0140618 ],      dtype=float32), Array(0.45053953, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 62 | T: -1.551739e-01 | T: ((Array([ 0.00174756,  0.00106469,  0.00389043, -0.00050174,  0.00880346,
#        -0.00995373, -0.00144306, -0.00726051,  0.00615429,  0.0144352 ],      dtype=float32), Array(0.45128644, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 63 | T: -1.579558e-01 | T: ((Array([ 0.00167072,  0.00081329,  0.00368333, -0.00046029,  0.0090476 ,
#        -0.01023544, -0.00140544, -0.00746341,  0.00629356,  0.01485295],      dtype=float32), Array(0.45200697, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 64 | T: -1.602607e-01 | T: ((Array([ 0.00161039,  0.00058842,  0.00347042, -0.00049461,  0.00930348,
#        -0.01052537, -0.0013379 , -0.00763919,  0.00640162,  0.01530063],      dtype=float32), Array(0.45270237, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 65 | T: -1.625960e-01 | T: ((Array([ 0.00156525,  0.00043372,  0.00327457, -0.00059643,  0.00955931,
#        -0.01081434, -0.00125847, -0.00778151,  0.00647627,  0.0157647 ],      dtype=float32), Array(0.45337376, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 66 | T: -1.639300e-01 | T: ((Array([ 0.00153691,  0.00038659,  0.00311012, -0.00076509,  0.009806  ,
#        -0.01109491, -0.00117906, -0.00789184,  0.00651155,  0.01623168],      dtype=float32), Array(0.45402235, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 67 | T: -1.649324e-01 | T: ((Array([ 0.00151198,  0.00043058,  0.00298242, -0.00096317,  0.01004186,
#        -0.01136168, -0.00110024, -0.00796512,  0.00651015,  0.01668834],      dtype=float32), Array(0.4546492, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 68 | T: -1.644849e-01 | T: ((Array([ 0.00150632,  0.00055889,  0.00289648, -0.00115602,  0.01025855,
#        -0.01160554, -0.00105077, -0.00799979,  0.00647561,  0.01712077],      dtype=float32), Array(0.45525542, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 69 | T: -1.665331e-01 | T: ((Array([ 0.00152065,  0.00072339,  0.00285819, -0.00132388,  0.01045279,
#        -0.01181985, -0.00102771, -0.00799863,  0.00641229,  0.01752281],      dtype=float32), Array(0.4558419, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 70 | T: -1.691642e-01 | T: ((Array([ 0.00154941,  0.00088986,  0.00286019, -0.00145143,  0.01062105,
#        -0.01200406, -0.00101877, -0.00796152,  0.00632911,  0.01788796],      dtype=float32), Array(0.45640948, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 71 | T: -1.711615e-01 | T: ((Array([ 0.00159024,  0.00103541,  0.00289243, -0.00152847,  0.0107594 ,
#        -0.01215694, -0.00104193, -0.00789441,  0.00622659,  0.01820829],      dtype=float32), Array(0.45695892, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 72 | T: -1.722479e-01 | T: ((Array([ 0.00163931,  0.00110256,  0.00296574, -0.0015633 ,  0.0108643 ,
#        -0.01227403, -0.00107661, -0.00779874,  0.00611197,  0.0184783 ],      dtype=float32), Array(0.45749104, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 73 | T: -1.742872e-01 | T: ((Array([ 0.00168326,  0.00110222,  0.00305827, -0.00155557,  0.01093866,
#        -0.01235427, -0.00110705, -0.00768343,  0.00598805,  0.01869459],      dtype=float32), Array(0.4580066, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 74 | T: -1.736116e-01 | T: ((Array([ 0.0017263 ,  0.00105837,  0.00316709, -0.0014951 ,  0.01097971,
#        -0.01239794, -0.00114583, -0.00755149,  0.00585669,  0.01885529],      dtype=float32), Array(0.45850632, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 75 | T: -1.749257e-01 | T: ((Array([ 0.00175503,  0.00097266,  0.00327858, -0.00138939,  0.01099081,
#        -0.01240575, -0.00118172, -0.00740736,  0.00572922,  0.01896139],      dtype=float32), Array(0.4589909, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 76 | T: -1.768684e-01 | T: ((Array([ 0.00177278,  0.00086539,  0.0033854 , -0.00126105,  0.01097531,
#        -0.01238067, -0.00120991, -0.00726008,  0.00560455,  0.01901911],      dtype=float32), Array(0.45946094, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 77 | T: -1.771325e-01 | T: ((Array([ 0.00177894,  0.00074834,  0.003485  , -0.00112727,  0.01093373,
#        -0.01232621, -0.00121545, -0.00711746,  0.00549215,  0.01902625],      dtype=float32), Array(0.45991698, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 78 | T: -1.786291e-01 | T: ((Array([ 0.0017735 ,  0.00066904,  0.00356277, -0.00099073,  0.01086994,
#        -0.01224247, -0.0012101 , -0.0069837 ,  0.00539747,  0.01898311],      dtype=float32), Array(0.46035963, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 79 | T: -1.778921e-01 | T: ((Array([ 0.00176214,  0.00064331,  0.00361513, -0.00088823,  0.01078728,
#        -0.01213515, -0.0011965 , -0.00686174,  0.00531749,  0.01889655],      dtype=float32), Array(0.46078947, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 80 | T: -1.792891e-01 | T: ((Array([ 0.00174885,  0.00065732,  0.0036434 , -0.00082191,  0.0106867 ,
#        -0.01201126, -0.00116619, -0.00674893,  0.00525782,  0.01877519],      dtype=float32), Array(0.46120697, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 81 | T: -1.824804e-01 | T: ((Array([ 0.00173273,  0.00068277,  0.00363728, -0.00080037,  0.01057731,
#        -0.01187366, -0.00113599, -0.00665773,  0.00521836,  0.0186204 ],      dtype=float32), Array(0.46161246, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 82 | T: -1.818684e-01 | T: ((Array([ 0.00171433,  0.00069847,  0.00360859, -0.00081435,  0.01046132,
#        -0.01172735, -0.00110725, -0.00658441,  0.00519978,  0.01844019],      dtype=float32), Array(0.46200648, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 83 | T: -1.812759e-01 | T: ((Array([ 0.00168936,  0.00073438,  0.0035578 , -0.00085964,  0.01033954,
#        -0.01157865, -0.00108444, -0.0065278 ,  0.00519718,  0.01823908],      dtype=float32), Array(0.46238953, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 84 | T: -1.802121e-01 | T: ((Array([ 0.00166341,  0.00079357,  0.00348927, -0.00093188,  0.01021744,
#        -0.01142854, -0.00106203, -0.00648938,  0.00521371,  0.01802594],      dtype=float32), Array(0.46276215, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 85 | T: -1.827871e-01 | T: ((Array([ 0.00162836,  0.00085488,  0.00341177, -0.00103713,  0.01009654,
#        -0.01128507, -0.00105913, -0.00646522,  0.00524415,  0.01780535],      dtype=float32), Array(0.46312457, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 86 | T: -1.836346e-01 | T: ((Array([ 0.00160427,  0.00091169,  0.00333168, -0.00113797,  0.00997938,
#        -0.01114905, -0.00106079, -0.00645533,  0.00528495,  0.01758113],      dtype=float32), Array(0.46347713, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 87 | T: -1.856004e-01 | T: ((Array([ 0.00158943,  0.00094819,  0.00325983, -0.00121455,  0.00986784,
#        -0.01102205, -0.00108342, -0.00646595,  0.00533029,  0.017362  ],      dtype=float32), Array(0.46382016, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 88 | T: -1.852828e-01 | T: ((Array([ 0.00157439,  0.00095536,  0.00319904, -0.00126549,  0.00976451,
#        -0.01091144, -0.00112073, -0.00649175,  0.00537812,  0.01714943],      dtype=float32), Array(0.46415398, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 89 | T: -1.857138e-01 | T: ((Array([ 0.00157958,  0.00095246,  0.00315209, -0.0012978 ,  0.00967168,
#        -0.01081718, -0.00115552, -0.00653144,  0.00542632,  0.01695069],      dtype=float32), Array(0.46447885, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 90 | T: -1.854225e-01 | T: ((Array([ 0.00158034,  0.00093033,  0.00311196, -0.00130301,  0.0095934 ,
#        -0.01074012, -0.00120616, -0.00658361,  0.00546969,  0.01676879],      dtype=float32), Array(0.4647952, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 91 | T: -1.865791e-01 | T: ((Array([ 0.00158522,  0.00089388,  0.00309213, -0.00127955,  0.00953168,
#        -0.01068034, -0.00123205, -0.00664157,  0.00551218,  0.01660489],      dtype=float32), Array(0.46510324, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 92 | T: -1.865415e-01 | T: ((Array([ 0.00159054,  0.00084332,  0.00309737, -0.00121897,  0.00948633,
#        -0.01063808, -0.00122259, -0.00669454,  0.00555003,  0.01646261],      dtype=float32), Array(0.46540326, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 93 | T: -1.869130e-01 | T: ((Array([ 0.00159688,  0.0008149 ,  0.0031157 , -0.00115332,  0.00945746,
#        -0.01061246, -0.00119185, -0.00674979,  0.0055795 ,  0.01634418],      dtype=float32), Array(0.46569547, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 94 | T: -1.887388e-01 | T: ((Array([ 0.0016028 ,  0.0008073 ,  0.00313417, -0.0010847 ,  0.00943947,
#        -0.01059868, -0.00114585, -0.00680369,  0.00560032,  0.01624925],      dtype=float32), Array(0.46598008, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 95 | T: -1.883326e-01 | T: ((Array([ 0.00161423,  0.00079483,  0.00316285, -0.00102332,  0.00943446,
#        -0.01059957, -0.00111221, -0.00685165,  0.00561066,  0.01618122],      dtype=float32), Array(0.4662574, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 96 | T: -1.891468e-01 | T: ((Array([ 0.00162639,  0.0008044 ,  0.00319434, -0.00097375,  0.00944063,
#        -0.01061143, -0.00108462, -0.00688978,  0.00561366,  0.01613911],      dtype=float32), Array(0.46652752, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 97 | T: -1.884199e-01 | T: ((Array([ 0.00164679,  0.00083494,  0.00322087, -0.00094598,  0.00945664,
#        -0.01063371, -0.00106505, -0.00692298,  0.00560271,  0.01611987],      dtype=float32), Array(0.4667908, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 98 | T: -1.891500e-01 | T: ((Array([ 0.00165568,  0.00084845,  0.00324408, -0.00093456,  0.0094803 ,
#        -0.01066479, -0.00105277, -0.00694533,  0.00558333,  0.01612177],      dtype=float32), Array(0.46704742, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Step 99 | T: -1.900799e-01 | T: ((Array([ 0.00165164,  0.00086207,  0.00327226, -0.00095097,  0.0095118 ,
#        -0.01070061, -0.00105413, -0.00695671,  0.00556173,  0.01614086],      dtype=float32), Array(0.46729746, dtype=float32)), Array([-0.03514728, -0.04309447,  0.09156618,  0.04486958, -0.14268303,
#        -0.2598482 ,  0.1977699 , -0.06345535,  0.15606503, -0.14791659,
#         0.89958596], dtype=float32))
# Final 99 | T: -1.900799e-01 | T: (Array([ 0.00165164,  0.00086207,  0.00327226, -0.00095097,  0.0095118 ,
#        -0.01070061, -0.00105413, -0.00695671,  0.00556173,  0.01614086],      dtype=float32), Array(0.46729746, dtype=float32))

# %%
#diffusion_mean.initialize(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t)[0], s2_model = lambda x,y,t: jacfwdx(lambda y: M.grady_log_hk(x,y,t)[0])(y), method="Gradient")
diffusion_mean(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t)[0], s2_model = M.gradt_log_hk, method="Gradient")
mu_opt, T_opt, _, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.2726 0.1346 0.9522 )
# T = 0.5180

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_176384/3061874042.py in <module>
#       1 print(f"Bridge Riemannian Diffusion Mean:")
# ----> 2 print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
#       3 print(f"T = {T_bridge[-1]:.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[1][-1]), ")")
print(f"T = {T_opt[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.1972 0.2795 -0.1738 -0.0545 -0.0874 -0.0610 0.1865 -0.3275 -0.1058 -0.1143 -0.4021 -0.0457 -0.2569 0.1579 0.1958 0.3779 -0.3512 0.1565 0.0370 0.2950 0.0085 )
# T = 0.4078

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_176384/1057633312.py in <module>
#       1 print("The difference between the score and bridge:")
# ----> 2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.02509
#  -T error = 0.0400
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/4208814940.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.4f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
T_sm[-1]
# Out:
# Array([0.34654832], dtype=float32)

# %%
# %timeit mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.1, max_iter=100)
# Out:
# 809 ms ± 4.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)
# Out:
# Step 0 | T: 9.623056e+00 | T: ((Array([-2.6668883e-09, -0.0000000e+00], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 1 | T: 8.450203e+00 | T: ((Array([ 0.00898598, -0.00248003], dtype=float32), Array(0.21992323, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 2 | T: 7.512320e+00 | T: ((Array([ 0.01740269, -0.00782265], dtype=float32), Array(0.22973019, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 3 | T: 6.700606e+00 | T: ((Array([ 0.02530241, -0.01437789], dtype=float32), Array(0.23938473, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 4 | T: 6.004924e+00 | T: ((Array([ 0.03266557, -0.02153107], dtype=float32), Array(0.24885654, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 5 | T: 5.410668e+00 | T: ((Array([ 0.03945813, -0.02896928], dtype=float32), Array(0.2581212, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 6 | T: 4.902855e+00 | T: ((Array([ 0.04564824, -0.03650007], dtype=float32), Array(0.26715967, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 7 | T: 4.466645e+00 | T: ((Array([ 0.0512125 , -0.04399235], dtype=float32), Array(0.27595767, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 8 | T: 4.091812e+00 | T: ((Array([ 0.05613925, -0.05134904], dtype=float32), Array(0.28450507, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 9 | T: 3.769066e+00 | T: ((Array([ 0.06042882, -0.05849446], dtype=float32), Array(0.29279536, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 10 | T: 3.489559e+00 | T: ((Array([ 0.06409127, -0.06536949], dtype=float32), Array(0.3008249, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 11 | T: 3.246536e+00 | T: ((Array([ 0.06714577, -0.07192671], dtype=float32), Array(0.30859265, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 12 | T: 3.034719e+00 | T: ((Array([4.8320753e-10, 3.7182617e-09], dtype=float32), Array(0.31609952, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 13 | T: 2.812186e+00 | T: ((Array([ 0.00267916, -0.00573474], dtype=float32), Array(0.32334673, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 14 | T: 2.645648e+00 | T: ((Array([ 0.00549177, -0.0109946 ], dtype=float32), Array(0.33033827, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 15 | T: 2.499379e+00 | T: ((Array([ 0.00837784, -0.01577824], dtype=float32), Array(0.3370794, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 16 | T: 2.367999e+00 | T: ((Array([ 0.01128581, -0.0200886 ], dtype=float32), Array(0.34357598, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 17 | T: 2.253002e+00 | T: ((Array([ 0.01416983, -0.0239342 ], dtype=float32), Array(0.34983474, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 18 | T: 2.148348e+00 | T: ((Array([ 0.01699278, -0.02732618], dtype=float32), Array(0.35586274, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 19 | T: 2.055281e+00 | T: ((Array([ 0.01972118, -0.03027857], dtype=float32), Array(0.36166745, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 20 | T: 1.971079e+00 | T: ((Array([ 0.02232808, -0.03280865], dtype=float32), Array(0.36725658, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 21 | T: 1.895103e+00 | T: ((Array([ 0.02479108, -0.03493647], dtype=float32), Array(0.37263796, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 22 | T: 1.826189e+00 | T: ((Array([ 0.02709256, -0.03668365], dtype=float32), Array(0.37781948, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 23 | T: 1.763664e+00 | T: ((Array([ 0.0292182, -0.0380719], dtype=float32), Array(0.3828091, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 24 | T: 1.705763e+00 | T: ((Array([ 0.0311575, -0.0391239], dtype=float32), Array(0.38761458, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 25 | T: 1.653217e+00 | T: ((Array([ 0.03290429, -0.03986397], dtype=float32), Array(0.39224365, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 26 | T: 1.605675e+00 | T: ((Array([ 0.03445488, -0.04031523], dtype=float32), Array(0.3967041, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 27 | T: 1.559619e+00 | T: ((Array([ 0.0358072 , -0.04050096], dtype=float32), Array(0.40100324, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 28 | T: 1.519739e+00 | T: ((Array([ 0.03696303, -0.04044469], dtype=float32), Array(0.40514845, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 29 | T: 1.481344e+00 | T: ((Array([ 0.03792696, -0.04017022], dtype=float32), Array(0.40914676, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 30 | T: 1.446062e+00 | T: ((Array([ 0.03870373, -0.03969987], dtype=float32), Array(0.41300502, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 31 | T: 1.412914e+00 | T: ((Array([ 0.03930011, -0.03905595], dtype=float32), Array(0.4167298, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 32 | T: 1.382394e+00 | T: ((Array([ 0.03972538, -0.03825961], dtype=float32), Array(0.42032754, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 33 | T: 1.353442e+00 | T: ((Array([ 0.03998893, -0.03733055], dtype=float32), Array(0.42380434, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 34 | T: 1.326411e+00 | T: ((Array([ 0.04010111, -0.03628861], dtype=float32), Array(0.42716607, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 35 | T: 1.300748e+00 | T: ((Array([ 0.04007302, -0.03515216], dtype=float32), Array(0.43041834, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 36 | T: 1.277452e+00 | T: ((Array([ 0.03991739, -0.03393828], dtype=float32), Array(0.43356657, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 37 | T: 1.254399e+00 | T: ((Array([ 0.03964698, -0.03266277], dtype=float32), Array(0.4366159, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 38 | T: 1.233503e+00 | T: ((Array([ 0.03927362, -0.03134173], dtype=float32), Array(0.4395713, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 39 | T: 1.213566e+00 | T: ((Array([ 0.03880955, -0.02998964], dtype=float32), Array(0.4424374, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 40 | T: 1.194888e+00 | T: ((Array([ 0.03826674, -0.02861835], dtype=float32), Array(0.44521877, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 41 | T: 1.177300e+00 | T: ((Array([ 0.03765827, -0.02724031], dtype=float32), Array(0.44791967, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 42 | T: 1.160664e+00 | T: ((Array([ 0.0369949 , -0.02586726], dtype=float32), Array(0.45054418, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 43 | T: 1.144747e+00 | T: ((Array([ 0.03628872, -0.02450845], dtype=float32), Array(0.4530961, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 44 | T: 1.129774e+00 | T: ((Array([ 0.03554997, -0.02317289], dtype=float32), Array(0.45557913, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 45 | T: 1.116190e+00 | T: ((Array([ 0.0347895 , -0.02186955], dtype=float32), Array(0.45799682, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 46 | T: 1.102494e+00 | T: ((Array([ 0.03401711, -0.02060514], dtype=float32), Array(0.46035245, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 47 | T: 1.090112e+00 | T: ((Array([ 0.0332413 , -0.01938567], dtype=float32), Array(0.46264914, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 48 | T: 1.077800e+00 | T: ((Array([ 0.03247004, -0.01821732], dtype=float32), Array(0.46488982, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 49 | T: 1.066390e+00 | T: ((Array([ 0.03171114, -0.01710337], dtype=float32), Array(0.46707729, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 50 | T: 1.055194e+00 | T: ((Array([ 0.03097202, -0.0160487 ], dtype=float32), Array(0.46921417, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 51 | T: 1.044781e+00 | T: ((Array([ 0.03025797, -0.01505514], dtype=float32), Array(0.471303, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 52 | T: 1.035101e+00 | T: ((Array([ 0.029574  , -0.01412417], dtype=float32), Array(0.47334608, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 53 | T: 1.025856e+00 | T: ((Array([ 0.02892423, -0.01325811], dtype=float32), Array(0.47534573, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 54 | T: 1.016557e+00 | T: ((Array([ 0.02831219, -0.0124576 ], dtype=float32), Array(0.47730398, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 55 | T: 1.007687e+00 | T: ((Array([ 0.02774085, -0.0117229 ], dtype=float32), Array(0.47922277, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 56 | T: 9.998270e-01 | T: ((Array([ 0.0272122 , -0.01105353], dtype=float32), Array(0.48110402, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 57 | T: 9.913591e-01 | T: ((Array([ 0.02672795, -0.01044882], dtype=float32), Array(0.4829494, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 58 | T: 9.838018e-01 | T: ((Array([ 0.02628888, -0.00990767], dtype=float32), Array(0.48476058, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 59 | T: 9.762996e-01 | T: ((Array([ 0.0258959 , -0.00942835], dtype=float32), Array(0.4865391, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 60 | T: 9.699023e-01 | T: ((Array([ 0.02554855, -0.00901005], dtype=float32), Array(0.4882865, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 61 | T: 9.623066e-01 | T: ((Array([ 0.02524635, -0.00864958], dtype=float32), Array(0.49000403, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 62 | T: 9.562947e-01 | T: ((Array([ 0.02498724, -0.0083437 ], dtype=float32), Array(0.49169305, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 63 | T: 9.497731e-01 | T: ((Array([ 0.02477099, -0.00809102], dtype=float32), Array(0.49335474, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 64 | T: 9.432250e-01 | T: ((Array([ 0.02459475, -0.00788792], dtype=float32), Array(0.49499017, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 65 | T: 9.371684e-01 | T: ((Array([ 0.02445713, -0.00773235], dtype=float32), Array(0.4966004, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 66 | T: 9.318779e-01 | T: ((Array([ 0.02435665, -0.00762032], dtype=float32), Array(0.49818647, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 67 | T: 9.259169e-01 | T: ((Array([ 0.02428872, -0.00754859], dtype=float32), Array(0.49974927, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 68 | T: 9.207840e-01 | T: ((Array([ 0.02425101, -0.00751401], dtype=float32), Array(0.5012897, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 69 | T: 9.149882e-01 | T: ((Array([ 0.02424062, -0.00751339], dtype=float32), Array(0.50280863, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 70 | T: 9.102252e-01 | T: ((Array([ 0.02425599, -0.00754404], dtype=float32), Array(0.5043068, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 71 | T: 9.053533e-01 | T: ((Array([ 0.02429385, -0.00760307], dtype=float32), Array(0.5057849, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 72 | T: 9.005165e-01 | T: ((Array([ 0.02434952, -0.00768644], dtype=float32), Array(0.50724375, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 73 | T: 8.957934e-01 | T: ((Array([ 0.0244218 , -0.00779121], dtype=float32), Array(0.50868386, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 74 | T: 8.913195e-01 | T: ((Array([ 0.02450717, -0.00791462], dtype=float32), Array(0.5101059, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 75 | T: 8.869214e-01 | T: ((Array([ 0.02460361, -0.00805376], dtype=float32), Array(0.51151043, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 76 | T: 8.822645e-01 | T: ((Array([ 0.02470768, -0.00820613], dtype=float32), Array(0.51289797, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 77 | T: 8.778980e-01 | T: ((Array([ 0.02481814, -0.00836792], dtype=float32), Array(0.51426893, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 78 | T: 8.738002e-01 | T: ((Array([ 0.02493338, -0.0085382 ], dtype=float32), Array(0.51562387, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 79 | T: 8.707456e-01 | T: ((Array([ 0.02505081, -0.0087141 ], dtype=float32), Array(0.5169633, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 80 | T: 8.664480e-01 | T: ((Array([ 0.02516795, -0.00889385], dtype=float32), Array(0.5182876, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 81 | T: 8.625988e-01 | T: ((Array([ 0.02528355, -0.00907557], dtype=float32), Array(0.5195972, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 82 | T: 8.587515e-01 | T: ((Array([ 0.02539538, -0.00925771], dtype=float32), Array(0.5208924, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 83 | T: 8.554252e-01 | T: ((Array([ 0.02550151, -0.00943831], dtype=float32), Array(0.52217364, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 84 | T: 8.515056e-01 | T: ((Array([ 0.02560124, -0.00961499], dtype=float32), Array(0.52344126, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 85 | T: 8.483146e-01 | T: ((Array([ 0.02569423, -0.00978647], dtype=float32), Array(0.5246956, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 86 | T: 8.449581e-01 | T: ((Array([ 0.02577902, -0.0099523 ], dtype=float32), Array(0.52593684, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 87 | T: 8.418765e-01 | T: ((Array([ 0.0258552 , -0.01011075], dtype=float32), Array(0.5271654, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 88 | T: 8.385633e-01 | T: ((Array([ 0.02592112, -0.01026115], dtype=float32), Array(0.5283816, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 89 | T: 8.353954e-01 | T: ((Array([ 0.02597624, -0.01040381], dtype=float32), Array(0.52958554, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 90 | T: 8.320614e-01 | T: ((Array([ 0.02602257, -0.01053702], dtype=float32), Array(0.5307776, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 91 | T: 8.294687e-01 | T: ((Array([ 0.02605921, -0.01066103], dtype=float32), Array(0.5319579, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 92 | T: 8.265152e-01 | T: ((Array([ 0.02608633, -0.01077524], dtype=float32), Array(0.53312683, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 93 | T: 8.237979e-01 | T: ((Array([ 0.02610396, -0.01087986], dtype=float32), Array(0.53428453, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 94 | T: 8.205805e-01 | T: ((Array([ 0.02611415, -0.01097526], dtype=float32), Array(0.5354312, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 95 | T: 8.186433e-01 | T: ((Array([ 0.0261159 , -0.01106048], dtype=float32), Array(0.53656715, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 96 | T: 8.158538e-01 | T: ((Array([ 0.02610912, -0.01113592], dtype=float32), Array(0.53769255, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 97 | T: 8.130861e-01 | T: ((Array([ 0.02609461, -0.01120172], dtype=float32), Array(0.5388075, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 98 | T: 8.103067e-01 | T: ((Array([ 0.02607221, -0.0112569 ], dtype=float32), Array(0.5399122, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Step 99 | T: 8.080032e-01 | T: ((Array([ 0.0260429 , -0.01130331], dtype=float32), Array(0.5410068, dtype=float32)), Array([-0.03537175,  0.07209431,  0.9966754 ], dtype=float32))
# Final 99 | T: 8.080032e-01 | T: (Array([ 0.0260429 , -0.01130331], dtype=float32), Array(0.5410068, dtype=float32))
# Step 0 | T: 9.622461e+00 | T: ((Array([-2.6668883e-09, -0.0000000e+00], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 1 | T: 8.449865e+00 | T: ((Array([ 0.00898834, -0.00248281], dtype=float32), Array(0.21992323, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 2 | T: 7.514197e+00 | T: ((Array([ 0.01740654, -0.00782688], dtype=float32), Array(0.22973043, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 3 | T: 6.699698e+00 | T: ((Array([ 0.02530766, -0.01438259], dtype=float32), Array(0.23938505, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 4 | T: 6.003155e+00 | T: ((Array([ 0.03267257, -0.02153582], dtype=float32), Array(0.24885671, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 5 | T: 5.410193e+00 | T: ((Array([ 0.03946598, -0.02897292], dtype=float32), Array(0.25812113, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 6 | T: 4.902257e+00 | T: ((Array([ 0.04565666, -0.036503  ], dtype=float32), Array(0.2671594, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 7 | T: 4.465929e+00 | T: ((Array([ 0.05122204, -0.04399501], dtype=float32), Array(0.27595723, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 8 | T: 4.093393e+00 | T: ((Array([ 0.05614917, -0.05135124], dtype=float32), Array(0.28450468, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 9 | T: 3.770090e+00 | T: ((Array([ 0.0604373 , -0.05849576], dtype=float32), Array(0.29279515, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 10 | T: 3.489941e+00 | T: ((Array([ 0.06409767, -0.06536929], dtype=float32), Array(0.30082485, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 11 | T: 3.247520e+00 | T: ((Array([ 0.06714977, -0.07192522], dtype=float32), Array(0.30859286, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 12 | T: 3.034139e+00 | T: ((Array([1.3526247e-10, 0.0000000e+00], dtype=float32), Array(0.31609985, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 13 | T: 2.812361e+00 | T: ((Array([ 0.00267669, -0.00573346], dtype=float32), Array(0.32334718, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 14 | T: 2.645430e+00 | T: ((Array([ 0.00548775, -0.0109921 ], dtype=float32), Array(0.33033878, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 15 | T: 2.498464e+00 | T: ((Array([ 0.00837295, -0.01577471], dtype=float32), Array(0.33707985, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 16 | T: 2.368733e+00 | T: ((Array([ 0.0112801 , -0.02008422], dtype=float32), Array(0.3435765, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 17 | T: 2.252447e+00 | T: ((Array([ 0.014164  , -0.02392843], dtype=float32), Array(0.34983528, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 18 | T: 2.148210e+00 | T: ((Array([ 0.01698593, -0.02731905], dtype=float32), Array(0.35586327, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 19 | T: 2.054783e+00 | T: ((Array([ 0.01971415, -0.03027103], dtype=float32), Array(0.36166793, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 20 | T: 1.970765e+00 | T: ((Array([ 0.02232088, -0.03280098], dtype=float32), Array(0.36725694, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 21 | T: 1.894742e+00 | T: ((Array([ 0.02478427, -0.03492821], dtype=float32), Array(0.3726381, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 22 | T: 1.825872e+00 | T: ((Array([ 0.027086 , -0.0366739], dtype=float32), Array(0.37781942, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 23 | T: 1.763635e+00 | T: ((Array([ 0.02921189, -0.03806029], dtype=float32), Array(0.38280883, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 24 | T: 1.706321e+00 | T: ((Array([ 0.03115184, -0.03911079], dtype=float32), Array(0.38761422, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 25 | T: 1.653780e+00 | T: ((Array([ 0.03289874, -0.03984913], dtype=float32), Array(0.39224333, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 26 | T: 1.605136e+00 | T: ((Array([ 0.03444931, -0.04029902], dtype=float32), Array(0.39670372, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 27 | T: 1.560869e+00 | T: ((Array([ 0.03580211, -0.04048407], dtype=float32), Array(0.4010029, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 28 | T: 1.519446e+00 | T: ((Array([ 0.03695783, -0.04042707], dtype=float32), Array(0.40514815, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 29 | T: 1.481265e+00 | T: ((Array([ 0.03792089, -0.04015193], dtype=float32), Array(0.40914646, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 30 | T: 1.445501e+00 | T: ((Array([ 0.03869699, -0.03968188], dtype=float32), Array(0.41300467, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 31 | T: 1.413031e+00 | T: ((Array([ 0.03929302, -0.03903753], dtype=float32), Array(0.41672942, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 32 | T: 1.382141e+00 | T: ((Array([ 0.03971827, -0.03824046], dtype=float32), Array(0.42032707, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 33 | T: 1.352572e+00 | T: ((Array([ 0.03998129, -0.03731141], dtype=float32), Array(0.4238037, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 34 | T: 1.326191e+00 | T: ((Array([ 0.04009372, -0.0362692 ], dtype=float32), Array(0.42716527, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 35 | T: 1.300829e+00 | T: ((Array([ 0.04006654, -0.03513306], dtype=float32), Array(0.43041742, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 36 | T: 1.277012e+00 | T: ((Array([ 0.03991122, -0.03391847], dtype=float32), Array(0.43356553, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 37 | T: 1.254628e+00 | T: ((Array([ 0.03964078, -0.03264289], dtype=float32), Array(0.43661472, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 38 | T: 1.233791e+00 | T: ((Array([ 0.0392677 , -0.03132197], dtype=float32), Array(0.43957004, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 39 | T: 1.213595e+00 | T: ((Array([ 0.03880397, -0.02997015], dtype=float32), Array(0.44243607, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 40 | T: 1.194900e+00 | T: ((Array([ 0.03826179, -0.02859994], dtype=float32), Array(0.44521737, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 41 | T: 1.177272e+00 | T: ((Array([ 0.03765429, -0.02722478], dtype=float32), Array(0.4479182, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 42 | T: 1.160939e+00 | T: ((Array([ 0.03699174, -0.02585389], dtype=float32), Array(0.45054266, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 43 | T: 1.144590e+00 | T: ((Array([ 0.03628691, -0.02449783], dtype=float32), Array(0.45309454, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 44 | T: 1.130074e+00 | T: ((Array([ 0.03554954, -0.02316511], dtype=float32), Array(0.45557758, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 45 | T: 1.115644e+00 | T: ((Array([ 0.03479002, -0.02186469], dtype=float32), Array(0.45799524, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 46 | T: 1.102906e+00 | T: ((Array([ 0.03401836, -0.02060298], dtype=float32), Array(0.46035087, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 47 | T: 1.089809e+00 | T: ((Array([ 0.0332426 , -0.01938661], dtype=float32), Array(0.46264756, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 48 | T: 1.077639e+00 | T: ((Array([ 0.03247139, -0.01822043], dtype=float32), Array(0.46488824, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 49 | T: 1.066212e+00 | T: ((Array([ 0.03171255, -0.01710882], dtype=float32), Array(0.4670757, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 50 | T: 1.055781e+00 | T: ((Array([ 0.03097274, -0.01605556], dtype=float32), Array(0.46921268, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 51 | T: 1.044789e+00 | T: ((Array([ 0.03025715, -0.01506333], dtype=float32), Array(0.47130156, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 52 | T: 1.035283e+00 | T: ((Array([ 0.02957106, -0.01413506], dtype=float32), Array(0.47334474, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 53 | T: 1.025791e+00 | T: ((Array([ 0.02891881, -0.01327152], dtype=float32), Array(0.47534448, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 54 | T: 1.016384e+00 | T: ((Array([ 0.02830513, -0.01247341], dtype=float32), Array(0.4773028, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 55 | T: 1.008280e+00 | T: ((Array([ 0.02773219, -0.01174111], dtype=float32), Array(0.47922167, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 56 | T: 9.993668e-01 | T: ((Array([ 0.02720239, -0.01107363], dtype=float32), Array(0.48110297, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 57 | T: 9.914522e-01 | T: ((Array([ 0.02671741, -0.01047088], dtype=float32), Array(0.48294842, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 58 | T: 9.839831e-01 | T: ((Array([ 0.02627857, -0.00993158], dtype=float32), Array(0.4847597, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 59 | T: 9.766939e-01 | T: ((Array([ 0.02588519, -0.0094539 ], dtype=float32), Array(0.48653832, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 60 | T: 9.692123e-01 | T: ((Array([ 0.02553657, -0.00903569], dtype=float32), Array(0.48828575, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 61 | T: 9.622464e-01 | T: ((Array([ 0.02523346, -0.00867545], dtype=float32), Array(0.49000332, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 62 | T: 9.562213e-01 | T: ((Array([ 0.02497367, -0.00837081], dtype=float32), Array(0.49169236, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 63 | T: 9.497771e-01 | T: ((Array([ 0.02475578, -0.00811858], dtype=float32), Array(0.49335408, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 64 | T: 9.437461e-01 | T: ((Array([ 0.02457912, -0.00791639], dtype=float32), Array(0.4949896, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 65 | T: 9.375476e-01 | T: ((Array([ 0.02444161, -0.00775977], dtype=float32), Array(0.49659997, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 66 | T: 9.316648e-01 | T: ((Array([ 0.02434094, -0.00764649], dtype=float32), Array(0.49818617, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 67 | T: 9.265883e-01 | T: ((Array([ 0.02427361, -0.00757329], dtype=float32), Array(0.49974924, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 68 | T: 9.203925e-01 | T: ((Array([ 0.02423687, -0.00753724], dtype=float32), Array(0.50128984, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 69 | T: 9.158373e-01 | T: ((Array([ 0.02422859, -0.00753494], dtype=float32), Array(0.502809, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 70 | T: 9.104374e-01 | T: ((Array([ 0.02424655, -0.00756392], dtype=float32), Array(0.5043074, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 71 | T: 9.051057e-01 | T: ((Array([ 0.02428659, -0.00762043], dtype=float32), Array(0.5057857, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 72 | T: 9.003484e-01 | T: ((Array([ 0.0243464 , -0.00770159], dtype=float32), Array(0.50724465, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 73 | T: 8.960859e-01 | T: ((Array([ 0.02442295, -0.00780399], dtype=float32), Array(0.50868493, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 74 | T: 8.907300e-01 | T: ((Array([ 0.02451366, -0.00792514], dtype=float32), Array(0.51010704, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 75 | T: 8.869532e-01 | T: ((Array([ 0.02461534, -0.00806196], dtype=float32), Array(0.5115117, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 76 | T: 8.823389e-01 | T: ((Array([ 0.024725  , -0.00821136], dtype=float32), Array(0.5128993, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 77 | T: 8.780476e-01 | T: ((Array([ 0.02484019, -0.00837128], dtype=float32), Array(0.51427037, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 78 | T: 8.739260e-01 | T: ((Array([ 0.02495771, -0.00854018], dtype=float32), Array(0.5156254, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 79 | T: 8.698872e-01 | T: ((Array([ 0.02507596, -0.00870926], dtype=float32), Array(0.5169649, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 80 | T: 8.659936e-01 | T: ((Array([ 0.02519381, -0.00888284], dtype=float32), Array(0.5182892, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 81 | T: 8.630084e-01 | T: ((Array([ 0.02530942, -0.00905834], dtype=float32), Array(0.51959884, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 82 | T: 8.589647e-01 | T: ((Array([ 0.02542185, -0.00923367], dtype=float32), Array(0.52089417, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 83 | T: 8.554835e-01 | T: ((Array([ 0.02552934, -0.00940808], dtype=float32), Array(0.5221755, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 84 | T: 8.517526e-01 | T: ((Array([ 0.02563127, -0.00957987], dtype=float32), Array(0.5234432, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 85 | T: 8.484387e-01 | T: ((Array([ 0.02572526, -0.00974783], dtype=float32), Array(0.52469766, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 86 | T: 8.448060e-01 | T: ((Array([ 0.02580995, -0.00991065], dtype=float32), Array(0.52593905, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 87 | T: 8.418895e-01 | T: ((Array([ 0.02588549, -0.01006696], dtype=float32), Array(0.52716774, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 88 | T: 8.380838e-01 | T: ((Array([ 0.02595157, -0.01021655], dtype=float32), Array(0.528384, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 89 | T: 8.350933e-01 | T: ((Array([ 0.02600718, -0.01035811], dtype=float32), Array(0.529588, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 90 | T: 8.325351e-01 | T: ((Array([ 0.02605396, -0.01049164], dtype=float32), Array(0.5307801, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 91 | T: 8.296718e-01 | T: ((Array([ 0.02609076, -0.01061608], dtype=float32), Array(0.53196055, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 92 | T: 8.265422e-01 | T: ((Array([ 0.02611843, -0.01073206], dtype=float32), Array(0.5331296, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 93 | T: 8.234708e-01 | T: ((Array([ 0.02613671, -0.01083793], dtype=float32), Array(0.53428733, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 94 | T: 8.210174e-01 | T: ((Array([ 0.02614617, -0.01093426], dtype=float32), Array(0.53543407, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 95 | T: 8.184044e-01 | T: ((Array([ 0.02614662, -0.01102105], dtype=float32), Array(0.53657, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 96 | T: 8.156844e-01 | T: ((Array([ 0.02613879, -0.01109852], dtype=float32), Array(0.5376954, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 97 | T: 8.131794e-01 | T: ((Array([ 0.02612351, -0.01116707], dtype=float32), Array(0.5388104, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 98 | T: 8.107590e-01 | T: ((Array([ 0.02610027, -0.01122688], dtype=float32), Array(0.53991514, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Step 99 | T: 8.081915e-01 | T: ((Array([ 0.02607006, -0.01127708], dtype=float32), Array(0.54100984, dtype=float32)), Array([-0.03537707,  0.07209699,  0.996675  ], dtype=float32))
# Final 99 | T: 8.081915e-01 | T: (Array([ 0.02607006, -0.01127708], dtype=float32), Array(0.54100984, dtype=float32))
# Step 0 | T: 9.623510e+00 | T: ((Array([-2.6668883e-09, -0.0000000e+00], dtype=float32), Array(0.20999993, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 1 | T: 8.448677e+00 | T: ((Array([ 0.00898792, -0.00247867], dtype=float32), Array(0.21992311, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 2 | T: 7.513188e+00 | T: ((Array([ 0.01740751, -0.00781939], dtype=float32), Array(0.2297301, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 3 | T: 6.700154e+00 | T: ((Array([ 0.02530915, -0.01437277], dtype=float32), Array(0.23938458, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 4 | T: 6.005126e+00 | T: ((Array([ 0.03267321, -0.02152457], dtype=float32), Array(0.24885635, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 5 | T: 5.409690e+00 | T: ((Array([ 0.03946594, -0.02896108], dtype=float32), Array(0.25812086, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 6 | T: 4.900913e+00 | T: ((Array([ 0.04565631, -0.03649089], dtype=float32), Array(0.26715907, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 7 | T: 4.466657e+00 | T: ((Array([ 0.05122077, -0.04398303], dtype=float32), Array(0.27595687, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 8 | T: 4.092934e+00 | T: ((Array([ 0.0561478 , -0.05133951], dtype=float32), Array(0.28450423, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 9 | T: 3.769226e+00 | T: ((Array([ 0.06043784, -0.05848506], dtype=float32), Array(0.2927945, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 10 | T: 3.490465e+00 | T: ((Array([ 0.06410103, -0.06535999], dtype=float32), Array(0.30082417, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 11 | T: 3.246193e+00 | T: ((Array([ 0.06715602, -0.07191738], dtype=float32), Array(0.30859196, dtype=float32)), Array([-0.18916447, -0.06646915,  0.9796931 ], dtype=float32))
# Step 12 | T: 3.035098e+00 | T: ((Array([ 1.1975262e-09, -3.7182581e-09], dtype=float32), Array(0.31609893, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 13 | T: 2.812734e+00 | T: ((Array([ 0.00268024, -0.00573504], dtype=float32), Array(0.3233463, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 14 | T: 2.645733e+00 | T: ((Array([ 0.00549488, -0.01099505], dtype=float32), Array(0.330338, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 15 | T: 2.498758e+00 | T: ((Array([ 0.00838379, -0.01577922], dtype=float32), Array(0.3370792, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 16 | T: 2.368727e+00 | T: ((Array([ 0.01129419, -0.02009048], dtype=float32), Array(0.34357592, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 17 | T: 2.251956e+00 | T: ((Array([ 0.01418108, -0.02393609], dtype=float32), Array(0.3498347, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 18 | T: 2.148592e+00 | T: ((Array([ 0.01700603, -0.02732738], dtype=float32), Array(0.3558628, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 19 | T: 2.055082e+00 | T: ((Array([ 0.01973606, -0.03027959], dtype=float32), Array(0.36166757, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 20 | T: 1.970793e+00 | T: ((Array([ 0.02234464, -0.03280969], dtype=float32), Array(0.36725673, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 21 | T: 1.895138e+00 | T: ((Array([ 0.02480866, -0.03493657], dtype=float32), Array(0.3726381, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 22 | T: 1.826556e+00 | T: ((Array([ 0.02711057, -0.03668215], dtype=float32), Array(0.3778197, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 23 | T: 1.762686e+00 | T: ((Array([ 0.02923596, -0.03806867], dtype=float32), Array(0.38280928, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 24 | T: 1.706017e+00 | T: ((Array([ 0.03117458, -0.03911883], dtype=float32), Array(0.38761476, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 25 | T: 1.653982e+00 | T: ((Array([ 0.03291997, -0.03985643], dtype=float32), Array(0.39224398, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 26 | T: 1.605712e+00 | T: ((Array([ 0.03446832, -0.04030576], dtype=float32), Array(0.39670455, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 27 | T: 1.560923e+00 | T: ((Array([ 0.03581854, -0.04049024], dtype=float32), Array(0.40100393, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 28 | T: 1.519730e+00 | T: ((Array([ 0.03697216, -0.04043345], dtype=float32), Array(0.40514934, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 29 | T: 1.481584e+00 | T: ((Array([ 0.03793324, -0.04015946], dtype=float32), Array(0.40914783, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 30 | T: 1.445597e+00 | T: ((Array([ 0.03870723, -0.03968996], dtype=float32), Array(0.41300622, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 31 | T: 1.412688e+00 | T: ((Array([ 0.03930122, -0.03904619], dtype=float32), Array(0.41673112, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 32 | T: 1.382548e+00 | T: ((Array([ 0.03972386, -0.03825072], dtype=float32), Array(0.42032897, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 33 | T: 1.352475e+00 | T: ((Array([ 0.03998569, -0.03732327], dtype=float32), Array(0.42380574, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 34 | T: 1.325834e+00 | T: ((Array([ 0.04009642, -0.03628294], dtype=float32), Array(0.42716736, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 35 | T: 1.300881e+00 | T: ((Array([ 0.04006696, -0.03514788], dtype=float32), Array(0.4304196, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 36 | T: 1.276845e+00 | T: ((Array([ 0.03991023, -0.03393491], dtype=float32), Array(0.43356773, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 37 | T: 1.254570e+00 | T: ((Array([ 0.03963831, -0.03266057], dtype=float32), Array(0.43661705, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 38 | T: 1.233345e+00 | T: ((Array([ 0.03926394, -0.0313409 ], dtype=float32), Array(0.43957236, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 39 | T: 1.213832e+00 | T: ((Array([ 0.03879967, -0.02998976], dtype=float32), Array(0.44243845, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 40 | T: 1.195227e+00 | T: ((Array([ 0.03825746, -0.02862049], dtype=float32), Array(0.44521984, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 41 | T: 1.177341e+00 | T: ((Array([ 0.0376491, -0.0272452], dtype=float32), Array(0.4479208, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 42 | T: 1.160621e+00 | T: ((Array([ 0.03698652, -0.0258745 ], dtype=float32), Array(0.45054534, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 43 | T: 1.144286e+00 | T: ((Array([ 0.03628088, -0.02451889], dtype=float32), Array(0.45309728, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 44 | T: 1.130308e+00 | T: ((Array([ 0.03554292, -0.02318698], dtype=float32), Array(0.4555804, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 45 | T: 1.115727e+00 | T: ((Array([ 0.03478331, -0.02188665], dtype=float32), Array(0.45799813, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 46 | T: 1.102339e+00 | T: ((Array([ 0.03401134, -0.02062507], dtype=float32), Array(0.46035376, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 47 | T: 1.089881e+00 | T: ((Array([ 0.03323537, -0.01940822], dtype=float32), Array(0.46265048, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 48 | T: 1.078057e+00 | T: ((Array([ 0.03246371, -0.01824107], dtype=float32), Array(0.46489125, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 49 | T: 1.065885e+00 | T: ((Array([ 0.03170516, -0.01712889], dtype=float32), Array(0.46707875, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 50 | T: 1.055397e+00 | T: ((Array([ 0.03096591, -0.01607536], dtype=float32), Array(0.46921563, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 51 | T: 1.045046e+00 | T: ((Array([ 0.0302514 , -0.01508283], dtype=float32), Array(0.47130448, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 52 | T: 1.035291e+00 | T: ((Array([ 0.02956752, -0.01415286], dtype=float32), Array(0.47334763, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 53 | T: 1.025535e+00 | T: ((Array([ 0.02891804, -0.01328729], dtype=float32), Array(0.47534725, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 54 | T: 1.016634e+00 | T: ((Array([ 0.0283064 , -0.01248729], dtype=float32), Array(0.4773055, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 55 | T: 1.008046e+00 | T: ((Array([ 0.02773646, -0.01175333], dtype=float32), Array(0.47922432, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 56 | T: 9.989086e-01 | T: ((Array([ 0.02721033, -0.01108384], dtype=float32), Array(0.48110554, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 57 | T: 9.913452e-01 | T: ((Array([ 0.02672764, -0.01047937], dtype=float32), Array(0.4829509, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 58 | T: 9.841785e-01 | T: ((Array([ 0.02629014, -0.00993855], dtype=float32), Array(0.4847621, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 59 | T: 9.766840e-01 | T: ((Array([ 0.02589808, -0.00945937], dtype=float32), Array(0.4865407, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 60 | T: 9.696098e-01 | T: ((Array([ 0.02555138, -0.00904078], dtype=float32), Array(0.48828816, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 61 | T: 9.623162e-01 | T: ((Array([ 0.02524936, -0.00868036], dtype=float32), Array(0.49000576, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 62 | T: 9.558738e-01 | T: ((Array([ 0.02499122, -0.00837508], dtype=float32), Array(0.4916948, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# Step 63 | T: 9.495198e-01 | T: ((Array([ 0.02477537, -0.00812266], dtype=float32), Array(0.4933565, dtype=float32)), Array([-0.03538923,  0.07211551,  0.9966733 ], dtype=float32))
# ...
# Step 13 | T: 2.813015e+00 | T: ((Array([ 0.00268036, -0.00573577], dtype=float32), Array(0.32334763, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 14 | T: 2.645922e+00 | T: ((Array([ 0.005495  , -0.01099669], dtype=float32), Array(0.33033943, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 15 | T: 2.498653e+00 | T: ((Array([ 0.00838293, -0.01578126], dtype=float32), Array(0.3370807, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 16 | T: 2.368373e+00 | T: ((Array([ 0.01129249, -0.02009276], dtype=float32), Array(0.34357744, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 17 | T: 2.252441e+00 | T: ((Array([ 0.01417873, -0.02393914], dtype=float32), Array(0.3498363, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 18 | T: 2.148826e+00 | T: ((Array([ 0.01700278, -0.02733194], dtype=float32), Array(0.3558644, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 19 | T: 2.054417e+00 | T: ((Array([ 0.01973275, -0.03028538], dtype=float32), Array(0.36166912, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 20 | T: 1.970795e+00 | T: ((Array([ 0.02234081, -0.03281644], dtype=float32), Array(0.3672582, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 21 | T: 1.894755e+00 | T: ((Array([ 0.02480412, -0.03494485], dtype=float32), Array(0.37263945, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 22 | T: 1.826335e+00 | T: ((Array([ 0.02710477, -0.03669201], dtype=float32), Array(0.37782088, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 23 | T: 1.763405e+00 | T: ((Array([ 0.02922928, -0.03807938], dtype=float32), Array(0.38281035, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 24 | T: 1.706355e+00 | T: ((Array([ 0.03116738, -0.03913021], dtype=float32), Array(0.38761577, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 25 | T: 1.653166e+00 | T: ((Array([ 0.03291267, -0.03986835], dtype=float32), Array(0.3922448, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 26 | T: 1.605228e+00 | T: ((Array([ 0.03446102, -0.04031822], dtype=float32), Array(0.39670512, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 27 | T: 1.560664e+00 | T: ((Array([ 0.03581223, -0.04050342], dtype=float32), Array(0.40100423, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 28 | T: 1.519892e+00 | T: ((Array([ 0.03696786, -0.04044729], dtype=float32), Array(0.4051494, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 29 | T: 1.481268e+00 | T: ((Array([ 0.03793057, -0.04017294], dtype=float32), Array(0.40914762, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 30 | T: 1.446041e+00 | T: ((Array([ 0.03870595, -0.03970245], dtype=float32), Array(0.41300583, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 31 | T: 1.413041e+00 | T: ((Array([ 0.03930133, -0.0390585 ], dtype=float32), Array(0.4167306, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 32 | T: 1.382426e+00 | T: ((Array([ 0.0397254 , -0.03826152], dtype=float32), Array(0.42032835, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 33 | T: 1.353431e+00 | T: ((Array([ 0.03998812, -0.03733267], dtype=float32), Array(0.42380515, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 34 | T: 1.326366e+00 | T: ((Array([ 0.04009969, -0.03629087], dtype=float32), Array(0.4271669, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 35 | T: 1.300722e+00 | T: ((Array([ 0.0400716 , -0.03515402], dtype=float32), Array(0.43041918, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 36 | T: 1.277033e+00 | T: ((Array([ 0.0399164 , -0.03393885], dtype=float32), Array(0.43356737, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 37 | T: 1.254607e+00 | T: ((Array([ 0.03964612, -0.03266282], dtype=float32), Array(0.43661666, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 38 | T: 1.233719e+00 | T: ((Array([ 0.03927229, -0.03134044], dtype=float32), Array(0.43957204, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 39 | T: 1.213739e+00 | T: ((Array([ 0.03880702, -0.02998666], dtype=float32), Array(0.44243816, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 40 | T: 1.195233e+00 | T: ((Array([ 0.03826396, -0.02861426], dtype=float32), Array(0.44521955, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 41 | T: 1.177459e+00 | T: ((Array([ 0.03765482, -0.02723591], dtype=float32), Array(0.4479205, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 42 | T: 1.160784e+00 | T: ((Array([ 0.03699113, -0.02586234], dtype=float32), Array(0.45054507, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 43 | T: 1.144746e+00 | T: ((Array([ 0.03628363, -0.02450368], dtype=float32), Array(0.4530971, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 44 | T: 1.130143e+00 | T: ((Array([ 0.03554404, -0.02316932], dtype=float32), Array(0.45558023, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 45 | T: 1.116088e+00 | T: ((Array([ 0.03478226, -0.02186656], dtype=float32), Array(0.457998, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 46 | T: 1.102402e+00 | T: ((Array([ 0.03400849, -0.02060262], dtype=float32), Array(0.46035364, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 47 | T: 1.089789e+00 | T: ((Array([ 0.03323129, -0.01938407], dtype=float32), Array(0.46265033, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 48 | T: 1.077912e+00 | T: ((Array([ 0.0324584 , -0.01821483], dtype=float32), Array(0.46489102, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 49 | T: 1.066516e+00 | T: ((Array([ 0.03169795, -0.01710028], dtype=float32), Array(0.4670785, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 50 | T: 1.055001e+00 | T: ((Array([ 0.03095636, -0.01604456], dtype=float32), Array(0.46921536, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 51 | T: 1.044808e+00 | T: ((Array([ 0.03023971, -0.01505058], dtype=float32), Array(0.47130415, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 52 | T: 1.034937e+00 | T: ((Array([ 0.02955298, -0.01411949], dtype=float32), Array(0.47334722, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 53 | T: 1.025594e+00 | T: ((Array([ 0.02890094, -0.01325361], dtype=float32), Array(0.4753468, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 54 | T: 1.016557e+00 | T: ((Array([ 0.02828784, -0.01245273], dtype=float32), Array(0.477305, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 55 | T: 1.008053e+00 | T: ((Array([ 0.02771521, -0.01171766], dtype=float32), Array(0.4792238, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 56 | T: 9.998417e-01 | T: ((Array([ 0.02718572, -0.01104804], dtype=float32), Array(0.48110503, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 57 | T: 9.917167e-01 | T: ((Array([ 0.02670121, -0.01044406], dtype=float32), Array(0.48295048, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 58 | T: 9.838666e-01 | T: ((Array([ 0.0262622 , -0.00990371], dtype=float32), Array(0.48476171, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 59 | T: 9.764562e-01 | T: ((Array([ 0.02586924, -0.00942569], dtype=float32), Array(0.4865403, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 60 | T: 9.693658e-01 | T: ((Array([ 0.02552204, -0.00900704], dtype=float32), Array(0.48828766, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 61 | T: 9.630707e-01 | T: ((Array([ 0.02522073, -0.00864558], dtype=float32), Array(0.49000525, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 62 | T: 9.559248e-01 | T: ((Array([ 0.02496291, -0.00833974], dtype=float32), Array(0.49169427, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 63 | T: 9.495593e-01 | T: ((Array([ 0.02474721, -0.00808743], dtype=float32), Array(0.4933559, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 64 | T: 9.435474e-01 | T: ((Array([ 0.02457264, -0.0078856 ], dtype=float32), Array(0.4949913, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 65 | T: 9.379131e-01 | T: ((Array([ 0.02443767, -0.00772942], dtype=float32), Array(0.49660167, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 66 | T: 9.317989e-01 | T: ((Array([ 0.02433962, -0.00761635], dtype=float32), Array(0.49818787, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 67 | T: 9.260917e-01 | T: ((Array([ 0.02427464, -0.00754416], dtype=float32), Array(0.49975082, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 68 | T: 9.204989e-01 | T: ((Array([ 0.02423891, -0.00750966], dtype=float32), Array(0.5012914, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 69 | T: 9.153829e-01 | T: ((Array([ 0.02423188, -0.00750989], dtype=float32), Array(0.50281036, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 70 | T: 9.100910e-01 | T: ((Array([ 0.02425016, -0.007541  ], dtype=float32), Array(0.5043085, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 71 | T: 9.049380e-01 | T: ((Array([ 0.02429039, -0.00759995], dtype=float32), Array(0.5057866, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 72 | T: 9.006777e-01 | T: ((Array([ 0.02434924, -0.00768332], dtype=float32), Array(0.50724536, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 73 | T: 8.960135e-01 | T: ((Array([ 0.02442359, -0.00778818], dtype=float32), Array(0.50868547, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 74 | T: 8.912163e-01 | T: ((Array([ 0.02451182, -0.00791238], dtype=float32), Array(0.51010746, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 75 | T: 8.868344e-01 | T: ((Array([ 0.02461035, -0.00805278], dtype=float32), Array(0.5115119, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 76 | T: 8.819903e-01 | T: ((Array([ 0.02471741, -0.00820559], dtype=float32), Array(0.5128993, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 77 | T: 8.778583e-01 | T: ((Array([ 0.02483064, -0.00836948], dtype=float32), Array(0.5142701, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 78 | T: 8.739505e-01 | T: ((Array([ 0.02494647, -0.00854065], dtype=float32), Array(0.5156249, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 79 | T: 8.701270e-01 | T: ((Array([ 0.02506332, -0.00871696], dtype=float32), Array(0.51696414, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 80 | T: 8.666934e-01 | T: ((Array([ 0.02517994, -0.00889624], dtype=float32), Array(0.5182883, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 81 | T: 8.625289e-01 | T: ((Array([ 0.02529356, -0.0090765 ], dtype=float32), Array(0.51959777, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 82 | T: 8.587947e-01 | T: ((Array([ 0.02540324, -0.00925661], dtype=float32), Array(0.52089286, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 83 | T: 8.552594e-01 | T: ((Array([ 0.02550813, -0.00943522], dtype=float32), Array(0.522174, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 84 | T: 8.515414e-01 | T: ((Array([ 0.0256062 , -0.00961111], dtype=float32), Array(0.5234415, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 85 | T: 8.480818e-01 | T: ((Array([ 0.02569725, -0.00978194], dtype=float32), Array(0.52469563, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 86 | T: 8.449616e-01 | T: ((Array([ 0.02578014, -0.00994698], dtype=float32), Array(0.5259368, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 87 | T: 8.422472e-01 | T: ((Array([ 0.02585531, -0.01010637], dtype=float32), Array(0.52716535, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 88 | T: 8.383120e-01 | T: ((Array([ 0.02592111, -0.01025795], dtype=float32), Array(0.5283814, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 89 | T: 8.356203e-01 | T: ((Array([ 0.0259771 , -0.01040052], dtype=float32), Array(0.52958536, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 90 | T: 8.320225e-01 | T: ((Array([ 0.02602299, -0.0105344 ], dtype=float32), Array(0.53077734, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 91 | T: 8.291940e-01 | T: ((Array([ 0.02605901, -0.01065858], dtype=float32), Array(0.5319576, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 92 | T: 8.266857e-01 | T: ((Array([ 0.02608528, -0.01077335], dtype=float32), Array(0.5331265, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 93 | T: 8.238491e-01 | T: ((Array([ 0.02610206, -0.01087842], dtype=float32), Array(0.5342842, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 94 | T: 8.211403e-01 | T: ((Array([ 0.02610992, -0.01097362], dtype=float32), Array(0.5354309, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 95 | T: 8.180975e-01 | T: ((Array([ 0.02610924, -0.01105924], dtype=float32), Array(0.53656685, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 96 | T: 8.159764e-01 | T: ((Array([ 0.02610017, -0.0111348 ], dtype=float32), Array(0.5376922, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 97 | T: 8.130935e-01 | T: ((Array([ 0.02608383, -0.01120063], dtype=float32), Array(0.53880715, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 98 | T: 8.108491e-01 | T: ((Array([ 0.02606095, -0.01125706], dtype=float32), Array(0.53991187, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Step 99 | T: 8.081603e-01 | T: ((Array([ 0.02603091, -0.01130429], dtype=float32), Array(0.5410065, dtype=float32)), Array([-0.03536546,  0.0721072 ,  0.99667466], dtype=float32))
# Final 99 | T: 8.081603e-01 | T: (Array([ 0.02603091, -0.01130429], dtype=float32), Array(0.5410065, dtype=float32))
# 1min 8s ± 73.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # n-Ellipsoid

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 10 #Change this for Ellipsoid2, Ellipsoid3, Ellipsoid5, Ellipsoid10, Ellipsoid20

# %%
M = nEllipsoid(N=N, params = jnp.linspace(0.5,1.0,N+1))
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*N)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/Ellipsoid'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Ellipsoid'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Ellipsoid'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/Ellipsoid'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.01, max_iter=1000)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
val = jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), 0.3))(X_obs[0],X_obs[1]), axis=0)
print(val)
# Out:
# -4.013881

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 4.656784e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.108107e+00 | T: ((Array([-0.01414834,  0.00562849], dtype=float32), Array(0.21991655, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 1 | T: 4.108107e+00 | T: (Array([-0.01414834,  0.00562849], dtype=float32), Array(0.21991655, dtype=float32))
# Step 0 | T: 4.659544e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.109814e+00 | T: ((Array([-0.01414779,  0.00563325], dtype=float32), Array(0.21991652, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.660100e+00 | T: ((Array([-0.00516789, -0.00353058], dtype=float32), Array(0.22970444, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.295745e+00 | T: ((Array([ 0.00278716, -0.01183691], dtype=float32), Array(0.23932675, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.994323e+00 | T: ((Array([ 0.00938818, -0.01899609], dtype=float32), Array(0.24875343, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.743281e+00 | T: ((Array([ 0.01446766, -0.02479183], dtype=float32), Array(0.2579605, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.532197e+00 | T: ((Array([ 0.01801716, -0.02913439], dtype=float32), Array(0.266929, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.354428e+00 | T: ((Array([ 0.02015652, -0.03206774], dtype=float32), Array(0.2756449, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.200300e+00 | T: ((Array([ 0.02106714, -0.0337104 ], dtype=float32), Array(0.28409722, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.063751e+00 | T: ((Array([ 0.02096374, -0.03423075], dtype=float32), Array(0.29227707, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.944985e+00 | T: ((Array([ 0.02003926, -0.03381933], dtype=float32), Array(0.30017912, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.845012e+00 | T: ((Array([ 0.01849147, -0.03265305], dtype=float32), Array(0.3078007, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.755181e+00 | T: ((Array([ 0.01648162, -0.03089927], dtype=float32), Array(0.31514072, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.676112e+00 | T: ((Array([ 0.0141667 , -0.02870642], dtype=float32), Array(0.32220003, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.605777e+00 | T: ((Array([ 0.01167233, -0.02621736], dtype=float32), Array(0.32898098, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.546782e+00 | T: ((Array([ 0.00910693, -0.02355435], dtype=float32), Array(0.33548808, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.493928e+00 | T: ((Array([ 0.00656212, -0.02082285], dtype=float32), Array(0.34172642, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.448176e+00 | T: ((Array([ 0.00411556, -0.01812196], dtype=float32), Array(0.34770232, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.408118e+00 | T: ((Array([ 0.00183308, -0.0155304 ], dtype=float32), Array(0.35342297, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 1.372678e+00 | T: ((Array([-0.00024497, -0.01310356], dtype=float32), Array(0.35889623, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.342004e+00 | T: ((Array([-0.0020831 , -0.01090683], dtype=float32), Array(0.36412987, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.316131e+00 | T: ((Array([-0.00365861, -0.00897919], dtype=float32), Array(0.36913264, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.291190e+00 | T: ((Array([-0.00496131, -0.00734996], dtype=float32), Array(0.3739133, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.270357e+00 | T: ((Array([-0.00597966, -0.00602577], dtype=float32), Array(0.37848023, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.250737e+00 | T: ((Array([-0.0067295 , -0.00502127], dtype=float32), Array(0.3828423, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.233049e+00 | T: ((Array([-0.00721813, -0.0043283 ], dtype=float32), Array(0.3870079, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.218297e+00 | T: ((Array([-0.00745621, -0.00394221], dtype=float32), Array(0.39098555, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.204437e+00 | T: ((Array([-0.00747072, -0.00383583], dtype=float32), Array(0.3947837, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.191879e+00 | T: ((Array([-0.00727886, -0.00398832], dtype=float32), Array(0.3984103, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.180771e+00 | T: ((Array([-0.00691007, -0.00437166], dtype=float32), Array(0.40187314, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.169761e+00 | T: ((Array([-0.00638782, -0.00494876], dtype=float32), Array(0.40517992, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.161644e+00 | T: ((Array([-0.00573854, -0.00568535], dtype=float32), Array(0.40833825, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.152462e+00 | T: ((Array([-0.00499199, -0.00655301], dtype=float32), Array(0.4113553, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.144252e+00 | T: ((Array([-0.00417831, -0.00752011], dtype=float32), Array(0.41423765, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.137567e+00 | T: ((Array([-0.00331025, -0.0085411 ], dtype=float32), Array(0.4169921, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.131509e+00 | T: ((Array([-0.00241153, -0.00957589], dtype=float32), Array(0.41962525, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.125638e+00 | T: ((Array([-0.00150082, -0.01060906], dtype=float32), Array(0.42214313, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.119773e+00 | T: ((Array([-0.0006029, -0.0116164], dtype=float32), Array(0.4245515, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.114982e+00 | T: ((Array([ 0.00027044, -0.01257004], dtype=float32), Array(0.426856, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.110785e+00 | T: ((Array([ 0.00110586, -0.01344955], dtype=float32), Array(0.429062, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.107862e+00 | T: ((Array([ 0.00188756, -0.01424373], dtype=float32), Array(0.43117508, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.102830e+00 | T: ((Array([ 0.00260643, -0.01493071], dtype=float32), Array(0.43319973, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.100149e+00 | T: ((Array([ 0.00325222, -0.01550631], dtype=float32), Array(0.4351408, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.096587e+00 | T: ((Array([ 0.00382243, -0.01596369], dtype=float32), Array(0.43700242, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.094512e+00 | T: ((Array([ 0.00431082, -0.01630116], dtype=float32), Array(0.4387892, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.090156e+00 | T: ((Array([ 0.00472096, -0.0165184 ], dtype=float32), Array(0.4405046, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.087860e+00 | T: ((Array([ 0.00504103, -0.01661934], dtype=float32), Array(0.44215244, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.086256e+00 | T: ((Array([ 0.00527693, -0.01660903], dtype=float32), Array(0.44373667, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.084105e+00 | T: ((Array([ 0.00543118, -0.01650178], dtype=float32), Array(0.44526055, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.082262e+00 | T: ((Array([ 0.00551099, -0.01631783], dtype=float32), Array(0.44672737, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.080187e+00 | T: ((Array([ 0.0055188 , -0.01606366], dtype=float32), Array(0.44813997, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.079674e+00 | T: ((Array([ 0.00546334, -0.01574822], dtype=float32), Array(0.4495017, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.077063e+00 | T: ((Array([ 0.00535393, -0.01537904], dtype=float32), Array(0.450815, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.074983e+00 | T: ((Array([ 0.00519637, -0.0149759 ], dtype=float32), Array(0.45208225, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 1.075133e+00 | T: ((Array([ 0.00499119, -0.01455592], dtype=float32), Array(0.45330587, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 1.072461e+00 | T: ((Array([ 0.00475213, -0.01413589], dtype=float32), Array(0.45448768, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 1.071372e+00 | T: ((Array([ 0.00448844, -0.01372868], dtype=float32), Array(0.45563006, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 1.069775e+00 | T: ((Array([ 0.00419811, -0.01333753], dtype=float32), Array(0.45673504, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 1.069752e+00 | T: ((Array([ 0.00388195, -0.01297304], dtype=float32), Array(0.45780492, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: 1.067631e+00 | T: ((Array([ 0.00356187, -0.01264437], dtype=float32), Array(0.45884073, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: 1.067994e+00 | T: ((Array([ 0.00323645, -0.01235079], dtype=float32), Array(0.45984456, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: 1.066488e+00 | T: ((Array([ 0.00292627, -0.01210157], dtype=float32), Array(0.46081784, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: 1.064735e+00 | T: ((Array([ 0.00262821, -0.01189102], dtype=float32), Array(0.46176183, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: 1.065959e+00 | T: ((Array([ 0.00234986, -0.01173257], dtype=float32), Array(0.4626782, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: 1.063987e+00 | T: ((Array([ 0.00210115, -0.01161976], dtype=float32), Array(0.4635677, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: 1.062473e+00 | T: ((Array([ 0.00186508, -0.01157716], dtype=float32), Array(0.46443003, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: 1.062709e+00 | T: ((Array([ 0.0016632 , -0.01158361], dtype=float32), Array(0.46526867, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: 1.062053e+00 | T: ((Array([ 0.00148831, -0.01163164], dtype=float32), Array(0.4660845, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: 1.062348e+00 | T: ((Array([ 0.00134623, -0.01171307], dtype=float32), Array(0.46687853, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: 1.060916e+00 | T: ((Array([ 0.0012337, -0.0118238], dtype=float32), Array(0.46765143, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: 1.060742e+00 | T: ((Array([ 0.00115832, -0.01196095], dtype=float32), Array(0.46840414, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: 1.059984e+00 | T: ((Array([ 0.00111948, -0.01210857], dtype=float32), Array(0.46913773, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: 1.059475e+00 | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.2818 0.3359 0.1734 -0.0184 0.0511 -0.0447 0.0011 0.0183 0.0044 0.0095 -0.1443 )
# T = 0.0010

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/3061874042.py in <module>
#       1 print(f"Bridge Riemannian Diffusion Mean:")
# ----> 2 print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
#       3 print(f"T = {T_bridge[-1]:.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/1057633312.py in <module>
#       1 print("The difference between the score and bridge:")
# ----> 2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.09899
#  -T error = 0.4800
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/2212210786.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 1.34 s ± 4.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)
# Out:
# Step 0 | T: 4.656562e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.110264e+00 | T: ((Array([-0.01414904,  0.00562994], dtype=float32), Array(0.21991679, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.660110e+00 | T: ((Array([-0.00516022, -0.00352163], dtype=float32), Array(0.22970495, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.294843e+00 | T: ((Array([ 0.00279815, -0.01182485], dtype=float32), Array(0.2393274, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.994320e+00 | T: ((Array([ 0.00941351, -0.01897685], dtype=float32), Array(0.24875428, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.744088e+00 | T: ((Array([ 0.01450081, -0.02477826], dtype=float32), Array(0.25796178, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.532049e+00 | T: ((Array([ 0.01811038, -0.02905273], dtype=float32), Array(0.2669328, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.353670e+00 | T: ((Array([ 0.02029044, -0.03192666], dtype=float32), Array(0.27565077, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.199343e+00 | T: ((Array([ 0.02123357, -0.03352421], dtype=float32), Array(0.2841046, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.063576e+00 | T: ((Array([ 0.02114506, -0.03401937], dtype=float32), Array(0.29228592, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.947466e+00 | T: ((Array([ 0.02023363, -0.03360003], dtype=float32), Array(0.30018955, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.843117e+00 | T: ((Array([ 0.01868227, -0.03243634], dtype=float32), Array(0.30781192, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.753647e+00 | T: ((Array([ 0.01666434, -0.03069441], dtype=float32), Array(0.31515226, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.675668e+00 | T: ((Array([ 0.01433165, -0.02852132], dtype=float32), Array(0.32221192, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.605927e+00 | T: ((Array([ 0.01181304, -0.02605541], dtype=float32), Array(0.3289932, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.545438e+00 | T: ((Array([ 0.00922611, -0.02342234], dtype=float32), Array(0.3355002, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.494208e+00 | T: ((Array([ 0.00665794, -0.02072421], dtype=float32), Array(0.34173846, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.447939e+00 | T: ((Array([ 0.00419093, -0.01805434], dtype=float32), Array(0.34771422, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.408363e+00 | T: ((Array([ 0.00187952, -0.01548656], dtype=float32), Array(0.35343468, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 1.373139e+00 | T: ((Array([-0.00022856, -0.01308883], dtype=float32), Array(0.35890752, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.341781e+00 | T: ((Array([-0.00209476, -0.01091116], dtype=float32), Array(0.36414072, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.314714e+00 | T: ((Array([-0.00369231, -0.00900065], dtype=float32), Array(0.36914286, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.290345e+00 | T: ((Array([-0.00501417, -0.00738531], dtype=float32), Array(0.37392256, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.270440e+00 | T: ((Array([-0.00605139, -0.0060796 ], dtype=float32), Array(0.37848866, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.251131e+00 | T: ((Array([-0.00680515, -0.00508893], dtype=float32), Array(0.38284975, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.234084e+00 | T: ((Array([-0.00729917, -0.00441146], dtype=float32), Array(0.3870144, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.217690e+00 | T: ((Array([-0.00754518, -0.0040306 ], dtype=float32), Array(0.39099094, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.204215e+00 | T: ((Array([-0.00755871, -0.00392027], dtype=float32), Array(0.39478782, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.191115e+00 | T: ((Array([-0.00736304, -0.00406298], dtype=float32), Array(0.398413, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.180182e+00 | T: ((Array([-0.0069885 , -0.00443015], dtype=float32), Array(0.40187466, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.170006e+00 | T: ((Array([-0.00646847, -0.00499848], dtype=float32), Array(0.40518287, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.160751e+00 | T: ((Array([-0.00581714, -0.00573459], dtype=float32), Array(0.40834242, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.152828e+00 | T: ((Array([-0.00506168, -0.00658862], dtype=float32), Array(0.41136047, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.144086e+00 | T: ((Array([-0.00423067, -0.00753878], dtype=float32), Array(0.4142437, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.137775e+00 | T: ((Array([-0.00334547, -0.00855282], dtype=float32), Array(0.4169991, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.131412e+00 | T: ((Array([-0.00243217, -0.00958996], dtype=float32), Array(0.41963336, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.125351e+00 | T: ((Array([-0.00151548, -0.01062358], dtype=float32), Array(0.42215207, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.120479e+00 | T: ((Array([-0.0006126 , -0.01163699], dtype=float32), Array(0.42456114, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.115574e+00 | T: ((Array([ 0.00026408, -0.01260229], dtype=float32), Array(0.42686644, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.110794e+00 | T: ((Array([ 0.00109078, -0.01349885], dtype=float32), Array(0.42907324, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.106857e+00 | T: ((Array([ 0.00186528, -0.0143016 ], dtype=float32), Array(0.4311868, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.102679e+00 | T: ((Array([ 0.0025754 , -0.01499857], dtype=float32), Array(0.43321162, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.099385e+00 | T: ((Array([ 0.00321254, -0.01557852], dtype=float32), Array(0.4351526, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.096066e+00 | T: ((Array([ 0.00377159, -0.01604203], dtype=float32), Array(0.43701425, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.093771e+00 | T: ((Array([ 0.00424892, -0.01638247], dtype=float32), Array(0.43880075, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.089226e+00 | T: ((Array([ 0.00461992, -0.01660693], dtype=float32), Array(0.44051573, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.089263e+00 | T: ((Array([ 0.00491141, -0.01671742], dtype=float32), Array(0.4421637, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.085697e+00 | T: ((Array([ 0.00512384, -0.0167177 ], dtype=float32), Array(0.44374794, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.083655e+00 | T: ((Array([ 0.00526501, -0.0166147 ], dtype=float32), Array(0.44527155, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.082271e+00 | T: ((Array([ 0.00533548, -0.01642553], dtype=float32), Array(0.44673795, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.081284e+00 | T: ((Array([ 0.00534268, -0.01616381], dtype=float32), Array(0.44815037, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.078545e+00 | T: ((Array([ 0.00529304, -0.01583429], dtype=float32), Array(0.44951153, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.077225e+00 | T: ((Array([ 0.00518496, -0.01545866], dtype=float32), Array(0.45082408, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.075268e+00 | T: ((Array([ 0.00503407, -0.01504685], dtype=float32), Array(0.4520906, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 1.074356e+00 | T: ((Array([ 0.0048395 , -0.01462019], dtype=float32), Array(0.4533135, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 1.072437e+00 | T: ((Array([ 0.00460536, -0.01418345], dtype=float32), Array(0.45449513, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 1.072083e+00 | T: ((Array([ 0.00434676, -0.01375451], dtype=float32), Array(0.4556374, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 1.070410e+00 | T: ((Array([ 0.00407332, -0.01335037], dtype=float32), Array(0.45674223, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 1.069486e+00 | T: ((Array([ 0.00378962, -0.01297385], dtype=float32), Array(0.45781136, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: 1.069300e+00 | T: ((Array([ 0.00350289, -0.01263457], dtype=float32), Array(0.45884684, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: 1.067418e+00 | T: ((Array([ 0.00322248, -0.0123378 ], dtype=float32), Array(0.45985016, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: 1.066396e+00 | T: ((Array([ 0.00294718, -0.01209697], dtype=float32), Array(0.46082282, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: 1.065836e+00 | T: ((Array([ 0.0026814 , -0.01190014], dtype=float32), Array(0.46176642, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: 1.065317e+00 | T: ((Array([ 0.00242775, -0.01174936], dtype=float32), Array(0.46268234, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: 1.064648e+00 | T: ((Array([ 0.00219112, -0.01164122], dtype=float32), Array(0.46357206, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: 1.062756e+00 | T: ((Array([ 0.00197928, -0.01157462], dtype=float32), Array(0.46443653, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: 1.062719e+00 | T: ((Array([ 0.00179723, -0.01154988], dtype=float32), Array(0.46527672, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: 1.062552e+00 | T: ((Array([ 0.00164293, -0.01156779], dtype=float32), Array(0.46609384, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: 1.062355e+00 | T: ((Array([ 0.00152636, -0.0116145 ], dtype=float32), Array(0.4668892, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: 1.060778e+00 | T: ((Array([ 0.00143473, -0.01169953], dtype=float32), Array(0.46766323, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: 1.060772e+00 | T: ((Array([ 0.00136693, -0.01181534], dtype=float32), Array(0.46841702, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: 1.060106e+00 | T: ((Array([ 0.00132316, -0.01195238], dtype=float32), Array(0.46915132, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: 1.059704e+00 | T: ((Array([ 0.00130439, -0.01211613], dtype=float32), Array(0.46986717, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: 1.059171e+00 | T: ((Array([ 0.00131445, -0.01229326], dtype=float32), Array(0.4705653, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: 1.058171e+00 | T: ((Array([ 0.00134065, -0.01246956], dtype=float32), Array(0.47124603, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: 1.058524e+00 | T: ((Array([ 0.00138522, -0.01264254], dtype=float32), Array(0.4719103, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: 1.057225e+00 | T: ((Array([ 0.0014463 , -0.01281097], dtype=float32), Array(0.4725586, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: 1.057537e+00 | T: ((Array([ 0.00152092, -0.01296942], dtype=float32), Array(0.47319186, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: 1.056167e+00 | T: ((Array([ 0.00159905, -0.01312194], dtype=float32), Array(0.4738108, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: 1.056634e+00 | T: ((Array([ 0.00168679, -0.01325347], dtype=float32), Array(0.47441575, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: 1.056570e+00 | T: ((Array([ 0.00179105, -0.01335102], dtype=float32), Array(0.475007, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: 1.055844e+00 | T: ((Array([ 0.00190101, -0.01342121], dtype=float32), Array(0.4755849, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: 1.055144e+00 | T: ((Array([ 0.00200698, -0.01347811], dtype=float32), Array(0.47614986, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: 1.055375e+00 | T: ((Array([ 0.00211277, -0.01351359], dtype=float32), Array(0.47670257, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: 1.054885e+00 | T: ((Array([ 0.00220778, -0.0135371 ], dtype=float32), Array(0.47724313, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: 1.055045e+00 | T: ((Array([ 0.0022985 , -0.01353867], dtype=float32), Array(0.4777721, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: 1.054448e+00 | T: ((Array([ 0.0023817 , -0.01352617], dtype=float32), Array(0.47828966, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: 1.055139e+00 | T: ((Array([ 0.00245784, -0.01348945], dtype=float32), Array(0.4787963, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: 1.051538e+00 | T: ((Array([ 0.00252884, -0.01343804], dtype=float32), Array(0.47929087, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: 1.054226e+00 | T: ((Array([ 0.00259161, -0.01338323], dtype=float32), Array(0.47977513, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: 1.053589e+00 | T: ((Array([ 0.00264349, -0.01332734], dtype=float32), Array(0.4802495, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: 1.052696e+00 | T: ((Array([ 0.00267647, -0.01326015], dtype=float32), Array(0.4807141, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: 1.053394e+00 | T: ((Array([ 0.00270037, -0.01319791], dtype=float32), Array(0.4811692, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: 1.053182e+00 | T: ((Array([ 0.00271804, -0.01313092], dtype=float32), Array(0.48161477, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: 1.053186e+00 | T: ((Array([ 0.00274079, -0.01305179], dtype=float32), Array(0.48205143, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: 1.053672e+00 | T: ((Array([ 0.00275849, -0.01297747], dtype=float32), Array(0.4824795, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: 1.051635e+00 | T: ((Array([ 0.00277179, -0.01290888], dtype=float32), Array(0.48289895, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: 1.052429e+00 | T: ((Array([ 0.00278276, -0.01283565], dtype=float32), Array(0.4833099, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: 1.052407e+00 | T: ((Array([ 0.00278095, -0.01277325], dtype=float32), Array(0.4837128, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: 1.051968e+00 | T: ((Array([ 0.00277621, -0.01271954], dtype=float32), Array(0.48410773, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: 1.051968e+00 | T: (Array([ 0.00277621, -0.01271954], dtype=float32), Array(0.48410773, dtype=float32))
# Step 0 | T: 4.656524e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.108750e+00 | T: ((Array([-0.01415608,  0.00563438], dtype=float32), Array(0.21991669, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.661696e+00 | T: ((Array([-0.0051676, -0.0035218], dtype=float32), Array(0.2297051, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.297496e+00 | T: ((Array([ 0.00278443, -0.01181966], dtype=float32), Array(0.23932837, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.993787e+00 | T: ((Array([ 0.00939223, -0.01897467], dtype=float32), Array(0.24875598, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.743882e+00 | T: ((Array([ 0.01447034, -0.02479933], dtype=float32), Array(0.2579643, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.533573e+00 | T: ((Array([ 0.01801355, -0.02917838], dtype=float32), Array(0.26693425, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.354910e+00 | T: ((Array([ 0.02014055, -0.03213925], dtype=float32), Array(0.27565128, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.198113e+00 | T: ((Array([ 0.02103149, -0.03380133], dtype=float32), Array(0.28410432, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.064346e+00 | T: ((Array([ 0.02090114, -0.03433661], dtype=float32), Array(0.29228517, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.946373e+00 | T: ((Array([ 0.01996153, -0.03393164], dtype=float32), Array(0.3001881, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.843269e+00 | T: ((Array([ 0.01840353, -0.03277338], dtype=float32), Array(0.30781, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.755532e+00 | T: ((Array([ 0.01639256, -0.03102046], dtype=float32), Array(0.31515032, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.675428e+00 | T: ((Array([ 0.01407603, -0.02883676], dtype=float32), Array(0.32220992, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.606848e+00 | T: ((Array([ 0.01157839, -0.02635077], dtype=float32), Array(0.3289912, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.545921e+00 | T: ((Array([ 0.00901582, -0.0236861 ], dtype=float32), Array(0.33549792, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.493386e+00 | T: ((Array([ 0.00647623, -0.02094021], dtype=float32), Array(0.34173578, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.448652e+00 | T: ((Array([ 0.004029  , -0.01822055], dtype=float32), Array(0.34771135, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.408740e+00 | T: ((Array([ 0.00173933, -0.01561204], dtype=float32), Array(0.3534317, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 1.373491e+00 | T: ((Array([-0.00034193, -0.01317138], dtype=float32), Array(0.35890454, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.342672e+00 | T: ((Array([-0.00217762, -0.01094855], dtype=float32), Array(0.364138, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.315126e+00 | T: ((Array([-0.00374741, -0.00899967], dtype=float32), Array(0.36914054, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.291329e+00 | T: ((Array([-0.0050381 , -0.00734443], dtype=float32), Array(0.37392062, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.270459e+00 | T: ((Array([-0.00604928, -0.00600055], dtype=float32), Array(0.3784872, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.250325e+00 | T: ((Array([-0.00678527, -0.00497613], dtype=float32), Array(0.38284856, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.233076e+00 | T: ((Array([-0.00725767, -0.00426693], dtype=float32), Array(0.3870135, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.217562e+00 | T: ((Array([-0.00748421, -0.00385923], dtype=float32), Array(0.3909903, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.204714e+00 | T: ((Array([-0.0074836 , -0.00376405], dtype=float32), Array(0.39478764, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.191658e+00 | T: ((Array([-0.00728418, -0.0039343 ], dtype=float32), Array(0.39841333, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.180164e+00 | T: ((Array([-0.00690041, -0.00433505], dtype=float32), Array(0.40187535, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.169779e+00 | T: ((Array([-0.00636251, -0.0049236 ], dtype=float32), Array(0.40518126, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.161678e+00 | T: ((Array([-0.00570779, -0.00567415], dtype=float32), Array(0.4083387, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.152139e+00 | T: ((Array([-0.00495213, -0.00655414], dtype=float32), Array(0.41135466, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.145702e+00 | T: ((Array([-0.00412006, -0.00752593], dtype=float32), Array(0.41423622, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.137174e+00 | T: ((Array([-0.0032324 , -0.00855384], dtype=float32), Array(0.41698986, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.131417e+00 | T: ((Array([-0.00231599, -0.00960722], dtype=float32), Array(0.4196221, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.125009e+00 | T: ((Array([-0.00139088, -0.01065664], dtype=float32), Array(0.42213908, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.120754e+00 | T: ((Array([-0.00048025, -0.01168017], dtype=float32), Array(0.42454684, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.115488e+00 | T: ((Array([ 0.00039387, -0.01264801], dtype=float32), Array(0.4268509, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.111879e+00 | T: ((Array([ 0.00122777, -0.01353667], dtype=float32), Array(0.42905685, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.107237e+00 | T: ((Array([ 0.00199672, -0.01434318], dtype=float32), Array(0.43116972, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.103250e+00 | T: ((Array([ 0.00269591, -0.0150469 ], dtype=float32), Array(0.43319428, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.100385e+00 | T: ((Array([ 0.00332498, -0.01563265], dtype=float32), Array(0.43513525, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.097113e+00 | T: ((Array([ 0.00387137, -0.01610187], dtype=float32), Array(0.43699712, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.094244e+00 | T: ((Array([ 0.00433923, -0.0164447 ], dtype=float32), Array(0.4387841, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.090817e+00 | T: ((Array([ 0.00472838, -0.01666736], dtype=float32), Array(0.4405, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.088932e+00 | T: ((Array([ 0.00503453, -0.01678923], dtype=float32), Array(0.44214895, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.082899e+00 | T: ((Array([ 0.00524449, -0.01612129], dtype=float32), Array(0.4436978, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.084695e+00 | T: ((Array([ 0.00537655, -0.01543021], dtype=float32), Array(0.44518974, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.082621e+00 | T: ((Array([ 0.00543711, -0.01474028], dtype=float32), Array(0.4466276, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.081308e+00 | T: ((Array([ 0.00542956, -0.01406279], dtype=float32), Array(0.4480142, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.079729e+00 | T: ((Array([ 0.00536027, -0.01342576], dtype=float32), Array(0.44935244, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.077039e+00 | T: ((Array([ 0.00524687, -0.01284662], dtype=float32), Array(0.45064467, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.076339e+00 | T: ((Array([ 0.00508313, -0.01232726], dtype=float32), Array(0.45189294, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 1.074225e+00 | T: ((Array([ 0.00487827, -0.01187751], dtype=float32), Array(0.45309958, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 1.072883e+00 | T: ((Array([ 0.00463823, -0.01150434], dtype=float32), Array(0.45426667, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 1.071757e+00 | T: ((Array([ 0.00438122, -0.01120924], dtype=float32), Array(0.4553961, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 1.071247e+00 | T: ((Array([ 0.00410567, -0.01099711], dtype=float32), Array(0.45648977, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 1.070132e+00 | T: ((Array([ 0.0038167 , -0.01086188], dtype=float32), Array(0.4575496, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: -inf | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 4.658387e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.109192e+00 | T: ((Array([-0.01414808,  0.00563707], dtype=float32), Array(0.21991645, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.659245e+00 | T: ((Array([-0.00516032, -0.0035265 ], dtype=float32), Array(0.22970387, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.293692e+00 | T: ((Array([ 0.00281079, -0.01183198], dtype=float32), Array(0.2393255, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.993619e+00 | T: ((Array([ 0.00943028, -0.01899477], dtype=float32), Array(0.24875173, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.743868e+00 | T: ((Array([ 0.01452132, -0.02480097], dtype=float32), Array(0.25795856, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.532474e+00 | T: ((Array([ 0.01806775, -0.02914844], dtype=float32), Array(0.2669272, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.353381e+00 | T: ((Array([ 0.02019826, -0.03208243], dtype=float32), Array(0.27564338, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.198775e+00 | T: ((Array([ 0.02109848, -0.03372434], dtype=float32), Array(0.2840956, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.065528e+00 | T: ((Array([ 0.02097582, -0.03424881], dtype=float32), Array(0.2922759, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.945940e+00 | T: ((Array([ 0.02004806, -0.03382888], dtype=float32), Array(0.30017847, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.844067e+00 | T: ((Array([ 0.0184879 , -0.03265443], dtype=float32), Array(0.30780044, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.752169e+00 | T: ((Array([ 0.01647256, -0.03090486], dtype=float32), Array(0.3151402, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.675208e+00 | T: ((Array([ 0.01415038, -0.02871668], dtype=float32), Array(0.32219914, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.606478e+00 | T: ((Array([ 0.01164733, -0.02623974], dtype=float32), Array(0.32897985, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.545936e+00 | T: ((Array([ 0.00906723, -0.02358624], dtype=float32), Array(0.33548632, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.494729e+00 | T: ((Array([ 0.00650993, -0.02086101], dtype=float32), Array(0.34172428, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.448474e+00 | T: ((Array([ 0.00405513, -0.01816251], dtype=float32), Array(0.34770006, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.407937e+00 | T: ((Array([ 0.00176186, -0.01556569], dtype=float32), Array(0.35342067, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 1.372994e+00 | T: ((Array([-0.00032209, -0.01313554], dtype=float32), Array(0.35889387, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.341928e+00 | T: ((Array([-0.00215947, -0.01092659], dtype=float32), Array(0.3641275, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.314672e+00 | T: ((Array([-0.00372939, -0.0089817 ], dtype=float32), Array(0.36912978, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.290768e+00 | T: ((Array([-0.00502316, -0.00732779], dtype=float32), Array(0.37390965, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.268680e+00 | T: ((Array([-0.00603562, -0.00599037], dtype=float32), Array(0.37847564, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.250884e+00 | T: ((Array([-0.00677099, -0.0049729 ], dtype=float32), Array(0.38283673, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.233799e+00 | T: ((Array([-0.00723908, -0.00426825], dtype=float32), Array(0.38700148, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.217584e+00 | T: ((Array([-0.00745961, -0.00386521], dtype=float32), Array(0.3909782, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.203780e+00 | T: ((Array([-0.00745496, -0.0037463 ], dtype=float32), Array(0.39477524, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.193098e+00 | T: ((Array([-0.00724466, -0.00388774], dtype=float32), Array(0.39840096, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.181027e+00 | T: ((Array([-0.00685634, -0.00425556], dtype=float32), Array(0.4018632, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.170970e+00 | T: ((Array([-0.00632084, -0.0048213 ], dtype=float32), Array(0.40516958, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.162101e+00 | T: ((Array([-0.00565881, -0.00555639], dtype=float32), Array(0.40832764, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.152712e+00 | T: ((Array([-0.00489978, -0.00642294], dtype=float32), Array(0.41134432, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.144310e+00 | T: ((Array([-0.00406686, -0.00738215], dtype=float32), Array(0.41422668, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.136664e+00 | T: ((Array([-0.00318358, -0.00839336], dtype=float32), Array(0.41698125, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.130775e+00 | T: ((Array([-0.00227416, -0.0094373 ], dtype=float32), Array(0.4196141, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.125402e+00 | T: ((Array([-0.00136515, -0.01048324], dtype=float32), Array(0.4221317, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.120665e+00 | T: ((Array([-0.0004697 , -0.01150887], dtype=float32), Array(0.4245399, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.114604e+00 | T: ((Array([ 0.00040011, -0.01248207], dtype=float32), Array(0.4268444, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.109144e+00 | T: ((Array([ 0.0012318 , -0.01338327], dtype=float32), Array(0.42904997, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.107490e+00 | T: ((Array([ 0.00200733, -0.01419881], dtype=float32), Array(0.43116248, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.103294e+00 | T: ((Array([ 0.00271405, -0.01491401], dtype=float32), Array(0.43318695, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.099116e+00 | T: ((Array([ 0.00334607, -0.01551721], dtype=float32), Array(0.43512768, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.096612e+00 | T: ((Array([ 0.00389358, -0.01600386], dtype=float32), Array(0.43698937, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.093754e+00 | T: ((Array([ 0.00436351, -0.01637006], dtype=float32), Array(0.43877608, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.091321e+00 | T: ((Array([ 0.00474855, -0.01661752], dtype=float32), Array(0.44049177, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.089153e+00 | T: ((Array([ 0.00505157, -0.01675217], dtype=float32), Array(0.44214037, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.086190e+00 | T: ((Array([ 0.00527351, -0.01677869], dtype=float32), Array(0.4437253, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.085425e+00 | T: ((Array([ 0.00542582, -0.01669837], dtype=float32), Array(0.44524997, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.083060e+00 | T: ((Array([ 0.00550616, -0.01652933], dtype=float32), Array(0.44671774, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.080810e+00 | T: ((Array([ 0.00552008, -0.01628065], dtype=float32), Array(0.4481312, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.078113e+00 | T: ((Array([ 0.00547083, -0.01596815], dtype=float32), Array(0.4494932, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.077707e+00 | T: ((Array([ 0.00536363, -0.01560446], dtype=float32), Array(0.4508066, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.075400e+00 | T: ((Array([ 0.00520545, -0.01520235], dtype=float32), Array(0.452074, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 1.074568e+00 | T: ((Array([ 0.00500191, -0.01478532], dtype=float32), Array(0.45329782, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 1.073181e+00 | T: ((Array([ 0.00475659, -0.01434921], dtype=float32), Array(0.4544803, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 1.072324e+00 | T: ((Array([ 0.00449282, -0.01390407], dtype=float32), Array(0.45562372, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 1.070948e+00 | T: ((Array([ 0.00420856, -0.01347736], dtype=float32), Array(0.4567299, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 1.070831e+00 | T: ((Array([ 0.00391829, -0.01307788], dtype=float32), Array(0.45780054, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: 1.068921e+00 | T: ((Array([ 0.0036283 , -0.01271325], dtype=float32), Array(0.45883727, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: 1.067620e+00 | T: ((Array([ 0.00333598, -0.01239738], dtype=float32), Array(0.4598418, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: 1.066698e+00 | T: ((Array([ 0.00305335, -0.01213065], dtype=float32), Array(0.46081564, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: 1.065707e+00 | T: ((Array([ 0.00277801, -0.01191589], dtype=float32), Array(0.46175998, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: 1.064832e+00 | T: ((Array([ 0.00252188, -0.01174953], dtype=float32), Array(0.46267658, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: 1.064361e+00 | T: ((Array([ 0.00228519, -0.01163033], dtype=float32), Array(0.46356657, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: 1.062136e+00 | T: ((Array([ 0.00207047, -0.01156089], dtype=float32), Array(0.46443084, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: 1.062589e+00 | T: ((Array([ 0.0018793 , -0.01154049], dtype=float32), Array(0.46527115, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: 1.062880e+00 | T: ((Array([ 0.00171431, -0.01155732], dtype=float32), Array(0.46608853, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: 1.061017e+00 | T: ((Array([ 0.00157324, -0.01159984], dtype=float32), Array(0.46688378, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: 1.061005e+00 | T: ((Array([ 0.00146099, -0.01167476], dtype=float32), Array(0.4676582, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: 1.060214e+00 | T: ((Array([ 0.0013805 , -0.01179644], dtype=float32), Array(0.46841264, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: 1.060592e+00 | T: ((Array([ 0.00132442, -0.01194098], dtype=float32), Array(0.4691478, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: 1.060753e+00 | T: ((Array([ 0.00129363, -0.01209942], dtype=float32), Array(0.4698645, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: 1.059362e+00 | T: ((Array([ 0.00129004, -0.01226157], dtype=float32), Array(0.4705634, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: 1.059503e+00 | T: ((Array([ 0.00131589, -0.01242162], dtype=float32), Array(0.4712453, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: 1.058682e+00 | T: ((Array([ 0.0013586 , -0.01258281], dtype=float32), Array(0.47191048, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: 1.058105e+00 | T: ((Array([ 0.00141745, -0.01274753], dtype=float32), Array(0.47255984, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: 1.057650e+00 | T: ((Array([ 0.00148627, -0.01290298], dtype=float32), Array(0.47319397, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: 1.057077e+00 | T: ((Array([ 0.00156742, -0.0130413 ], dtype=float32), Array(0.47381327, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: 1.057233e+00 | T: ((Array([ 0.00166253, -0.01315686], dtype=float32), Array(0.47441816, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: 1.056363e+00 | T: ((Array([ 0.00176583, -0.01324944], dtype=float32), Array(0.47500923, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: 1.056731e+00 | T: ((Array([ 0.00187057, -0.01332478], dtype=float32), Array(0.4755869, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: 1.055404e+00 | T: ((Array([ 0.00197748, -0.01337825], dtype=float32), Array(0.4761516, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: 1.055465e+00 | T: ((Array([ 0.00208273, -0.0134079 ], dtype=float32), Array(0.47670367, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: 1.054454e+00 | T: ((Array([ 0.00218769, -0.01340899], dtype=float32), Array(0.4772435, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: 1.054879e+00 | T: ((Array([ 0.00228698, -0.01340155], dtype=float32), Array(0.47777176, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: 1.054690e+00 | T: ((Array([ 0.00238266, -0.01337246], dtype=float32), Array(0.4782889, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: 1.054139e+00 | T: ((Array([ 0.00246344, -0.01333169], dtype=float32), Array(0.478795, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: 1.053836e+00 | T: ((Array([ 0.00253934, -0.01328397], dtype=float32), Array(0.47929028, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: 1.052604e+00 | T: ((Array([ 0.00260686, -0.01321857], dtype=float32), Array(0.47977448, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: 1.054225e+00 | T: ((Array([ 0.00266316, -0.01314839], dtype=float32), Array(0.4802485, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: 1.053539e+00 | T: ((Array([ 0.00270611, -0.01307958], dtype=float32), Array(0.48071283, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: 1.054725e+00 | T: ((Array([ 0.00273439, -0.01300721], dtype=float32), Array(0.4811681, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: 1.053223e+00 | T: ((Array([ 0.00275859, -0.01294168], dtype=float32), Array(0.4816141, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: 1.052164e+00 | T: ((Array([ 0.00277085, -0.01288655], dtype=float32), Array(0.48205096, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: 1.053265e+00 | T: ((Array([ 0.00277521, -0.01283795], dtype=float32), Array(0.48247924, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: 1.052812e+00 | T: ((Array([ 0.0027776, -0.0127979], dtype=float32), Array(0.482899, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: 1.052218e+00 | T: ((Array([ 0.00277454, -0.0127687 ], dtype=float32), Array(0.48331037, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: 1.051260e+00 | T: ((Array([ 0.00277332, -0.01275546], dtype=float32), Array(0.48371345, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: 1.052309e+00 | T: ((Array([ 0.00277466, -0.01274957], dtype=float32), Array(0.4841086, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: 1.052309e+00 | T: (Array([ 0.00277466, -0.01274957], dtype=float32), Array(0.4841086, dtype=float32))
# Step 0 | T: 4.658171e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.107621e+00 | T: ((Array([-0.01415354,  0.00564461], dtype=float32), Array(0.21991633, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.662513e+00 | T: ((Array([-0.00516776, -0.00350852], dtype=float32), Array(0.22970453, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.296830e+00 | T: ((Array([ 0.00278844, -0.01180986], dtype=float32), Array(0.23932734, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.993890e+00 | T: ((Array([ 0.00940616, -0.01896735], dtype=float32), Array(0.24875444, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.742109e+00 | T: ((Array([ 0.01450728, -0.02477725], dtype=float32), Array(0.2579616, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.531815e+00 | T: ((Array([ 0.01807101, -0.02914691], dtype=float32), Array(0.26693025, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.353652e+00 | T: ((Array([ 0.02021367, -0.03210216], dtype=float32), Array(0.2756462, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.198940e+00 | T: ((Array([ 0.02113205, -0.03376547], dtype=float32), Array(0.28409833, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.064461e+00 | T: ((Array([ 0.02102761, -0.03430841], dtype=float32), Array(0.2922784, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.946473e+00 | T: ((Array([ 0.02010646, -0.03391173], dtype=float32), Array(0.3001808, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.843497e+00 | T: ((Array([ 0.01855466, -0.03275513], dtype=float32), Array(0.30780205, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.754531e+00 | T: ((Array([ 0.0165409 , -0.03100896], dtype=float32), Array(0.31514168, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.675937e+00 | T: ((Array([ 0.01421764, -0.02881993], dtype=float32), Array(0.32220072, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.606809e+00 | T: ((Array([ 0.01171263, -0.0263344 ], dtype=float32), Array(0.32898167, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.546803e+00 | T: ((Array([ 0.00913526, -0.02366274], dtype=float32), Array(0.33548862, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.495521e+00 | T: ((Array([ 0.00658419, -0.02091827], dtype=float32), Array(0.3417271, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.446547e+00 | T: ((Array([ 0.00412749, -0.01819439], dtype=float32), Array(0.34770286, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.408750e+00 | T: ((Array([ 0.00182428, -0.0155759 ], dtype=float32), Array(0.35342345, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# ...
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 4.660534e+00 | T: ((Array([-0.02380762,  0.01534564], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 4.107599e+00 | T: ((Array([-0.01415456,  0.00562956], dtype=float32), Array(0.21991602, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 3.662402e+00 | T: ((Array([-0.00517297, -0.00353026], dtype=float32), Array(0.22970375, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 3.294331e+00 | T: ((Array([ 0.00278957, -0.01183421], dtype=float32), Array(0.23932564, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 2.993066e+00 | T: ((Array([ 0.00942461, -0.01898732], dtype=float32), Array(0.24875183, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 2.745331e+00 | T: ((Array([ 0.01452566, -0.02478871], dtype=float32), Array(0.25795907, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 2.533237e+00 | T: ((Array([ 0.01809048, -0.02914563], dtype=float32), Array(0.266928, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 2.353674e+00 | T: ((Array([ 0.02022888, -0.03209445], dtype=float32), Array(0.27564427, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 2.199979e+00 | T: ((Array([ 0.02114789, -0.03375168], dtype=float32), Array(0.28409672, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 2.063215e+00 | T: ((Array([ 0.02104732, -0.03428837], dtype=float32), Array(0.29227656, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 1.946270e+00 | T: ((Array([ 0.02012308, -0.03388977], dtype=float32), Array(0.30017862, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 1.844004e+00 | T: ((Array([ 0.01856604, -0.03273511], dtype=float32), Array(0.30779988, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 1.753667e+00 | T: ((Array([ 0.01655007, -0.03099177], dtype=float32), Array(0.31513938, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 1.676087e+00 | T: ((Array([ 0.01421733, -0.02881797], dtype=float32), Array(0.32219845, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 1.607149e+00 | T: ((Array([ 0.01171029, -0.02634632], dtype=float32), Array(0.32897958, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 1.547208e+00 | T: ((Array([ 0.00913353, -0.02369811], dtype=float32), Array(0.33548668, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 1.493721e+00 | T: ((Array([ 0.00657263, -0.02097389], dtype=float32), Array(0.34172508, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 1.448024e+00 | T: ((Array([ 0.0041052 , -0.01826715], dtype=float32), Array(0.34770098, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 1.408658e+00 | T: ((Array([ 0.00179836, -0.01566181], dtype=float32), Array(0.3534216, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 1.373182e+00 | T: ((Array([-0.00030388, -0.01322982], dtype=float32), Array(0.35889474, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.341673e+00 | T: ((Array([-0.00216577, -0.01101731], dtype=float32), Array(0.36412832, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.313572e+00 | T: ((Array([-0.00375684, -0.00907764], dtype=float32), Array(0.3691306, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.291013e+00 | T: ((Array([-0.00506689, -0.00743143], dtype=float32), Array(0.3739105, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.267735e+00 | T: ((Array([-0.00610477, -0.00609647], dtype=float32), Array(0.37847635, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.250325e+00 | T: ((Array([-0.00686203, -0.00507776], dtype=float32), Array(0.38283712, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.233790e+00 | T: ((Array([-0.00736632, -0.00437143], dtype=float32), Array(0.38700157, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.218362e+00 | T: ((Array([-0.00761851, -0.00396593], dtype=float32), Array(0.39097795, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.204000e+00 | T: ((Array([-0.00763028, -0.00384472], dtype=float32), Array(0.39477482, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.192519e+00 | T: ((Array([-0.00743594, -0.00397856], dtype=float32), Array(0.39840043, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.181305e+00 | T: ((Array([-0.00705957, -0.00433252], dtype=float32), Array(0.40186262, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.170568e+00 | T: ((Array([-0.00652297, -0.00488735], dtype=float32), Array(0.40516895, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.160773e+00 | T: ((Array([-0.00585753, -0.00560663], dtype=float32), Array(0.40832677, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.152455e+00 | T: ((Array([-0.00509342, -0.00646465], dtype=float32), Array(0.41134322, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.143918e+00 | T: ((Array([-0.00424915, -0.00740373], dtype=float32), Array(0.4142251, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.137461e+00 | T: ((Array([-0.00335443, -0.00838677], dtype=float32), Array(0.41697937, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.130855e+00 | T: ((Array([-0.00243109, -0.00940351], dtype=float32), Array(0.41961217, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.125057e+00 | T: ((Array([-0.00149894, -0.01042378], dtype=float32), Array(0.42212972, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.119667e+00 | T: ((Array([-0.00057752, -0.01142617], dtype=float32), Array(0.42453775, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.115024e+00 | T: ((Array([ 0.00031115, -0.01237104], dtype=float32), Array(0.4268421, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.110823e+00 | T: ((Array([ 0.00115392, -0.01325009], dtype=float32), Array(0.429048, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.106961e+00 | T: ((Array([ 0.00193117, -0.01404512], dtype=float32), Array(0.43116078, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.102591e+00 | T: ((Array([ 0.0026417 , -0.01474128], dtype=float32), Array(0.43318522, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.100068e+00 | T: ((Array([ 0.00328135, -0.01532957], dtype=float32), Array(0.4351261, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.097046e+00 | T: ((Array([ 0.00384005, -0.01580466], dtype=float32), Array(0.43698788, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.094056e+00 | T: ((Array([ 0.00431756, -0.01616769], dtype=float32), Array(0.43877456, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.090100e+00 | T: ((Array([ 0.00471118, -0.01641599], dtype=float32), Array(0.4404899, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.088677e+00 | T: ((Array([ 0.00502014, -0.01655541], dtype=float32), Array(0.44213828, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.086651e+00 | T: ((Array([ 0.00524535, -0.01658892], dtype=float32), Array(0.44372293, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.084491e+00 | T: ((Array([ 0.00539616, -0.01653257], dtype=float32), Array(0.44524735, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.082511e+00 | T: ((Array([ 0.00547182, -0.01638933], dtype=float32), Array(0.4467147, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.080717e+00 | T: ((Array([ 0.00547907, -0.01617154], dtype=float32), Array(0.44812799, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: -inf | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# 1min 9s ± 600 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Cylinder

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = Cylinder(params=(1.,jnp.array([0.,0.,1.]),jnp.pi/2.))
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
x0[1]
# Out:
# using M.Exp for Logarithm
# Array([0., 0.], dtype=float32)

# %%
file_path = 'scores/Cylinder/'+ loss_type + '/'
state = model_loader.load_model(file_path)
layers = [50, 100, 100, 50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.emb_dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), M.F(y))), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), M.F(y))), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Cylinder/' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Cylinder/xs.csv', header=None)
charts = pd.read_csv('Data/Cylinder/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean.initialize(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                     step_size=0.1, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.130957e+01 | T: ((Array([-0.02587204,  0.06452829], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.021403e+01 | T: ((Array([-0.03275904,  0.05470097], dtype=float32), Array(0.21992894, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 1 | T: 1.021403e+01 | T: (Array([-0.03275904,  0.05470097], dtype=float32), Array(0.21992894, dtype=float32))
# Step 0 | T: 1.130957e+01 | T: ((Array([-0.02587204,  0.06452829], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.021403e+01 | T: ((Array([-0.03275904,  0.05470097], dtype=float32), Array(0.21992894, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 2 | T: 9.283365e+00 | T: ((Array([-0.03446573,  0.04518323], dtype=float32), Array(0.2297475, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 3 | T: 8.488744e+00 | T: ((Array([-0.03292985,  0.03612189], dtype=float32), Array(0.23942202, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 4 | T: 7.807626e+00 | T: ((Array([-0.02987175,  0.02766396], dtype=float32), Array(0.2489243, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 5 | T: 7.221890e+00 | T: ((Array([-0.02639477,  0.01994391], dtype=float32), Array(0.25823137, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 6 | T: 6.716361e+00 | T: ((Array([-0.02330824,  0.01307091], dtype=float32), Array(0.26732498, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 7 | T: 6.278265e+00 | T: ((Array([-0.02115707,  0.00711916], dtype=float32), Array(0.27619112, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 8 | T: 5.896918e+00 | T: ((Array([-0.02016032,  0.00212382], dtype=float32), Array(0.28481933, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 9 | T: 5.563476e+00 | T: ((Array([-0.02025464, -0.00191736], dtype=float32), Array(0.2932024, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 10 | T: 5.270672e+00 | T: ((Array([-0.02121626, -0.00503792], dtype=float32), Array(0.30133572, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 11 | T: 5.012537e+00 | T: ((Array([-0.02276046, -0.00729472], dtype=float32), Array(0.30921704, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 12 | T: 4.784132e+00 | T: ((Array([-0.02459487, -0.00875987], dtype=float32), Array(0.31684598, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 13 | T: 4.581334e+00 | T: ((Array([-0.02644788, -0.00951401], dtype=float32), Array(0.32422385, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 14 | T: 4.400681e+00 | T: ((Array([-0.02808986, -0.00964112], dtype=float32), Array(0.3313533, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 15 | T: 4.239238e+00 | T: ((Array([-0.02935139, -0.00922497], dtype=float32), Array(0.33823815, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 16 | T: 4.094520e+00 | T: ((Array([-0.03013404, -0.00834686], dtype=float32), Array(0.3448831, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 17 | T: 3.964409e+00 | T: ((Array([-0.03040999, -0.00708414], dtype=float32), Array(0.35129365, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 18 | T: 3.847108e+00 | T: ((Array([-0.03021182, -0.00550949], dtype=float32), Array(0.35747585, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 19 | T: 3.741078e+00 | T: ((Array([-0.02961685, -0.00369046], dtype=float32), Array(0.36343622, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 20 | T: 3.645003e+00 | T: ((Array([-0.02873094, -0.00168934], dtype=float32), Array(0.3691817, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 21 | T: 3.557749e+00 | T: ((Array([-0.02767373,  0.00043694], dtype=float32), Array(0.37471935, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 22 | T: 3.478329e+00 | T: ((Array([-0.02656595,  0.00263676], dtype=float32), Array(0.38005656, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 23 | T: 3.405880e+00 | T: ((Array([-0.02551866,  0.00486375], dtype=float32), Array(0.38520068, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 24 | T: 3.339650e+00 | T: ((Array([-0.02462443,  0.00707673], dtype=float32), Array(0.3901592, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 25 | T: 3.278969e+00 | T: ((Array([-0.02395109,  0.00923959], dtype=float32), Array(0.3949395, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 26 | T: 3.223252e+00 | T: ((Array([-0.02353835,  0.01132116], dtype=float32), Array(0.399549, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 27 | T: 3.171983e+00 | T: ((Array([-0.02339759,  0.01329511], dtype=float32), Array(0.40399492, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 28 | T: 3.124706e+00 | T: ((Array([-0.02351438,  0.0151397 ], dtype=float32), Array(0.40828443, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 29 | T: 3.081018e+00 | T: ((Array([-0.02385299,  0.01683766], dtype=float32), Array(0.41242447, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 30 | T: 3.040567e+00 | T: ((Array([-0.02436215,  0.01837587], dtype=float32), Array(0.41642186, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 31 | T: 3.003039e+00 | T: ((Array([-0.02498116,  0.01974517], dtype=float32), Array(0.42028317, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 32 | T: 2.968158e+00 | T: ((Array([-0.02564614,  0.02094003], dtype=float32), Array(0.42401484, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 33 | T: 2.935673e+00 | T: ((Array([-0.02629565,  0.02195825], dtype=float32), Array(0.427623, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 34 | T: 2.905365e+00 | T: ((Array([-0.02687563,  0.02280065], dtype=float32), Array(0.43111363, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 35 | T: 2.877035e+00 | T: ((Array([-0.02734321,  0.02347071], dtype=float32), Array(0.43449244, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 36 | T: 2.850507e+00 | T: ((Array([-0.02766923,  0.02397427], dtype=float32), Array(0.4377649, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 37 | T: 2.825620e+00 | T: ((Array([-0.02783931,  0.02431913], dtype=float32), Array(0.4409363, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 38 | T: 2.802234e+00 | T: ((Array([-0.02785362,  0.0245148 ], dtype=float32), Array(0.44401166, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 39 | T: 2.780223e+00 | T: ((Array([-0.02772538,  0.02457214], dtype=float32), Array(0.44699576, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 40 | T: 2.759473e+00 | T: ((Array([-0.02747846,  0.02450303], dtype=float32), Array(0.4498932, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 41 | T: 2.739882e+00 | T: ((Array([-0.02714434,  0.02432016], dtype=float32), Array(0.45270833, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 42 | T: 2.721359e+00 | T: ((Array([-0.02675879,  0.0240367 ], dtype=float32), Array(0.4554453, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 43 | T: 2.703823e+00 | T: ((Array([-0.02635849,  0.02366605], dtype=float32), Array(0.45810804, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 44 | T: 2.687197e+00 | T: ((Array([-0.02597797,  0.02322168], dtype=float32), Array(0.46070027, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 45 | T: 2.671416e+00 | T: ((Array([-0.02564692,  0.02271686], dtype=float32), Array(0.46322557, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 46 | T: 2.656417e+00 | T: ((Array([-0.02538821,  0.02216452], dtype=float32), Array(0.46568727, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 47 | T: 2.642142e+00 | T: ((Array([-0.02521661,  0.0215771 ], dtype=float32), Array(0.46808857, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 48 | T: 2.628542e+00 | T: ((Array([-0.02513836,  0.02096638], dtype=float32), Array(0.47043246, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 49 | T: 2.615567e+00 | T: ((Array([-0.02515138,  0.02034341], dtype=float32), Array(0.4727218, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 50 | T: 2.603178e+00 | T: ((Array([-0.02524626,  0.01971838], dtype=float32), Array(0.47495922, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 51 | T: 2.591333e+00 | T: ((Array([-0.02540771,  0.01910059], dtype=float32), Array(0.4771473, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 52 | T: 2.579996e+00 | T: ((Array([-0.02561631,  0.01849838], dtype=float32), Array(0.47928846, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 53 | T: 2.569135e+00 | T: ((Array([-0.02585055,  0.01791908], dtype=float32), Array(0.4813849, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 54 | T: 2.558720e+00 | T: ((Array([-0.02608876,  0.01736902], dtype=float32), Array(0.48343876, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 55 | T: 2.548722e+00 | T: ((Array([-0.02631092,  0.01685355], dtype=float32), Array(0.48545206, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 56 | T: 2.539115e+00 | T: ((Array([-0.02650013,  0.01637699], dtype=float32), Array(0.48742664, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 57 | T: 2.529876e+00 | T: ((Array([-0.02664378,  0.01594271], dtype=float32), Array(0.48936433, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 58 | T: 2.520983e+00 | T: ((Array([-0.02673416,  0.01555317], dtype=float32), Array(0.49126676, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 59 | T: 2.512416e+00 | T: ((Array([-0.02676868,  0.01520993], dtype=float32), Array(0.4931355, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 60 | T: 2.504154e+00 | T: ((Array([-0.0267496 ,  0.01491375], dtype=float32), Array(0.49497208, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 61 | T: 2.496182e+00 | T: ((Array([-0.02668342,  0.01466461], dtype=float32), Array(0.49677786, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 62 | T: 2.488483e+00 | T: ((Array([-0.02657995,  0.01446183], dtype=float32), Array(0.49855414, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 63 | T: 2.481042e+00 | T: ((Array([-0.0264512 ,  0.01430411], dtype=float32), Array(0.50030214, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 64 | T: 2.473846e+00 | T: ((Array([-0.02631019,  0.0141896 ], dtype=float32), Array(0.50202304, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 65 | T: 2.466882e+00 | T: ((Array([-0.02616976,  0.01411599], dtype=float32), Array(0.50371796, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 66 | T: 2.460139e+00 | T: ((Array([-0.02604155,  0.01408058], dtype=float32), Array(0.5053879, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 67 | T: 2.453604e+00 | T: ((Array([-0.02593509,  0.01408038], dtype=float32), Array(0.5070338, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 68 | T: 2.447270e+00 | T: ((Array([-0.02585727,  0.01411214], dtype=float32), Array(0.5086566, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 69 | T: 2.441125e+00 | T: ((Array([-0.02581191,  0.01417243], dtype=float32), Array(0.5102572, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 70 | T: 2.435161e+00 | T: ((Array([-0.0257998 ,  0.01425775], dtype=float32), Array(0.5118363, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 71 | T: 2.429370e+00 | T: ((Array([-0.02581889,  0.01436452], dtype=float32), Array(0.51339465, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 72 | T: 2.423744e+00 | T: ((Array([-0.02586468,  0.01448919], dtype=float32), Array(0.51493305, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 73 | T: 2.418277e+00 | T: ((Array([-0.02593086,  0.01462827], dtype=float32), Array(0.51645213, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 74 | T: 2.412960e+00 | T: ((Array([-0.02601   ,  0.01477839], dtype=float32), Array(0.5179525, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 75 | T: 2.407789e+00 | T: ((Array([-0.02609425,  0.01493631], dtype=float32), Array(0.5194348, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 76 | T: 2.402756e+00 | T: ((Array([-0.02617607,  0.01509899], dtype=float32), Array(0.5208996, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 77 | T: 2.397859e+00 | T: ((Array([-0.02624881,  0.01526358], dtype=float32), Array(0.5223474, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 78 | T: 2.393088e+00 | T: ((Array([-0.02630718,  0.01542748], dtype=float32), Array(0.5237787, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 79 | T: 2.388441e+00 | T: ((Array([-0.02634761,  0.01558834], dtype=float32), Array(0.5251939, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 80 | T: 2.383913e+00 | T: ((Array([-0.02636836,  0.01574407], dtype=float32), Array(0.5265936, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 81 | T: 2.379499e+00 | T: ((Array([-0.02636951,  0.01589283], dtype=float32), Array(0.5279782, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 82 | T: 2.375196e+00 | T: ((Array([-0.0263528 ,  0.01603309], dtype=float32), Array(0.529348, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 83 | T: 2.370997e+00 | T: ((Array([-0.02632132,  0.01616355], dtype=float32), Array(0.5307035, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 84 | T: 2.366902e+00 | T: ((Array([-0.0262791,  0.0162832], dtype=float32), Array(0.53204495, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 85 | T: 2.362904e+00 | T: ((Array([-0.02623072,  0.01639127], dtype=float32), Array(0.5333727, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 86 | T: 2.359004e+00 | T: ((Array([-0.02618087,  0.01648724], dtype=float32), Array(0.53468716, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 87 | T: 2.355194e+00 | T: ((Array([-0.02613392,  0.01657081], dtype=float32), Array(0.53598857, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 88 | T: 2.351474e+00 | T: ((Array([-0.02609359,  0.01664191], dtype=float32), Array(0.5372772, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 89 | T: 2.347840e+00 | T: ((Array([-0.02606268,  0.01670065], dtype=float32), Array(0.5385534, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 90 | T: 2.344290e+00 | T: ((Array([-0.02604294,  0.0167473 ], dtype=float32), Array(0.53981745, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 91 | T: 2.340819e+00 | T: ((Array([-0.02603503,  0.01678231], dtype=float32), Array(0.5410695, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 92 | T: 2.337428e+00 | T: ((Array([-0.02603849,  0.01680624], dtype=float32), Array(0.5423099, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 93 | T: 2.334112e+00 | T: ((Array([-0.02605196,  0.01681979], dtype=float32), Array(0.5435388, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 94 | T: 2.330870e+00 | T: ((Array([-0.02607335,  0.01682371], dtype=float32), Array(0.5447565, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 95 | T: 2.327699e+00 | T: ((Array([-0.02610009,  0.01681887], dtype=float32), Array(0.5459631, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 96 | T: 2.324598e+00 | T: ((Array([-0.02612938,  0.01680616], dtype=float32), Array(0.5471589, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 97 | T: 2.321563e+00 | T: ((Array([-0.02615847,  0.0167865 ], dtype=float32), Array(0.548344, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 98 | T: 2.318595e+00 | T: ((Array([-0.02618488,  0.01676085], dtype=float32), Array(0.5495187, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 99 | T: 2.315690e+00 | T: ((Array([-0.02620658,  0.01673017], dtype=float32), Array(0.5506831, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 99 | T: 2.315690e+00 | T: (Array([-0.02620658,  0.01673017], dtype=float32), Array(0.5506831, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -0.0341 0.0185 )
# T = 0.5071

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0000 0.0000 )
# T = 0.5507

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0388
#  -T error = 0.0436

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/2:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/2:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.01940
#  -T error = 0.0071
# Bridge Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.0507

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # Torus

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = Torus()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
x0[1]
# Out:
# using M.Exp for Logarithm
# Array([0., 0.], dtype=float32)

# %%
file_path = 'scores/Torus/'+ loss_type + '/'
state = model_loader.load_model(file_path)
layers = [50, 100, 100, 50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.emb_dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), M.F(y))), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), M.F(y))), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Torus/' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Torus/xs.csv', header=None)
charts = pd.read_csv('Data/Torus/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean.initialize(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), 
                                     step_size=0.1, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.453338e+01 | T: ((Array([-0.18177876, -0.00945805], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.265824e+01 | T: ((Array([-0.17184542, -0.01500721], dtype=float32), Array(0.219913, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 1 | T: 1.265824e+01 | T: (Array([-0.17184542, -0.01500721], dtype=float32), Array(0.219913, dtype=float32))
# Step 0 | T: 1.453340e+01 | T: ((Array([-0.18177876, -0.00945805], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.265763e+01 | T: ((Array([-0.17184542, -0.015028  ], dtype=float32), Array(0.21991298, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 2 | T: 1.108802e+01 | T: ((Array([-0.16201945, -0.02065388], dtype=float32), Array(0.22969085, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 3 | T: 9.771928e+00 | T: ((Array([-0.15233807, -0.02273714], dtype=float32), Array(0.2392931, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 4 | T: 8.665657e+00 | T: ((Array([-0.14283484, -0.02159458], dtype=float32), Array(0.2486868, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 5 | T: 7.731694e+00 | T: ((Array([-0.13353942, -0.01877476], dtype=float32), Array(0.25784603, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 6 | T: 6.941618e+00 | T: ((Array([-0.12447762, -0.01548404], dtype=float32), Array(0.26675117, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 7 | T: 6.270371e+00 | T: ((Array([-0.11567149, -0.01271017], dtype=float32), Array(0.2753882, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 8 | T: 5.698425e+00 | T: ((Array([-0.10713954, -0.01112683], dtype=float32), Array(0.28374788, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 9 | T: 5.209940e+00 | T: ((Array([-0.09889688, -0.01088306], dtype=float32), Array(0.29182497, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 10 | T: 4.789880e+00 | T: ((Array([-0.09095556, -0.01174235], dtype=float32), Array(0.2996175, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 11 | T: 4.428392e+00 | T: ((Array([-0.08332466, -0.01329946], dtype=float32), Array(0.3071263, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 12 | T: 4.116339e+00 | T: ((Array([-0.07601065, -0.01510678], dtype=float32), Array(0.31435448, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 13 | T: 3.845485e+00 | T: ((Array([-0.06901763, -0.01675476], dtype=float32), Array(0.3213068, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 14 | T: 3.609640e+00 | T: ((Array([-0.06234752, -0.01791202], dtype=float32), Array(0.32798943, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 15 | T: 3.404012e+00 | T: ((Array([-0.05600031, -0.0184004 ], dtype=float32), Array(0.33440974, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 16 | T: 3.223542e+00 | T: ((Array([-0.04997426, -0.01820218], dtype=float32), Array(0.34057578, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 17 | T: 3.065178e+00 | T: ((Array([-0.04426618, -0.01743431], dtype=float32), Array(0.34649625, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 18 | T: 2.925501e+00 | T: ((Array([-0.0388715, -0.0162848], dtype=float32), Array(0.35218027, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 19 | T: 2.801942e+00 | T: ((Array([-0.03378458, -0.01498309], dtype=float32), Array(0.35763717, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 20 | T: 2.692142e+00 | T: ((Array([-0.02899874, -0.0137518 ], dtype=float32), Array(0.36287645, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 21 | T: 2.594517e+00 | T: ((Array([-0.02450654, -0.01278469], dtype=float32), Array(0.36790758, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 22 | T: 2.506560e+00 | T: ((Array([-0.0202998, -0.0122065], dtype=float32), Array(0.37274, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 23 | T: 2.428350e+00 | T: ((Array([-0.01636979, -0.01206261], dtype=float32), Array(0.37738302, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 24 | T: 2.357594e+00 | T: ((Array([-0.01270734, -0.01232953], dtype=float32), Array(0.38184577, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 25 | T: 2.293628e+00 | T: ((Array([-0.00930289, -0.01292171], dtype=float32), Array(0.38613713, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 26 | T: 2.235742e+00 | T: ((Array([-0.00614666, -0.01370466], dtype=float32), Array(0.3902657, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 27 | T: 2.183125e+00 | T: ((Array([-0.00322866, -0.01453952], dtype=float32), Array(0.39423987, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 28 | T: 2.134993e+00 | T: ((Array([-0.0005388 , -0.01529291], dtype=float32), Array(0.39806768, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 29 | T: 2.090705e+00 | T: ((Array([ 0.00193307, -0.01585581], dtype=float32), Array(0.40175685, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 30 | T: 2.050170e+00 | T: ((Array([ 0.00419706, -0.01615573], dtype=float32), Array(0.4053148, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 31 | T: 2.012636e+00 | T: ((Array([ 0.00626325, -0.01617463], dtype=float32), Array(0.4087486, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 32 | T: 1.978205e+00 | T: ((Array([ 0.00814158, -0.01592822], dtype=float32), Array(0.412065, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 33 | T: 1.945994e+00 | T: ((Array([ 0.00984187, -0.01547763], dtype=float32), Array(0.41527048, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 34 | T: 1.915810e+00 | T: ((Array([ 0.01137376, -0.01490612], dtype=float32), Array(0.41837108, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 35 | T: 1.887794e+00 | T: ((Array([ 0.01274668, -0.01430832], dtype=float32), Array(0.42137262, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 36 | T: 1.861552e+00 | T: ((Array([ 0.01396983, -0.01376798], dtype=float32), Array(0.4242806, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 37 | T: 1.837010e+00 | T: ((Array([ 0.01505217, -0.01335713], dtype=float32), Array(0.42710024, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 38 | T: 1.813626e+00 | T: ((Array([ 0.01600238, -0.01313041], dtype=float32), Array(0.42983642, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 39 | T: 1.791643e+00 | T: ((Array([ 0.01682887, -0.01309762], dtype=float32), Array(0.43249378, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 40 | T: 1.770879e+00 | T: ((Array([ 0.01753976, -0.01324071], dtype=float32), Array(0.43507668, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 41 | T: 1.751250e+00 | T: ((Array([ 0.01814289, -0.01352565], dtype=float32), Array(0.43758926, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 42 | T: 1.732166e+00 | T: ((Array([ 0.01864578, -0.01389507], dtype=float32), Array(0.4400353, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 43 | T: 1.714505e+00 | T: ((Array([ 0.01905565, -0.01428853], dtype=float32), Array(0.44241855, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 44 | T: 1.697238e+00 | T: ((Array([ 0.01937941, -0.01464073], dtype=float32), Array(0.44474235, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 45 | T: 1.681140e+00 | T: ((Array([ 0.01962369, -0.01490626], dtype=float32), Array(0.44700995, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 46 | T: 1.665355e+00 | T: ((Array([ 0.01979479, -0.01504882], dtype=float32), Array(0.44922435, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 47 | T: 1.650431e+00 | T: ((Array([ 0.01989871, -0.01506276], dtype=float32), Array(0.45138836, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 48 | T: 1.636099e+00 | T: ((Array([ 0.01994118, -0.01494877], dtype=float32), Array(0.45350465, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 49 | T: 1.622229e+00 | T: ((Array([ 0.0199276 , -0.01473697], dtype=float32), Array(0.4555757, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 50 | T: 1.608997e+00 | T: ((Array([ 0.01986311, -0.01446169], dtype=float32), Array(0.45760387, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 51 | T: 1.596318e+00 | T: ((Array([ 0.01975257, -0.01416761], dtype=float32), Array(0.4595913, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 52 | T: 1.583989e+00 | T: ((Array([ 0.01960056, -0.01389937], dtype=float32), Array(0.46154007, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 53 | T: 1.572088e+00 | T: ((Array([ 0.01941139, -0.01369051], dtype=float32), Array(0.46345207, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 54 | T: 1.560797e+00 | T: ((Array([ 0.01918913, -0.0135701 ], dtype=float32), Array(0.4653291, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 55 | T: 1.549640e+00 | T: ((Array([ 0.01893759, -0.01354981], dtype=float32), Array(0.46717286, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 56 | T: 1.538876e+00 | T: ((Array([ 0.01866033, -0.0136252 ], dtype=float32), Array(0.4689849, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 57 | T: 1.528749e+00 | T: ((Array([ 0.01836071, -0.01377137], dtype=float32), Array(0.4707667, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 58 | T: 1.518717e+00 | T: ((Array([ 0.01804182, -0.01395113], dtype=float32), Array(0.47251964, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 59 | T: 1.508847e+00 | T: ((Array([ 0.01770659, -0.01414127], dtype=float32), Array(0.47424498, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 60 | T: 1.499558e+00 | T: ((Array([ 0.01735769, -0.01431152], dtype=float32), Array(0.47594395, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 61 | T: 1.490479e+00 | T: ((Array([ 0.01699764, -0.01442916], dtype=float32), Array(0.4776177, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 62 | T: 1.481852e+00 | T: ((Array([ 0.01662874, -0.01448383], dtype=float32), Array(0.4792673, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 63 | T: 1.473108e+00 | T: ((Array([ 0.01625312, -0.0144686 ], dtype=float32), Array(0.48089373, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 64 | T: 1.464864e+00 | T: ((Array([ 0.01587276, -0.01439592], dtype=float32), Array(0.4824979, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 65 | T: 1.456973e+00 | T: ((Array([ 0.01548944, -0.01427865], dtype=float32), Array(0.48408073, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 66 | T: 1.449010e+00 | T: ((Array([ 0.01510482, -0.01414147], dtype=float32), Array(0.48564303, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 67 | T: 1.441473e+00 | T: ((Array([ 0.01472039, -0.01400633], dtype=float32), Array(0.48718557, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 68 | T: 1.434119e+00 | T: ((Array([ 0.01433751, -0.01388667], dtype=float32), Array(0.48870906, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 69 | T: 1.426940e+00 | T: ((Array([ 0.01395741, -0.01379656], dtype=float32), Array(0.4902142, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 70 | T: 1.419913e+00 | T: ((Array([ 0.01358121, -0.01374515], dtype=float32), Array(0.4917016, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 71 | T: 1.413188e+00 | T: ((Array([ 0.01320989, -0.0137424 ], dtype=float32), Array(0.4931719, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 72 | T: 1.406323e+00 | T: ((Array([ 0.01284434, -0.01377822], dtype=float32), Array(0.49462563, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 73 | T: 1.400128e+00 | T: ((Array([ 0.01248534, -0.01384501], dtype=float32), Array(0.49606332, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 74 | T: 1.393741e+00 | T: ((Array([ 0.01213358, -0.01392629], dtype=float32), Array(0.4974855, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 75 | T: 1.387634e+00 | T: ((Array([ 0.01178964, -0.01400222], dtype=float32), Array(0.4988926, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 76 | T: 1.381791e+00 | T: ((Array([ 0.01145405, -0.01406551], dtype=float32), Array(0.50028515, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 77 | T: 1.375851e+00 | T: ((Array([ 0.01112724, -0.01411011], dtype=float32), Array(0.50166345, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 78 | T: 1.370249e+00 | T: ((Array([ 0.01080958, -0.01412406], dtype=float32), Array(0.503028, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 79 | T: 1.364747e+00 | T: ((Array([ 0.01050135, -0.0141089 ], dtype=float32), Array(0.5043791, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 80 | T: 1.359370e+00 | T: ((Array([ 0.01020281, -0.0140675 ], dtype=float32), Array(0.50571716, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 81 | T: 1.354099e+00 | T: ((Array([ 0.00991412, -0.01401174], dtype=float32), Array(0.50704247, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 82 | T: 1.348991e+00 | T: ((Array([ 0.00963541, -0.01395295], dtype=float32), Array(0.5083554, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 83 | T: 1.343849e+00 | T: ((Array([ 0.00936676, -0.0138932 ], dtype=float32), Array(0.5096562, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 84 | T: 1.339066e+00 | T: ((Array([ 0.00910821, -0.01384374], dtype=float32), Array(0.5109452, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 85 | T: 1.334323e+00 | T: ((Array([ 0.00885975, -0.01380428], dtype=float32), Array(0.51222265, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 86 | T: 1.329456e+00 | T: ((Array([ 0.00862134, -0.01378656], dtype=float32), Array(0.51348877, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 87 | T: 1.324947e+00 | T: ((Array([ 0.00839291, -0.0137877 ], dtype=float32), Array(0.51474386, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 88 | T: 1.320385e+00 | T: ((Array([ 0.00817436, -0.01380189], dtype=float32), Array(0.5159881, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 89 | T: 1.316251e+00 | T: ((Array([ 0.00796555, -0.01383085], dtype=float32), Array(0.5172218, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 90 | T: 1.311716e+00 | T: ((Array([ 0.00776633, -0.01387029], dtype=float32), Array(0.5184451, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 91 | T: 1.307467e+00 | T: ((Array([ 0.00757653, -0.01390883], dtype=float32), Array(0.51965815, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 92 | T: 1.303365e+00 | T: ((Array([ 0.00739597, -0.01393503], dtype=float32), Array(0.5208612, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 93 | T: 1.299244e+00 | T: ((Array([ 0.00722442, -0.01394909], dtype=float32), Array(0.52205443, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 94 | T: 1.295384e+00 | T: ((Array([ 0.00706168, -0.01395102], dtype=float32), Array(0.523238, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 95 | T: 1.291507e+00 | T: ((Array([ 0.0069075 , -0.01393405], dtype=float32), Array(0.5244121, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 96 | T: 1.287609e+00 | T: ((Array([ 0.00676165, -0.0138993 ], dtype=float32), Array(0.52557683, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 97 | T: 1.284137e+00 | T: ((Array([ 0.00662388, -0.01385681], dtype=float32), Array(0.5267324, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 98 | T: 1.280383e+00 | T: ((Array([ 0.00649394, -0.01381648], dtype=float32), Array(0.52787894, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 99 | T: 1.276822e+00 | T: ((Array([ 0.00637155, -0.01377724], dtype=float32), Array(0.5290166, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 99 | T: 1.276822e+00 | T: (Array([ 0.00637155, -0.01377724], dtype=float32), Array(0.5290166, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0266 -0.0372 )
# T = 0.5016

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0000 0.0000 )
# T = 0.5290

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0457
#  -T error = 0.0274

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/2:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/2:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.02286
#  -T error = 0.0016
# Bridge Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.0290

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # Hyperbolic Parabolid

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = HypParaboloid()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/HypParaboloid/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
layers = [50, 100, 100, 50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/HypParaboloid/s1_' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/HypParaboloid/xs.csv', header=None)
charts = pd.read_csv('Data/HypParaboloid/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.001, max_iter=1000)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 140005670970288 was created on line:
#   /home/fmry/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py:42 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_718353/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      81
#      82     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 83             iterative_mle(samples,\
#      84                 neg_log_p_Ts,\
#      85                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      55
#      56     for i in range(num_steps):
# ---> 57         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      58         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      59         if i % 1 == 0:
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      42
#      43         params = get_params(opt_state)
# ---> 44         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      45         opt_state = opt_update(step, grads, opt_state)
#      46         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     133         T = jnp.sum(dts)
#     134
# --> 135         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     136
#     137         # sample
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63     # guide function
#      64     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 65                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      66                                       (1,0))
#      67     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      50             v0 = jnp.zeros(M.dim)
#      51
# ---> 52         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      53
#      54         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.2148 -0.7179 )
# T = 0.7120

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/3061874042.py in <module>
#       1 print(f"Bridge Riemannian Diffusion Mean:")
# ----> 2 print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
#       3 print(f"T = {T_bridge[-1]:.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0000
#  -T error = 0.4710

# %%
M.F((mu_sm[0][-1], mu_sm[1][-1]))
# Out:
# Array([  1.0282233,  -3.7317057, -12.868383 ], dtype=float32)

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 3.8708
#  -T error = 0.2000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/3470961726.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 426 ms ± 7.06 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # SPDN

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 10

# %%
M = SPDN(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([10.]*(N*(N+1)//2))
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/SPDN'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
from jax import jacfwd
if N*N<10:
    layers = [50,100,100,50]
elif N*N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    #ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/SPDN'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  60

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/SPDN'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/SPDN'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values)[~jnp.isnan(xs.values).any(axis=1)], jnp.array(charts.values)[~jnp.isnan(xs.values).any(axis=1)])

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.01, max_iter=1000)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_216162/2011504933.py in <module>
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# /tmp/ipykernel_216162/2011504933.py in <lambda>(t)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# /tmp/ipykernel_216162/2011504933.py in <lambda>(x, chart)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
# /tmp/ipykernel_216162/1380410703.py in gradt_log(x, y, t)
#      19
#      20     s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
# ---> 21     s2_val = ggrady_log(x,y,t)
#      22
#      23     div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
#
# /tmp/ipykernel_216162/1380410703.py in ggrady_log(x, y, t)
#      27 def ggrady_log(x,y,t):
#      28
# ---> 29     ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
#      30     #ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
#      31
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/autodiff/tuple.py in jacf(x, *args, **kwargs)
#      39         return f((x,chart),*args,**kwargs)
#      40     def jacf(x:Tuple[Array, Array],*args,**kwargs)->Array:
# ---> 41         return jacfwd(fxchart,argnums=0)(x[0],x[1],*args,**kwargs)
#      42     return jacf
#      43
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in jacfun(*args, **kwargs)
#     858     if not has_aux:
#     859       pushfwd: Callable = partial(_jvp, f_partial, dyn_args)
# --> 860       y, jac = vmap(pushfwd, out_axes=(None, -1))(_std_basis(dyn_args))
#     861     else:
#     862       pushfwd: Callable = partial(_jvp, f_partial, dyn_args, has_aux=True)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in _jvp(fun, primals, tangents, has_aux)
#    1985   if not has_aux:
#    1986     flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 1987     out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    1988     out_tree = out_tree()
#    1989     return (tree_unflatten(out_tree, out_primals),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/autodiff/tuple.py in fxchart(x, chart, *args, **kwargs)
#      37     """jax.jacfwd but only for the x variable of a function taking coordinates and chart"""
#      38     def fxchart(x:Array,chart:Array,*args,**kwargs)->Array:
# ---> 39         return f((x,chart),*args,**kwargs)
#      40     def jacf(x:Tuple[Array, Array],*args,**kwargs)->Array:
#      41         return jacfwd(fxchart,argnums=0)(x[0],x[1],*args,**kwargs)
#
# /tmp/ipykernel_216162/1380410703.py in <lambda>(y)
#      27 def ggrady_log(x,y,t):
#      28
# ---> 29     ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
#      30     #ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
#      31
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_216162/1380410703.py in <lambda>(x)
#       8 else:
#       9     layers = [50,100,200,400,400,200,100,50]
# ---> 10 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      11 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      12                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      53         grad_euc = (x1-x2)/t
#      54
# ---> 55         return self.model()(x)+grad_euc
#      56
#      57 @dataclasses.dataclass
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, *args, **kwargs)
#     125         out = layer(out, *args, **kwargs)
#     126       else:
# --> 127         out = layer(out)
#     128     return out
#     129
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# KeyboardInterrupt:

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 139768308431904 was created on line:
#   /home/fmry/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py:42 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_915229/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      81
#      82     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 83             iterative_mle(samples,\
#      84                 neg_log_p_Ts,\
#      85                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      55
#      56     for i in range(num_steps):
# ---> 57         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      58         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      59         if i % 1 == 0:
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      42
#      43         params = get_params(opt_state)
# ---> 44         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      45         opt_state = opt_update(step, grads, opt_state)
#      46         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     133         T = jnp.sum(dts)
#     134
# --> 135         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     136
#     137         # sample
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63     # guide function
#      64     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 65                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      66                                       (1,0))
#      67     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      50             v0 = jnp.zeros(M.dim)
#      51
# ---> 52         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      53
#      54         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.0220
#  -T error = 0.4990

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 1min 7s ± 2.18 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Landmarks

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2

# %%
M = Landmarks(N=N,m=2)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords(jnp.vstack((jnp.linspace(-5.0,5.0,M.N),jnp.linspace(5.0,-5.0,M.N))).T.flatten())
x0 = M.coords(jnp.vstack((jnp.linspace(-5.0,5.0,M.N),jnp.zeros(M.N))).T.flatten())
if N >=10:
    with open('../../Data/landmarks/Papilonidae/Papilionidae_landmarks.txt', 'r') as the_file:
        all_data = [line.strip() for line in the_file.readlines()]

        x1 = jnp.array([float(x) for x in all_data[0].split()[2:]])
        x2 = jnp.array([float(x) for x in all_data[1].split()[2:]])

        x0 = M.coords(jnp.vstack((x1[::len(x1)//N],x2[::len(x2)//N])).T.flatten())
# Out:
# using M.Exp for Logarithm

# %%
x0[0].reshape(-1,2)
# Out:
# Array([[-5.,  0.],
#        [ 5.,  0.]], dtype=float32)

# %%
file_path = 'scores/Landmarks'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/Landmarks'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if 2*N<10:
    layers = [50,100,100,50]
elif 2*N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    #ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    ggrad = s2.apply(state_s2.params,rng_key, jnp.hstack((x[0], y[0], t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Landmarks'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/Landmarks'+str(N)+'/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  200

# %%
fig = plt.figure(figsize=(10,10))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Landmarks'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/Landmarks'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                    step_size=0.1, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 132292243607856 was created on line:
#   /home/fmry/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/riemannian/Log.py:43 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_137911/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      82
#      83     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 84             iterative_mle(samples,\
#      85                 neg_log_p_Ts,\
#      86                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      56
#      57     for i in range(num_steps):
# ---> 58         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      59         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      60         if i % 1 == 0:
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      43
#      44         params = get_params(opt_state)
# ---> 45         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      46         opt_state = opt_update(step, grads, opt_state)
#      47         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     134         T = jnp.sum(dts)
#     135
# --> 136         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     137
#     138         # sample
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      64     # guide function
#      65     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 66                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      67                                       (1,0))
#      68     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      51             v0 = jnp.zeros(M.dim)
#      52
# ---> 53         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      54
#      55         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -4.9548 -0.0284 4.9063 0.0468 )
# T = 0.6400

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.1175
#  -T error = 0.1400

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 10.1 s ± 2.39 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
