# %% [markdown]
# # Score Table

# %% [markdown]
# This notebook estimates the diffusion t-mean for synthetic data compared to the estimation using bridge sampling. Further time-complexity is estimated in this note book

# %%
from jaxgeometry.manifolds import *
from jaxgeometry.integration import dts
from jaxgeometry.autodiff import jacfwdx
from jaxgeometry.statistics.score_matching import diffusion_mean
import jaxgeometry.statistics as jstat
import jaxgeometry.stochastics as jstoch
import jax.numpy as jnp
import haiku as hk
import jax
from jax import vmap

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr

from jaxgeometry.statistics.score_matching import model_loader
from models import models

# %%
loss_type = 'dsm'
s2_approximation = True

# %%
def get_coords(M, Fx):
    chart = M.centered_chart(Fx)
    return (M.invF((Fx,chart)),chart)

def to_TM(M, Fx,v):
    x = get_coords(Fx)
#     return jnp.dot(M.JF(x),jnp.dot(M.invJF((Fx,x[1])),v))
    JFx = M.JF(x)
    return jnp.dot(JFx,jnp.linalg.lstsq(JFx,v)[0])

def to_TMx(M, Fx,v):

    x = get_coords(M, Fx)

    return jnp.dot(M.invJF((Fx,x[1])),v)

# %% [markdown]
# # Euclidean

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2 #Change this for R2, R3, R5, R10, R20, R50

# %%
M = Euclidean(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = (jnp.zeros(N), jnp.zeros(1))
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/R'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/R'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)

if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))

rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad

# %%
file_path_s1s2 = 'scores/R'+str(N)+'/s1s2/'
state_s1s2 = model_loader.load_model(file_path_s1s2)

@hk.transform
def s1s2_model(x):

    s1s2 =  models.MLP_s1s2(
        models.MLP_s1(dim=M.dim, layers=layers), 
        models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                        dim=M.dim,
                                                        r = max(M.dim//2,1)))
    return s1s2(x)

rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1s2_model.apply(state_s1s2.params,rng_key, jnp.hstack((x[0], y[0], t)))[0]

def gradt_log(x,y,t):
    
    s1_val, s2_val = s1s2_model.apply(state_s1s2.params,rng_key, jnp.hstack((x[0], y[0], t)))
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_359239/3308516828.py in <module>
#       1 file_path_s1s2 = 'scores/R'+str(N)+'/s1s2/'
# ----> 2 state_s1s2 = model_loader.load_model(file_path_s1s2)
#       3
#       4 @hk.transform
#       5 def s1s2_model(x):
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/model_loader.py in load_model(ckpt_dir)
#      34
#      35     file_name = os.path.join(ckpt_dir, "tree.pkl")
# ---> 36     with open(file_name, "rb") as f:
#      37         tree_struct = pickle.load(f)
#      38
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scores/R20/s1s2/tree.pkl'

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/R'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/R'+str(N)+'/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  10

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/R'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/R'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                    step_size=0.01, max_iter=1000)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.155812e+01 | T: ((Array([0.01136593, 0.09555456], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.042644e+01 | T: ((Array([0.00212493, 0.08565386], dtype=float32), Array(0.21992828, dtype=float32)), Array([0.], dtype=float32))
# Final 1 | T: 1.042644e+01 | T: (Array([0.00212493, 0.08565386], dtype=float32), Array(0.21992828, dtype=float32))
# Step 0 | T: 1.155812e+01 | T: ((Array([0.01136593, 0.09555456], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.042644e+01 | T: ((Array([0.00212493, 0.08565386], dtype=float32), Array(0.21992828, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.465787e+00 | T: ((Array([-0.0053882 ,  0.07591895], dtype=float32), Array(0.22974522, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.647336e+00 | T: ((Array([-0.01034314,  0.06641454], dtype=float32), Array(0.23941696, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 7.946887e+00 | T: ((Array([-0.01267188,  0.05720215], dtype=float32), Array(0.24891524, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.344659e+00 | T: ((Array([-0.01287851,  0.04833843], dtype=float32), Array(0.25821704, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.824751e+00 | T: ((Array([-0.01156912,  0.03987393], dtype=float32), Array(0.26730403, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.374244e+00 | T: ((Array([-0.00926234,  0.03185201], dtype=float32), Array(0.27616215, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 5.982482e+00 | T: ((Array([-0.00637595,  0.02430826], dtype=float32), Array(0.284781, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.640588e+00 | T: ((Array([-0.00325052,  0.01727003], dtype=float32), Array(0.29315343, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.341134e+00 | T: ((Array([-0.0001663 ,  0.01075657], dtype=float32), Array(0.30127499, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.077882e+00 | T: ((Array([0.00265194, 0.00477912], dtype=float32), Array(0.30914363, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.845583e+00 | T: ((Array([ 0.00503667, -0.0006584 ], dtype=float32), Array(0.3167593, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.639821e+00 | T: ((Array([ 0.00687964, -0.00555876], dtype=float32), Array(0.32412347, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.456881e+00 | T: ((Array([ 0.00812964, -0.00993059], dtype=float32), Array(0.33123913, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.293637e+00 | T: ((Array([ 0.00878515, -0.01378757], dtype=float32), Array(0.3381103, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.147457e+00 | T: ((Array([ 0.00888371, -0.01714749], dtype=float32), Array(0.3447419, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.016124e+00 | T: ((Array([ 0.00849073, -0.02003149], dtype=float32), Array(0.35113958, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.897761e+00 | T: ((Array([ 0.00768939, -0.02246327], dtype=float32), Array(0.35730955, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.790775e+00 | T: ((Array([ 0.00657245, -0.02446842], dtype=float32), Array(0.36325848, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.693802e+00 | T: ((Array([ 0.0052359 , -0.02607383], dtype=float32), Array(0.36899334, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.605675e+00 | T: ((Array([ 0.00377403, -0.02730715], dtype=float32), Array(0.37452132, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.525383e+00 | T: ((Array([ 0.00227544, -0.02819638], dtype=float32), Array(0.3798498, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.452051e+00 | T: ((Array([ 0.00081989, -0.0287695 ], dtype=float32), Array(0.3849862, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.384918e+00 | T: ((Array([-0.00052422, -0.02905417], dtype=float32), Array(0.38993794, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.323315e+00 | T: ((Array([-0.00170173, -0.02907749], dtype=float32), Array(0.39471245, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.266661e+00 | T: ((Array([-0.00267174, -0.0288658 ], dtype=float32), Array(0.3993171, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.214442e+00 | T: ((Array([-0.00340796, -0.02844457], dtype=float32), Array(0.40375906, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.166210e+00 | T: ((Array([-0.00389826, -0.0278382 ], dtype=float32), Array(0.40804547, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.121569e+00 | T: ((Array([-0.00414355, -0.02707002], dtype=float32), Array(0.41218323, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.080172e+00 | T: ((Array([-0.00415619, -0.02616217], dtype=float32), Array(0.41617906, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.041711e+00 | T: ((Array([-0.00395808, -0.02513558], dtype=float32), Array(0.42003953, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 3.005914e+00 | T: ((Array([-0.0035785 , -0.02400993], dtype=float32), Array(0.423771, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.972540e+00 | T: ((Array([-0.00305199, -0.02280365], dtype=float32), Array(0.42737952, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.941376e+00 | T: ((Array([-0.00241621, -0.0215339 ], dtype=float32), Array(0.43087104, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.912229e+00 | T: ((Array([-0.00170997, -0.0202166 ], dtype=float32), Array(0.43425122, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.884927e+00 | T: ((Array([-0.00097141, -0.01886641], dtype=float32), Array(0.4375255, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.859314e+00 | T: ((Array([-0.00023642, -0.0174968 ], dtype=float32), Array(0.44069913, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.835250e+00 | T: ((Array([ 0.00046272, -0.01612003], dtype=float32), Array(0.44377705, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.812607e+00 | T: ((Array([ 0.00109837, -0.01474722], dtype=float32), Array(0.44676405, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.791270e+00 | T: ((Array([ 0.00164829, -0.01338835], dtype=float32), Array(0.44966468, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.771135e+00 | T: ((Array([ 0.00209615, -0.01205234], dtype=float32), Array(0.4524833, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.752106e+00 | T: ((Array([ 0.00243161, -0.01074707], dtype=float32), Array(0.455224, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.734097e+00 | T: ((Array([ 0.00265026, -0.00947942], dtype=float32), Array(0.45789072, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.717029e+00 | T: ((Array([ 0.00275323, -0.00825534], dtype=float32), Array(0.46048716, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.700832e+00 | T: ((Array([ 0.00274661, -0.00707986], dtype=float32), Array(0.46301687, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.685440e+00 | T: ((Array([ 0.00264072, -0.00595721], dtype=float32), Array(0.4654832, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.670794e+00 | T: ((Array([ 0.00244925, -0.00489078], dtype=float32), Array(0.46788928, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.656842e+00 | T: ((Array([ 0.00218835, -0.00388325], dtype=float32), Array(0.47023815, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.643534e+00 | T: ((Array([ 0.00187573, -0.00293661], dtype=float32), Array(0.4725326, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.630826e+00 | T: ((Array([ 0.0015297 , -0.00205218], dtype=float32), Array(0.47477534, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.618677e+00 | T: ((Array([ 0.00116836, -0.00123073], dtype=float32), Array(0.47696888, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.607051e+00 | T: ((Array([ 0.00080881, -0.00047248], dtype=float32), Array(0.47911564, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.595911e+00 | T: ((Array([0.00046651, 0.00022284], dtype=float32), Array(0.4812178, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.585228e+00 | T: ((Array([0.00015478, 0.00085596], dtype=float32), Array(0.48327753, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.574970e+00 | T: ((Array([-0.00011561,  0.00142795], dtype=float32), Array(0.48529682, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.565113e+00 | T: ((Array([-0.0003367 ,  0.00194029], dtype=float32), Array(0.48727754, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.555630e+00 | T: ((Array([-0.00050336,  0.00239471], dtype=float32), Array(0.48922145, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.546501e+00 | T: ((Array([-0.00061332,  0.00279325], dtype=float32), Array(0.49113026, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.537703e+00 | T: ((Array([-0.000667  ,  0.00313814], dtype=float32), Array(0.4930055, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.529217e+00 | T: ((Array([-0.00066722,  0.0034318 ], dtype=float32), Array(0.49484867, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.521026e+00 | T: ((Array([-0.00061887,  0.00367683], dtype=float32), Array(0.49666113, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.513113e+00 | T: ((Array([-0.00052853,  0.00387592], dtype=float32), Array(0.4984442, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.505464e+00 | T: ((Array([-0.000404  ,  0.00403186], dtype=float32), Array(0.5001991, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.498065e+00 | T: ((Array([-0.00025388,  0.00414747], dtype=float32), Array(0.50192696, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.490903e+00 | T: ((Array([-8.7072927e-05,  4.2256583e-03], dtype=float32), Array(0.5036289, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.483966e+00 | T: ((Array([8.7570515e-05, 4.2692912e-03], dtype=float32), Array(0.50530595, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.477243e+00 | T: ((Array([0.00026168, 0.00428124], dtype=float32), Array(0.5069591, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.470723e+00 | T: ((Array([0.00042768, 0.00426436], dtype=float32), Array(0.50858915, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.464398e+00 | T: ((Array([0.00057902, 0.00422141], dtype=float32), Array(0.51019704, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.458258e+00 | T: ((Array([0.00071043, 0.00415513], dtype=float32), Array(0.51178354, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.452295e+00 | T: ((Array([0.00081796, 0.00406816], dtype=float32), Array(0.5133494, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.446500e+00 | T: ((Array([0.00089909, 0.00396304], dtype=float32), Array(0.5148954, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.440868e+00 | T: ((Array([0.00095271, 0.00384222], dtype=float32), Array(0.5164221, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.435390e+00 | T: ((Array([0.000979  , 0.00370802], dtype=float32), Array(0.51793015, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.430060e+00 | T: ((Array([0.00097933, 0.00356268], dtype=float32), Array(0.51942015, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.424873e+00 | T: ((Array([0.00095611, 0.00340827], dtype=float32), Array(0.5208927, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.419822e+00 | T: ((Array([0.00091254, 0.00324677], dtype=float32), Array(0.5223483, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.414903e+00 | T: ((Array([0.00085246, 0.00308   ], dtype=float32), Array(0.52378744, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.410110e+00 | T: ((Array([0.00078006, 0.00290969], dtype=float32), Array(0.5252106, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.405438e+00 | T: ((Array([0.00069969, 0.00273739], dtype=float32), Array(0.5266183, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.400884e+00 | T: ((Array([0.00061568, 0.00256455], dtype=float32), Array(0.52801085, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.396442e+00 | T: ((Array([0.00053208, 0.00239249], dtype=float32), Array(0.5293887, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.392109e+00 | T: ((Array([0.00045258, 0.00222238], dtype=float32), Array(0.53075224, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.387881e+00 | T: ((Array([0.00038034, 0.0020553 ], dtype=float32), Array(0.5321018, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.383754e+00 | T: ((Array([0.0003179 , 0.00189217], dtype=float32), Array(0.5334377, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.379725e+00 | T: ((Array([0.00026711, 0.00173383], dtype=float32), Array(0.53476036, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.375791e+00 | T: ((Array([0.00022917, 0.00158099], dtype=float32), Array(0.53607, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.371948e+00 | T: ((Array([0.00020455, 0.00143425], dtype=float32), Array(0.5373669, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.368194e+00 | T: ((Array([0.00019312, 0.00129412], dtype=float32), Array(0.5386514, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.364525e+00 | T: ((Array([0.00019414, 0.00116102], dtype=float32), Array(0.5399237, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.360939e+00 | T: ((Array([0.00020641, 0.00103525], dtype=float32), Array(0.5411841, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.357434e+00 | T: ((Array([0.0002283 , 0.00091706], dtype=float32), Array(0.54243284, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.354006e+00 | T: ((Array([0.00025795, 0.00080661], dtype=float32), Array(0.5436702, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.350654e+00 | T: ((Array([0.00029328, 0.00070398], dtype=float32), Array(0.54489625, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.347376e+00 | T: ((Array([0.00033217, 0.00060919], dtype=float32), Array(0.5461113, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.344168e+00 | T: ((Array([0.00037253, 0.00052221], dtype=float32), Array(0.54731554, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.341030e+00 | T: ((Array([0.00041241, 0.00044295], dtype=float32), Array(0.5485092, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.337958e+00 | T: ((Array([0.00045005, 0.00037126], dtype=float32), Array(0.5496924, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.334953e+00 | T: ((Array([0.00048397, 0.00030697], dtype=float32), Array(0.55086535, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.334953e+00 | T: (Array([0.00048397, 0.00030697], dtype=float32), Array(0.55086535, dtype=float32))

# %%
mu_opt, T_opt = M.mlxt_hk(X_obs)

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0008 -0.0248 -0.0360 0.0100 0.0187 -0.0231 -0.0127 0.0094 0.0205 0.0018 -0.0018 -0.0194 0.0400 -0.0087 0.0052 -0.0137 -0.0046 0.0154 0.0049 -0.0303 )
# T = 0.4979

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgex[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0005 0.0003 )
# T = 0.5509

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[0]), ")")
print(f"T = {T_opt:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -0.0020 -0.0167 -0.0325 0.0214 0.0249 -0.0179 -0.0031 0.0078 0.0194 -0.0090 -0.0114 -0.0111 0.0276 -0.0282 0.0010 -0.0050 -0.0120 0.0215 0.0094 -0.0232 )
# T = 0.5007

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_sm[0][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt):.5f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_bridgex[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt):.5f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.00190
#  -T error = 0.00283
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_359239/3769845863.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_sm[0][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt):.5f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[0]-mu_bridgex[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt):.5f}")
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     254     args = (other, self) if swap else (self, other)
#     255     if isinstance(other, _accepted_binop_types):
# --> 256       return binary_op(*args)
#     257     if isinstance(other, _rejected_binop_types):
#     258       raise TypeError(f"unsupported operand type(s) for {opchar}: "
#
#     [... skipping hidden 12 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/ufuncs.py in <lambda>(x1, x2)
#      80     fn = lambda x1, x2, /: lax_fn(*promote_args_numeric(numpy_fn.__name__, x1, x2))
#      81   else:
# ---> 82     fn = lambda x1, x2, /: lax_fn(*promote_args(numpy_fn.__name__, x1, x2))
#      83   fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#      84   fn = jit(fn, inline=True)
#
#     [... skipping hidden 7 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in broadcasting_shape_rule(name, *avals)
#    1585         result_shape.append(non_1s[0])
#    1586       else:
# -> 1587         raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    1588                         f'{", ".join(map(str, map(tuple, shapes)))}.')
#    1589
#
# TypeError: sub got incompatible shapes for broadcasting: (20,), (2,).

# %% [markdown]
# ## Timing Score

# %%
dims = [2,3,5,10]
time_score = []
time_bridge = []

for N in dims:
    M = Euclidean(N=N)
    jstoch.Brownian_coords(M)
    jstat.diffusion_mean(M)
    x0 = (jnp.zeros(N), jnp.zeros(1))
    
    file_path = 'scores/R'+str(N)+'/s1_'+ loss_type + '/'
    state = model_loader.load_model(file_path)

    file_path_s2 = 'scores/R'+str(N)+'/s2/'
    state_s2 = model_loader.load_model(file_path_s2)
    if N<10:
        layers = [50,100,100,50]
    elif N<50:
        layers = [50,100,200,200,100,50]
    else:
        layers = [50,100,200,400,400,200,100,50]
    s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
    s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                    dim=M.dim, r = max(M.dim//2,1))(x))
    rng_key = jax.random.PRNGKey(2712)
    def grady_log(x,y,t):

        return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

    def gradt_log(x,y,t):

        s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
        s2_val = ggrady_log(x,y,t)

        div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())

        return 0.5*(jnp.dot(s1_val, s1_val)+div)

    def ggrady_log_ad(x,y,t):

        ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)

        return ggrad

    def ggrady_log_score(x,y,t):

        ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))

        return ggrad

    if s2_approximation:
        ggrady_log = ggrady_log_score
    else:
        ggrady_log = ggrady_log_ad
        
    xs = pd.read_csv('Data/R'+str(N)+'/xs.csv', header=None)
    charts = pd.read_csv('Data/R'+str(N)+'/chart.csv', header=None)
    X_obs = (jnp.array(xs.values), jnp.array(charts.values))
    
    diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
    result = %timeit -o M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), \
                                           step_size=0.01, max_iter=100)
    time_score.append(result)
    result = %timeit -o M.diffusion_mean(X_obs,num_steps=100, N=1)
    time_bridge.append(result)
# Out:
# using M.Exp for Logarithm
# 231 ms ± 4.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Step 0 | T: 1.190953e+01 | T: ((Array([-0.18854065, -0.00813   ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.072831e+01 | T: ((Array([-0.17860703, -0.00201511], dtype=float32), Array(0.2199275, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.722255e+00 | T: ((Array([-0.1687803 ,  0.00415572], dtype=float32), Array(0.22974214, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.864707e+00 | T: ((Array([-0.15909755,  0.00704197], dtype=float32), Array(0.23940943, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 8.130839e+00 | T: ((Array([-0.14959241,  0.00662608], dtype=float32), Array(0.24890064, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.500125e+00 | T: ((Array([-0.1402947 ,  0.00432054], dtype=float32), Array(0.25819233, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.956180e+00 | T: ((Array([-0.13123041,  0.00126469], dtype=float32), Array(0.26726595, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.485485e+00 | T: ((Array([-0.12242181, -0.00163689], dtype=float32), Array(0.2761073, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 6.076708e+00 | T: ((Array([-0.11388758, -0.0037074 ], dtype=float32), Array(0.284706, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.720333e+00 | T: ((Array([-0.10564299, -0.00462384], dtype=float32), Array(0.29305488, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.408418e+00 | T: ((Array([-0.09770017, -0.00441812], dtype=float32), Array(0.3011496, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.134396e+00 | T: ((Array([-0.09006823, -0.00333683], dtype=float32), Array(0.30898827, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.892823e+00 | T: ((Array([-0.08275362, -0.00171179], dtype=float32), Array(0.31657094, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.679152e+00 | T: ((Array([-0.07576034,  0.00011104], dtype=float32), Array(0.32389933, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.489553e+00 | T: ((Array([-0.06909017,  0.00181418], dtype=float32), Array(0.33097658, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.320774e+00 | T: ((Array([-0.06274289,  0.00314593], dtype=float32), Array(0.33780694, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.170044e+00 | T: ((Array([-0.05671657,  0.00394983], dtype=float32), Array(0.34439564, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.035003e+00 | T: ((Array([-0.05100773,  0.00417425], dtype=float32), Array(0.3507486, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.913647e+00 | T: ((Array([-0.04561154,  0.00385993], dtype=float32), Array(0.3568723, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.804269e+00 | T: ((Array([-0.04052204,  0.00311494], dtype=float32), Array(0.3627737, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.705415e+00 | T: ((Array([-0.03573229,  0.00208747], dtype=float32), Array(0.36846, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.615835e+00 | T: ((Array([-0.03123453,  0.00094146], dtype=float32), Array(0.3739387, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.534453e+00 | T: ((Array([-0.02702029, -0.00016455], dtype=float32), Array(0.37921745, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.460329e+00 | T: ((Array([-0.02308058, -0.00109554], dtype=float32), Array(0.38430384, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.392645e+00 | T: ((Array([-0.01940599, -0.00175375], dtype=float32), Array(0.38920557, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.330687e+00 | T: ((Array([-0.01598674, -0.00208645], dtype=float32), Array(0.3939303, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.273831e+00 | T: ((Array([-0.01281285, -0.00208673], dtype=float32), Array(0.39848545, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.221533e+00 | T: ((Array([-0.00987418, -0.00178824], dtype=float32), Array(0.40287852, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.173320e+00 | T: ((Array([-0.0071605 , -0.00125582], dtype=float32), Array(0.4071167, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.128778e+00 | T: ((Array([-0.00466161, -0.00057422], dtype=float32), Array(0.41120705, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.087540e+00 | T: ((Array([-0.0023673 ,  0.00016373], dtype=float32), Array(0.41515642, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.049284e+00 | T: ((Array([-0.00026751,  0.00086824], dtype=float32), Array(0.41897148, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 3.013723e+00 | T: ((Array([0.00164772, 0.00146232], dtype=float32), Array(0.42265865, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.980602e+00 | T: ((Array([0.00338815, 0.00188909], dtype=float32), Array(0.4262241, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.949691e+00 | T: ((Array([0.00496336, 0.00211622], dtype=float32), Array(0.42967382, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.920789e+00 | T: ((Array([0.00638267, 0.00213702], dtype=float32), Array(0.43301347, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.893714e+00 | T: ((Array([0.00765516, 0.00196851], dtype=float32), Array(0.43624857, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.868307e+00 | T: ((Array([0.00878964, 0.00164702], dtype=float32), Array(0.43938434, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.844423e+00 | T: ((Array([0.00979463, 0.00122225], dtype=float32), Array(0.4424258, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.821935e+00 | T: ((Array([0.01067836, 0.00075049], dtype=float32), Array(0.44537768, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.800728e+00 | T: ((Array([0.01144875, 0.0002879 ], dtype=float32), Array(0.44824454, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.780698e+00 | T: ((Array([ 0.01211341, -0.00011562], dtype=float32), Array(0.45103073, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.761750e+00 | T: ((Array([ 0.01267964, -0.00042128], dtype=float32), Array(0.4537403, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.743800e+00 | T: ((Array([ 0.01315445, -0.0006046 ], dtype=float32), Array(0.45637718, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.726770e+00 | T: ((Array([ 0.01354451, -0.00065675], dtype=float32), Array(0.45894507, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.710589e+00 | T: ((Array([ 0.0138562 , -0.00058407], dtype=float32), Array(0.46144745, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.695196e+00 | T: ((Array([ 0.01409558, -0.00040588], dtype=float32), Array(0.4638876, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.680533e+00 | T: ((Array([ 0.01426842, -0.00015123], dtype=float32), Array(0.4662687, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.666548e+00 | T: ((Array([0.0143802 , 0.00014522], dtype=float32), Array(0.46859366, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.653195e+00 | T: ((Array([0.0144361 , 0.00044741], dtype=float32), Array(0.4708653, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.640429e+00 | T: ((Array([0.01444104, 0.00072195], dtype=float32), Array(0.47308627, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.628213e+00 | T: ((Array([0.01439964, 0.00094153], dtype=float32), Array(0.475259, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.616509e+00 | T: ((Array([0.01431627, 0.00108726], dtype=float32), Array(0.47738588, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.605286e+00 | T: ((Array([0.01419505, 0.00115004], dtype=float32), Array(0.47946912, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.594510e+00 | T: ((Array([0.01403985, 0.00113062], dtype=float32), Array(0.48151076, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.584155e+00 | T: ((Array([0.01385429, 0.00103864], dtype=float32), Array(0.4835128, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.574196e+00 | T: ((Array([0.01364177, 0.00089074], dtype=float32), Array(0.48547703, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.564610e+00 | T: ((Array([0.01340547, 0.00070815], dtype=float32), Array(0.48740524, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.555373e+00 | T: ((Array([0.01314836, 0.00051395], dtype=float32), Array(0.48929903, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.546467e+00 | T: ((Array([0.0128732 , 0.00033038], dtype=float32), Array(0.49115995, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.537874e+00 | T: ((Array([0.01258256, 0.00017649], dtype=float32), Array(0.49298942, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.529575e+00 | T: ((Array([1.2278834e-02, 6.6372282e-05], dtype=float32), Array(0.49478883, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.521555e+00 | T: ((Array([1.1964234e-02, 8.0347090e-06], dtype=float32), Array(0.4965594, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.513799e+00 | T: ((Array([1.1640803e-02, 3.1023474e-06], dtype=float32), Array(0.4983024, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.506295e+00 | T: ((Array([1.1310428e-02, 4.7201425e-05], dtype=float32), Array(0.5000189, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.499028e+00 | T: ((Array([0.01097485, 0.00013098], dtype=float32), Array(0.50171, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.491988e+00 | T: ((Array([0.01063565, 0.00024161], dtype=float32), Array(0.50337666, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.485163e+00 | T: ((Array([0.0102943 , 0.00036445], dtype=float32), Array(0.50501984, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.478543e+00 | T: ((Array([0.00995213, 0.0004849 ], dtype=float32), Array(0.50664043, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.472119e+00 | T: ((Array([0.00961034, 0.00058993], dtype=float32), Array(0.5082392, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.465882e+00 | T: ((Array([0.00927004, 0.0006694 ], dtype=float32), Array(0.509817, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.459823e+00 | T: ((Array([0.00893221, 0.00071692], dtype=float32), Array(0.51137453, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.453934e+00 | T: ((Array([0.00859776, 0.00073022], dtype=float32), Array(0.5129125, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.448209e+00 | T: ((Array([0.00826747, 0.00071099], dtype=float32), Array(0.5144316, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.442640e+00 | T: ((Array([0.00794205, 0.00066438], dtype=float32), Array(0.5159324, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.437221e+00 | T: ((Array([0.00762214, 0.00059809], dtype=float32), Array(0.51741546, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.431945e+00 | T: ((Array([0.00730829, 0.00052128], dtype=float32), Array(0.5188814, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.426808e+00 | T: ((Array([0.00700097, 0.00044345], dtype=float32), Array(0.52033067, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.421803e+00 | T: ((Array([0.0067006 , 0.00037331], dtype=float32), Array(0.52176374, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.416926e+00 | T: ((Array([0.00640754, 0.00031795], dtype=float32), Array(0.52318114, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.412172e+00 | T: ((Array([0.00612207, 0.00028214], dtype=float32), Array(0.5245833, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.407536e+00 | T: ((Array([0.00584444, 0.00026804], dtype=float32), Array(0.5259706, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.403014e+00 | T: ((Array([0.00557484, 0.0002752 ], dtype=float32), Array(0.5273434, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.398602e+00 | T: ((Array([0.00531343, 0.00030083], dtype=float32), Array(0.5287021, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.394296e+00 | T: ((Array([0.0050603 , 0.00034034], dtype=float32), Array(0.53004706, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.390092e+00 | T: ((Array([0.00481553, 0.00038803], dtype=float32), Array(0.5313786, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.385988e+00 | T: ((Array([0.00457916, 0.0004378 ], dtype=float32), Array(0.5326971, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.381978e+00 | T: ((Array([0.00435119, 0.00048387], dtype=float32), Array(0.5340027, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.378062e+00 | T: ((Array([0.00413159, 0.00052144], dtype=float32), Array(0.53529584, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.374234e+00 | T: ((Array([0.00392032, 0.00054709], dtype=float32), Array(0.53657675, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.370494e+00 | T: ((Array([0.0037173 , 0.00055905], dtype=float32), Array(0.5378457, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.366838e+00 | T: ((Array([0.00352244, 0.00055727], dtype=float32), Array(0.53910285, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.363262e+00 | T: ((Array([0.00333562, 0.00054324], dtype=float32), Array(0.54034853, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.359766e+00 | T: ((Array([0.00315672, 0.0005197 ], dtype=float32), Array(0.54158294, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.356346e+00 | T: ((Array([0.00298559, 0.00049018], dtype=float32), Array(0.54280627, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.353001e+00 | T: ((Array([0.00282208, 0.00045858], dtype=float32), Array(0.54401875, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.349727e+00 | T: ((Array([0.00266601, 0.00042867], dtype=float32), Array(0.54522055, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.346524e+00 | T: ((Array([0.00251723, 0.00040366], dtype=float32), Array(0.54641193, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.343388e+00 | T: ((Array([0.00237553, 0.00038593], dtype=float32), Array(0.547593, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.340318e+00 | T: ((Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.340318e+00 | T: (Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32))
# Step 0 | T: 1.190953e+01 | T: ((Array([-0.18854065, -0.00813   ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.072831e+01 | T: ((Array([-0.17860703, -0.00201511], dtype=float32), Array(0.2199275, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.722255e+00 | T: ((Array([-0.1687803 ,  0.00415572], dtype=float32), Array(0.22974214, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.864707e+00 | T: ((Array([-0.15909755,  0.00704197], dtype=float32), Array(0.23940943, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 8.130839e+00 | T: ((Array([-0.14959241,  0.00662608], dtype=float32), Array(0.24890064, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.500125e+00 | T: ((Array([-0.1402947 ,  0.00432054], dtype=float32), Array(0.25819233, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.956180e+00 | T: ((Array([-0.13123041,  0.00126469], dtype=float32), Array(0.26726595, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.485485e+00 | T: ((Array([-0.12242181, -0.00163689], dtype=float32), Array(0.2761073, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 6.076708e+00 | T: ((Array([-0.11388758, -0.0037074 ], dtype=float32), Array(0.284706, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.720333e+00 | T: ((Array([-0.10564299, -0.00462384], dtype=float32), Array(0.29305488, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.408418e+00 | T: ((Array([-0.09770017, -0.00441812], dtype=float32), Array(0.3011496, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.134396e+00 | T: ((Array([-0.09006823, -0.00333683], dtype=float32), Array(0.30898827, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.892823e+00 | T: ((Array([-0.08275362, -0.00171179], dtype=float32), Array(0.31657094, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.679152e+00 | T: ((Array([-0.07576034,  0.00011104], dtype=float32), Array(0.32389933, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.489553e+00 | T: ((Array([-0.06909017,  0.00181418], dtype=float32), Array(0.33097658, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.320774e+00 | T: ((Array([-0.06274289,  0.00314593], dtype=float32), Array(0.33780694, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.170044e+00 | T: ((Array([-0.05671657,  0.00394983], dtype=float32), Array(0.34439564, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.035003e+00 | T: ((Array([-0.05100773,  0.00417425], dtype=float32), Array(0.3507486, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.913647e+00 | T: ((Array([-0.04561154,  0.00385993], dtype=float32), Array(0.3568723, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.804269e+00 | T: ((Array([-0.04052204,  0.00311494], dtype=float32), Array(0.3627737, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.705415e+00 | T: ((Array([-0.03573229,  0.00208747], dtype=float32), Array(0.36846, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.615835e+00 | T: ((Array([-0.03123453,  0.00094146], dtype=float32), Array(0.3739387, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.534453e+00 | T: ((Array([-0.02702029, -0.00016455], dtype=float32), Array(0.37921745, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.460329e+00 | T: ((Array([-0.02308058, -0.00109554], dtype=float32), Array(0.38430384, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.392645e+00 | T: ((Array([-0.01940599, -0.00175375], dtype=float32), Array(0.38920557, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.330687e+00 | T: ((Array([-0.01598674, -0.00208645], dtype=float32), Array(0.3939303, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.273831e+00 | T: ((Array([-0.01281285, -0.00208673], dtype=float32), Array(0.39848545, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.221533e+00 | T: ((Array([-0.00987418, -0.00178824], dtype=float32), Array(0.40287852, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.173320e+00 | T: ((Array([-0.0071605 , -0.00125582], dtype=float32), Array(0.4071167, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.128778e+00 | T: ((Array([-0.00466161, -0.00057422], dtype=float32), Array(0.41120705, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.087540e+00 | T: ((Array([-0.0023673 ,  0.00016373], dtype=float32), Array(0.41515642, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.049284e+00 | T: ((Array([-0.00026751,  0.00086824], dtype=float32), Array(0.41897148, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 3.013723e+00 | T: ((Array([0.00164772, 0.00146232], dtype=float32), Array(0.42265865, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.980602e+00 | T: ((Array([0.00338815, 0.00188909], dtype=float32), Array(0.4262241, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.949691e+00 | T: ((Array([0.00496336, 0.00211622], dtype=float32), Array(0.42967382, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.920789e+00 | T: ((Array([0.00638267, 0.00213702], dtype=float32), Array(0.43301347, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.893714e+00 | T: ((Array([0.00765516, 0.00196851], dtype=float32), Array(0.43624857, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.868307e+00 | T: ((Array([0.00878964, 0.00164702], dtype=float32), Array(0.43938434, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.844423e+00 | T: ((Array([0.00979463, 0.00122225], dtype=float32), Array(0.4424258, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.821935e+00 | T: ((Array([0.01067836, 0.00075049], dtype=float32), Array(0.44537768, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.800728e+00 | T: ((Array([0.01144875, 0.0002879 ], dtype=float32), Array(0.44824454, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.780698e+00 | T: ((Array([ 0.01211341, -0.00011562], dtype=float32), Array(0.45103073, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.761750e+00 | T: ((Array([ 0.01267964, -0.00042128], dtype=float32), Array(0.4537403, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.743800e+00 | T: ((Array([ 0.01315445, -0.0006046 ], dtype=float32), Array(0.45637718, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.726770e+00 | T: ((Array([ 0.01354451, -0.00065675], dtype=float32), Array(0.45894507, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.710589e+00 | T: ((Array([ 0.0138562 , -0.00058407], dtype=float32), Array(0.46144745, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.695196e+00 | T: ((Array([ 0.01409558, -0.00040588], dtype=float32), Array(0.4638876, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.680533e+00 | T: ((Array([ 0.01426842, -0.00015123], dtype=float32), Array(0.4662687, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.666548e+00 | T: ((Array([0.0143802 , 0.00014522], dtype=float32), Array(0.46859366, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.653195e+00 | T: ((Array([0.0144361 , 0.00044741], dtype=float32), Array(0.4708653, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.640429e+00 | T: ((Array([0.01444104, 0.00072195], dtype=float32), Array(0.47308627, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.628213e+00 | T: ((Array([0.01439964, 0.00094153], dtype=float32), Array(0.475259, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.616509e+00 | T: ((Array([0.01431627, 0.00108726], dtype=float32), Array(0.47738588, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.605286e+00 | T: ((Array([0.01419505, 0.00115004], dtype=float32), Array(0.47946912, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.594510e+00 | T: ((Array([0.01403985, 0.00113062], dtype=float32), Array(0.48151076, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.584155e+00 | T: ((Array([0.01385429, 0.00103864], dtype=float32), Array(0.4835128, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.574196e+00 | T: ((Array([0.01364177, 0.00089074], dtype=float32), Array(0.48547703, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.564610e+00 | T: ((Array([0.01340547, 0.00070815], dtype=float32), Array(0.48740524, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.555373e+00 | T: ((Array([0.01314836, 0.00051395], dtype=float32), Array(0.48929903, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.546467e+00 | T: ((Array([0.0128732 , 0.00033038], dtype=float32), Array(0.49115995, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.537874e+00 | T: ((Array([0.01258256, 0.00017649], dtype=float32), Array(0.49298942, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.529575e+00 | T: ((Array([1.2278834e-02, 6.6372282e-05], dtype=float32), Array(0.49478883, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.521555e+00 | T: ((Array([1.1964234e-02, 8.0347090e-06], dtype=float32), Array(0.4965594, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.513799e+00 | T: ((Array([1.1640803e-02, 3.1023474e-06], dtype=float32), Array(0.4983024, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.506295e+00 | T: ((Array([1.1310428e-02, 4.7201425e-05], dtype=float32), Array(0.5000189, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.499028e+00 | T: ((Array([0.01097485, 0.00013098], dtype=float32), Array(0.50171, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.491988e+00 | T: ((Array([0.01063565, 0.00024161], dtype=float32), Array(0.50337666, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.485163e+00 | T: ((Array([0.0102943 , 0.00036445], dtype=float32), Array(0.50501984, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.478543e+00 | T: ((Array([0.00995213, 0.0004849 ], dtype=float32), Array(0.50664043, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.472119e+00 | T: ((Array([0.00961034, 0.00058993], dtype=float32), Array(0.5082392, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.465882e+00 | T: ((Array([0.00927004, 0.0006694 ], dtype=float32), Array(0.509817, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.459823e+00 | T: ((Array([0.00893221, 0.00071692], dtype=float32), Array(0.51137453, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.453934e+00 | T: ((Array([0.00859776, 0.00073022], dtype=float32), Array(0.5129125, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.448209e+00 | T: ((Array([0.00826747, 0.00071099], dtype=float32), Array(0.5144316, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.442640e+00 | T: ((Array([0.00794205, 0.00066438], dtype=float32), Array(0.5159324, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.437221e+00 | T: ((Array([0.00762214, 0.00059809], dtype=float32), Array(0.51741546, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.431945e+00 | T: ((Array([0.00730829, 0.00052128], dtype=float32), Array(0.5188814, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.426808e+00 | T: ((Array([0.00700097, 0.00044345], dtype=float32), Array(0.52033067, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.421803e+00 | T: ((Array([0.0067006 , 0.00037331], dtype=float32), Array(0.52176374, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.416926e+00 | T: ((Array([0.00640754, 0.00031795], dtype=float32), Array(0.52318114, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.412172e+00 | T: ((Array([0.00612207, 0.00028214], dtype=float32), Array(0.5245833, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.407536e+00 | T: ((Array([0.00584444, 0.00026804], dtype=float32), Array(0.5259706, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.403014e+00 | T: ((Array([0.00557484, 0.0002752 ], dtype=float32), Array(0.5273434, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.398602e+00 | T: ((Array([0.00531343, 0.00030083], dtype=float32), Array(0.5287021, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.394296e+00 | T: ((Array([0.0050603 , 0.00034034], dtype=float32), Array(0.53004706, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.390092e+00 | T: ((Array([0.00481553, 0.00038803], dtype=float32), Array(0.5313786, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.385988e+00 | T: ((Array([0.00457916, 0.0004378 ], dtype=float32), Array(0.5326971, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.381978e+00 | T: ((Array([0.00435119, 0.00048387], dtype=float32), Array(0.5340027, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.378062e+00 | T: ((Array([0.00413159, 0.00052144], dtype=float32), Array(0.53529584, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.374234e+00 | T: ((Array([0.00392032, 0.00054709], dtype=float32), Array(0.53657675, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.370494e+00 | T: ((Array([0.0037173 , 0.00055905], dtype=float32), Array(0.5378457, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.366838e+00 | T: ((Array([0.00352244, 0.00055727], dtype=float32), Array(0.53910285, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.363262e+00 | T: ((Array([0.00333562, 0.00054324], dtype=float32), Array(0.54034853, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.359766e+00 | T: ((Array([0.00315672, 0.0005197 ], dtype=float32), Array(0.54158294, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.356346e+00 | T: ((Array([0.00298559, 0.00049018], dtype=float32), Array(0.54280627, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.353001e+00 | T: ((Array([0.00282208, 0.00045858], dtype=float32), Array(0.54401875, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.349727e+00 | T: ((Array([0.00266601, 0.00042867], dtype=float32), Array(0.54522055, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.346524e+00 | T: ((Array([0.00251723, 0.00040366], dtype=float32), Array(0.54641193, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.343388e+00 | T: ((Array([0.00237553, 0.00038593], dtype=float32), Array(0.547593, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.340318e+00 | T: ((Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.340318e+00 | T: (Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32))
# Step 0 | T: 1.190953e+01 | T: ((Array([-0.18854065, -0.00813   ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.072831e+01 | T: ((Array([-0.17860703, -0.00201511], dtype=float32), Array(0.2199275, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.722255e+00 | T: ((Array([-0.1687803 ,  0.00415572], dtype=float32), Array(0.22974214, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.864707e+00 | T: ((Array([-0.15909755,  0.00704197], dtype=float32), Array(0.23940943, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 8.130839e+00 | T: ((Array([-0.14959241,  0.00662608], dtype=float32), Array(0.24890064, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.500125e+00 | T: ((Array([-0.1402947 ,  0.00432054], dtype=float32), Array(0.25819233, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.956180e+00 | T: ((Array([-0.13123041,  0.00126469], dtype=float32), Array(0.26726595, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.485485e+00 | T: ((Array([-0.12242181, -0.00163689], dtype=float32), Array(0.2761073, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 6.076708e+00 | T: ((Array([-0.11388758, -0.0037074 ], dtype=float32), Array(0.284706, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.720333e+00 | T: ((Array([-0.10564299, -0.00462384], dtype=float32), Array(0.29305488, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.408418e+00 | T: ((Array([-0.09770017, -0.00441812], dtype=float32), Array(0.3011496, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.134396e+00 | T: ((Array([-0.09006823, -0.00333683], dtype=float32), Array(0.30898827, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.892823e+00 | T: ((Array([-0.08275362, -0.00171179], dtype=float32), Array(0.31657094, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.679152e+00 | T: ((Array([-0.07576034,  0.00011104], dtype=float32), Array(0.32389933, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.489553e+00 | T: ((Array([-0.06909017,  0.00181418], dtype=float32), Array(0.33097658, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.320774e+00 | T: ((Array([-0.06274289,  0.00314593], dtype=float32), Array(0.33780694, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.170044e+00 | T: ((Array([-0.05671657,  0.00394983], dtype=float32), Array(0.34439564, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.035003e+00 | T: ((Array([-0.05100773,  0.00417425], dtype=float32), Array(0.3507486, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.913647e+00 | T: ((Array([-0.04561154,  0.00385993], dtype=float32), Array(0.3568723, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.804269e+00 | T: ((Array([-0.04052204,  0.00311494], dtype=float32), Array(0.3627737, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.705415e+00 | T: ((Array([-0.03573229,  0.00208747], dtype=float32), Array(0.36846, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.615835e+00 | T: ((Array([-0.03123453,  0.00094146], dtype=float32), Array(0.3739387, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.534453e+00 | T: ((Array([-0.02702029, -0.00016455], dtype=float32), Array(0.37921745, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.460329e+00 | T: ((Array([-0.02308058, -0.00109554], dtype=float32), Array(0.38430384, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.392645e+00 | T: ((Array([-0.01940599, -0.00175375], dtype=float32), Array(0.38920557, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.330687e+00 | T: ((Array([-0.01598674, -0.00208645], dtype=float32), Array(0.3939303, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.273831e+00 | T: ((Array([-0.01281285, -0.00208673], dtype=float32), Array(0.39848545, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.221533e+00 | T: ((Array([-0.00987418, -0.00178824], dtype=float32), Array(0.40287852, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.173320e+00 | T: ((Array([-0.0071605 , -0.00125582], dtype=float32), Array(0.4071167, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 3.128778e+00 | T: ((Array([-0.00466161, -0.00057422], dtype=float32), Array(0.41120705, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 3.087540e+00 | T: ((Array([-0.0023673 ,  0.00016373], dtype=float32), Array(0.41515642, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 3.049284e+00 | T: ((Array([-0.00026751,  0.00086824], dtype=float32), Array(0.41897148, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 3.013723e+00 | T: ((Array([0.00164772, 0.00146232], dtype=float32), Array(0.42265865, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 2.980602e+00 | T: ((Array([0.00338815, 0.00188909], dtype=float32), Array(0.4262241, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 2.949691e+00 | T: ((Array([0.00496336, 0.00211622], dtype=float32), Array(0.42967382, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 2.920789e+00 | T: ((Array([0.00638267, 0.00213702], dtype=float32), Array(0.43301347, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 2.893714e+00 | T: ((Array([0.00765516, 0.00196851], dtype=float32), Array(0.43624857, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 2.868307e+00 | T: ((Array([0.00878964, 0.00164702], dtype=float32), Array(0.43938434, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 2.844423e+00 | T: ((Array([0.00979463, 0.00122225], dtype=float32), Array(0.4424258, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 2.821935e+00 | T: ((Array([0.01067836, 0.00075049], dtype=float32), Array(0.44537768, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 2.800728e+00 | T: ((Array([0.01144875, 0.0002879 ], dtype=float32), Array(0.44824454, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 2.780698e+00 | T: ((Array([ 0.01211341, -0.00011562], dtype=float32), Array(0.45103073, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 2.761750e+00 | T: ((Array([ 0.01267964, -0.00042128], dtype=float32), Array(0.4537403, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 2.743800e+00 | T: ((Array([ 0.01315445, -0.0006046 ], dtype=float32), Array(0.45637718, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 2.726770e+00 | T: ((Array([ 0.01354451, -0.00065675], dtype=float32), Array(0.45894507, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 2.710589e+00 | T: ((Array([ 0.0138562 , -0.00058407], dtype=float32), Array(0.46144745, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 2.695196e+00 | T: ((Array([ 0.01409558, -0.00040588], dtype=float32), Array(0.4638876, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 2.680533e+00 | T: ((Array([ 0.01426842, -0.00015123], dtype=float32), Array(0.4662687, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 2.666548e+00 | T: ((Array([0.0143802 , 0.00014522], dtype=float32), Array(0.46859366, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 2.653195e+00 | T: ((Array([0.0144361 , 0.00044741], dtype=float32), Array(0.4708653, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 2.640429e+00 | T: ((Array([0.01444104, 0.00072195], dtype=float32), Array(0.47308627, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 2.628213e+00 | T: ((Array([0.01439964, 0.00094153], dtype=float32), Array(0.475259, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 2.616509e+00 | T: ((Array([0.01431627, 0.00108726], dtype=float32), Array(0.47738588, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 2.605286e+00 | T: ((Array([0.01419505, 0.00115004], dtype=float32), Array(0.47946912, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 2.594510e+00 | T: ((Array([0.01403985, 0.00113062], dtype=float32), Array(0.48151076, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 2.584155e+00 | T: ((Array([0.01385429, 0.00103864], dtype=float32), Array(0.4835128, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 2.574196e+00 | T: ((Array([0.01364177, 0.00089074], dtype=float32), Array(0.48547703, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 2.564610e+00 | T: ((Array([0.01340547, 0.00070815], dtype=float32), Array(0.48740524, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 2.555373e+00 | T: ((Array([0.01314836, 0.00051395], dtype=float32), Array(0.48929903, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 2.546467e+00 | T: ((Array([0.0128732 , 0.00033038], dtype=float32), Array(0.49115995, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 2.537874e+00 | T: ((Array([0.01258256, 0.00017649], dtype=float32), Array(0.49298942, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 2.529575e+00 | T: ((Array([1.2278834e-02, 6.6372282e-05], dtype=float32), Array(0.49478883, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 2.521555e+00 | T: ((Array([1.1964234e-02, 8.0347090e-06], dtype=float32), Array(0.4965594, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 2.513799e+00 | T: ((Array([1.1640803e-02, 3.1023474e-06], dtype=float32), Array(0.4983024, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 2.506295e+00 | T: ((Array([1.1310428e-02, 4.7201425e-05], dtype=float32), Array(0.5000189, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 2.499028e+00 | T: ((Array([0.01097485, 0.00013098], dtype=float32), Array(0.50171, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 2.491988e+00 | T: ((Array([0.01063565, 0.00024161], dtype=float32), Array(0.50337666, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 2.485163e+00 | T: ((Array([0.0102943 , 0.00036445], dtype=float32), Array(0.50501984, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 2.478543e+00 | T: ((Array([0.00995213, 0.0004849 ], dtype=float32), Array(0.50664043, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 2.472119e+00 | T: ((Array([0.00961034, 0.00058993], dtype=float32), Array(0.5082392, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 2.465882e+00 | T: ((Array([0.00927004, 0.0006694 ], dtype=float32), Array(0.509817, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.459823e+00 | T: ((Array([0.00893221, 0.00071692], dtype=float32), Array(0.51137453, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.453934e+00 | T: ((Array([0.00859776, 0.00073022], dtype=float32), Array(0.5129125, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.448209e+00 | T: ((Array([0.00826747, 0.00071099], dtype=float32), Array(0.5144316, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.442640e+00 | T: ((Array([0.00794205, 0.00066438], dtype=float32), Array(0.5159324, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.437221e+00 | T: ((Array([0.00762214, 0.00059809], dtype=float32), Array(0.51741546, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.431945e+00 | T: ((Array([0.00730829, 0.00052128], dtype=float32), Array(0.5188814, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.426808e+00 | T: ((Array([0.00700097, 0.00044345], dtype=float32), Array(0.52033067, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.421803e+00 | T: ((Array([0.0067006 , 0.00037331], dtype=float32), Array(0.52176374, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.416926e+00 | T: ((Array([0.00640754, 0.00031795], dtype=float32), Array(0.52318114, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.412172e+00 | T: ((Array([0.00612207, 0.00028214], dtype=float32), Array(0.5245833, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.407536e+00 | T: ((Array([0.00584444, 0.00026804], dtype=float32), Array(0.5259706, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.403014e+00 | T: ((Array([0.00557484, 0.0002752 ], dtype=float32), Array(0.5273434, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.398602e+00 | T: ((Array([0.00531343, 0.00030083], dtype=float32), Array(0.5287021, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.394296e+00 | T: ((Array([0.0050603 , 0.00034034], dtype=float32), Array(0.53004706, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.390092e+00 | T: ((Array([0.00481553, 0.00038803], dtype=float32), Array(0.5313786, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.385988e+00 | T: ((Array([0.00457916, 0.0004378 ], dtype=float32), Array(0.5326971, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.381978e+00 | T: ((Array([0.00435119, 0.00048387], dtype=float32), Array(0.5340027, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.378062e+00 | T: ((Array([0.00413159, 0.00052144], dtype=float32), Array(0.53529584, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.374234e+00 | T: ((Array([0.00392032, 0.00054709], dtype=float32), Array(0.53657675, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.370494e+00 | T: ((Array([0.0037173 , 0.00055905], dtype=float32), Array(0.5378457, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.366838e+00 | T: ((Array([0.00352244, 0.00055727], dtype=float32), Array(0.53910285, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.363262e+00 | T: ((Array([0.00333562, 0.00054324], dtype=float32), Array(0.54034853, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.359766e+00 | T: ((Array([0.00315672, 0.0005197 ], dtype=float32), Array(0.54158294, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.356346e+00 | T: ((Array([0.00298559, 0.00049018], dtype=float32), Array(0.54280627, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.353001e+00 | T: ((Array([0.00282208, 0.00045858], dtype=float32), Array(0.54401875, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.349727e+00 | T: ((Array([0.00266601, 0.00042867], dtype=float32), Array(0.54522055, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.346524e+00 | T: ((Array([0.00251723, 0.00040366], dtype=float32), Array(0.54641193, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.343388e+00 | T: ((Array([0.00237553, 0.00038593], dtype=float32), Array(0.547593, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.340318e+00 | T: ((Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.340318e+00 | T: (Array([0.00224073, 0.00037679], dtype=float32), Array(0.54876393, dtype=float32))
# Step 0 | T: 1.190953e+01 | T: ((Array([-0.18854065, -0.00813   ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.072831e+01 | T: ((Array([-0.17860703, -0.00201511], dtype=float32), Array(0.2199275, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 9.722255e+00 | T: ((Array([-0.1687803 ,  0.00415572], dtype=float32), Array(0.22974214, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 8.864707e+00 | T: ((Array([-0.15909755,  0.00704197], dtype=float32), Array(0.23940943, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 8.130839e+00 | T: ((Array([-0.14959241,  0.00662608], dtype=float32), Array(0.24890064, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 7.500125e+00 | T: ((Array([-0.1402947 ,  0.00432054], dtype=float32), Array(0.25819233, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 6.956180e+00 | T: ((Array([-0.13123041,  0.00126469], dtype=float32), Array(0.26726595, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 6.485485e+00 | T: ((Array([-0.12242181, -0.00163689], dtype=float32), Array(0.2761073, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 6.076708e+00 | T: ((Array([-0.11388758, -0.0037074 ], dtype=float32), Array(0.284706, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 5.720333e+00 | T: ((Array([-0.10564299, -0.00462384], dtype=float32), Array(0.29305488, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 5.408418e+00 | T: ((Array([-0.09770017, -0.00441812], dtype=float32), Array(0.3011496, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 5.134396e+00 | T: ((Array([-0.09006823, -0.00333683], dtype=float32), Array(0.30898827, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 4.892823e+00 | T: ((Array([-0.08275362, -0.00171179], dtype=float32), Array(0.31657094, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 4.679152e+00 | T: ((Array([-0.07576034,  0.00011104], dtype=float32), Array(0.32389933, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 4.489553e+00 | T: ((Array([-0.06909017,  0.00181418], dtype=float32), Array(0.33097658, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 4.320774e+00 | T: ((Array([-0.06274289,  0.00314593], dtype=float32), Array(0.33780694, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 4.170044e+00 | T: ((Array([-0.05671657,  0.00394983], dtype=float32), Array(0.34439564, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 4.035003e+00 | T: ((Array([-0.05100773,  0.00417425], dtype=float32), Array(0.3507486, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 3.913647e+00 | T: ((Array([-0.04561154,  0.00385993], dtype=float32), Array(0.3568723, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 3.804269e+00 | T: ((Array([-0.04052204,  0.00311494], dtype=float32), Array(0.3627737, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 3.705415e+00 | T: ((Array([-0.03573229,  0.00208747], dtype=float32), Array(0.36846, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 3.615835e+00 | T: ((Array([-0.03123453,  0.00094146], dtype=float32), Array(0.3739387, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 3.534453e+00 | T: ((Array([-0.02702029, -0.00016455], dtype=float32), Array(0.37921745, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 3.460329e+00 | T: ((Array([-0.02308058, -0.00109554], dtype=float32), Array(0.38430384, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 3.392645e+00 | T: ((Array([-0.01940599, -0.00175375], dtype=float32), Array(0.38920557, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 3.330687e+00 | T: ((Array([-0.01598674, -0.00208645], dtype=float32), Array(0.3939303, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 3.273831e+00 | T: ((Array([-0.01281285, -0.00208673], dtype=float32), Array(0.39848545, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 3.221533e+00 | T: ((Array([-0.00987418, -0.00178824], dtype=float32), Array(0.40287852, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 3.173320e+00 | T: ((Array([-0.0071605 , -0.00125582], dtype=float32), Array(0.4071167, dtype=float32)), Array([0.], dtype=float32))
# ...
#        -2.2682283e-02, -5.2437382e-03, -1.6654560e-02, -9.4913412e-03,
#         8.1977341e-06, -4.1900761e-04], dtype=float32), Array(0.44962108, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 1.395670e+01 | T: ((Array([-0.00393208, -0.00536262, -0.00206664,  0.01608647, -0.02276288,
#        -0.0049838 , -0.0153178 , -0.00988858, -0.00086611,  0.00046767],      dtype=float32), Array(0.45244104, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 1.386048e+01 | T: ((Array([-0.00421362, -0.00620705, -0.00228472,  0.01495184, -0.02275872,
#        -0.00463516, -0.01401211, -0.010163  , -0.00170229,  0.0012388 ],      dtype=float32), Array(0.4551833, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 1.376938e+01 | T: ((Array([-0.00437967, -0.00694067, -0.00256486,  0.01381273, -0.02267759,
#        -0.00422453, -0.01274437, -0.01032239, -0.00248666,  0.00189655],      dtype=float32), Array(0.4578518, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 1.368298e+01 | T: ((Array([-0.00442961, -0.00756584, -0.00286243,  0.01267665, -0.02252689,
#        -0.00377944, -0.01152049, -0.01037528, -0.00320789,  0.00244416],      dtype=float32), Array(0.46045026, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 1.360095e+01 | T: ((Array([-0.00437073, -0.00808587, -0.00313449,  0.01155038, -0.02231358,
#        -0.0033267 , -0.01034551, -0.01033074, -0.00385696,  0.00288575],      dtype=float32), Array(0.4629822, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 1.352295e+01 | T: ((Array([-0.00421693, -0.00850489, -0.0033456 ,  0.01043999, -0.02204426,
#        -0.00289105, -0.00922363, -0.01019825, -0.00442722,  0.00322625],      dtype=float32), Array(0.46545094, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 1.344870e+01 | T: ((Array([-0.00398722, -0.00882774, -0.00347203,  0.00935088, -0.02172516,
#        -0.00249404, -0.00815822, -0.00998751, -0.00491422,  0.00347122],      dtype=float32), Array(0.46785966, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 1.337792e+01 | T: ((Array([-0.00370393, -0.0090598 , -0.003504  ,  0.00828781, -0.02136209,
#        -0.00215319, -0.00715194, -0.0097083 , -0.00531563,  0.00362675],      dtype=float32), Array(0.47021133, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 1.331038e+01 | T: ((Array([-0.00339091, -0.00920694, -0.0034457 ,  0.0072549 , -0.02096055,
#        -0.00188146, -0.00620676, -0.00937037, -0.00563109,  0.00369935],      dtype=float32), Array(0.4725088, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 1.324585e+01 | T: ((Array([-0.00307186, -0.00927538, -0.00331347,  0.00625573, -0.02052566,
#        -0.00168693, -0.00532399, -0.00898329, -0.00586203,  0.0036958 ],      dtype=float32), Array(0.4747547, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 1.318412e+01 | T: ((Array([-0.00276867, -0.00927159, -0.00313236,  0.00529331, -0.02006221,
#        -0.00157285, -0.00450436, -0.00855636, -0.00601148,  0.00362311],      dtype=float32), Array(0.47695154, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 1.312501e+01 | T: ((Array([-0.00250021, -0.00920222, -0.00293193,  0.00437015, -0.01957465,
#        -0.00153792, -0.00374808, -0.00809854, -0.00608383,  0.00348836],      dtype=float32), Array(0.47910172, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 1.306836e+01 | T: ((Array([-0.00228129, -0.00907398, -0.00274171,  0.00348828, -0.01906712,
#        -0.00157675, -0.00305485, -0.00761832, -0.00608467,  0.00329868],      dtype=float32), Array(0.48120746, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 1.301400e+01 | T: ((Array([-0.00212203, -0.00889359, -0.00258712,  0.00264929, -0.01854347,
#        -0.00168054, -0.00242395, -0.00712373, -0.00602053,  0.00306111],      dtype=float32), Array(0.48327088, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 1.296179e+01 | T: ((Array([-0.00202765, -0.00866769, -0.00248634,  0.00185434, -0.01800724,
#        -0.00183784, -0.00185425, -0.0066222 , -0.00589864,  0.00278257],      dtype=float32), Array(0.48529398, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 1.291160e+01 | T: ((Array([-0.00199855, -0.0084028 , -0.00244842,  0.00110422, -0.0174617 ,
#        -0.00203543, -0.00134428, -0.0061206 , -0.00572678,  0.00246977],      dtype=float32), Array(0.48727864, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 1.286331e+01 | T: ((Array([-0.00203068, -0.00810524, -0.00247287,  0.00039938, -0.01690986,
#        -0.00225915, -0.00089226, -0.00562515, -0.005513  ,  0.00212919],      dtype=float32), Array(0.48922658, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 1.281681e+01 | T: ((Array([-0.0021163 , -0.00778109, -0.00255056, -0.00026007, -0.01635446,
#        -0.00249474, -0.00049616, -0.00514143, -0.00526548,  0.00176701],      dtype=float32), Array(0.4911395, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 1.277199e+01 | T: ((Array([-0.00224474, -0.00743616, -0.00266584, -0.00087429, -0.01579802,
#        -0.00272861, -0.00015373, -0.00467436, -0.00499236,  0.00138906],      dtype=float32), Array(0.49301893, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 1.272876e+01 | T: ((Array([-0.00240346, -0.00707594, -0.00279923, -0.00144372, -0.01524282,
#        -0.00294852,  0.00013749, -0.00422822, -0.00470152,  0.00100082],      dtype=float32), Array(0.49486634, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 1.268703e+01 | T: ((Array([-0.002579  , -0.00670557, -0.00293053, -0.00196903, -0.01469093,
#        -0.00314406,  0.00038009, -0.0038066 , -0.00440051,  0.00060737],      dtype=float32), Array(0.49668315, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 1.264673e+01 | T: ((Array([-0.00275804, -0.00632983, -0.00304164, -0.0024511 , -0.01414419,
#        -0.00330708,  0.00057678, -0.0034125 , -0.00409637,  0.00021339],      dtype=float32), Array(0.49847063, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 1.260776e+01 | T: ((Array([-0.00292819, -0.00595312, -0.00311896, -0.00289098, -0.0136043 ,
#        -0.00343189,  0.00073036, -0.00304828, -0.00379559, -0.00017688],      dtype=float32), Array(0.50023, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 1.257007e+01 | T: ((Array([-0.00307882, -0.00557945, -0.00315481, -0.00328989, -0.01307272,
#        -0.00351537,  0.00084368, -0.00271571, -0.00350398, -0.0005596 ],      dtype=float32), Array(0.5019624, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 1.253359e+01 | T: ((Array([-0.00320158, -0.00521242, -0.00314802, -0.00364921, -0.01255078,
#        -0.00355688,  0.00091964, -0.00241602, -0.00322664, -0.0009314 ],      dtype=float32), Array(0.50366896, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 1.249826e+01 | T: ((Array([-0.00329076, -0.00485523, -0.00310345, -0.0039704 , -0.01203963,
#        -0.00355808,  0.00096113, -0.00214989, -0.0029679 , -0.00128931],      dtype=float32), Array(0.50535065, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 1.246401e+01 | T: ((Array([-0.00334343, -0.0045107 , -0.00303083, -0.00425504, -0.01154028,
#        -0.00352261,  0.00097102, -0.00191754, -0.00273133, -0.00163079],      dtype=float32), Array(0.50700843, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 1.243081e+01 | T: ((Array([-0.0033594 , -0.00418124, -0.0029429 , -0.00450478, -0.01105359,
#        -0.00345577,  0.00095217, -0.00171875, -0.00251971, -0.00195369],      dtype=float32), Array(0.50864327, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 1.239858e+01 | T: ((Array([-0.003341  , -0.0038689 , -0.00285338, -0.00472134, -0.0105803 ,
#        -0.00336401,  0.00090736, -0.00155289, -0.00233505, -0.0022563 ],      dtype=float32), Array(0.51025593, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 1.236731e+01 | T: ((Array([-0.00329264, -0.00357536, -0.00277497, -0.00490646, -0.01012103,
#        -0.00325457,  0.00083933, -0.00141899, -0.00217865, -0.00253723],      dtype=float32), Array(0.51184726, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 1.233693e+01 | T: ((Array([-0.00322037, -0.00330192, -0.00271764, -0.00506195, -0.00967627,
#        -0.00313492,  0.0007507 , -0.00131576, -0.00205109, -0.00279549],      dtype=float32), Array(0.51341796, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 1.230742e+01 | T: ((Array([-0.00313131, -0.00304959, -0.00268748, -0.00518959, -0.00924642,
#        -0.00301243,  0.00064405, -0.00124164, -0.0019523 , -0.00303042],      dtype=float32), Array(0.5149688, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 1.227872e+01 | T: ((Array([-0.00303305, -0.00281906, -0.00268621, -0.00529121, -0.00883179,
#        -0.00289393,  0.0005218 , -0.00119487, -0.00188166, -0.00324165],      dtype=float32), Array(0.5165004, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 1.225081e+01 | T: ((Array([-0.00293313, -0.00261069, -0.00271133, -0.00536859, -0.00843258,
#        -0.00278541,  0.0003863 , -0.00117349, -0.00183798, -0.00342911],      dtype=float32), Array(0.5180134, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 1.222366e+01 | T: ((Array([-0.00283849, -0.00242463, -0.00275685, -0.00542352, -0.00804894,
#        -0.00269178,  0.00023976, -0.0011754 , -0.00181968, -0.003593  ],      dtype=float32), Array(0.5195084, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 1.219723e+01 | T: ((Array([-2.7550887e-03, -2.2607397e-03, -2.8144668e-03, -5.4577426e-03,
#        -7.6809181e-03, -2.6166923e-03,  8.4276180e-05, -1.1984357e-03,
#        -1.8247592e-03, -3.7337474e-03], dtype=float32), Array(0.520986, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 1.217149e+01 | T: ((Array([-2.6875534e-03, -2.1186823e-03, -2.8749199e-03, -5.4729865e-03,
#        -7.3285094e-03, -2.5624637e-03, -7.8190162e-05, -1.2403266e-03,
#        -1.8509468e-03, -3.8519874e-03], dtype=float32), Array(0.5224467, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 1.214642e+01 | T: ((Array([-0.00263902, -0.00199791, -0.00292941, -0.00547092, -0.00699164,
#        -0.00253008, -0.0002458 , -0.0012988 , -0.00189574, -0.00394854],      dtype=float32), Array(0.523891, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 1.212199e+01 | T: ((Array([-0.00261102, -0.00189772, -0.00297079, -0.00545317, -0.0066702 ,
#        -0.00251924, -0.00041686, -0.00137157, -0.00195647, -0.00402439],      dtype=float32), Array(0.5253193, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 1.209818e+01 | T: ((Array([-0.00260356, -0.00181724, -0.00299443, -0.00542131, -0.006364  ,
#        -0.00252853, -0.0005898 , -0.00145639, -0.00203042, -0.00408064],      dtype=float32), Array(0.5267321, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 1.207496e+01 | T: ((Array([-0.00261524, -0.00175547, -0.00299863, -0.00537684, -0.00607283,
#        -0.00255558, -0.00076318, -0.00155107, -0.00211481, -0.00411852],      dtype=float32), Array(0.5281298, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 1.205232e+01 | T: ((Array([-0.00264347, -0.00171133, -0.00298462, -0.00532122, -0.00579644,
#        -0.00259725, -0.00093568, -0.00165351, -0.00220694, -0.00413934],      dtype=float32), Array(0.5295129, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 1.203022e+01 | T: ((Array([-0.00268476, -0.00168363, -0.00295608, -0.00525582, -0.00553452,
#        -0.00264993, -0.00110614, -0.00176167, -0.00230416, -0.00414445],      dtype=float32), Array(0.53088164, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 1.200866e+01 | T: ((Array([-0.00273507, -0.00167112, -0.00291842, -0.00518197, -0.00528676,
#        -0.00270973, -0.00127348, -0.00187368, -0.002404  , -0.00413527],      dtype=float32), Array(0.53223646, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 1.198761e+01 | T: ((Array([-0.00279009, -0.00167252, -0.00287786, -0.00510089, -0.00505282,
#        -0.00277274, -0.00143679, -0.00198774, -0.00250414, -0.00411325],      dtype=float32), Array(0.5335777, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 1.196706e+01 | T: ((Array([-0.00284561, -0.00168651, -0.00284044, -0.00501377, -0.00483233,
#        -0.00283524, -0.00159523, -0.00210223, -0.00260247, -0.00407982],      dtype=float32), Array(0.5349056, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 1.194699e+01 | T: ((Array([-0.00289776, -0.00171176, -0.00281119, -0.00492171, -0.00462488,
#        -0.00289388, -0.00174811, -0.00221566, -0.00269712, -0.00403641],      dtype=float32), Array(0.53622055, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 1.192739e+01 | T: ((Array([-0.00294326, -0.00174695, -0.00279352, -0.00482573, -0.00443009,
#        -0.00294582, -0.00189481, -0.00232669, -0.00278647, -0.00398442],      dtype=float32), Array(0.5375228, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 1.190823e+01 | T: ((Array([-0.00297961, -0.00179077, -0.00278887, -0.00472678, -0.00424754,
#        -0.00298888, -0.00203484, -0.00243415, -0.00286916, -0.00392524],      dtype=float32), Array(0.53881264, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 1.188950e+01 | T: ((Array([-0.00300514, -0.00184195, -0.00279667, -0.00462576, -0.00407679,
#        -0.00302152, -0.0021678 , -0.002537  , -0.00294409, -0.00386018],      dtype=float32), Array(0.5400903, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 1.187120e+01 | T: ((Array([-0.00301912, -0.00189926, -0.00281465, -0.00452349, -0.00391742,
#        -0.00304296, -0.00229337, -0.00263437, -0.00301043, -0.00379049],      dtype=float32), Array(0.54135615, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 1.185331e+01 | T: ((Array([-0.00302167, -0.00196151, -0.00283927, -0.0044207 , -0.003769  ,
#        -0.00305307, -0.00241132, -0.00272554, -0.00306759, -0.00371738],      dtype=float32), Array(0.5426103, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 1.183581e+01 | T: ((Array([-0.00301368, -0.00202757, -0.00286639, -0.00431807, -0.00363107,
#        -0.00305237, -0.00252149, -0.00280994, -0.00311526, -0.00364196],      dtype=float32), Array(0.543853, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 1.181870e+01 | T: ((Array([-0.0029967 , -0.00209639, -0.00289187, -0.00421624, -0.00350321,
#        -0.0030419 , -0.0026238 , -0.00288712, -0.00315333, -0.00356528],      dtype=float32), Array(0.5450845, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 1.180196e+01 | T: ((Array([-0.00297275, -0.00216697, -0.00291221, -0.00411574, -0.00338497,
#        -0.00302317, -0.00271825, -0.00295679, -0.0031819 , -0.00348829],      dtype=float32), Array(0.546305, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 1.178558e+01 | T: ((Array([-0.00294415, -0.00223839, -0.00292497, -0.00401708, -0.00327591,
#        -0.00299797, -0.00280486, -0.00301876, -0.00320128, -0.00341186],      dtype=float32), Array(0.54751474, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 1.176955e+01 | T: ((Array([-0.00291332, -0.00230981, -0.00292904, -0.00392068, -0.00317561,
#        -0.00296831, -0.00288374, -0.00307296, -0.00321191, -0.00333677],      dtype=float32), Array(0.54871386, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 1.175387e+01 | T: ((Array([-0.00288262, -0.00238047, -0.00292464, -0.00382694, -0.00308364,
#        -0.00293622, -0.00295503, -0.00311944, -0.00321441, -0.00326373],      dtype=float32), Array(0.54990256, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 1.173851e+01 | T: ((Array([-0.00285417, -0.00244969, -0.00291322, -0.00373618, -0.00299957,
#        -0.00290371, -0.00301892, -0.00315834, -0.00320949, -0.00319335],      dtype=float32), Array(0.551081, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 1.173851e+01 | T: (Array([-0.00285417, -0.00244969, -0.00291322, -0.00373618, -0.00299957,
#        -0.00290371, -0.00301892, -0.00315834, -0.00320949, -0.00319335],      dtype=float32), Array(0.551081, dtype=float32))
# 14.7 s ± 177 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#Plotting time difference

rn_dims = jnp.array(dims)

rn_score_tmean = jnp.array([time.average for time in time_score])
rn_score_tstd = jnp.array([time.stdev for time in time_bridge])

rn_bridge_tmean = jnp.array([time.average for time in time_bridge])
rn_bridge_tstd = jnp.array([time.stdev for time in time_bridge])

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.plot(rn_dims, rn_score_tmean, color='orange')
ax.plot(rn_dims, bridge_tmean, color='blue')
ax.set_xlabel(f'$N$')
ax.set_ylabel(f'$Time$')
ax.grid(True)
ax.fill_between(
    rn_dims,
    jnp.maximum(rn_score_tmean - 1.96 * rn_score_tstd, jnp.zeros_like(rn_score_tmean)),
    jnp.maximum(rn_score_tmean + 1.96 * rn_score_tstd, jnp.zeros_like(rn_score_tmean)),
    color="tab:red",
    alpha=0.5,
)
ax.fill_between(
    dims,
    jnp.maximum(rn_bridge_tmean - 1.96 * rn_bridge_tstd, jnp.zeros_like(rn_bridge_tmean)),
    jnp.maximum(rn_bridge_tmean + 1.96 * rn_bridge_tstd, jnp.zeros_like(rn_bridge_tmean)),
    color="tab:pink",
    alpha=0.5,
)
ax.grid(True)

# %% [markdown]
# # Circle

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = S1()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.])
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/S1/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
layers = [50,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/S1/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/S1/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_263434/4054132456.py in <module>
# ----> 1 loss = jnp.load('scores/S1/s2/loss_arrays.npy')
#       2 print("Number of Epochs: ", len(loss)*10)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in load(*args, **kwargs)
#     284   # The main purpose of this wrapper is to recover bfloat16 data types.
#     285   # Note: this will only work for files created via np.save(), not np.savez().
# --> 286   out = np.load(*args, **kwargs)
#     287   if isinstance(out, np.ndarray):
#     288     # numpy does not recognize bfloat16, so arrays are serialized as void16
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425             own_fid = False
#     426         else:
# --> 427             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428             own_fid = True
#     429
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scores/S1/s2/loss_arrays.npy'

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/S1/xs.csv', header=None)
charts = pd.read_csv('Data/S1/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[0][0]), jnp.array([0.2]), 
                                     step_size=0.01, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean((X_obs[0],X_obs[0]),num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean((X_obs[0],X_obs[0]),num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.714728e+02 | T: ((Array([-0.09553418], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.566660e+02 | T: ((Array([-0.08556889], dtype=float32), Array(0.21993957, dtype=float32)), Array([0.], dtype=float32))
# Final 1 | T: 1.566660e+02 | T: (Array([-0.08556889], dtype=float32), Array(0.21993957, dtype=float32))
# Step 0 | T: 1.714728e+02 | T: ((Array([-0.09553418], dtype=float32), Array(0.20999993, dtype=float32)), Array([0.], dtype=float32))
# Step 1 | T: 1.566660e+02 | T: ((Array([-0.08556889], dtype=float32), Array(0.21993957, dtype=float32)), Array([0.], dtype=float32))
# Step 2 | T: 1.442695e+02 | T: ((Array([-0.07565641], dtype=float32), Array(0.22978765, dtype=float32)), Array([0.], dtype=float32))
# Step 3 | T: 1.331197e+02 | T: ((Array([-0.06581438], dtype=float32), Array(0.23951484, dtype=float32)), Array([0.], dtype=float32))
# Step 4 | T: 1.240912e+02 | T: ((Array([-0.05605482], dtype=float32), Array(0.24910116, dtype=float32)), Array([0.], dtype=float32))
# Step 5 | T: 1.161743e+02 | T: ((Array([-0.04638842], dtype=float32), Array(0.2585295, dtype=float32)), Array([0.], dtype=float32))
# Step 6 | T: 1.089097e+02 | T: ((Array([-0.03682572], dtype=float32), Array(0.26778406, dtype=float32)), Array([0.], dtype=float32))
# Step 7 | T: 1.022243e+02 | T: ((Array([-0.0273766], dtype=float32), Array(0.27685076, dtype=float32)), Array([0.], dtype=float32))
# Step 8 | T: 9.553817e+01 | T: ((Array([-0.01805293], dtype=float32), Array(0.28571412, dtype=float32)), Array([0.], dtype=float32))
# Step 9 | T: 8.961499e+01 | T: ((Array([-0.00886383], dtype=float32), Array(0.29436302, dtype=float32)), Array([0.], dtype=float32))
# Step 10 | T: 8.480560e+01 | T: ((Array([0.00018633], dtype=float32), Array(0.30279285, dtype=float32)), Array([0.], dtype=float32))
# Step 11 | T: 8.158693e+01 | T: ((Array([0.00910078], dtype=float32), Array(0.31100821, dtype=float32)), Array([0.], dtype=float32))
# Step 12 | T: 7.829155e+01 | T: ((Array([0.01788009], dtype=float32), Array(0.31901112, dtype=float32)), Array([0.], dtype=float32))
# Step 13 | T: 7.551983e+01 | T: ((Array([0.0265265], dtype=float32), Array(0.32680565, dtype=float32)), Array([0.], dtype=float32))
# Step 14 | T: 7.246345e+01 | T: ((Array([0.03503902], dtype=float32), Array(0.33439267, dtype=float32)), Array([0.], dtype=float32))
# Step 15 | T: 6.987266e+01 | T: ((Array([0.0434187], dtype=float32), Array(0.3417754, dtype=float32)), Array([0.], dtype=float32))
# Step 16 | T: 6.701527e+01 | T: ((Array([0.05166384], dtype=float32), Array(0.3489544, dtype=float32)), Array([0.], dtype=float32))
# Step 17 | T: 6.506128e+01 | T: ((Array([0.05977803], dtype=float32), Array(0.3559358, dtype=float32)), Array([0.], dtype=float32))
# Step 18 | T: 6.281385e+01 | T: ((Array([0.06776194], dtype=float32), Array(0.36272287, dtype=float32)), Array([0.], dtype=float32))
# Step 19 | T: 6.075789e+01 | T: ((Array([0.07561681], dtype=float32), Array(0.36931956, dtype=float32)), Array([0.], dtype=float32))
# Step 20 | T: 5.901746e+01 | T: ((Array([0.0833455], dtype=float32), Array(0.37573138, dtype=float32)), Array([0.], dtype=float32))
# Step 21 | T: 5.755929e+01 | T: ((Array([0.09095212], dtype=float32), Array(0.38196498, dtype=float32)), Array([0.], dtype=float32))
# Step 22 | T: 5.594869e+01 | T: ((Array([0.09843897], dtype=float32), Array(0.38802537, dtype=float32)), Array([0.], dtype=float32))
# Step 23 | T: 5.433099e+01 | T: ((Array([0.10580768], dtype=float32), Array(0.39391696, dtype=float32)), Array([0.], dtype=float32))
# Step 24 | T: 5.334148e+01 | T: ((Array([0.11306415], dtype=float32), Array(0.3996479, dtype=float32)), Array([0.], dtype=float32))
# Step 25 | T: 5.218303e+01 | T: ((Array([0.12021221], dtype=float32), Array(0.40522435, dtype=float32)), Array([0.], dtype=float32))
# Step 26 | T: 5.098854e+01 | T: ((Array([0.12725484], dtype=float32), Array(0.41065177, dtype=float32)), Array([0.], dtype=float32))
# Step 27 | T: 4.999371e+01 | T: ((Array([0.13419612], dtype=float32), Array(0.41593644, dtype=float32)), Array([0.], dtype=float32))
# Step 28 | T: 4.895429e+01 | T: ((Array([0.1410392], dtype=float32), Array(0.42108378, dtype=float32)), Array([0.], dtype=float32))
# Step 29 | T: 4.787263e+01 | T: ((Array([0.14778642], dtype=float32), Array(0.4260984, dtype=float32)), Array([0.], dtype=float32))
# Step 30 | T: 4.685929e+01 | T: ((Array([0.15444034], dtype=float32), Array(0.4309851, dtype=float32)), Array([0.], dtype=float32))
# Step 31 | T: 4.590874e+01 | T: ((Array([0.16100362], dtype=float32), Array(0.43574858, dtype=float32)), Array([0.], dtype=float32))
# Step 32 | T: 4.543112e+01 | T: ((Array([0.16748257], dtype=float32), Array(0.44039643, dtype=float32)), Array([0.], dtype=float32))
# Step 33 | T: 4.447897e+01 | T: ((Array([0.17387877], dtype=float32), Array(0.4449323, dtype=float32)), Array([0.], dtype=float32))
# Step 34 | T: 4.377926e+01 | T: ((Array([0.18019573], dtype=float32), Array(0.44936135, dtype=float32)), Array([0.], dtype=float32))
# Step 35 | T: 4.302237e+01 | T: ((Array([0.18643606], dtype=float32), Array(0.45368782, dtype=float32)), Array([0.], dtype=float32))
# Step 36 | T: 4.240237e+01 | T: ((Array([0.1926032], dtype=float32), Array(0.4579166, dtype=float32)), Array([0.], dtype=float32))
# Step 37 | T: 4.172270e+01 | T: ((Array([0.19869971], dtype=float32), Array(0.46205172, dtype=float32)), Array([0.], dtype=float32))
# Step 38 | T: 4.098599e+01 | T: ((Array([0.2047273], dtype=float32), Array(0.46609655, dtype=float32)), Array([0.], dtype=float32))
# Step 39 | T: 4.064851e+01 | T: ((Array([0.21069112], dtype=float32), Array(0.47005686, dtype=float32)), Array([0.], dtype=float32))
# Step 40 | T: 4.015281e+01 | T: ((Array([0.21659434], dtype=float32), Array(0.4739369, dtype=float32)), Array([0.], dtype=float32))
# Step 41 | T: 3.976982e+01 | T: ((Array([0.22244082], dtype=float32), Array(0.47774124, dtype=float32)), Array([0.], dtype=float32))
# Step 42 | T: 3.906110e+01 | T: ((Array([0.22823095], dtype=float32), Array(0.4814719, dtype=float32)), Array([0.], dtype=float32))
# Step 43 | T: 3.846759e+01 | T: ((Array([0.2339661], dtype=float32), Array(0.4851315, dtype=float32)), Array([0.], dtype=float32))
# Step 44 | T: 3.781567e+01 | T: ((Array([0.23964684], dtype=float32), Array(0.48872206, dtype=float32)), Array([0.], dtype=float32))
# Step 45 | T: 3.743801e+01 | T: ((Array([0.24527633], dtype=float32), Array(0.49224728, dtype=float32)), Array([0.], dtype=float32))
# Step 46 | T: 3.691472e+01 | T: ((Array([0.25085598], dtype=float32), Array(0.4957096, dtype=float32)), Array([0.], dtype=float32))
# Step 47 | T: 3.641253e+01 | T: ((Array([0.25638714], dtype=float32), Array(0.49911132, dtype=float32)), Array([0.], dtype=float32))
# Step 48 | T: 3.632563e+01 | T: ((Array([0.26187527], dtype=float32), Array(0.50245756, dtype=float32)), Array([0.], dtype=float32))
# Step 49 | T: 3.601150e+01 | T: ((Array([0.26732296], dtype=float32), Array(0.5057513, dtype=float32)), Array([0.], dtype=float32))
# Step 50 | T: 3.578706e+01 | T: ((Array([0.27273345], dtype=float32), Array(0.508996, dtype=float32)), Array([0.], dtype=float32))
# Step 51 | T: 3.542025e+01 | T: ((Array([0.27810818], dtype=float32), Array(0.5121937, dtype=float32)), Array([0.], dtype=float32))
# Step 52 | T: 3.499142e+01 | T: ((Array([0.28344774], dtype=float32), Array(0.5153458, dtype=float32)), Array([0.], dtype=float32))
# Step 53 | T: 3.472555e+01 | T: ((Array([0.28875437], dtype=float32), Array(0.5184549, dtype=float32)), Array([0.], dtype=float32))
# Step 54 | T: 3.446944e+01 | T: ((Array([0.29403016], dtype=float32), Array(0.5215233, dtype=float32)), Array([0.], dtype=float32))
# Step 55 | T: 3.414987e+01 | T: ((Array([0.2992763], dtype=float32), Array(0.5245527, dtype=float32)), Array([0.], dtype=float32))
# Step 56 | T: 3.384070e+01 | T: ((Array([0.3044939], dtype=float32), Array(0.5275447, dtype=float32)), Array([0.], dtype=float32))
# Step 57 | T: 3.339967e+01 | T: ((Array([0.30968255], dtype=float32), Array(0.5304997, dtype=float32)), Array([0.], dtype=float32))
# Step 58 | T: 3.311160e+01 | T: ((Array([0.31484348], dtype=float32), Array(0.5334194, dtype=float32)), Array([0.], dtype=float32))
# Step 59 | T: 3.297110e+01 | T: ((Array([0.31997937], dtype=float32), Array(0.53630614, dtype=float32)), Array([0.], dtype=float32))
# Step 60 | T: 3.283566e+01 | T: ((Array([0.32509276], dtype=float32), Array(0.53916234, dtype=float32)), Array([0.], dtype=float32))
# Step 61 | T: 3.263702e+01 | T: ((Array([0.33018517], dtype=float32), Array(0.5419896, dtype=float32)), Array([0.], dtype=float32))
# Step 62 | T: 3.230989e+01 | T: ((Array([0.33525652], dtype=float32), Array(0.5447885, dtype=float32)), Array([0.], dtype=float32))
# Step 63 | T: 3.199137e+01 | T: ((Array([0.3403068], dtype=float32), Array(0.5475595, dtype=float32)), Array([0.], dtype=float32))
# Step 64 | T: 3.168121e+01 | T: ((Array([0.345336], dtype=float32), Array(0.5503032, dtype=float32)), Array([0.], dtype=float32))
# Step 65 | T: 3.150926e+01 | T: ((Array([0.35034573], dtype=float32), Array(0.55302113, dtype=float32)), Array([0.], dtype=float32))
# Step 66 | T: 3.127750e+01 | T: ((Array([0.3553367], dtype=float32), Array(0.5557142, dtype=float32)), Array([0.], dtype=float32))
# Step 67 | T: 3.098785e+01 | T: ((Array([0.36030886], dtype=float32), Array(0.5583828, dtype=float32)), Array([0.], dtype=float32))
# Step 68 | T: 3.076848e+01 | T: ((Array([0.36526296], dtype=float32), Array(0.5610279, dtype=float32)), Array([0.], dtype=float32))
# Step 69 | T: 3.055449e+01 | T: ((Array([0.37019968], dtype=float32), Array(0.5636503, dtype=float32)), Array([0.], dtype=float32))
# Step 70 | T: 3.022157e+01 | T: ((Array([0.37511823], dtype=float32), Array(0.5662499, dtype=float32)), Array([0.], dtype=float32))
# Step 71 | T: 2.995768e+01 | T: ((Array([0.38001865], dtype=float32), Array(0.5688271, dtype=float32)), Array([0.], dtype=float32))
# Step 72 | T: 2.988280e+01 | T: ((Array([0.38490325], dtype=float32), Array(0.57138366, dtype=float32)), Array([0.], dtype=float32))
# Step 73 | T: 2.974966e+01 | T: ((Array([0.3897734], dtype=float32), Array(0.5739207, dtype=float32)), Array([0.], dtype=float32))
# Step 74 | T: 2.955979e+01 | T: ((Array([0.3946296], dtype=float32), Array(0.576439, dtype=float32)), Array([0.], dtype=float32))
# Step 75 | T: 2.943345e+01 | T: ((Array([0.3994731], dtype=float32), Array(0.57893956, dtype=float32)), Array([0.], dtype=float32))
# Step 76 | T: 2.919222e+01 | T: ((Array([0.40430355], dtype=float32), Array(0.5814224, dtype=float32)), Array([0.], dtype=float32))
# Step 77 | T: 2.889762e+01 | T: ((Array([0.40911996], dtype=float32), Array(0.5838872, dtype=float32)), Array([0.], dtype=float32))
# Step 78 | T: 2.872466e+01 | T: ((Array([0.41392294], dtype=float32), Array(0.58633465, dtype=float32)), Array([0.], dtype=float32))
# Step 79 | T: 2.844060e+01 | T: ((Array([0.41871157], dtype=float32), Array(0.5887643, dtype=float32)), Array([0.], dtype=float32))
# Step 80 | T: 2.838971e+01 | T: ((Array([0.42348796], dtype=float32), Array(0.5911778, dtype=float32)), Array([0.], dtype=float32))
# Step 81 | T: 2.817086e+01 | T: ((Array([0.4282519], dtype=float32), Array(0.5935752, dtype=float32)), Array([0.], dtype=float32))
# Step 82 | T: 2.795633e+01 | T: ((Array([0.43300316], dtype=float32), Array(0.5959565, dtype=float32)), Array([0.], dtype=float32))
# Step 83 | T: 2.785697e+01 | T: ((Array([0.43774304], dtype=float32), Array(0.5983228, dtype=float32)), Array([0.], dtype=float32))
# Step 84 | T: 2.770457e+01 | T: ((Array([0.442472], dtype=float32), Array(0.6006745, dtype=float32)), Array([0.], dtype=float32))
# Step 85 | T: 2.750042e+01 | T: ((Array([0.4471898], dtype=float32), Array(0.60301167, dtype=float32)), Array([0.], dtype=float32))
# Step 86 | T: 2.746274e+01 | T: ((Array([0.45189834], dtype=float32), Array(0.6053356, dtype=float32)), Array([0.], dtype=float32))
# Step 87 | T: 2.737204e+01 | T: ((Array([0.4565986], dtype=float32), Array(0.607647, dtype=float32)), Array([0.], dtype=float32))
# Step 88 | T: 2.733639e+01 | T: ((Array([0.46129227], dtype=float32), Array(0.6099471, dtype=float32)), Array([0.], dtype=float32))
# Step 89 | T: 2.719533e+01 | T: ((Array([0.46597937], dtype=float32), Array(0.61223596, dtype=float32)), Array([0.], dtype=float32))
# Step 90 | T: 2.700393e+01 | T: ((Array([0.4706593], dtype=float32), Array(0.61451346, dtype=float32)), Array([0.], dtype=float32))
# Step 91 | T: 2.676347e+01 | T: ((Array([0.47533077], dtype=float32), Array(0.61677897, dtype=float32)), Array([0.], dtype=float32))
# Step 92 | T: 2.657881e+01 | T: ((Array([0.4799934], dtype=float32), Array(0.6190324, dtype=float32)), Array([0.], dtype=float32))
# Step 93 | T: 2.644873e+01 | T: ((Array([0.48464754], dtype=float32), Array(0.62127405, dtype=float32)), Array([0.], dtype=float32))
# Step 94 | T: 2.626979e+01 | T: ((Array([0.4892928], dtype=float32), Array(0.62350386, dtype=float32)), Array([0.], dtype=float32))
# Step 95 | T: 2.614452e+01 | T: ((Array([0.49392956], dtype=float32), Array(0.62572217, dtype=float32)), Array([0.], dtype=float32))
# Step 96 | T: 2.597097e+01 | T: ((Array([0.4985575], dtype=float32), Array(0.62792885, dtype=float32)), Array([0.], dtype=float32))
# Step 97 | T: 2.590028e+01 | T: ((Array([0.5031777], dtype=float32), Array(0.6301247, dtype=float32)), Array([0.], dtype=float32))
# Step 98 | T: 2.593010e+01 | T: ((Array([0.50779253], dtype=float32), Array(0.6323111, dtype=float32)), Array([0.], dtype=float32))
# Step 99 | T: 2.571275e+01 | T: ((Array([0.51240075], dtype=float32), Array(0.6344875, dtype=float32)), Array([0.], dtype=float32))
# Final 99 | T: 2.571275e+01 | T: (Array([0.51240075], dtype=float32), Array(0.6344875, dtype=float32))

# %%
def gradt_log_opt(x,y,t):
    
    s1_val = M.grady_log_hk(x,y,t)
    s2_val = jacfwdx(lambda y: M.grady_log_hk(x,y,t))(y)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div).squeeze()

# %%
def gradt_log_opt(x,y,t):
    
    ggrad = jacfwdx(lambda y: M.grady_log_hk(x,y,t))(y)
    
    return ggrad.squeeze()

# %%
diffusion_mean(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t).squeeze(), s2_model = gradt_log_opt, method="Gradient")
mu_opt, T_opt, _, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[0][0]), jnp.array([0.2]))

# %%
mu_opt = x0
T_opt = jnp.array([0.5]).reshape(1,1)

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0179 )
# T = 0.1000

# %%
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1]):.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.5f}")
# Out:
# Score Diffusion mean:
#  -mean error = 0.01786
#  -T error = 0.40000

# %%
mu_bridge = M.F((mu_bridgex[-1], mu_bridgechart[-1]))

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridge), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.5124 )
# T = 0.6345

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[1]), ")")
print(f"T = {T_opt[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0000 )
# T = 0.5000

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1]-mu_sm[1][-1]):.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.5f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1]-mu_bridgechart[-1]):.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.5f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.01786
#  -T error = 0.40000
# Bridge Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.13449

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[0][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 183 ms ± 2.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100, N=1)
# Out:
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883113e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032158e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465624e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227062, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398962, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.4656617, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.467289, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.4688735, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041705, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.4719214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832603e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338825, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.47621548, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.4775787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.47891006, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.48021078, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.481482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683385e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.4827248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394015, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.48512906, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.48629236, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743093, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591662e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854554, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574530e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.48963696, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.4917529, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277872, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.4937839, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.494769, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573454, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464089e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.496681, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.49760887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.4985186, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.49941057, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407409e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.5002852, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.50114286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.50198394, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.267695], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.2758596, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507274e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437075, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883111e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.2926175, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334002e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.30059552, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830318, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418879e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.31574082, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.3229106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157136], dtype=float32), Array(0.32981613, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387371e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646217, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572083], dtype=float32), Array(0.34285444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862518e+00 | T: ((Array([-0.07804246], dtype=float32), Array(0.34899938, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637067e+00 | T: ((Array([-0.0705253], dtype=float32), Array(0.35490403, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432304e+00 | T: ((Array([-0.06316626], dtype=float32), Array(0.36057585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245780e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.36602262, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075386e+00 | T: ((Array([-0.04890837], dtype=float32), Array(0.37125227, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200172], dtype=float32), Array(0.3762729, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775929e+00 | T: ((Array([-0.03523772], dtype=float32), Array(0.3810926, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861202], dtype=float32), Array(0.3857195, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522033e+00 | T: ((Array([-0.02212016], dtype=float32), Array(0.39016163, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409250e+00 | T: ((Array([-0.01575764], dtype=float32), Array(0.39442685, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304638e+00 | T: ((Array([-0.00951992], dtype=float32), Array(0.39852297, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207382e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.40245754, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.0025993], dtype=float32), Array(0.4062379, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032158e+00 | T: ((Array([0.00848978], dtype=float32), Array(0.40987122, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427341], dtype=float32), Array(0.41336444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.4167242, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553736], dtype=float32), Array(0.41995695, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306885, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681561e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.4260658, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623114e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895347, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567810e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.43173724, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515391e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442228, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465624e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.4370135, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951556, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373231e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.44193292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330245e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426975, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871765, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083606, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288867, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.4548787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.45680913, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.45868284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.4605025, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227065, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398965, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.46566173, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.46728903, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.46887353, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041708, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.47192144, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832602e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481915, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.4762155, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.47757873, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.4789101, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336694], dtype=float32), Array(0.4802108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734694], dtype=float32), Array(0.48148203, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130283], dtype=float32), Array(0.48272482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523545], dtype=float32), Array(0.48394018, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.17914562], dtype=float32), Array(0.4851291, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303409], dtype=float32), Array(0.4862924, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690157], dtype=float32), Array(0.48743096, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591661e+00 | T: ((Array([0.19074872], dtype=float32), Array(0.48854557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574529e+00 | T: ((Array([0.19457619], dtype=float32), Array(0.489637, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838455], dtype=float32), Array(0.49070588, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217437], dtype=float32), Array(0.49175292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594616], dtype=float32), Array(0.49277875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970044], dtype=float32), Array(0.49378392, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343765], dtype=float32), Array(0.49476904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715823], dtype=float32), Array(0.49573457, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464090e+00 | T: ((Array([0.22086261], dtype=float32), Array(0.49668103, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455117], dtype=float32), Array(0.4976089, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822428], dtype=float32), Array(0.49851862, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188227], dtype=float32), Array(0.4994106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407408e+00 | T: ((Array([0.23552549], dtype=float32), Array(0.50028527, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915423], dtype=float32), Array(0.5011429, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.501984, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.5028088, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354655e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.50361764, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.50441086, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.50518876, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059516, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.50669956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293538e+00 | T: ((Array([0.267695], dtype=float32), Array(0.507433, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281897e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.5081521, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.5088572, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.5095484, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248045e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.510226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.5108901, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.511541, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.51217884, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.5128038, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.5128038, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883113e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848980e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227062, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398962, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.4656617, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.467289, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.4688735, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041705, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.4719214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832603e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338825, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787068e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.47621548, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.4775787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.47891006, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.48021078, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.481482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.4827248, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394015, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.48512906, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.48629236, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743093, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591662e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854554, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574530e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.48963696, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.4917529, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277872, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.4937839, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.494769, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573454, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464089e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.496681, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.49760887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.4985186, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.49941057, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407409e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.5002852, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.50114286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.2427688], dtype=float32), Array(0.50198394, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636945], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995646], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353009], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709054], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063803], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.2641728], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.267695], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120486], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470255], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818823], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.28166208], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.2851242], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.2885748], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.292014], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544193], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883114e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.30059552, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848978e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830318, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418879e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.31574082, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.3229106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157136], dtype=float32), Array(0.32981613, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387371e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646217, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.34285444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862518e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899938, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637067e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.35490403, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432304e+00 | T: ((Array([-0.06316626], dtype=float32), Array(0.36057585, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245780e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.36602262, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075386e+00 | T: ((Array([-0.04890837], dtype=float32), Array(0.37125227, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200172], dtype=float32), Array(0.3762729, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775929e+00 | T: ((Array([-0.03523773], dtype=float32), Array(0.3810926, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861202], dtype=float32), Array(0.3857195, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522033e+00 | T: ((Array([-0.02212016], dtype=float32), Array(0.39016163, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409250e+00 | T: ((Array([-0.01575765], dtype=float32), Array(0.39442685, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304638e+00 | T: ((Array([-0.00951992], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340245], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259929], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848978], dtype=float32), Array(0.4098712, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427341], dtype=float32), Array(0.4133644, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995452], dtype=float32), Array(0.41672418, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553736], dtype=float32), Array(0.41995692, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102605], dtype=float32), Array(0.42306882, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681560e+00 | T: ((Array([0.03642463], dtype=float32), Array(0.42606577, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623115e+00 | T: ((Array([0.04173699], dtype=float32), Array(0.42895344, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567811e+00 | T: ((Array([0.04696692], dtype=float32), Array(0.4317372, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515392e+00 | T: ((Array([0.05211806], dtype=float32), Array(0.43442225, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719394], dtype=float32), Array(0.43701348, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951553, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373232e+00 | T: ((Array([0.06713332], dtype=float32), Array(0.4419329, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330246e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426972, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681053], dtype=float32), Array(0.44653004, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155821], dtype=float32), Array(0.44871762, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624895], dtype=float32), Array(0.45083603, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088534], dtype=float32), Array(0.45288864, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141595e+00 | T: ((Array([0.09546987], dtype=float32), Array(0.45487866, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.10000489], dtype=float32), Array(0.4568091, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.4586828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893522], dtype=float32), Array(0.46050248, dtype=float32)), Array([1., 0.], dtype=float32))
# ...
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636948], dtype=float32), Array(0.50280875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995649], dtype=float32), Array(0.5036176, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.2535301], dtype=float32), Array(0.5044108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.25709057], dtype=float32), Array(0.5051887, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.26063806], dtype=float32), Array(0.5059515, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.26417282], dtype=float32), Array(0.5066995, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293539e+00 | T: ((Array([0.26769504], dtype=float32), Array(0.50743294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.2712049], dtype=float32), Array(0.50815207, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470258], dtype=float32), Array(0.50885713, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.27818826], dtype=float32), Array(0.50954837, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248046e+00 | T: ((Array([0.2816621], dtype=float32), Array(0.51022595, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.28512424], dtype=float32), Array(0.51089007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.28857484], dtype=float32), Array(0.51154095, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.29201403], dtype=float32), Array(0.5121788, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.29544196], dtype=float32), Array(0.51280373, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.29544196], dtype=float32), Array(0.51280373, dtype=float32))
# Step 0 | T: 1.852988e+01 | T: ((Array([-0.23001227], dtype=float32), Array(0.20999993, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 1 | T: 1.651170e+01 | T: ((Array([-0.22005376], dtype=float32), Array(0.21992284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 2 | T: 1.479264e+01 | T: ((Array([-0.2101603], dtype=float32), Array(0.22972557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 3 | T: 1.332320e+01 | T: ((Array([-0.20035248], dtype=float32), Array(0.23937148, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 4 | T: 1.206231e+01 | T: ((Array([-0.19064815], dtype=float32), Array(0.24883002, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 5 | T: 1.097600e+01 | T: ((Array([-0.18106249], dtype=float32), Array(0.25807643, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 6 | T: 1.003619e+01 | T: ((Array([-0.17160816], dtype=float32), Array(0.2670912, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 7 | T: 9.219672e+00 | T: ((Array([-0.16229557], dtype=float32), Array(0.27585956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 8 | T: 8.507276e+00 | T: ((Array([-0.15313306], dtype=float32), Array(0.28437072, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 9 | T: 7.883114e+00 | T: ((Array([-0.14412718], dtype=float32), Array(0.29261747, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 10 | T: 7.334003e+00 | T: ((Array([-0.13528283], dtype=float32), Array(0.3005955, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 11 | T: 6.848979e+00 | T: ((Array([-0.12660344], dtype=float32), Array(0.30830315, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 12 | T: 6.418880e+00 | T: ((Array([-0.11809118], dtype=float32), Array(0.3157408, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 13 | T: 6.036039e+00 | T: ((Array([-0.10974713], dtype=float32), Array(0.32291058, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 14 | T: 5.694015e+00 | T: ((Array([-0.10157135], dtype=float32), Array(0.3298161, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 15 | T: 5.387372e+00 | T: ((Array([-0.09356309], dtype=float32), Array(0.33646214, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 16 | T: 5.111509e+00 | T: ((Array([-0.08572082], dtype=float32), Array(0.3428544, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 17 | T: 4.862519e+00 | T: ((Array([-0.07804245], dtype=float32), Array(0.34899935, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 18 | T: 4.637068e+00 | T: ((Array([-0.07052529], dtype=float32), Array(0.354904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 19 | T: 4.432305e+00 | T: ((Array([-0.06316625], dtype=float32), Array(0.36057582, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 20 | T: 4.245781e+00 | T: ((Array([-0.05596187], dtype=float32), Array(0.3660226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 21 | T: 4.075387e+00 | T: ((Array([-0.04890836], dtype=float32), Array(0.37125224, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 22 | T: 3.919297e+00 | T: ((Array([-0.04200171], dtype=float32), Array(0.37627286, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 23 | T: 3.775930e+00 | T: ((Array([-0.03523771], dtype=float32), Array(0.38109258, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 24 | T: 3.643910e+00 | T: ((Array([-0.02861201], dtype=float32), Array(0.38571948, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 25 | T: 3.522034e+00 | T: ((Array([-0.02212015], dtype=float32), Array(0.3901616, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 26 | T: 3.409251e+00 | T: ((Array([-0.01575763], dtype=float32), Array(0.39442682, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 27 | T: 3.304639e+00 | T: ((Array([-0.00951991], dtype=float32), Array(0.39852294, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 28 | T: 3.207383e+00 | T: ((Array([-0.00340244], dtype=float32), Array(0.4024575, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 29 | T: 3.116768e+00 | T: ((Array([0.00259931], dtype=float32), Array(0.40623787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 30 | T: 3.032159e+00 | T: ((Array([0.00848979], dtype=float32), Array(0.40987122, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 31 | T: 2.952994e+00 | T: ((Array([0.01427342], dtype=float32), Array(0.41336444, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 32 | T: 2.878774e+00 | T: ((Array([0.01995453], dtype=float32), Array(0.4167242, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 33 | T: 2.809053e+00 | T: ((Array([0.02553737], dtype=float32), Array(0.41995695, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 34 | T: 2.743433e+00 | T: ((Array([0.03102606], dtype=float32), Array(0.42306885, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 35 | T: 2.681561e+00 | T: ((Array([0.03642464], dtype=float32), Array(0.4260658, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 36 | T: 2.623114e+00 | T: ((Array([0.041737], dtype=float32), Array(0.42895347, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 37 | T: 2.567810e+00 | T: ((Array([0.04696693], dtype=float32), Array(0.43173724, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 38 | T: 2.515391e+00 | T: ((Array([0.05211807], dtype=float32), Array(0.43442228, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 39 | T: 2.465625e+00 | T: ((Array([0.05719395], dtype=float32), Array(0.4370135, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 40 | T: 2.418301e+00 | T: ((Array([0.06219795], dtype=float32), Array(0.43951556, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 41 | T: 2.373231e+00 | T: ((Array([0.06713333], dtype=float32), Array(0.44193292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 42 | T: 2.330245e+00 | T: ((Array([0.07200319], dtype=float32), Array(0.44426975, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 43 | T: 2.289187e+00 | T: ((Array([0.07681054], dtype=float32), Array(0.44653007, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 44 | T: 2.249915e+00 | T: ((Array([0.08155822], dtype=float32), Array(0.44871765, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 45 | T: 2.212302e+00 | T: ((Array([0.08624896], dtype=float32), Array(0.45083606, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 46 | T: 2.176231e+00 | T: ((Array([0.09088535], dtype=float32), Array(0.45288867, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 47 | T: 2.141594e+00 | T: ((Array([0.09546988], dtype=float32), Array(0.4548787, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 48 | T: 2.108297e+00 | T: ((Array([0.1000049], dtype=float32), Array(0.45680913, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 49 | T: 2.076249e+00 | T: ((Array([0.10449263], dtype=float32), Array(0.45868284, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 50 | T: 2.045369e+00 | T: ((Array([0.10893523], dtype=float32), Array(0.4605025, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 51 | T: 2.015582e+00 | T: ((Array([0.11333469], dtype=float32), Array(0.46227065, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 52 | T: 1.986821e+00 | T: ((Array([0.11769294], dtype=float32), Array(0.46398965, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 53 | T: 1.959023e+00 | T: ((Array([0.12201177], dtype=float32), Array(0.46566173, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 54 | T: 1.932129e+00 | T: ((Array([0.12629291], dtype=float32), Array(0.46728903, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 55 | T: 1.906087e+00 | T: ((Array([0.13053799], dtype=float32), Array(0.46887353, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 56 | T: 1.880849e+00 | T: ((Array([0.13474852], dtype=float32), Array(0.47041708, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 57 | T: 1.856367e+00 | T: ((Array([0.13892595], dtype=float32), Array(0.47192144, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 58 | T: 1.832602e+00 | T: ((Array([0.14307165], dtype=float32), Array(0.47338828, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 59 | T: 1.809515e+00 | T: ((Array([0.14718692], dtype=float32), Array(0.47481915, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 60 | T: 1.787069e+00 | T: ((Array([0.15127297], dtype=float32), Array(0.4762155, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 61 | T: 1.765231e+00 | T: ((Array([0.15533094], dtype=float32), Array(0.47757873, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 62 | T: 1.743972e+00 | T: ((Array([0.15936193], dtype=float32), Array(0.4789101, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 63 | T: 1.723262e+00 | T: ((Array([0.16336693], dtype=float32), Array(0.4802108, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 64 | T: 1.703075e+00 | T: ((Array([0.16734692], dtype=float32), Array(0.48148203, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 65 | T: 1.683386e+00 | T: ((Array([0.17130281], dtype=float32), Array(0.48272482, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 66 | T: 1.664172e+00 | T: ((Array([0.17523544], dtype=float32), Array(0.48394018, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 67 | T: 1.645412e+00 | T: ((Array([0.1791456], dtype=float32), Array(0.4851291, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 68 | T: 1.627086e+00 | T: ((Array([0.18303408], dtype=float32), Array(0.4862924, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 69 | T: 1.609175e+00 | T: ((Array([0.18690155], dtype=float32), Array(0.48743096, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 70 | T: 1.591661e+00 | T: ((Array([0.1907487], dtype=float32), Array(0.48854557, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 71 | T: 1.574529e+00 | T: ((Array([0.19457617], dtype=float32), Array(0.489637, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 72 | T: 1.557763e+00 | T: ((Array([0.19838454], dtype=float32), Array(0.49070588, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 73 | T: 1.541347e+00 | T: ((Array([0.20217435], dtype=float32), Array(0.49175292, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 74 | T: 1.525269e+00 | T: ((Array([0.20594615], dtype=float32), Array(0.49277875, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 75 | T: 1.509517e+00 | T: ((Array([0.20970042], dtype=float32), Array(0.49378392, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 76 | T: 1.494076e+00 | T: ((Array([0.21343763], dtype=float32), Array(0.49476904, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 77 | T: 1.478937e+00 | T: ((Array([0.21715821], dtype=float32), Array(0.49573457, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 78 | T: 1.464090e+00 | T: ((Array([0.2208626], dtype=float32), Array(0.49668103, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 79 | T: 1.449522e+00 | T: ((Array([0.22455116], dtype=float32), Array(0.4976089, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 80 | T: 1.435225e+00 | T: ((Array([0.22822426], dtype=float32), Array(0.49851862, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 81 | T: 1.421190e+00 | T: ((Array([0.23188226], dtype=float32), Array(0.4994106, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 82 | T: 1.407408e+00 | T: ((Array([0.23552547], dtype=float32), Array(0.50028527, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 83 | T: 1.393872e+00 | T: ((Array([0.23915422], dtype=float32), Array(0.5011429, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 84 | T: 1.380572e+00 | T: ((Array([0.24276878], dtype=float32), Array(0.501984, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 85 | T: 1.367503e+00 | T: ((Array([0.24636944], dtype=float32), Array(0.5028088, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 86 | T: 1.354656e+00 | T: ((Array([0.24995644], dtype=float32), Array(0.50361764, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 87 | T: 1.342025e+00 | T: ((Array([0.25353006], dtype=float32), Array(0.50441086, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 88 | T: 1.329604e+00 | T: ((Array([0.2570905], dtype=float32), Array(0.50518876, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 89 | T: 1.317386e+00 | T: ((Array([0.260638], dtype=float32), Array(0.5059516, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 90 | T: 1.305366e+00 | T: ((Array([0.26417276], dtype=float32), Array(0.50669956, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 91 | T: 1.293538e+00 | T: ((Array([0.26769498], dtype=float32), Array(0.507433, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 92 | T: 1.281898e+00 | T: ((Array([0.27120483], dtype=float32), Array(0.5081521, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 93 | T: 1.270439e+00 | T: ((Array([0.27470252], dtype=float32), Array(0.5088572, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 94 | T: 1.259156e+00 | T: ((Array([0.2781882], dtype=float32), Array(0.5095484, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 95 | T: 1.248045e+00 | T: ((Array([0.28166205], dtype=float32), Array(0.510226, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 96 | T: 1.237103e+00 | T: ((Array([0.28512418], dtype=float32), Array(0.5108901, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 97 | T: 1.226323e+00 | T: ((Array([0.28857478], dtype=float32), Array(0.511541, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 98 | T: 1.215703e+00 | T: ((Array([0.29201397], dtype=float32), Array(0.51217884, dtype=float32)), Array([1., 0.], dtype=float32))
# Step 99 | T: 1.205237e+00 | T: ((Array([0.2954419], dtype=float32), Array(0.5128038, dtype=float32)), Array([1., 0.], dtype=float32))
# Final 99 | T: 1.205237e+00 | T: (Array([0.2954419], dtype=float32), Array(0.5128038, dtype=float32))
# 10.9 s ± 39.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # n-Sphere

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2 #Change this for S2, S3, S5, S10, S20

# %%
M = nSphere(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*N)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/S'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/S'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))
    
    return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/S'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  210

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/S'+str(N)+'/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  270

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/S'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/S'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")

# %%
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.1, max_iter=1000)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.532447e+01 | T: ((Array([-2.2847826e-09,  6.5007510e-10,  2.8858853e-09,  3.3108427e-10,
#         2.1574467e-09,  4.8258170e-10,  5.0847299e-10,  4.1910438e-12,
#        -4.6942193e-11,  4.2621540e-10], dtype=float32), Array(0.20999993, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 1 | T: 1.256124e+01 | T: ((Array([ 0.00884337,  0.00999874,  0.00912418, -0.00987595,  0.00855115,
#         0.00692009, -0.00302555,  0.00766935,  0.00854711, -0.00235898],      dtype=float32), Array(0.21991883, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Final 1 | T: 1.256124e+01 | T: (Array([ 0.00884337,  0.00999874,  0.00912418, -0.00987595,  0.00855115,
#         0.00692009, -0.00302555,  0.00766935,  0.00854711, -0.00235898],      dtype=float32), Array(0.21991883, dtype=float32))
# Step 0 | T: 1.531675e+01 | T: ((Array([-2.2847826e-09,  6.5007510e-10,  2.8858853e-09,  3.3108427e-10,
#         2.1574467e-09,  4.8258170e-10,  5.0847299e-10,  4.1910429e-12,
#        -4.6942193e-11,  4.2621540e-10], dtype=float32), Array(0.20999993, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 1 | T: 1.256185e+01 | T: ((Array([ 0.00884188,  0.00999558,  0.0091283 , -0.0098493 ,  0.00856276,
#         0.00692162, -0.00283743,  0.00778645,  0.00853901, -0.00232648],      dtype=float32), Array(0.21991913, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 2 | T: 1.069882e+01 | T: ((Array([ 0.01705784,  0.01716935,  0.01773207, -0.01861346,  0.01615275,
#         0.01059859, -0.00770071,  0.00866417,  0.01585069, -0.00101804],      dtype=float32), Array(0.22971202, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 3 | T: 9.141707e+00 | T: ((Array([ 0.0247054 ,  0.0192118 ,  0.02581392, -0.02369936,  0.02276317,
#         0.01143374, -0.01199431,  0.00607219,  0.02175917,  0.00206105],      dtype=float32), Array(0.2393391, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 4 | T: 7.836973e+00 | T: ((Array([ 0.03174771,  0.01764072,  0.03330452, -0.02479914,  0.02829511,
#         0.01030931, -0.0138316 ,  0.00214868,  0.02608901,  0.00591361],      dtype=float32), Array(0.24876733, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 5 | T: 6.739297e+00 | T: ((Array([ 0.03811681,  0.01413084,  0.04011193, -0.02317604,  0.03267185,
#         0.00794453, -0.01307292, -0.00165847,  0.02879108,  0.00986854],      dtype=float32), Array(0.2579697, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 6 | T: 5.814740e+00 | T: ((Array([ 0.04375371,  0.00967988,  0.04615043, -0.01986992,  0.03585353,
#         0.00494314, -0.0106387 , -0.00411937,  0.02995773,  0.01337844],      dtype=float32), Array(0.26692477, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 7 | T: 5.024370e+00 | T: ((Array([ 0.04859722,  0.00508972,  0.05134317, -0.0156726 ,  0.03787345,
#         0.00181551, -0.0073452 , -0.00476681,  0.02978925,  0.01604612],      dtype=float32), Array(0.27561566, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 8 | T: 4.361857e+00 | T: ((Array([ 0.05260644,  0.0010971 ,  0.05564107, -0.01121002,  0.03879708,
#        -0.00097565, -0.00410358, -0.00382781,  0.02852044,  0.0176249 ],      dtype=float32), Array(0.28403056, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 9 | T: 3.788455e+00 | T: ((Array([ 0.05575964, -0.00173229,  0.05900858, -0.00702032,  0.03873431,
#        -0.00309514, -0.00155391, -0.00183956,  0.02638691,  0.01806752],      dtype=float32), Array(0.29216075, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 10 | T: 3.302993e+00 | T: ((Array([ 0.05806401, -0.00309021,  0.06144604, -0.00361039,  0.03781614,
#        -0.00435122, -0.00020666,  0.00056756,  0.02361486,  0.0174659 ],      dtype=float32), Array(0.30000123, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 11 | T: 2.885199e+00 | T: ((Array([ 0.05954234, -0.00301922,  0.06297845, -0.00131604,  0.03617528,
#        -0.00472241, -0.0001707 ,  0.00276236,  0.02040603,  0.01600268],      dtype=float32), Array(0.30754983, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 12 | T: 2.519357e+00 | T: ((Array([ 0.06023489, -0.0017879 ,  0.06365569, -0.00025153,  0.0339459 ,
#        -0.00426458, -0.00120091,  0.00424371,  0.01695787,  0.01388302],      dtype=float32), Array(0.31480634, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 13 | T: 2.202391e+00 | T: ((Array([ 0.06019666,  0.00024026,  0.063533  , -0.00034349,  0.03126004,
#        -0.00314035, -0.00289842,  0.00469064,  0.01344519,  0.011363  ],      dtype=float32), Array(0.32177263, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 14 | T: 1.925709e+00 | T: ((Array([ 0.05949261,  0.00265883,  0.06268715, -0.00136331,  0.02824258,
#        -0.00157733, -0.00481903,  0.00414103,  0.01003405,  0.00867811],      dtype=float32), Array(0.32845226, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 15 | T: 1.689624e+00 | T: ((Array([ 0.05819213,  0.00509834,  0.06119929, -0.00306634,  0.02501045,
#         0.00019611, -0.00648558,  0.00286741,  0.00686798,  0.00607407],      dtype=float32), Array(0.33485037, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 16 | T: 1.477390e+00 | T: ((Array([ 0.05636784,  0.00714605,  0.05915422, -0.00513848,  0.02167328,
#         0.00192646, -0.00752159,  0.00122124,  0.00407238,  0.00375638],      dtype=float32), Array(0.34097287, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 17 | T: 1.293637e+00 | T: ((Array([ 0.05410089,  0.00858739,  0.05663792, -0.00729707,  0.01834377,
#         0.00342296, -0.00772411, -0.00043773,  0.0017449 ,  0.00192106],      dtype=float32), Array(0.34682655, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 18 | T: 1.133659e+00 | T: ((Array([ 5.1467024e-02,  9.2320181e-03,  5.3735949e-02, -9.2574116e-03,
#         1.5120372e-02,  4.4925790e-03, -7.1625700e-03, -1.7375284e-03,
#        -4.2606494e-05,  6.7571248e-04], dtype=float32), Array(0.3524191, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 19 | T: 9.921764e-01 | T: ((Array([ 4.8538487e-02,  9.0696532e-03,  5.0526924e-02, -1.0761491e-02,
#         1.2087273e-02,  5.0221654e-03, -5.9948112e-03, -2.4024523e-03,
#        -1.2463648e-03,  7.0529990e-05], dtype=float32), Array(0.3577586, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 20 | T: 8.678766e-01 | T: ((Array([ 4.5388769e-02,  8.1981923e-03,  4.7094431e-02, -1.1644943e-02,
#         9.3237562e-03,  4.9829846e-03, -4.5249648e-03, -2.3690683e-03,
#        -1.8711765e-03,  8.7985041e-05], dtype=float32), Array(0.36285362, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 21 | T: 7.547988e-01 | T: ((Array([ 0.04208471,  0.00679869,  0.0435154 , -0.01183502,  0.00690013,
#         0.00445522, -0.0030529 , -0.00171908, -0.00193853,  0.0006708 ],      dtype=float32), Array(0.36771265, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 22 | T: 6.594523e-01 | T: ((Array([ 0.03869366,  0.00510555,  0.03986448, -0.01135958,  0.00486572,
#         0.00351534, -0.00193355, -0.00066298, -0.00150978,  0.0016969 ],      dtype=float32), Array(0.3723447, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 23 | T: 5.742795e-01 | T: ((Array([ 0.03528284,  0.00337588,  0.03621314, -0.01032777,  0.00325728,
#         0.00231261, -0.00135507,  0.0005413 , -0.0006553 ,  0.00301636],      dtype=float32), Array(0.37675878, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 24 | T: 4.956870e-01 | T: ((Array([ 0.03190901,  0.00186972,  0.03262509, -0.00891075,  0.00208502,
#         0.00102226, -0.00136398,  0.0016197 ,  0.00053267,  0.00445378],      dtype=float32), Array(0.3809637, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 25 | T: 4.291571e-01 | T: ((Array([ 0.0286341 ,  0.00075615,  0.02916278, -0.00729195,  0.00134685,
#        -0.0001973 , -0.00189735,  0.00229227,  0.00195778,  0.00586068],      dtype=float32), Array(0.38496846, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 26 | T: 3.712485e-01 | T: ((Array([ 0.02550696,  0.00016947,  0.02588155, -0.00566206,  0.00102913,
#        -0.00121251, -0.00277091,  0.00245426,  0.00351891,  0.00710774],      dtype=float32), Array(0.3887818, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 27 | T: 3.154954e-01 | T: ((Array([ 0.02256985,  0.00016006,  0.02282953, -0.00421127,  0.00110284,
#        -0.00191107, -0.00376331,  0.0021124 ,  0.00511653,  0.0080822 ],      dtype=float32), Array(0.39241216, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 28 | T: 2.689310e-01 | T: ((Array([ 0.01986248,  0.00065189,  0.02004942, -0.00311658,  0.00152813,
#        -0.00222297, -0.00463107,  0.00137613,  0.00665301,  0.00870026],      dtype=float32), Array(0.3958679, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 29 | T: 2.274583e-01 | T: ((Array([ 0.01742085,  0.0015532 ,  0.0175743 , -0.00247264,  0.00225269,
#        -0.00213124, -0.00515779,  0.00047762,  0.00805037,  0.00891237],      dtype=float32), Array(0.39915723, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 30 | T: 1.915797e-01 | T: ((Array([ 0.01527208,  0.00267215,  0.01543128, -0.00230481,  0.00322172,
#        -0.00169616, -0.00523891, -0.00037772,  0.0092372 ,  0.00872638],      dtype=float32), Array(0.40228808, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 31 | T: 1.558815e-01 | T: ((Array([ 0.01343591,  0.00381799,  0.01363629, -0.00260475,  0.00436963,
#        -0.00100791, -0.00487638, -0.00097908,  0.01014977,  0.00818705],      dtype=float32), Array(0.40526798, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 32 | T: 1.294034e-01 | T: ((Array([ 0.01191824,  0.0048055 ,  0.01219611, -0.00327438,  0.00563471,
#        -0.0001873 , -0.00421133, -0.00120564,  0.01075047,  0.00737553],      dtype=float32), Array(0.4081045, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 33 | T: 1.000271e-01 | T: ((Array([ 0.01072579,  0.00550407,  0.01110791, -0.00418117,  0.00694749,
#         0.00064595, -0.00340506, -0.00100073,  0.01103153,  0.0063962 ],      dtype=float32), Array(0.4108046, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 34 | T: 7.631572e-02 | T: ((Array([ 0.00985223,  0.00581021,  0.01036749, -0.00518498,  0.00825002,
#         0.00136472, -0.00264945, -0.00046449,  0.01100142,  0.00535748],      dtype=float32), Array(0.41337508, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 35 | T: 5.547766e-02 | T: ((Array([ 0.00928737,  0.00570154,  0.00995791, -0.00615851,  0.00949103,
#         0.00190129, -0.00211073,  0.00023941,  0.01068515,  0.00437821],      dtype=float32), Array(0.41582257, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 36 | T: 3.518320e-02 | T: ((Array([ 0.00901372,  0.00522729,  0.00985596, -0.0069375 ,  0.01062427,
#         0.00218833, -0.0019165 ,  0.00091985,  0.01012728,  0.00355215],      dtype=float32), Array(0.41815332, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 37 | T: 1.931496e-02 | T: ((Array([ 0.00901088,  0.00448555,  0.01003586, -0.00742151,  0.01160137,
#         0.00219701, -0.00205859,  0.00141711,  0.00936959,  0.00294164],      dtype=float32), Array(0.42037338, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 38 | T: 1.417412e-03 | T: ((Array([ 0.00925358,  0.00359413,  0.01046329, -0.00753702,  0.01239556,
#         0.00194861, -0.00250582,  0.00158672,  0.00846905,  0.00260117],      dtype=float32), Array(0.42248845, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 39 | T: -1.373746e-02 | T: ((Array([ 0.00970966,  0.00270981,  0.01110404, -0.00731771,  0.01298678,
#         0.00149306, -0.00306809,  0.00143911,  0.00749671,  0.00253103],      dtype=float32), Array(0.42450398, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 40 | T: -2.686092e-02 | T: ((Array([ 0.01034725,  0.00197606,  0.01192032, -0.00683074,  0.01336186,
#         0.00093344, -0.00360934,  0.00106855,  0.00651071,  0.00271626],      dtype=float32), Array(0.42642522, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 41 | T: -3.891154e-02 | T: ((Array([ 0.0111302 ,  0.00152744,  0.0128722 , -0.00613569,  0.01351946,
#         0.00033876, -0.00397972,  0.00055665,  0.00557473,  0.00311322],      dtype=float32), Array(0.4282571, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 42 | T: -5.025812e-02 | T: ((Array([ 1.20282117e-02,  1.38469960e-03,  1.39201945e-02, -5.34708239e-03,
#         1.34706544e-02, -1.88128266e-04, -4.08246275e-03,  6.08168193e-05,
#         4.73551499e-03,  3.65607534e-03], dtype=float32), Array(0.4300043, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 43 | T: -5.931459e-02 | T: ((Array([ 0.01300299,  0.00154046,  0.01502304, -0.00460198,  0.01322769,
#        -0.00056399, -0.00392357, -0.00033433,  0.00403073,  0.00425413],      dtype=float32), Array(0.4316714, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 44 | T: -6.782980e-02 | T: ((Array([ 0.01402024,  0.00195249,  0.01614414, -0.0039754 ,  0.01281398,
#        -0.00076927, -0.00354413, -0.00047142,  0.00350245,  0.00482982],      dtype=float32), Array(0.43326274, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 45 | T: -7.892919e-02 | T: ((Array([ 0.01504701,  0.00250625,  0.01724864, -0.00355081,  0.01226537,
#        -0.00077355, -0.00305798, -0.00035127,  0.00316374,  0.00531833],      dtype=float32), Array(0.43478212, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 46 | T: -8.637390e-02 | T: ((Array([ 1.6055783e-02,  3.1057936e-03,  1.8304218e-02, -3.3744287e-03,
#         1.1610842e-02, -6.1335205e-04, -2.5822057e-03, -3.0775525e-05,
#         3.0161799e-03,  5.6704753e-03], dtype=float32), Array(0.4362334, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 47 | T: -9.209678e-02 | T: ((Array([ 0.01701506,  0.00363236,  0.01928573, -0.00346705,  0.0108875 ,
#        -0.00029312, -0.00226457,  0.0003693 ,  0.00305048,  0.00585183],      dtype=float32), Array(0.43762028, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 48 | T: -9.991399e-02 | T: ((Array([ 0.01790383,  0.00399194,  0.0201671 , -0.00374457,  0.0101279 ,
#         0.00011618, -0.00217596,  0.00074675,  0.00324745,  0.00584318],      dtype=float32), Array(0.4389461, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 49 | T: -1.057449e-01 | T: ((Array([ 0.01870178,  0.00413719,  0.02093222, -0.00416856,  0.00936282,
#         0.000514  , -0.00232144,  0.00100709,  0.00358339,  0.00565943],      dtype=float32), Array(0.44021416, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 50 | T: -1.099958e-01 | T: ((Array([ 0.01939178,  0.00405282,  0.02156338, -0.00465014,  0.0086246 ,
#         0.00086067, -0.00264122,  0.0010732 ,  0.00401567,  0.00534594],      dtype=float32), Array(0.44142753, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 51 | T: -1.148525e-01 | T: ((Array([ 0.01996178,  0.00378275,  0.02205156, -0.00511605,  0.0079456 ,
#         0.00110448, -0.00303904,  0.00091469,  0.00450775,  0.00494846],      dtype=float32), Array(0.44258913, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 52 | T: -1.203350e-01 | T: ((Array([ 0.02040342,  0.0033817 ,  0.02239566, -0.00548932,  0.0073552 ,
#         0.00121431, -0.00335967,  0.00062334,  0.0050244 ,  0.00451105],      dtype=float32), Array(0.4437017, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 53 | T: -1.244731e-01 | T: ((Array([ 0.02071552,  0.00292746,  0.0225936 , -0.00571506,  0.00687468,
#         0.00117884, -0.00346846,  0.00024489,  0.00551903,  0.00408882],      dtype=float32), Array(0.44476786, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 54 | T: -1.283676e-01 | T: ((Array([ 2.0899985e-02,  2.5273776e-03,  2.2647552e-02, -5.7563437e-03,
#         6.5116645e-03,  1.0227540e-03, -3.4162099e-03, -5.3065683e-05,
#         5.9590135e-03,  3.7237443e-03], dtype=float32), Array(0.44579005, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 55 | T: -1.335009e-01 | T: ((Array([ 0.02095631,  0.00221776,  0.02256737, -0.00563902,  0.00627755,
#         0.00079504, -0.00320996, -0.00022802,  0.00631383,  0.00347922],      dtype=float32), Array(0.4467705, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 56 | T: -1.339246e-01 | T: ((Array([ 0.0208991 ,  0.00204513,  0.02236436, -0.00537144,  0.00617026,
#         0.00052109, -0.00291605, -0.00023019,  0.0065586 ,  0.00336968],      dtype=float32), Array(0.44771153, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 57 | T: -1.372460e-01 | T: ((Array([ 2.0728579e-02,  2.0345584e-03,  2.2055050e-02, -5.0048865e-03,
#         6.1816904e-03,  2.6037244e-04, -2.6399796e-03, -6.3663610e-05,
#         6.6808416e-03,  3.3767358e-03], dtype=float32), Array(0.44861522, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 58 | T: -1.404936e-01 | T: ((Array([ 2.0461304e-02,  2.1844890e-03,  2.1655507e-02, -4.6097068e-03,
#         6.2984177e-03,  3.5245219e-05, -2.4417310e-03,  1.8585820e-04,
#         6.6930731e-03,  3.4813073e-03], dtype=float32), Array(0.44948354, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 59 | T: -1.419288e-01 | T: ((Array([ 2.0111380e-02,  2.4608651e-03,  2.1184145e-02, -4.2661252e-03,
#         6.5039583e-03, -9.0794914e-05, -2.3700206e-03,  4.6540826e-04,
#         6.6027902e-03,  3.6679707e-03], dtype=float32), Array(0.45031834, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 60 | T: -1.434907e-01 | T: ((Array([ 0.01969836,  0.00274311,  0.02065797, -0.00403815,  0.00678097,
#        -0.00012385, -0.00242264,  0.00068978,  0.00641951,  0.00391403],      dtype=float32), Array(0.4511215, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 61 | T: -1.475747e-01 | T: ((Array([ 1.9232033e-02,  2.9993074e-03,  2.0097842e-02, -3.9391015e-03,
#         7.1037766e-03, -4.0243140e-05, -2.6082431e-03,  8.2248013e-04,
#         6.1661825e-03,  4.1768625e-03], dtype=float32), Array(0.4518945, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 62 | T: -1.498947e-01 | T: ((Array([ 0.01872933,  0.00318759,  0.01951826, -0.00397627,  0.00745008,
#         0.00013295, -0.00284406,  0.00081297,  0.00585864,  0.00442292],      dtype=float32), Array(0.4526389, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 63 | T: -1.519140e-01 | T: ((Array([ 0.01820864,  0.0032853 ,  0.01893943, -0.00413076,  0.00780437,
#         0.00032825, -0.00305863,  0.00064981,  0.0055255 ,  0.00462066],      dtype=float32), Array(0.4533561, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 64 | T: -1.556670e-01 | T: ((Array([ 0.0176864 ,  0.00328143,  0.01837741, -0.00435875,  0.00814506,
#         0.00050416, -0.003169  ,  0.0004384 ,  0.00519242,  0.00473648],      dtype=float32), Array(0.45404738, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 65 | T: -1.570441e-01 | T: ((Array([ 0.01717417,  0.00320509,  0.01784687, -0.00460976,  0.00845405,
#         0.00066067, -0.00318866,  0.00022699,  0.00488068,  0.00476407],      dtype=float32), Array(0.45471406, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 66 | T: -1.583442e-01 | T: ((Array([ 1.6687952e-02,  3.0380434e-03,  1.7362915e-02, -4.8247124e-03,
#         8.7219654e-03,  7.5728277e-04, -3.0837094e-03,  5.5030454e-05,
#         4.6291719e-03,  4.7102026e-03], dtype=float32), Array(0.45535743, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 67 | T: -1.592112e-01 | T: ((Array([ 1.6236933e-02,  2.8539363e-03,  1.6930697e-02, -4.9685957e-03,
#         8.9400541e-03,  7.7966001e-04, -2.8878858e-03,  9.2261071e-06,
#         4.4474597e-03,  4.5997351e-03], dtype=float32), Array(0.4559786, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 68 | T: -1.619165e-01 | T: ((Array([ 1.5835691e-02,  2.6477952e-03,  1.6561609e-02, -5.0346479e-03,
#         9.0905558e-03,  7.1681157e-04, -2.6959451e-03,  6.9512462e-05,
#         4.3364223e-03,  4.4300649e-03], dtype=float32), Array(0.45657864, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 69 | T: -1.613802e-01 | T: ((Array([ 0.01548942,  0.00247839,  0.01626352, -0.00500626,  0.0091706 ,
#         0.00059062, -0.00253701,  0.00021953,  0.00429992,  0.00424143],      dtype=float32), Array(0.4571586, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 70 | T: -1.653602e-01 | T: ((Array([ 0.01520064,  0.00239201,  0.01603749, -0.00488518,  0.00918209,
#         0.00043059, -0.00244348,  0.0003753 ,  0.00432628,  0.00404801],      dtype=float32), Array(0.4577192, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 71 | T: -1.659279e-01 | T: ((Array([ 0.0149749 ,  0.00239883,  0.01588531, -0.00472394,  0.00913351,
#         0.0002742 , -0.00245529,  0.0005111 ,  0.00442112,  0.00388139],      dtype=float32), Array(0.4582615, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 72 | T: -1.663537e-01 | T: ((Array([ 0.01480951,  0.00248865,  0.01580212, -0.00453856,  0.00903076,
#         0.00015904, -0.00255111,  0.0005766 ,  0.00456478,  0.00375551],      dtype=float32), Array(0.45878634, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 73 | T: -1.656120e-01 | T: ((Array([ 0.01470783,  0.00262964,  0.01578118, -0.00437963,  0.00888037,
#         0.00010772, -0.00272498,  0.0005652 ,  0.00474143,  0.00368758],      dtype=float32), Array(0.4592946, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 74 | T: -1.684117e-01 | T: ((Array([ 0.01466249,  0.00278154,  0.0158156 , -0.00426206,  0.00869668,
#         0.00013229, -0.00289572,  0.00051822,  0.004936  ,  0.00370588],      dtype=float32), Array(0.45978683, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 75 | T: -1.684714e-01 | T: ((Array([ 0.01467304,  0.00292622,  0.01589778, -0.0042017 ,  0.00848485,
#         0.00019914, -0.00300392,  0.00041391,  0.00512119,  0.00377949],      dtype=float32), Array(0.46026385, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 76 | T: -1.702668e-01 | T: ((Array([ 0.01472972,  0.00303098,  0.01602455, -0.00420125,  0.00826264,
#         0.00030801, -0.00297187,  0.0002766 ,  0.00527541,  0.00387747],      dtype=float32), Array(0.46072605, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 77 | T: -1.698448e-01 | T: ((Array([ 0.01482688,  0.00308058,  0.0161862 , -0.0042625 ,  0.00804367,
#         0.0004129 , -0.00284513,  0.00017589,  0.00539304,  0.00399637],      dtype=float32), Array(0.46117422, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 78 | T: -1.714769e-01 | T: ((Array([ 0.01495985,  0.00305367,  0.01637322, -0.00437459,  0.00784146,
#         0.000481  , -0.00271858,  0.00015663,  0.00546582,  0.0041213 ],      dtype=float32), Array(0.4616089, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 79 | T: -1.721356e-01 | T: ((Array([ 0.01511598,  0.00295938,  0.01657284, -0.00448491,  0.00766771,
#         0.00052572, -0.00260028,  0.00020466,  0.0054965 ,  0.00423015],      dtype=float32), Array(0.46203056, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 80 | T: -1.732133e-01 | T: ((Array([ 0.01528987,  0.00280919,  0.01677835, -0.00457525,  0.00751925,
#         0.00055526, -0.00251727,  0.00031798,  0.00548381,  0.00429353],      dtype=float32), Array(0.4624397, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 81 | T: -1.709515e-01 | T: ((Array([ 0.01547061,  0.00264695,  0.01698043, -0.00464494,  0.00740286,
#         0.00053226, -0.00251876,  0.00041848,  0.00543317,  0.00430275],      dtype=float32), Array(0.46283686, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 82 | T: -1.741840e-01 | T: ((Array([ 0.01564799,  0.00253342,  0.0171716 , -0.00467216,  0.00733146,
#         0.00047854, -0.00258279,  0.00047596,  0.00534544,  0.00427338],      dtype=float32), Array(0.46322247, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 83 | T: -1.763560e-01 | T: ((Array([ 0.01582275,  0.00247757,  0.01734511, -0.00465769,  0.00729962,
#         0.0004272 , -0.00267851,  0.00044907,  0.00523804,  0.00421437],      dtype=float32), Array(0.4635969, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 84 | T: -1.777388e-01 | T: ((Array([ 0.01598407,  0.00249911,  0.01749825, -0.00459899,  0.00730817,
#         0.0003802 , -0.00276661,  0.0004056 ,  0.00511344,  0.0041385 ],      dtype=float32), Array(0.46396053, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 85 | T: -1.758404e-01 | T: ((Array([ 0.01612906,  0.00258887,  0.01762444, -0.00451423,  0.00734264,
#         0.00034264, -0.00281278,  0.00032496,  0.00498679,  0.00404917],      dtype=float32), Array(0.4643138, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 86 | T: -1.779145e-01 | T: ((Array([ 0.01624899,  0.00270653,  0.01771914, -0.00441138,  0.00740564,
#         0.00030727, -0.0028149 ,  0.00025423,  0.00487842,  0.00394621],      dtype=float32), Array(0.4646571, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 87 | T: -1.772321e-01 | T: ((Array([ 0.01634447,  0.00281123,  0.01778103, -0.0043144 ,  0.00748734,
#         0.0002828 , -0.00279257,  0.00023572,  0.00478448,  0.00386415],      dtype=float32), Array(0.46499074, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 88 | T: -1.770904e-01 | T: ((Array([ 0.01641657,  0.00287492,  0.01780881, -0.00424172,  0.00758273,
#         0.0002776 , -0.00275194,  0.00027141,  0.00471649,  0.00382873],      dtype=float32), Array(0.46531507, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 89 | T: -1.777039e-01 | T: ((Array([ 0.01646204,  0.00287443,  0.01780002, -0.00421974,  0.00768462,
#         0.00029372, -0.00269678,  0.00031477,  0.00468373,  0.00383838],      dtype=float32), Array(0.46563035, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 90 | T: -1.790458e-01 | T: ((Array([ 0.01648422,  0.00284833,  0.01776011, -0.00421941,  0.00777634,
#         0.00031393, -0.00262084,  0.00034727,  0.0046754 ,  0.0038746 ],      dtype=float32), Array(0.46593693, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 91 | T: -1.778862e-01 | T: ((Array([ 0.01647829,  0.00278625,  0.01769629, -0.00424249,  0.00785394,
#         0.00034444, -0.00256517,  0.00040409,  0.00469504,  0.00391382],      dtype=float32), Array(0.46623513, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 92 | T: -1.804306e-01 | T: ((Array([ 0.01645107,  0.00271018,  0.01760712, -0.00432435,  0.00791828,
#         0.00038779, -0.00252032,  0.00040924,  0.0047417 ,  0.00396408],      dtype=float32), Array(0.46652514, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 93 | T: -1.781066e-01 | T: ((Array([ 0.01639536,  0.00265218,  0.01749742, -0.00439238,  0.00796938,
#         0.00042424, -0.00251552,  0.00041677,  0.00479845,  0.00400233],      dtype=float32), Array(0.4668074, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 94 | T: -1.786864e-01 | T: ((Array([ 0.01631493,  0.00258775,  0.01737897, -0.00444532,  0.00799828,
#         0.00044127, -0.00254826,  0.00040798,  0.00486334,  0.0040419 ],      dtype=float32), Array(0.467082, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 95 | T: -1.810348e-01 | T: ((Array([ 0.0162211 ,  0.00258877,  0.01725156, -0.00449454,  0.00801511,
#         0.00045575, -0.00262772,  0.00037869,  0.00492708,  0.00406494],      dtype=float32), Array(0.46734914, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 96 | T: -1.811349e-01 | T: ((Array([ 0.01611693,  0.0026382 ,  0.01711944, -0.00449987,  0.00801271,
#         0.00045703, -0.00271425,  0.00033929,  0.00499038,  0.0040764 ],      dtype=float32), Array(0.46760914, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 97 | T: -1.814284e-01 | T: ((Array([ 0.01600965,  0.00268808,  0.01699123, -0.00448166,  0.00799197,
#         0.00044785, -0.00280485,  0.00032395,  0.0050384 ,  0.00407484],      dtype=float32), Array(0.4678622, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 98 | T: -1.816699e-01 | T: ((Array([ 0.01590137,  0.00272571,  0.01686885, -0.00446123,  0.00795678,
#         0.00042846, -0.00279667,  0.00032246,  0.00507727,  0.00404612],      dtype=float32), Array(0.4681085, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Step 99 | T: -1.836410e-01 | T: ((Array([ 0.01579251,  0.00275303,  0.01676073, -0.00441832,  0.00791184,
#         0.00039452, -0.00274018,  0.00032868,  0.00510447,  0.00400808],      dtype=float32), Array(0.4683481, dtype=float32)), Array([ 0.01318251, -0.2719123 ,  0.0348863 , -0.20547883, -0.05547192,
#        -0.17059147, -0.04376092, -0.018911  ,  0.0090002 , -0.10080759,
#         0.9152906 ], dtype=float32))
# Final 99 | T: -1.836410e-01 | T: (Array([ 0.01579251,  0.00275303,  0.01676073, -0.00441832,  0.00791184,
#         0.00039452, -0.00274018,  0.00032868,  0.00510447,  0.00400808],      dtype=float32), Array(0.4683481, dtype=float32))

# %%
#diffusion_mean.initialize(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t)[0], s2_model = lambda x,y,t: jacfwdx(lambda y: M.grady_log_hk(x,y,t)[0])(y), method="Gradient")
diffusion_mean(M, s1_model=lambda x,y,t: M.grady_log_hk(x,y,t)[0], s2_model = M.gradt_log_hk, method="Gradient")
mu_opt, T_opt, _, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0891 0.0801 0.9927 )
# T = 1.0000

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0132 -0.2719 0.0349 -0.2055 -0.0555 -0.1706 -0.0438 -0.0189 0.0090 -0.1008 0.9153 )
# T = 0.4683

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_opt[1][-1]), ")")
print(f"T = {T_opt[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0567 0.0145 0.1066 0.0924 -0.0552 -0.0367 0.0101 -0.0443 0.0050 -0.0209 0.9848 )
# T = 0.5000

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.4588
#  -T error = 0.0317

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-T_opt[-1][0]):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_opt[1][-1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.0000
# Bridge Diffusion mean:
#  -mean error = 0.04588
#  -T error = 0.0317

# %% [markdown]
# ## Timing Score

# %%
dims = [2,3,5,10]
time_score = []
time_bridge = []

for N in dims:
    print(N)
    M = nSphere(N=N)
    jstoch.Brownian_coords(M)
    jstat.diffusion_mean(M)
    x0 = M.coords([0.]*N)

    file_path = 'scores/S'+str(N)+'/s1_'+ loss_type + '/'
    state = model_loader.load_model(file_path)

    file_path_s2 = 'scores/S'+str(N)+'/s2/'
    state_s2 = model_loader.load_model(file_path_s2)
    if N<10:
        layers = [50,100,100,50]
    elif N<50:
        layers = [50,100,200,200,100,50]
    else:
        layers = [50,100,200,400,400,200,100,50]
    s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
    s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                    dim=M.emb_dim, r = max(M.dim//2,1))(x))
    rng_key = jax.random.PRNGKey(2712)
    def grady_log(x,y,t):

        return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

    def gradt_log(x,y,t):

        s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
        s2_val = ggrady_log(x,y,t)
        s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)

        div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())

        return 0.5*(jnp.dot(s1_val, s1_val)+div)

    def ggrady_log_ad(x,y,t):

        ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)

        return ggrad

    def ggrady_log_score(x,y,t):

        ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))

        return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

    if s2_approximation:
        ggrady_log = ggrady_log_score
    else:
        ggrady_log = ggrady_log_ad
        
    xs = pd.read_csv('Data/S'+str(N)+'/xs.csv', header=None)
    charts = pd.read_csv('Data/S'+str(N)+'/chart.csv', header=None)
    X_obs = (jnp.array(xs.values), jnp.array(charts.values))
    
    diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
    result = %timeit -o M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), \
                                           step_size=0.01, max_iter=100)
    time_score.append(result)
    result = %timeit -o M.diffusion_mean(X_obs,num_steps=100, N=1)
    time_bridge.append(result)
# Out:
# 2
# using M.Exp for Logarithm
# 914 ms ± 9.41 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Step 0 | T: 9.045785e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.991252e+00 | T: ((Array([ 0.01245216, -0.03357188], dtype=float32), Array(0.21992584, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.101362e+00 | T: ((Array([ 0.0160122 , -0.02392925], dtype=float32), Array(0.22973661, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.349108e+00 | T: ((Array([ 0.01915262, -0.01461921], dtype=float32), Array(0.2393977, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.710273e+00 | T: ((Array([ 0.02020616, -0.00574349], dtype=float32), Array(0.2488805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166684e+00 | T: ((Array([0.01926227, 0.00260007], dtype=float32), Array(0.25816208, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.702184e+00 | T: ((Array([0.01717741, 0.01032713], dtype=float32), Array(0.2672245, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.301497e+00 | T: ((Array([0.01480488, 0.01736527], dtype=float32), Array(0.2760541, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.955870e+00 | T: ((Array([0.01288735, 0.02366214], dtype=float32), Array(0.28464103, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.656199e+00 | T: ((Array([0.01188654, 0.02918502], dtype=float32), Array(0.29297864, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394952e+00 | T: ((Array([0.01186582, 0.03392284], dtype=float32), Array(0.30106306, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165463e+00 | T: ((Array([0.01264212, 0.03788259], dtype=float32), Array(0.3088926, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 9.046937e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.992067e+00 | T: ((Array([ 0.01242449, -0.03357167], dtype=float32), Array(0.21992579, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.100922e+00 | T: ((Array([ 0.01598322, -0.02392922], dtype=float32), Array(0.2297364, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.349375e+00 | T: ((Array([ 0.01912951, -0.0146169 ], dtype=float32), Array(0.23939733, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.711009e+00 | T: ((Array([ 0.02019943, -0.00573833], dtype=float32), Array(0.24887991, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166975e+00 | T: ((Array([0.01926998, 0.00260802], dtype=float32), Array(0.25816122, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.700554e+00 | T: ((Array([0.01720253, 0.01033519], dtype=float32), Array(0.26722318, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.300456e+00 | T: ((Array([0.01484011, 0.01737478], dtype=float32), Array(0.2760522, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.954968e+00 | T: ((Array([0.01293837, 0.02367163], dtype=float32), Array(0.2846385, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655836e+00 | T: ((Array([0.01192673, 0.02919341], dtype=float32), Array(0.2929755, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394949e+00 | T: ((Array([0.0118959 , 0.03392985], dtype=float32), Array(0.30105934, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165575e+00 | T: ((Array([0.01266015, 0.03788795], dtype=float32), Array(0.30888835, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963725e+00 | T: ((Array([0.01388179, 0.04108858], dtype=float32), Array(0.31646276, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784155e+00 | T: ((Array([0.01517844, 0.04356783], dtype=float32), Array(0.3237843, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625489e+00 | T: ((Array([0.01624126, 0.04537161], dtype=float32), Array(0.33085606, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.482440e+00 | T: ((Array([0.01683068, 0.04655195], dtype=float32), Array(0.33768207, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.354994e+00 | T: ((Array([0.01686354, 0.0471632 ], dtype=float32), Array(0.34426728, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 2.239847e+00 | T: ((Array([0.01640008, 0.04726414], dtype=float32), Array(0.35061732, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 2.135906e+00 | T: ((Array([0.01557988, 0.04691181], dtype=float32), Array(0.3567384, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 2.041190e+00 | T: ((Array([0.01459303, 0.04616362], dtype=float32), Array(0.362637, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.956228e+00 | T: ((Array([0.01361819, 0.04507434], dtype=float32), Array(0.3683202, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.877946e+00 | T: ((Array([0.01283006, 0.04369732], dtype=float32), Array(0.37379503, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.806684e+00 | T: ((Array([0.01235299, 0.04208224], dtype=float32), Array(0.3790688, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.742396e+00 | T: ((Array([0.0122398 , 0.04027643], dtype=float32), Array(0.38414893, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.682893e+00 | T: ((Array([0.0124645 , 0.03832451], dtype=float32), Array(0.38904288, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.628686e+00 | T: ((Array([0.01294184, 0.03626966], dtype=float32), Array(0.3937581, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.578584e+00 | T: ((Array([0.01356781, 0.03414906], dtype=float32), Array(0.3983018, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.532483e+00 | T: ((Array([0.01421534, 0.03199829], dtype=float32), Array(0.40268132, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.490357e+00 | T: ((Array([0.01475554, 0.02984851], dtype=float32), Array(0.40690377, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.450842e+00 | T: ((Array([0.0151051 , 0.02772752], dtype=float32), Array(0.41097602, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.415187e+00 | T: ((Array([0.01520836, 0.02566148], dtype=float32), Array(0.41490492, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.382138e+00 | T: ((Array([0.01506971, 0.02367251], dtype=float32), Array(0.41869718, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.351546e+00 | T: ((Array([0.01473211, 0.02178018], dtype=float32), Array(0.42235923, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.323228e+00 | T: ((Array([0.0142596 , 0.01999927], dtype=float32), Array(0.4258973, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.296724e+00 | T: ((Array([0.01374171, 0.01834241], dtype=float32), Array(0.4293174, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.271764e+00 | T: ((Array([0.0132767 , 0.01682092], dtype=float32), Array(0.43262532, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.248891e+00 | T: ((Array([0.01293363, 0.01544187], dtype=float32), Array(0.43582657, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.227044e+00 | T: ((Array([0.0127635, 0.0142102], dtype=float32), Array(0.4389264, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.207560e+00 | T: ((Array([0.01277023, 0.01312893], dtype=float32), Array(0.44193, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.188344e+00 | T: ((Array([0.01293107, 0.01219809], dtype=float32), Array(0.4448422, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.170699e+00 | T: ((Array([0.01320322, 0.0114168 ], dtype=float32), Array(0.44766757, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.153996e+00 | T: ((Array([0.01352111, 0.01078095], dtype=float32), Array(0.4504106, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.138145e+00 | T: ((Array([0.01381769, 0.01028516], dtype=float32), Array(0.4530754, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.123176e+00 | T: ((Array([0.01404532, 0.00992278], dtype=float32), Array(0.45566598, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.108494e+00 | T: ((Array([0.01416965, 0.00968729], dtype=float32), Array(0.458186, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.095714e+00 | T: ((Array([0.01417362, 0.00957027], dtype=float32), Array(0.4606391, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.082330e+00 | T: ((Array([0.01405424, 0.00956229], dtype=float32), Array(0.46302858, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.070530e+00 | T: ((Array([0.01383956, 0.00965285], dtype=float32), Array(0.4653577, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.058464e+00 | T: ((Array([0.01358248, 0.00983   ], dtype=float32), Array(0.46762937, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.047926e+00 | T: ((Array([0.01332214, 0.01008345], dtype=float32), Array(0.46984655, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.037326e+00 | T: ((Array([0.01308241, 0.010403  ], dtype=float32), Array(0.4720119, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.026631e+00 | T: ((Array([0.01291407, 0.01077717], dtype=float32), Array(0.47412786, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.017188e+00 | T: ((Array([0.01283468, 0.01119666], dtype=float32), Array(0.4761969, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.008057e+00 | T: ((Array([0.01284271, 0.01165194], dtype=float32), Array(0.47822124, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 9.996551e-01 | T: ((Array([0.0129184 , 0.01213331], dtype=float32), Array(0.4802031, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 9.907440e-01 | T: ((Array([0.01302942, 0.01263061], dtype=float32), Array(0.48214436, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 9.822368e-01 | T: ((Array([0.01315561, 0.01313522], dtype=float32), Array(0.48404688, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 9.748445e-01 | T: ((Array([0.01326762, 0.0136391 ], dtype=float32), Array(0.4859125, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 9.671729e-01 | T: ((Array([0.01334396, 0.01413285], dtype=float32), Array(0.4877428, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: 9.601886e-01 | T: ((Array([0.01338221, 0.01461246], dtype=float32), Array(0.4895395, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: 9.528071e-01 | T: ((Array([0.01335566, 0.01507284], dtype=float32), Array(0.491304, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: 9.463540e-01 | T: ((Array([0.01327787, 0.0155094 ], dtype=float32), Array(0.49303776, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: 9.399056e-01 | T: ((Array([0.01316367, 0.01591826], dtype=float32), Array(0.49474204, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: 9.336089e-01 | T: ((Array([0.01304091, 0.01629613], dtype=float32), Array(0.49641806, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: 9.273965e-01 | T: ((Array([0.01292396, 0.01663977], dtype=float32), Array(0.498067, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: 9.212734e-01 | T: ((Array([0.01281198, 0.01694814], dtype=float32), Array(0.49968985, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: 9.160638e-01 | T: ((Array([0.0127373 , 0.01721898], dtype=float32), Array(0.5012877, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: 9.104387e-01 | T: ((Array([0.01271746, 0.01745101], dtype=float32), Array(0.5028615, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: 9.051179e-01 | T: ((Array([0.01273461, 0.01764524], dtype=float32), Array(0.5044122, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: 9.001122e-01 | T: ((Array([0.012773  , 0.01780205], dtype=float32), Array(0.50594056, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: 8.952849e-01 | T: ((Array([0.01282419, 0.0179226 ], dtype=float32), Array(0.50744754, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: 8.907717e-01 | T: ((Array([0.01286937, 0.01800872], dtype=float32), Array(0.50893396, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: 8.853250e-01 | T: ((Array([0.01290378, 0.01806103], dtype=float32), Array(0.5104003, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: 8.812345e-01 | T: ((Array([0.01292642, 0.01808321], dtype=float32), Array(0.5118474, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: 8.767087e-01 | T: ((Array([0.01292564, 0.01807647], dtype=float32), Array(0.51327574, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: 8.722214e-01 | T: ((Array([0.01289125, 0.01804174], dtype=float32), Array(0.514686, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: 8.682020e-01 | T: ((Array([0.0128387, 0.0179824], dtype=float32), Array(0.5160788, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: 8.643842e-01 | T: ((Array([0.01277377, 0.01790034], dtype=float32), Array(0.5174547, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: 8.604202e-01 | T: ((Array([0.01270133, 0.01779923], dtype=float32), Array(0.51881415, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: 8.569341e-01 | T: ((Array([0.01264071, 0.01768233], dtype=float32), Array(0.5201577, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: 8.526035e-01 | T: ((Array([0.01261372, 0.01755135], dtype=float32), Array(0.52148575, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: 8.493322e-01 | T: ((Array([0.01260655, 0.01741161], dtype=float32), Array(0.5227987, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: 8.456793e-01 | T: ((Array([0.01259632, 0.0172654 ], dtype=float32), Array(0.524097, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: 8.416598e-01 | T: ((Array([0.0125951 , 0.01711522], dtype=float32), Array(0.52538097, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: 8.386741e-01 | T: ((Array([0.01258443, 0.0169617 ], dtype=float32), Array(0.5266509, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: 8.350921e-01 | T: ((Array([0.01258632, 0.01680811], dtype=float32), Array(0.52790713, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: 8.323963e-01 | T: ((Array([0.01258634, 0.01665593], dtype=float32), Array(0.5291501, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: 8.289315e-01 | T: ((Array([0.01259454, 0.01650773], dtype=float32), Array(0.5303802, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: 8.260980e-01 | T: ((Array([0.01257639, 0.01636413], dtype=float32), Array(0.53159755, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: 8.232544e-01 | T: ((Array([0.01255836, 0.01622568], dtype=float32), Array(0.5328026, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: 8.198782e-01 | T: ((Array([0.01253057, 0.01609494], dtype=float32), Array(0.5339954, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: 8.177725e-01 | T: ((Array([0.01250111, 0.01597274], dtype=float32), Array(0.53517634, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: 8.146769e-01 | T: ((Array([0.01247145, 0.01585971], dtype=float32), Array(0.53634566, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: 8.119498e-01 | T: ((Array([0.01246149, 0.01575512], dtype=float32), Array(0.5375036, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: 8.092536e-01 | T: ((Array([0.01246596, 0.0156614 ], dtype=float32), Array(0.53865033, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: 8.069177e-01 | T: ((Array([0.01246909, 0.01557686], dtype=float32), Array(0.53978616, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: 8.043978e-01 | T: ((Array([0.01248225, 0.01550334], dtype=float32), Array(0.5409112, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: 8.015819e-01 | T: ((Array([0.01249347, 0.01543903], dtype=float32), Array(0.54202557, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: 7.996032e-01 | T: ((Array([0.01249353, 0.01538373], dtype=float32), Array(0.54312956, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: 7.968124e-01 | T: ((Array([0.01248888, 0.01533787], dtype=float32), Array(0.54422337, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: 7.968124e-01 | T: (Array([0.01248888, 0.01533787], dtype=float32), Array(0.54422337, dtype=float32))
# Step 0 | T: 9.045611e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.994441e+00 | T: ((Array([ 0.01239991, -0.03357195], dtype=float32), Array(0.21992603, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.102816e+00 | T: ((Array([ 0.01595641, -0.02392943], dtype=float32), Array(0.22973698, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.348824e+00 | T: ((Array([ 0.01914522, -0.01461876], dtype=float32), Array(0.23939805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.710011e+00 | T: ((Array([ 0.02023363, -0.00574149], dtype=float32), Array(0.24888064, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.167312e+00 | T: ((Array([0.01932531, 0.00260429], dtype=float32), Array(0.25816202, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.701108e+00 | T: ((Array([0.01723596, 0.01033245], dtype=float32), Array(0.26722407, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.301041e+00 | T: ((Array([0.01485198, 0.01737128], dtype=float32), Array(0.27605325, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.956070e+00 | T: ((Array([0.01290745, 0.02366934], dtype=float32), Array(0.28463978, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655661e+00 | T: ((Array([0.0118706 , 0.02919376], dtype=float32), Array(0.29297698, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394799e+00 | T: ((Array([0.01183076, 0.03393228], dtype=float32), Array(0.30106094, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165933e+00 | T: ((Array([0.01259295, 0.03789081], dtype=float32), Array(0.30889007, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963724e+00 | T: ((Array([0.01383993, 0.04109311], dtype=float32), Array(0.3164646, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784252e+00 | T: ((Array([0.01517212, 0.0435744 ], dtype=float32), Array(0.32378623, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625494e+00 | T: ((Array([0.01626797, 0.04537907], dtype=float32), Array(0.33085802, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.483053e+00 | T: ((Array([0.01690081, 0.04655989], dtype=float32), Array(0.33768412, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.355308e+00 | T: ((Array([0.01697805, 0.04717194], dtype=float32), Array(0.34426945, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 9.044426e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.991736e+00 | T: ((Array([ 0.01241619, -0.03357207], dtype=float32), Array(0.21992591, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.102967e+00 | T: ((Array([ 0.01595829, -0.02392905], dtype=float32), Array(0.22973691, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.348410e+00 | T: ((Array([ 0.01911102, -0.01461669], dtype=float32), Array(0.23939805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.711473e+00 | T: ((Array([ 0.02016209, -0.00573971], dtype=float32), Array(0.24888098, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166816e+00 | T: ((Array([0.01922329, 0.0026055 ], dtype=float32), Array(0.2581626, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.701509e+00 | T: ((Array([0.01714822, 0.01033262], dtype=float32), Array(0.26722497, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.300499e+00 | T: ((Array([0.01478965, 0.01736988], dtype=float32), Array(0.2760544, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.955084e+00 | T: ((Array([0.01288747, 0.02366466], dtype=float32), Array(0.28464112, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655872e+00 | T: ((Array([0.01190002, 0.02918439], dtype=float32), Array(0.29297855, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.393794e+00 | T: ((Array([0.0119092 , 0.03391863], dtype=float32), Array(0.30106267, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165677e+00 | T: ((Array([0.01270484, 0.03787243], dtype=float32), Array(0.30889198, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963511e+00 | T: ((Array([0.01395004, 0.04107071], dtype=float32), Array(0.3164666, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784414e+00 | T: ((Array([0.01526974, 0.04354875], dtype=float32), Array(0.32378834, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625108e+00 | T: ((Array([0.01633775, 0.04535253], dtype=float32), Array(0.3308603, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.483034e+00 | T: ((Array([0.01691632, 0.04653218], dtype=float32), Array(0.33768654, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.355436e+00 | T: ((Array([0.01692732, 0.04714392], dtype=float32), Array(0.34427208, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 2.239251e+00 | T: ((Array([0.01643059, 0.04724531], dtype=float32), Array(0.35062242, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 2.135758e+00 | T: ((Array([0.01556807, 0.04689433], dtype=float32), Array(0.35674378, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 2.041965e+00 | T: ((Array([0.01452768, 0.0461467 ], dtype=float32), Array(0.36264282, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.955260e+00 | T: ((Array([0.01353747, 0.04505795], dtype=float32), Array(0.3683263, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.877844e+00 | T: ((Array([0.01275851, 0.04368161], dtype=float32), Array(0.37380135, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.806706e+00 | T: ((Array([0.01230555, 0.04206792], dtype=float32), Array(0.3790753, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.741689e+00 | T: ((Array([0.01221389, 0.04026436], dtype=float32), Array(0.38415557, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.682478e+00 | T: ((Array([0.01246546, 0.03831495], dtype=float32), Array(0.38904962, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.627784e+00 | T: ((Array([0.0129663 , 0.03626254], dtype=float32), Array(0.3937648, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.578525e+00 | T: ((Array([0.01360096, 0.03414344], dtype=float32), Array(0.39830852, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.532576e+00 | T: ((Array([0.01424548, 0.03199461], dtype=float32), Array(0.40268803, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.490191e+00 | T: ((Array([0.01477826, 0.0298472 ], dtype=float32), Array(0.40691045, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.451847e+00 | T: ((Array([0.01511117, 0.02772845], dtype=float32), Array(0.41098282, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.415508e+00 | T: ((Array([0.01521006, 0.02566399], dtype=float32), Array(0.41491187, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.382088e+00 | T: ((Array([0.01506319, 0.02367586], dtype=float32), Array(0.41870424, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.351442e+00 | T: ((Array([0.01472132, 0.02178508], dtype=float32), Array(0.4223664, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.323201e+00 | T: ((Array([0.01425232, 0.0200064 ], dtype=float32), Array(0.4259046, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.296095e+00 | T: ((Array([0.01374669, 0.01835197], dtype=float32), Array(0.42932472, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.271857e+00 | T: ((Array([0.01329257, 0.01683342], dtype=float32), Array(0.43263263, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.249114e+00 | T: ((Array([0.01296614, 0.01545571], dtype=float32), Array(0.43583393, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.227369e+00 | T: ((Array([0.01279529, 0.01422598], dtype=float32), Array(0.4389339, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.206527e+00 | T: ((Array([0.01278611, 0.01314583], dtype=float32), Array(0.4419375, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.188462e+00 | T: ((Array([0.01291976, 0.01221553], dtype=float32), Array(0.4448497, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.170259e+00 | T: ((Array([0.01317032, 0.0114326 ], dtype=float32), Array(0.44767505, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.153474e+00 | T: ((Array([0.01347347, 0.01079573], dtype=float32), Array(0.45041794, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.137769e+00 | T: ((Array([0.01375992, 0.01029935], dtype=float32), Array(0.45308256, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.123332e+00 | T: ((Array([0.01398554, 0.0099368 ], dtype=float32), Array(0.455673, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.108785e+00 | T: ((Array([0.0141127 , 0.00969985], dtype=float32), Array(0.45819294, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.095614e+00 | T: ((Array([0.01412401, 0.00958018], dtype=float32), Array(0.46064597, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.082305e+00 | T: ((Array([0.0140198 , 0.00956881], dtype=float32), Array(0.46303537, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# ...
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      82
#      83     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 84             iterative_mle(samples,\
#      85                 neg_log_p_Ts,\
#      86                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      56
#      57     for i in range(num_steps):
# ---> 58         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      59         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      60         if i % 1 == 0:
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      43
#      44         params = get_params(opt_state)
# ---> 45         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      46         opt_state = opt_update(step, grads, opt_state)
#      47         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in value_and_grad_f(*args, **kwargs)
#     739       _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     740     if not has_aux:
# --> 741       ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     742     else:
#     743       ans, vjp_py, aux = _vjp(
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in _vjp(fun, has_aux, reduce_axes, *primals)
#    2234   if not has_aux:
#    2235     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2236     out_primal, out_vjp = ad.vjp(
#    2237         flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2238     out_tree = out_tree()
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in vjp(traceable, primals, has_aux, reduce_axes)
#     138 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     139   if not has_aux:
# --> 140     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     141   else:
#     142     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#     127   _, in_tree = tree_flatten(((primals, primals), {}))
#     128   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 129   jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     130   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     131   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     312   def wrapper(*args, **kwargs):
#     313     with TraceAnnotation(name, **decorator_kwargs):
# --> 314       return func(*args, **kwargs)
#     315     return wrapper
#     316   return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     775   with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     776     fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 777     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     778     assert not env
#     779     del main, fun, env
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     137
#     138         # sample
# --> 139         log_varphis = vmap(lambda dW: guided(x,v,dts,dW,*ys)[4][-1],1)(dW)
#     140
#     141         log_varphi = jnp.log(jnp.mean(jnp.exp(log_varphis)))
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(dW)
#     137
#     138         # sample
# --> 139         log_varphis = vmap(lambda dW: guided(x,v,dts,dW,*ys)[4][-1],1)(dW)
#     140
#     141         log_varphi = jnp.log(jnp.mean(jnp.exp(log_varphis)))
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     251   @api_boundary
#     252   def cache_miss(*args, **kwargs):
# --> 253     outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     254         fun, infer_params_fn, *args, **kwargs)
#     255     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     164     dispatch.check_arg(arg)
#     165   try:
# --> 166     out_flat = pjit_p.bind(*args_flat, **params)
#     167   except pxla.DeviceAssignmentMismatchError as e:
#     168     fails, = e.args
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     429       frame = self.get_frame(vals_in, dims_in)
#     430       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 431       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     432     src = source_info_util.current()
#     433     if primitive.multiple_results:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1429       if axis_out is not None else o
#    1430       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1431   vals_out = pjit_p.bind(
#    1432     *vals_in,
#    1433     jaxpr=new_jaxpr,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     429       frame = self.get_frame(vals_in, dims_in)
#     430       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 431       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     432     src = source_info_util.current()
#     433     if primitive.multiple_results:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1429       if axis_out is not None else o
#    1430       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1431   vals_out = pjit_p.bind(
#    1432     *vals_in,
#    1433     jaxpr=new_jaxpr,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in process_primitive(self, primitive, tracers, params)
#     314       msg = f"Differentiation rule for '{primitive}' not implemented"
#     315       raise NotImplementedError(msg)
# --> 316     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     317     if primitive.multiple_results:
#     318       return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1488   _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1489   _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1490   outputs = pjit_p.bind(
#    1491       *primals_in, *_filter_zeros_in(tangents_in),
#    1492       jaxpr=jaxpr_jvp,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#     211   def process_primitive(self, primitive, tracers, params):
#     212     if primitive in custom_partial_eval_rules:
# --> 213       return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     214     else:
#     215       return self.default_process_primitive(primitive, tracers, params)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    1567   # Bind known things to pjit_p.
#    1568   known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 1569   all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    1570
#    1571   known_outs_iter = iter(all_known_outs)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     819
#     820   def process_primitive(self, primitive, tracers, params):
# --> 821     return primitive.impl(*tracers, **params)
#     822
#     823   def process_call(self, primitive, f, tracers, params):
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1207       in_shardings, out_shardings, None, None)
#    1208   if xla_extension_version >= 169:
# -> 1209     return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1210                         tree_util.default_registry,
#    1211                         _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:

# %%
#Plotting time difference

sn_dims = jnp.array(dims)

sn_score_tmean = jnp.array([time.average for time in time_score])
sn_score_tstd = jnp.array([time.stdev for time in time_bridge])

sn_bridge_tmean = jnp.array([time.average for time in time_bridge])
sn_bridge_tstd = jnp.array([time.stdev for time in time_bridge])

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.plot(sn_dims, sn_score_tmean, color='orange')
ax.plot(sn_dims, sn_bridge_tmean, color='blue')
ax.set_xlabel(f'$N$')
ax.set_ylabel(f'$Time$')
ax.grid(True)
ax.fill_between(
    rn_dims,
    jnp.maximum(sn_score_tmean - 1.96 * sn_score_tstd, jnp.zeros_like(sn_score_tmean)),
    jnp.maximum(sn_score_tmean + 1.96 * sn_score_tstd, jnp.zeros_like(sn_score_tmean)),
    color="tab:red",
    alpha=0.5,
)
ax.fill_between(
    dims,
    jnp.maximum(sn_bridge_tmean - 1.96 * sn_bridge_tstd, jnp.zeros_like(sn_bridge_tmean)),
    jnp.maximum(sn_bridge_tmean + 1.96 * sn_bridge_tstd, jnp.zeros_like(sn_bridge_tmean)),
    color="tab:pink",
    alpha=0.5,
)
ax.grid(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/977382752.py in <module>
#      11 fig = plt.figure(figsize=(10,10))
#      12 ax = fig.add_subplot(111)
# ---> 13 ax.plot(sn_dims, sn_score_tmean, color='orange')
#      14 ax.plot(sn_dims, sn_bridge_tmean, color='blue')
#      15 ax.set_xlabel(f'$N$')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (2,)

# %% [markdown]
# # n-Ellipsoid

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 5 #Change this for Ellipsoid2, Ellipsoid3, Ellipsoid5, Ellipsoid10, Ellipsoid20

# %%
M = nEllipsoid(N=N, params = jnp.linspace(0.5,1.0,N+1))
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*N)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/Ellipsoid'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/Ellipsoid'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,200,200,100,50]
elif N<50:
    layers = [50,100,200,400,400,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))
    
    return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Ellipsoid'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Ellipsoid'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/Ellipsoid'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")

# %%
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                     step_size=0.01, max_iter=1000)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 7.988443e+00 | T: ((Array([ 7.304285e-10,  7.072030e-09, -7.675185e-10,  0.000000e+00,
#        -0.000000e+00], dtype=float32), Array(0.20999993, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 1 | T: 6.308940e+00 | T: ((Array([ 0.00267503, -0.00850208,  0.00732838, -0.00878681,  0.0043459 ],      dtype=float32), Array(0.21986869, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Final 1 | T: 6.308940e+00 | T: (Array([ 0.00267503, -0.00850208,  0.00732838, -0.00878681,  0.0043459 ],      dtype=float32), Array(0.21986869, dtype=float32))
# Step 0 | T: 7.988943e+00 | T: ((Array([ 7.304285e-10,  7.072030e-09, -7.675185e-10,  0.000000e+00,
#        -0.000000e+00], dtype=float32), Array(0.20999993, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 1 | T: 6.311311e+00 | T: ((Array([ 0.00186337, -0.00850924,  0.00731894, -0.00880198,  0.00435333],      dtype=float32), Array(0.21986872, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 2 | T: 5.547271e+00 | T: ((Array([-0.00258265, -0.01615796,  0.01231511, -0.01655262,  0.00560537],      dtype=float32), Array(0.22958992, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 3 | T: 4.916532e+00 | T: ((Array([-0.00428324, -0.02305101,  0.01514498, -0.0230377 ,  0.00488095],      dtype=float32), Array(0.23913123, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 4 | T: 4.385246e+00 | T: ((Array([-0.00231243, -0.02919117,  0.01616124, -0.02809494,  0.00283574],      dtype=float32), Array(0.24846153, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 5 | T: 3.939902e+00 | T: ((Array([ 0.00017701, -0.03455891,  0.01576782, -0.03164172, -0.00010294],      dtype=float32), Array(0.25755453, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 6 | T: 3.565125e+00 | T: ((Array([ 0.00098076, -0.03913633,  0.01434843, -0.03372187, -0.00363295],      dtype=float32), Array(0.26638913, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 7 | T: 3.251474e+00 | T: ((Array([-0.00015531, -0.04292056,  0.01223588, -0.03448159, -0.00754109],      dtype=float32), Array(0.2749493, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 8 | T: 2.982104e+00 | T: ((Array([-0.00205852, -0.04592767,  0.00972828, -0.03411569, -0.01167286],      dtype=float32), Array(0.28322288, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 9 | T: 2.754448e+00 | T: ((Array([-0.00356903, -0.04818676,  0.00706819, -0.03282189, -0.01590715],      dtype=float32), Array(0.29120138, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 10 | T: 2.560565e+00 | T: ((Array([-0.00383912, -0.04973948,  0.00446663, -0.03080353, -0.02013558],      dtype=float32), Array(0.29887998, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 11 | T: 2.394073e+00 | T: ((Array([-0.00297177, -0.05063422,  0.00208989, -0.02825207, -0.02427233],      dtype=float32), Array(0.30625638, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 12 | T: 2.252562e+00 | T: ((Array([-1.5188988e-03, -5.0928678e-02,  6.8977242e-05, -2.5335016e-02,
#        -2.8240792e-02], dtype=float32), Array(0.313331, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 13 | T: 2.131365e+00 | T: ((Array([-0.00016793, -0.05067914, -0.00150148, -0.02221502, -0.03198991],      dtype=float32), Array(0.3201061, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 14 | T: 2.027925e+00 | T: ((Array([ 0.00041703, -0.0499458 , -0.00258321, -0.01904144, -0.03547716],      dtype=float32), Array(0.3265857, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 15 | T: 1.937892e+00 | T: ((Array([ 0.00016211, -0.04879194, -0.00316406, -0.01594475, -0.03866842],      dtype=float32), Array(0.33277526, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 16 | T: 1.861620e+00 | T: ((Array([-0.00066424, -0.04727829, -0.00327417, -0.01303614, -0.04154395],      dtype=float32), Array(0.33868107, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 17 | T: 1.794276e+00 | T: ((Array([-0.00169503, -0.04546723, -0.00295375, -0.01042319, -0.0440902 ],      dtype=float32), Array(0.34431037, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 18 | T: 1.735045e+00 | T: ((Array([-0.00245262, -0.04341756, -0.00227254, -0.00818085, -0.04630597],      dtype=float32), Array(0.34967074, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 19 | T: 1.686875e+00 | T: ((Array([-0.00253033, -0.04118153, -0.00131155, -0.00635894, -0.04819093],      dtype=float32), Array(0.35477087, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 20 | T: 1.641247e+00 | T: ((Array([-0.00192609, -0.03881153, -0.00014998, -0.00499364, -0.04975785],      dtype=float32), Array(0.35961926, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 21 | T: 1.603600e+00 | T: ((Array([-0.0009724 , -0.0363552 ,  0.00111565, -0.00410239, -0.05101712],      dtype=float32), Array(0.3642249, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 22 | T: 1.569258e+00 | T: ((Array([-3.3337041e-05, -3.3856619e-02,  2.4115869e-03, -3.6777393e-03,
#        -5.1993564e-02], dtype=float32), Array(0.3685968, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 23 | T: 1.542464e+00 | T: ((Array([ 0.00053803, -0.03135714,  0.00364531, -0.00369384, -0.05271205],      dtype=float32), Array(0.37274438, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 24 | T: 1.516170e+00 | T: ((Array([ 0.00066557, -0.02889079,  0.00474331, -0.0041073 , -0.05319656],      dtype=float32), Array(0.37667665, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 25 | T: 1.496050e+00 | T: ((Array([ 0.0003019 , -0.02649165,  0.00565993, -0.00486221, -0.05347527],      dtype=float32), Array(0.3804029, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 26 | T: 1.475188e+00 | T: ((Array([-0.00029794, -0.02419066,  0.00634838, -0.0058952 , -0.05357454],      dtype=float32), Array(0.38393196, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 27 | T: 1.459278e+00 | T: ((Array([-0.00085929, -0.02201401,  0.00678697, -0.00714335, -0.05352696],      dtype=float32), Array(0.38727272, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 28 | T: 1.443838e+00 | T: ((Array([-0.00113742, -0.01998527,  0.00696823, -0.0085279 , -0.05336267],      dtype=float32), Array(0.39043367, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 29 | T: 1.431378e+00 | T: ((Array([-0.00105809, -0.01812041,  0.00690034, -0.00997708, -0.0531062 ],      dtype=float32), Array(0.39342338, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 30 | T: 1.419907e+00 | T: ((Array([-0.00059141, -0.01643053,  0.00661477, -0.01143166, -0.05278644],      dtype=float32), Array(0.3962499, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 31 | T: 1.411155e+00 | T: ((Array([ 7.74780638e-05, -1.49261085e-02,  6.13748934e-03, -1.28165698e-02,
#        -5.24291657e-02], dtype=float32), Array(0.39892128, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 32 | T: 1.402786e+00 | T: ((Array([ 0.00075122, -0.01361202,  0.00551587, -0.01408367, -0.05205886],      dtype=float32), Array(0.40144518, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 33 | T: 1.393532e+00 | T: ((Array([ 0.00121964, -0.01249191,  0.0047765 , -0.01519132, -0.05169078],      dtype=float32), Array(0.40382895, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 34 | T: 1.388671e+00 | T: ((Array([ 0.00126738, -0.01156613,  0.00398237, -0.01610291, -0.05134336],      dtype=float32), Array(0.4060799, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 35 | T: 1.381461e+00 | T: ((Array([ 0.0009846 , -0.01082754,  0.00318818, -0.01679675, -0.05103123],      dtype=float32), Array(0.40820467, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 36 | T: 1.376760e+00 | T: ((Array([ 0.00046881, -0.01027212,  0.00244238, -0.01726332, -0.05077022],      dtype=float32), Array(0.41020992, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 37 | T: 1.373501e+00 | T: ((Array([-1.9276049e-05, -9.8926853e-03,  1.7790747e-03, -1.7487463e-02,
#        -5.0567836e-02], dtype=float32), Array(0.4121021, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 38 | T: 1.368177e+00 | T: ((Array([-0.00031222, -0.00967683,  0.00123306, -0.01748504, -0.05043293],      dtype=float32), Array(0.41388702, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 39 | T: 1.366949e+00 | T: ((Array([-0.00027101, -0.00961244,  0.00082854, -0.0172774 , -0.05037248],      dtype=float32), Array(0.41557065, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 40 | T: 1.362171e+00 | T: ((Array([ 0.00012493, -0.00968649,  0.00057866, -0.01688514, -0.05038682],      dtype=float32), Array(0.41715834, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 41 | T: 1.358645e+00 | T: ((Array([ 0.00068384, -0.00988474,  0.00048545, -0.01633968, -0.05047506],      dtype=float32), Array(0.41865534, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 42 | T: 1.357216e+00 | T: ((Array([ 0.00108601, -0.01018938,  0.00055554, -0.01567485, -0.05063858],      dtype=float32), Array(0.42006668, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 43 | T: 1.357129e+00 | T: ((Array([ 0.00127991, -0.01058395,  0.0007601 , -0.01492985, -0.05086872],      dtype=float32), Array(0.42139736, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 44 | T: 1.353493e+00 | T: ((Array([ 0.00118364, -0.01105241,  0.0010811 , -0.01414683, -0.05116579],      dtype=float32), Array(0.4226516, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 45 | T: 1.350847e+00 | T: ((Array([ 0.00085597, -0.01158012,  0.0014773 , -0.01336236, -0.05152135],      dtype=float32), Array(0.4238337, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 46 | T: 1.349128e+00 | T: ((Array([ 0.00040542, -0.01215063,  0.00192005, -0.01261041, -0.05191991],      dtype=float32), Array(0.42494768, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 47 | T: 1.347433e+00 | T: ((Array([ 3.2151234e-05, -1.2752734e-02,  2.3822915e-03, -1.1933628e-02,
#        -5.2357893e-02], dtype=float32), Array(0.42599735, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 48 | T: 1.347232e+00 | T: ((Array([-0.00014407, -0.01336777,  0.00283651, -0.01135568, -0.05282657],      dtype=float32), Array(0.4269865, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 49 | T: 1.345376e+00 | T: ((Array([-9.2603157e-05, -1.3986989e-02,  3.2488273e-03, -1.0882884e-02,
#        -5.3311259e-02], dtype=float32), Array(0.42791843, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 50 | T: 1.344544e+00 | T: ((Array([ 0.0001923 , -0.01459553,  0.00359815, -0.01053559, -0.05380362],      dtype=float32), Array(0.4287966, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 51 | T: 1.343452e+00 | T: ((Array([ 0.00057823, -0.01518233,  0.00386209, -0.01032284, -0.05429572],      dtype=float32), Array(0.42962408, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 52 | T: 1.343606e+00 | T: ((Array([ 0.00085956, -0.01573881,  0.00403425, -0.01025326, -0.0547775 ],      dtype=float32), Array(0.4304039, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 53 | T: 1.340137e+00 | T: ((Array([ 0.00089254, -0.01624043,  0.00404604, -0.01031375, -0.05523215],      dtype=float32), Array(0.4311394, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 54 | T: 1.341154e+00 | T: ((Array([ 0.00069765, -0.01669341,  0.00398205, -0.01048574, -0.0556594 ],      dtype=float32), Array(0.43183255, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 55 | T: 1.340202e+00 | T: ((Array([ 0.00041396, -0.01709574,  0.00385285, -0.01074648, -0.05605912],      dtype=float32), Array(0.43248567, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 56 | T: 1.341726e+00 | T: ((Array([ 0.00018571, -0.01744375,  0.00368344, -0.01106781, -0.05642709],      dtype=float32), Array(0.43310124, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 57 | T: 1.339244e+00 | T: ((Array([ 9.6167059e-05, -1.7733047e-02,  3.4795697e-03, -1.1435037e-02,
#        -5.6757603e-02], dtype=float32), Array(0.43368137, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 58 | T: 1.340508e+00 | T: ((Array([ 0.00017663, -0.01796327,  0.00326702, -0.01182691, -0.05704661],      dtype=float32), Array(0.43422815, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 59 | T: 1.341329e+00 | T: ((Array([ 0.0004388 , -0.01813338,  0.00306873, -0.01221958, -0.05729782],      dtype=float32), Array(0.4347436, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 60 | T: 1.338729e+00 | T: ((Array([ 0.0006343 , -0.01824311,  0.00288849, -0.01259238, -0.05749977],      dtype=float32), Array(0.43522942, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 61 | T: 1.340548e+00 | T: ((Array([ 0.00075199, -0.0182962 ,  0.00273261, -0.01292981, -0.05765264],      dtype=float32), Array(0.43568757, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 62 | T: 1.339953e+00 | T: ((Array([ 0.00061703, -0.01830037,  0.00261944, -0.01321245, -0.05776385],      dtype=float32), Array(0.43611956, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 63 | T: 1.336303e+00 | T: ((Array([ 0.0004012 , -0.01825727,  0.00255193, -0.01343151, -0.05783493],      dtype=float32), Array(0.4365265, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 64 | T: 1.339315e+00 | T: ((Array([ 0.00024746, -0.0181702 ,  0.00252189, -0.01357962, -0.05787285],      dtype=float32), Array(0.43691024, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 65 | T: 1.337280e+00 | T: ((Array([ 0.00014052, -0.01804471,  0.00253238, -0.01365628, -0.05787323],      dtype=float32), Array(0.43727192, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 66 | T: 1.338958e+00 | T: ((Array([ 0.0001893 , -0.0178856 ,  0.00258419, -0.01366484, -0.05784574],      dtype=float32), Array(0.43761298, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 67 | T: 1.338747e+00 | T: ((Array([ 0.00039663, -0.01769959,  0.00266818, -0.01360503, -0.05779322],      dtype=float32), Array(0.43793458, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 68 | T: 1.336912e+00 | T: ((Array([ 0.00065149, -0.01749347,  0.00277692, -0.01348863, -0.05772862],      dtype=float32), Array(0.43823746, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 69 | T: 1.337228e+00 | T: ((Array([ 0.00081399, -0.01726935,  0.00290027, -0.01332539, -0.05765654],      dtype=float32), Array(0.4385228, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 70 | T: 1.336763e+00 | T: ((Array([ 0.00084599, -0.01703697,  0.0030332 , -0.01312855, -0.05757495],      dtype=float32), Array(0.43879172, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 71 | T: 1.337001e+00 | T: ((Array([ 0.00066911, -0.01679963,  0.00315226, -0.01290538, -0.05748535],      dtype=float32), Array(0.4390452, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 72 | T: 1.337367e+00 | T: ((Array([ 0.00036288, -0.01656093,  0.00325547, -0.01268551, -0.05739513],      dtype=float32), Array(0.43928418, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 73 | T: 1.335878e+00 | T: ((Array([ 8.40895227e-05, -1.63281653e-02,  3.33235087e-03, -1.24687515e-02,
#        -5.73114343e-02], dtype=float32), Array(0.43950924, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 74 | T: 1.336312e+00 | T: ((Array([-2.7946808e-06, -1.6103977e-02,  3.3901189e-03, -1.2269878e-02,
#        -5.7235528e-02], dtype=float32), Array(0.43972123, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 75 | T: 1.337228e+00 | T: ((Array([ 0.00026133, -0.01589682,  0.00341903, -0.01210371, -0.05717326],      dtype=float32), Array(0.43992105, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 76 | T: 1.337717e+00 | T: ((Array([ 0.00068306, -0.0157021 ,  0.00341396, -0.01197759, -0.0571174 ],      dtype=float32), Array(0.44010958, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 77 | T: 1.336850e+00 | T: ((Array([ 0.00099739, -0.01552725,  0.00336899, -0.01188916, -0.05707388],      dtype=float32), Array(0.44028738, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 78 | T: 1.337052e+00 | T: ((Array([ 0.00111193, -0.01537589,  0.0032894 , -0.01185457, -0.05704136],      dtype=float32), Array(0.44045508, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 79 | T: 1.336723e+00 | T: ((Array([ 0.00095308, -0.01524565,  0.0031852 , -0.01186794, -0.0570256 ],      dtype=float32), Array(0.4406131, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 80 | T: 1.336636e+00 | T: ((Array([ 0.00058332, -0.01513284,  0.00307806, -0.0119141 , -0.05702982],      dtype=float32), Array(0.44076195, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 81 | T: 1.336467e+00 | T: ((Array([ 0.00023541, -0.01504427,  0.00297011, -0.0119838 , -0.05704688],      dtype=float32), Array(0.44090214, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 82 | T: 1.336023e+00 | T: ((Array([ 7.9283025e-05, -1.4977351e-02,  2.8867698e-03, -1.2078382e-02,
#        -5.7078630e-02], dtype=float32), Array(0.44103408, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 83 | T: 1.336670e+00 | T: ((Array([ 0.00026078, -0.01493355,  0.00282576, -0.01218476, -0.05712434],      dtype=float32), Array(0.44115838, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 84 | T: 1.336404e+00 | T: ((Array([ 0.00058806, -0.01491041,  0.00277675, -0.01229051, -0.05718247],      dtype=float32), Array(0.4412754, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 85 | T: 1.335555e+00 | T: ((Array([ 0.00087171, -0.01490509,  0.00276134, -0.01239654, -0.05725309],      dtype=float32), Array(0.44138542, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 86 | T: 1.336241e+00 | T: ((Array([ 0.00108713, -0.01491839,  0.00277563, -0.01250791, -0.05733   ],      dtype=float32), Array(0.44148898, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 87 | T: 1.338173e+00 | T: ((Array([ 0.00106433, -0.01494509,  0.0028106 , -0.01260022, -0.05741162],      dtype=float32), Array(0.44158667, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 88 | T: 1.336439e+00 | T: ((Array([ 0.00074154, -0.01498456,  0.0028538 , -0.01266982, -0.05749325],      dtype=float32), Array(0.4416787, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 89 | T: 1.336584e+00 | T: ((Array([ 0.00036709, -0.01503757,  0.0029117 , -0.01270778, -0.05757137],      dtype=float32), Array(0.44176534, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 90 | T: 1.337759e+00 | T: ((Array([ 0.0001713 , -0.01509787,  0.00297327, -0.01272994, -0.05764845],      dtype=float32), Array(0.44184697, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 91 | T: 1.337981e+00 | T: ((Array([ 0.00021848, -0.01516283,  0.00303546, -0.0127139 , -0.05772037],      dtype=float32), Array(0.44192395, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 92 | T: 1.337053e+00 | T: ((Array([ 0.00053351, -0.01523165,  0.00308997, -0.01266958, -0.05778564],      dtype=float32), Array(0.44199648, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 93 | T: 1.336360e+00 | T: ((Array([ 0.00090904, -0.01530004,  0.00313976, -0.01262387, -0.057846  ],      dtype=float32), Array(0.44206482, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 94 | T: 1.336899e+00 | T: ((Array([ 0.00106782, -0.01536749,  0.00318691, -0.01256571, -0.05789478],      dtype=float32), Array(0.44212922, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 95 | T: 1.334594e+00 | T: ((Array([ 0.00099938, -0.01543082,  0.0032086 , -0.01250147, -0.05793004],      dtype=float32), Array(0.44218954, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 96 | T: 1.336072e+00 | T: ((Array([ 0.00079102, -0.01549133,  0.00320965, -0.0124512 , -0.05796147],      dtype=float32), Array(0.44224602, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 97 | T: 1.335099e+00 | T: ((Array([ 0.00057374, -0.01554997,  0.00320286, -0.01240399, -0.05798025],      dtype=float32), Array(0.44229892, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 98 | T: 1.337050e+00 | T: ((Array([ 0.00041715, -0.0156049 ,  0.00317621, -0.01236269, -0.05798813],      dtype=float32), Array(0.44234875, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Step 99 | T: 1.335083e+00 | T: ((Array([ 0.00040183, -0.01565352,  0.00313841, -0.01232056, -0.05799057],      dtype=float32), Array(0.44239536, dtype=float32)), Array([ 0.13723479,  0.0201403 ,  0.19753148, -0.0797253 ,  0.09387902,
#         0.9625865 ], dtype=float32))
# Final 99 | T: 1.335083e+00 | T: (Array([ 0.00040183, -0.01565352,  0.00313841, -0.01232056, -0.05799057],      dtype=float32), Array(0.44239536, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -0.0014 0.0008 0.0003 -0.0023 0.0009 0.0307 )
# T = 0.1586

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.1372 0.0201 0.1975 -0.0797 0.0939 0.9626 )
# T = 0.4424

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_263434/1057633312.py in <module>
#       1 print("The difference between the score and bridge:")
# ----> 2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_opt[-1][0]):.4f}")
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     254     args = (other, self) if swap else (self, other)
#     255     if isinstance(other, _accepted_binop_types):
# --> 256       return binary_op(*args)
#     257     if isinstance(other, _rejected_binop_types):
#     258       raise TypeError(f"unsupported operand type(s) for {opchar}: "
#
#     [... skipping hidden 12 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/ufuncs.py in <lambda>(x1, x2)
#      80     fn = lambda x1, x2, /: lax_fn(*promote_args_numeric(numpy_fn.__name__, x1, x2))
#      81   else:
# ---> 82     fn = lambda x1, x2, /: lax_fn(*promote_args(numpy_fn.__name__, x1, x2))
#      83   fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#      84   fn = jit(fn, inline=True)
#
#     [... skipping hidden 7 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in broadcasting_shape_rule(name, *avals)
#    1585         result_shape.append(non_1s[0])
#    1586       else:
# -> 1587         raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    1588                         f'{", ".join(map(str, map(tuple, shapes)))}.')
#    1589
#
# TypeError: sub got incompatible shapes for broadcasting: (2,), (6,).

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.19516
#  -T error = 0.4600
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_263434/2212210786.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/N:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/N:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     254     args = (other, self) if swap else (self, other)
#     255     if isinstance(other, _accepted_binop_types):
# --> 256       return binary_op(*args)
#     257     if isinstance(other, _rejected_binop_types):
#     258       raise TypeError(f"unsupported operand type(s) for {opchar}: "
#
#     [... skipping hidden 12 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/ufuncs.py in <lambda>(x1, x2)
#      80     fn = lambda x1, x2, /: lax_fn(*promote_args_numeric(numpy_fn.__name__, x1, x2))
#      81   else:
# ---> 82     fn = lambda x1, x2, /: lax_fn(*promote_args(numpy_fn.__name__, x1, x2))
#      83   fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#      84   fn = jit(fn, inline=True)
#
#     [... skipping hidden 7 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in broadcasting_shape_rule(name, *avals)
#    1585         result_shape.append(non_1s[0])
#    1586       else:
# -> 1587         raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    1588                         f'{", ".join(map(str, map(tuple, shapes)))}.')
#    1589
#
# TypeError: sub got incompatible shapes for broadcasting: (6,), (2,).

# %% [markdown]
# ## Timing Score

# %%
dims = [2,3,5,10]
time_score = []
time_bridge = []

for N in dims:
    print(N)
    M = nEllipsoid(N=N, params = jnp.linspace(0.5,1.0,N+1))
    jstoch.Brownian_coords(M)
    jstat.diffusion_mean(M)
    x0 = M.coords([0.]*N)

    file_path = 'scores/Ellipsoid'+str(N)+'/s1_'+ loss_type + '/'
    state = model_loader.load_model(file_path)

    file_path_s2 = 'scores/Ellipsoid'+str(N)+'/s2/'
    state_s2 = model_loader.load_model(file_path_s2)
    if N<10:
        layers = [50,100,100,50]
    elif N<50:
        layers = [50,100,200,200,100,50]
    else:
        layers = [50,100,200,400,400,200,100,50]
    s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
    s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                    dim=M.emb_dim, r = max(M.dim//2,1))(x))
    rng_key = jax.random.PRNGKey(2712)
    def grady_log(x,y,t):

        return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

    def gradt_log(x,y,t):

        s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
        s2_val = ggrady_log(x,y,t)
        s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)

        div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())

        return 0.5*(jnp.dot(s1_val, s1_val)+div)

    def ggrady_log_ad(x,y,t):

        ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)

        return ggrad

    def ggrady_log_score(x,y,t):

        ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))

        return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

    if s2_approximation:
        ggrady_log = ggrady_log_score
    else:
        ggrady_log = ggrady_log_ad
        
    xs = pd.read_csv('Data/Ellipsoid'+str(N)+'/xs.csv', header=None)
    charts = pd.read_csv('Data/Ellipsoid'+str(N)+'/chart.csv', header=None)
    X_obs = (jnp.array(xs.values), jnp.array(charts.values))
    
    diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
    result = %timeit -o M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), \
                                           step_size=0.01, max_iter=100)
    time_score.append(result)
    result = %timeit -o M.diffusion_mean(X_obs,num_steps=100, N=1)
    time_bridge.append(result)
# Out:
# 2
# using M.Exp for Logarithm
# 914 ms ± 9.41 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Step 0 | T: 9.045785e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.991252e+00 | T: ((Array([ 0.01245216, -0.03357188], dtype=float32), Array(0.21992584, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.101362e+00 | T: ((Array([ 0.0160122 , -0.02392925], dtype=float32), Array(0.22973661, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.349108e+00 | T: ((Array([ 0.01915262, -0.01461921], dtype=float32), Array(0.2393977, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.710273e+00 | T: ((Array([ 0.02020616, -0.00574349], dtype=float32), Array(0.2488805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166684e+00 | T: ((Array([0.01926227, 0.00260007], dtype=float32), Array(0.25816208, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.702184e+00 | T: ((Array([0.01717741, 0.01032713], dtype=float32), Array(0.2672245, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.301497e+00 | T: ((Array([0.01480488, 0.01736527], dtype=float32), Array(0.2760541, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.955870e+00 | T: ((Array([0.01288735, 0.02366214], dtype=float32), Array(0.28464103, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.656199e+00 | T: ((Array([0.01188654, 0.02918502], dtype=float32), Array(0.29297864, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394952e+00 | T: ((Array([0.01186582, 0.03392284], dtype=float32), Array(0.30106306, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165463e+00 | T: ((Array([0.01264212, 0.03788259], dtype=float32), Array(0.3088926, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 9.046937e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.992067e+00 | T: ((Array([ 0.01242449, -0.03357167], dtype=float32), Array(0.21992579, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.100922e+00 | T: ((Array([ 0.01598322, -0.02392922], dtype=float32), Array(0.2297364, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.349375e+00 | T: ((Array([ 0.01912951, -0.0146169 ], dtype=float32), Array(0.23939733, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.711009e+00 | T: ((Array([ 0.02019943, -0.00573833], dtype=float32), Array(0.24887991, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166975e+00 | T: ((Array([0.01926998, 0.00260802], dtype=float32), Array(0.25816122, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.700554e+00 | T: ((Array([0.01720253, 0.01033519], dtype=float32), Array(0.26722318, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.300456e+00 | T: ((Array([0.01484011, 0.01737478], dtype=float32), Array(0.2760522, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.954968e+00 | T: ((Array([0.01293837, 0.02367163], dtype=float32), Array(0.2846385, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655836e+00 | T: ((Array([0.01192673, 0.02919341], dtype=float32), Array(0.2929755, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394949e+00 | T: ((Array([0.0118959 , 0.03392985], dtype=float32), Array(0.30105934, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165575e+00 | T: ((Array([0.01266015, 0.03788795], dtype=float32), Array(0.30888835, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963725e+00 | T: ((Array([0.01388179, 0.04108858], dtype=float32), Array(0.31646276, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784155e+00 | T: ((Array([0.01517844, 0.04356783], dtype=float32), Array(0.3237843, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625489e+00 | T: ((Array([0.01624126, 0.04537161], dtype=float32), Array(0.33085606, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.482440e+00 | T: ((Array([0.01683068, 0.04655195], dtype=float32), Array(0.33768207, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.354994e+00 | T: ((Array([0.01686354, 0.0471632 ], dtype=float32), Array(0.34426728, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 2.239847e+00 | T: ((Array([0.01640008, 0.04726414], dtype=float32), Array(0.35061732, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 2.135906e+00 | T: ((Array([0.01557988, 0.04691181], dtype=float32), Array(0.3567384, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 2.041190e+00 | T: ((Array([0.01459303, 0.04616362], dtype=float32), Array(0.362637, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.956228e+00 | T: ((Array([0.01361819, 0.04507434], dtype=float32), Array(0.3683202, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.877946e+00 | T: ((Array([0.01283006, 0.04369732], dtype=float32), Array(0.37379503, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.806684e+00 | T: ((Array([0.01235299, 0.04208224], dtype=float32), Array(0.3790688, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.742396e+00 | T: ((Array([0.0122398 , 0.04027643], dtype=float32), Array(0.38414893, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.682893e+00 | T: ((Array([0.0124645 , 0.03832451], dtype=float32), Array(0.38904288, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.628686e+00 | T: ((Array([0.01294184, 0.03626966], dtype=float32), Array(0.3937581, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.578584e+00 | T: ((Array([0.01356781, 0.03414906], dtype=float32), Array(0.3983018, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.532483e+00 | T: ((Array([0.01421534, 0.03199829], dtype=float32), Array(0.40268132, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.490357e+00 | T: ((Array([0.01475554, 0.02984851], dtype=float32), Array(0.40690377, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.450842e+00 | T: ((Array([0.0151051 , 0.02772752], dtype=float32), Array(0.41097602, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.415187e+00 | T: ((Array([0.01520836, 0.02566148], dtype=float32), Array(0.41490492, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.382138e+00 | T: ((Array([0.01506971, 0.02367251], dtype=float32), Array(0.41869718, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.351546e+00 | T: ((Array([0.01473211, 0.02178018], dtype=float32), Array(0.42235923, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.323228e+00 | T: ((Array([0.0142596 , 0.01999927], dtype=float32), Array(0.4258973, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.296724e+00 | T: ((Array([0.01374171, 0.01834241], dtype=float32), Array(0.4293174, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.271764e+00 | T: ((Array([0.0132767 , 0.01682092], dtype=float32), Array(0.43262532, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.248891e+00 | T: ((Array([0.01293363, 0.01544187], dtype=float32), Array(0.43582657, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.227044e+00 | T: ((Array([0.0127635, 0.0142102], dtype=float32), Array(0.4389264, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.207560e+00 | T: ((Array([0.01277023, 0.01312893], dtype=float32), Array(0.44193, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.188344e+00 | T: ((Array([0.01293107, 0.01219809], dtype=float32), Array(0.4448422, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.170699e+00 | T: ((Array([0.01320322, 0.0114168 ], dtype=float32), Array(0.44766757, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.153996e+00 | T: ((Array([0.01352111, 0.01078095], dtype=float32), Array(0.4504106, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.138145e+00 | T: ((Array([0.01381769, 0.01028516], dtype=float32), Array(0.4530754, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.123176e+00 | T: ((Array([0.01404532, 0.00992278], dtype=float32), Array(0.45566598, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.108494e+00 | T: ((Array([0.01416965, 0.00968729], dtype=float32), Array(0.458186, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.095714e+00 | T: ((Array([0.01417362, 0.00957027], dtype=float32), Array(0.4606391, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.082330e+00 | T: ((Array([0.01405424, 0.00956229], dtype=float32), Array(0.46302858, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: 1.070530e+00 | T: ((Array([0.01383956, 0.00965285], dtype=float32), Array(0.4653577, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: 1.058464e+00 | T: ((Array([0.01358248, 0.00983   ], dtype=float32), Array(0.46762937, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: 1.047926e+00 | T: ((Array([0.01332214, 0.01008345], dtype=float32), Array(0.46984655, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: 1.037326e+00 | T: ((Array([0.01308241, 0.010403  ], dtype=float32), Array(0.4720119, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: 1.026631e+00 | T: ((Array([0.01291407, 0.01077717], dtype=float32), Array(0.47412786, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: 1.017188e+00 | T: ((Array([0.01283468, 0.01119666], dtype=float32), Array(0.4761969, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: 1.008057e+00 | T: ((Array([0.01284271, 0.01165194], dtype=float32), Array(0.47822124, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: 9.996551e-01 | T: ((Array([0.0129184 , 0.01213331], dtype=float32), Array(0.4802031, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: 9.907440e-01 | T: ((Array([0.01302942, 0.01263061], dtype=float32), Array(0.48214436, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: 9.822368e-01 | T: ((Array([0.01315561, 0.01313522], dtype=float32), Array(0.48404688, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: 9.748445e-01 | T: ((Array([0.01326762, 0.0136391 ], dtype=float32), Array(0.4859125, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: 9.671729e-01 | T: ((Array([0.01334396, 0.01413285], dtype=float32), Array(0.4877428, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: 9.601886e-01 | T: ((Array([0.01338221, 0.01461246], dtype=float32), Array(0.4895395, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: 9.528071e-01 | T: ((Array([0.01335566, 0.01507284], dtype=float32), Array(0.491304, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: 9.463540e-01 | T: ((Array([0.01327787, 0.0155094 ], dtype=float32), Array(0.49303776, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: 9.399056e-01 | T: ((Array([0.01316367, 0.01591826], dtype=float32), Array(0.49474204, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: 9.336089e-01 | T: ((Array([0.01304091, 0.01629613], dtype=float32), Array(0.49641806, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: 9.273965e-01 | T: ((Array([0.01292396, 0.01663977], dtype=float32), Array(0.498067, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: 9.212734e-01 | T: ((Array([0.01281198, 0.01694814], dtype=float32), Array(0.49968985, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: 9.160638e-01 | T: ((Array([0.0127373 , 0.01721898], dtype=float32), Array(0.5012877, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: 9.104387e-01 | T: ((Array([0.01271746, 0.01745101], dtype=float32), Array(0.5028615, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: 9.051179e-01 | T: ((Array([0.01273461, 0.01764524], dtype=float32), Array(0.5044122, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: 9.001122e-01 | T: ((Array([0.012773  , 0.01780205], dtype=float32), Array(0.50594056, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: 8.952849e-01 | T: ((Array([0.01282419, 0.0179226 ], dtype=float32), Array(0.50744754, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: 8.907717e-01 | T: ((Array([0.01286937, 0.01800872], dtype=float32), Array(0.50893396, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: 8.853250e-01 | T: ((Array([0.01290378, 0.01806103], dtype=float32), Array(0.5104003, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: 8.812345e-01 | T: ((Array([0.01292642, 0.01808321], dtype=float32), Array(0.5118474, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: 8.767087e-01 | T: ((Array([0.01292564, 0.01807647], dtype=float32), Array(0.51327574, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: 8.722214e-01 | T: ((Array([0.01289125, 0.01804174], dtype=float32), Array(0.514686, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: 8.682020e-01 | T: ((Array([0.0128387, 0.0179824], dtype=float32), Array(0.5160788, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: 8.643842e-01 | T: ((Array([0.01277377, 0.01790034], dtype=float32), Array(0.5174547, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: 8.604202e-01 | T: ((Array([0.01270133, 0.01779923], dtype=float32), Array(0.51881415, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: 8.569341e-01 | T: ((Array([0.01264071, 0.01768233], dtype=float32), Array(0.5201577, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: 8.526035e-01 | T: ((Array([0.01261372, 0.01755135], dtype=float32), Array(0.52148575, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: 8.493322e-01 | T: ((Array([0.01260655, 0.01741161], dtype=float32), Array(0.5227987, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: 8.456793e-01 | T: ((Array([0.01259632, 0.0172654 ], dtype=float32), Array(0.524097, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: 8.416598e-01 | T: ((Array([0.0125951 , 0.01711522], dtype=float32), Array(0.52538097, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: 8.386741e-01 | T: ((Array([0.01258443, 0.0169617 ], dtype=float32), Array(0.5266509, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: 8.350921e-01 | T: ((Array([0.01258632, 0.01680811], dtype=float32), Array(0.52790713, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: 8.323963e-01 | T: ((Array([0.01258634, 0.01665593], dtype=float32), Array(0.5291501, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: 8.289315e-01 | T: ((Array([0.01259454, 0.01650773], dtype=float32), Array(0.5303802, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: 8.260980e-01 | T: ((Array([0.01257639, 0.01636413], dtype=float32), Array(0.53159755, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: 8.232544e-01 | T: ((Array([0.01255836, 0.01622568], dtype=float32), Array(0.5328026, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: 8.198782e-01 | T: ((Array([0.01253057, 0.01609494], dtype=float32), Array(0.5339954, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: 8.177725e-01 | T: ((Array([0.01250111, 0.01597274], dtype=float32), Array(0.53517634, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: 8.146769e-01 | T: ((Array([0.01247145, 0.01585971], dtype=float32), Array(0.53634566, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: 8.119498e-01 | T: ((Array([0.01246149, 0.01575512], dtype=float32), Array(0.5375036, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: 8.092536e-01 | T: ((Array([0.01246596, 0.0156614 ], dtype=float32), Array(0.53865033, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: 8.069177e-01 | T: ((Array([0.01246909, 0.01557686], dtype=float32), Array(0.53978616, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: 8.043978e-01 | T: ((Array([0.01248225, 0.01550334], dtype=float32), Array(0.5409112, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: 8.015819e-01 | T: ((Array([0.01249347, 0.01543903], dtype=float32), Array(0.54202557, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: 7.996032e-01 | T: ((Array([0.01249353, 0.01538373], dtype=float32), Array(0.54312956, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: 7.968124e-01 | T: ((Array([0.01248888, 0.01533787], dtype=float32), Array(0.54422337, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: 7.968124e-01 | T: (Array([0.01248888, 0.01533787], dtype=float32), Array(0.54422337, dtype=float32))
# Step 0 | T: 9.045611e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.994441e+00 | T: ((Array([ 0.01239991, -0.03357195], dtype=float32), Array(0.21992603, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.102816e+00 | T: ((Array([ 0.01595641, -0.02392943], dtype=float32), Array(0.22973698, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.348824e+00 | T: ((Array([ 0.01914522, -0.01461876], dtype=float32), Array(0.23939805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.710011e+00 | T: ((Array([ 0.02023363, -0.00574149], dtype=float32), Array(0.24888064, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.167312e+00 | T: ((Array([0.01932531, 0.00260429], dtype=float32), Array(0.25816202, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.701108e+00 | T: ((Array([0.01723596, 0.01033245], dtype=float32), Array(0.26722407, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.301041e+00 | T: ((Array([0.01485198, 0.01737128], dtype=float32), Array(0.27605325, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.956070e+00 | T: ((Array([0.01290745, 0.02366934], dtype=float32), Array(0.28463978, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655661e+00 | T: ((Array([0.0118706 , 0.02919376], dtype=float32), Array(0.29297698, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.394799e+00 | T: ((Array([0.01183076, 0.03393228], dtype=float32), Array(0.30106094, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165933e+00 | T: ((Array([0.01259295, 0.03789081], dtype=float32), Array(0.30889007, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963724e+00 | T: ((Array([0.01383993, 0.04109311], dtype=float32), Array(0.3164646, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784252e+00 | T: ((Array([0.01517212, 0.0435744 ], dtype=float32), Array(0.32378623, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625494e+00 | T: ((Array([0.01626797, 0.04537907], dtype=float32), Array(0.33085802, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.483053e+00 | T: ((Array([0.01690081, 0.04655989], dtype=float32), Array(0.33768412, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.355308e+00 | T: ((Array([0.01697805, 0.04717194], dtype=float32), Array(0.34426945, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 47 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 48 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 49 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 50 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 51 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 52 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 53 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 54 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 55 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 56 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 57 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 58 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 59 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 60 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 61 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 62 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 63 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 64 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 65 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 66 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 67 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 68 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 69 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 70 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 71 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 72 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 73 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 74 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 75 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 76 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 77 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 78 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 79 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 80 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 81 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 82 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 83 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 84 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 85 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 86 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 87 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 88 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 89 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 90 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 91 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 92 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 93 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 94 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 95 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 96 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 97 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 98 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 99 | T: nan | T: ((Array([nan, nan], dtype=float32), Array(nan, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Final 99 | T: nan | T: (Array([nan, nan], dtype=float32), Array(nan, dtype=float32))
# Step 0 | T: 9.044426e+00 | T: ((Array([ 0.01163083, -0.0434425 ], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 1 | T: 7.991736e+00 | T: ((Array([ 0.01241619, -0.03357207], dtype=float32), Array(0.21992591, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 2 | T: 7.102967e+00 | T: ((Array([ 0.01595829, -0.02392905], dtype=float32), Array(0.22973691, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 3 | T: 6.348410e+00 | T: ((Array([ 0.01911102, -0.01461669], dtype=float32), Array(0.23939805, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 4 | T: 5.711473e+00 | T: ((Array([ 0.02016209, -0.00573971], dtype=float32), Array(0.24888098, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 5 | T: 5.166816e+00 | T: ((Array([0.01922329, 0.0026055 ], dtype=float32), Array(0.2581626, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 6 | T: 4.701509e+00 | T: ((Array([0.01714822, 0.01033262], dtype=float32), Array(0.26722497, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 7 | T: 4.300499e+00 | T: ((Array([0.01478965, 0.01736988], dtype=float32), Array(0.2760544, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 8 | T: 3.955084e+00 | T: ((Array([0.01288747, 0.02366466], dtype=float32), Array(0.28464112, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 9 | T: 3.655872e+00 | T: ((Array([0.01190002, 0.02918439], dtype=float32), Array(0.29297855, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 10 | T: 3.393794e+00 | T: ((Array([0.0119092 , 0.03391863], dtype=float32), Array(0.30106267, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 11 | T: 3.165677e+00 | T: ((Array([0.01270484, 0.03787243], dtype=float32), Array(0.30889198, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 12 | T: 2.963511e+00 | T: ((Array([0.01395004, 0.04107071], dtype=float32), Array(0.3164666, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 13 | T: 2.784414e+00 | T: ((Array([0.01526974, 0.04354875], dtype=float32), Array(0.32378834, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 14 | T: 2.625108e+00 | T: ((Array([0.01633775, 0.04535253], dtype=float32), Array(0.3308603, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 15 | T: 2.483034e+00 | T: ((Array([0.01691632, 0.04653218], dtype=float32), Array(0.33768654, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 16 | T: 2.355436e+00 | T: ((Array([0.01692732, 0.04714392], dtype=float32), Array(0.34427208, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 17 | T: 2.239251e+00 | T: ((Array([0.01643059, 0.04724531], dtype=float32), Array(0.35062242, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 18 | T: 2.135758e+00 | T: ((Array([0.01556807, 0.04689433], dtype=float32), Array(0.35674378, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 19 | T: 2.041965e+00 | T: ((Array([0.01452768, 0.0461467 ], dtype=float32), Array(0.36264282, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 20 | T: 1.955260e+00 | T: ((Array([0.01353747, 0.04505795], dtype=float32), Array(0.3683263, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 21 | T: 1.877844e+00 | T: ((Array([0.01275851, 0.04368161], dtype=float32), Array(0.37380135, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 22 | T: 1.806706e+00 | T: ((Array([0.01230555, 0.04206792], dtype=float32), Array(0.3790753, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 23 | T: 1.741689e+00 | T: ((Array([0.01221389, 0.04026436], dtype=float32), Array(0.38415557, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 24 | T: 1.682478e+00 | T: ((Array([0.01246546, 0.03831495], dtype=float32), Array(0.38904962, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 25 | T: 1.627784e+00 | T: ((Array([0.0129663 , 0.03626254], dtype=float32), Array(0.3937648, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 26 | T: 1.578525e+00 | T: ((Array([0.01360096, 0.03414344], dtype=float32), Array(0.39830852, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 27 | T: 1.532576e+00 | T: ((Array([0.01424548, 0.03199461], dtype=float32), Array(0.40268803, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 28 | T: 1.490191e+00 | T: ((Array([0.01477826, 0.0298472 ], dtype=float32), Array(0.40691045, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 29 | T: 1.451847e+00 | T: ((Array([0.01511117, 0.02772845], dtype=float32), Array(0.41098282, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 30 | T: 1.415508e+00 | T: ((Array([0.01521006, 0.02566399], dtype=float32), Array(0.41491187, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 31 | T: 1.382088e+00 | T: ((Array([0.01506319, 0.02367586], dtype=float32), Array(0.41870424, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 32 | T: 1.351442e+00 | T: ((Array([0.01472132, 0.02178508], dtype=float32), Array(0.4223664, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 33 | T: 1.323201e+00 | T: ((Array([0.01425232, 0.0200064 ], dtype=float32), Array(0.4259046, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 34 | T: 1.296095e+00 | T: ((Array([0.01374669, 0.01835197], dtype=float32), Array(0.42932472, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 35 | T: 1.271857e+00 | T: ((Array([0.01329257, 0.01683342], dtype=float32), Array(0.43263263, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 36 | T: 1.249114e+00 | T: ((Array([0.01296614, 0.01545571], dtype=float32), Array(0.43583393, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 37 | T: 1.227369e+00 | T: ((Array([0.01279529, 0.01422598], dtype=float32), Array(0.4389339, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 38 | T: 1.206527e+00 | T: ((Array([0.01278611, 0.01314583], dtype=float32), Array(0.4419375, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 39 | T: 1.188462e+00 | T: ((Array([0.01291976, 0.01221553], dtype=float32), Array(0.4448497, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 40 | T: 1.170259e+00 | T: ((Array([0.01317032, 0.0114326 ], dtype=float32), Array(0.44767505, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 41 | T: 1.153474e+00 | T: ((Array([0.01347347, 0.01079573], dtype=float32), Array(0.45041794, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 42 | T: 1.137769e+00 | T: ((Array([0.01375992, 0.01029935], dtype=float32), Array(0.45308256, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 43 | T: 1.123332e+00 | T: ((Array([0.01398554, 0.0099368 ], dtype=float32), Array(0.455673, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 44 | T: 1.108785e+00 | T: ((Array([0.0141127 , 0.00969985], dtype=float32), Array(0.45819294, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 45 | T: 1.095614e+00 | T: ((Array([0.01412401, 0.00958018], dtype=float32), Array(0.46064597, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# Step 46 | T: 1.082305e+00 | T: ((Array([0.0140198 , 0.00956881], dtype=float32), Array(0.46303537, dtype=float32)), Array([0., 0., 1.], dtype=float32))
# ...
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      82
#      83     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 84             iterative_mle(samples,\
#      85                 neg_log_p_Ts,\
#      86                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      56
#      57     for i in range(num_steps):
# ---> 58         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      59         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      60         if i % 1 == 0:
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      43
#      44         params = get_params(opt_state)
# ---> 45         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      46         opt_state = opt_update(step, grads, opt_state)
#      47         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in value_and_grad_f(*args, **kwargs)
#     739       _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     740     if not has_aux:
# --> 741       ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     742     else:
#     743       ans, vjp_py, aux = _vjp(
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in _vjp(fun, has_aux, reduce_axes, *primals)
#    2234   if not has_aux:
#    2235     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2236     out_primal, out_vjp = ad.vjp(
#    2237         flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2238     out_tree = out_tree()
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in vjp(traceable, primals, has_aux, reduce_axes)
#     138 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     139   if not has_aux:
# --> 140     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     141   else:
#     142     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#     127   _, in_tree = tree_flatten(((primals, primals), {}))
#     128   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 129   jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     130   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     131   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     312   def wrapper(*args, **kwargs):
#     313     with TraceAnnotation(name, **decorator_kwargs):
# --> 314       return func(*args, **kwargs)
#     315     return wrapper
#     316   return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     775   with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     776     fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 777     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     778     assert not env
#     779     del main, fun, env
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     137
#     138         # sample
# --> 139         log_varphis = vmap(lambda dW: guided(x,v,dts,dW,*ys)[4][-1],1)(dW)
#     140
#     141         log_varphi = jnp.log(jnp.mean(jnp.exp(log_varphis)))
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1256     axis_size_ = (axis_size if axis_size is not None else
#    1257                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258     out_flat = batching.batch(
#    1259         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(dW)
#     137
#     138         # sample
# --> 139         log_varphis = vmap(lambda dW: guided(x,v,dts,dW,*ys)[4][-1],1)(dW)
#     140
#     141         log_varphi = jnp.log(jnp.mean(jnp.exp(log_varphis)))
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     251   @api_boundary
#     252   def cache_miss(*args, **kwargs):
# --> 253     outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     254         fun, infer_params_fn, *args, **kwargs)
#     255     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     164     dispatch.check_arg(arg)
#     165   try:
# --> 166     out_flat = pjit_p.bind(*args_flat, **params)
#     167   except pxla.DeviceAssignmentMismatchError as e:
#     168     fails, = e.args
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     429       frame = self.get_frame(vals_in, dims_in)
#     430       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 431       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     432     src = source_info_util.current()
#     433     if primitive.multiple_results:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1429       if axis_out is not None else o
#    1430       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1431   vals_out = pjit_p.bind(
#    1432     *vals_in,
#    1433     jaxpr=new_jaxpr,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     429       frame = self.get_frame(vals_in, dims_in)
#     430       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 431       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     432     src = source_info_util.current()
#     433     if primitive.multiple_results:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1429       if axis_out is not None else o
#    1430       for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1431   vals_out = pjit_p.bind(
#    1432     *vals_in,
#    1433     jaxpr=new_jaxpr,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py in process_primitive(self, primitive, tracers, params)
#     314       msg = f"Differentiation rule for '{primitive}' not implemented"
#     315       raise NotImplementedError(msg)
# --> 316     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     317     if primitive.multiple_results:
#     318       return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1488   _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1489   _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1490   outputs = pjit_p.bind(
#    1491       *primals_in, *_filter_zeros_in(tangents_in),
#    1492       jaxpr=jaxpr_jvp,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#     211   def process_primitive(self, primitive, tracers, params):
#     212     if primitive in custom_partial_eval_rules:
# --> 213       return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     214     else:
#     215       return self.default_process_primitive(primitive, tracers, params)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    1567   # Bind known things to pjit_p.
#    1568   known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 1569   all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    1570
#    1571   known_outs_iter = iter(all_known_outs)
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2594     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595                  else axis_main.with_cur_sublevel())
# -> 2596     return self.bind_with_trace(top_trace, args, params)
#    2597
#    2598
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     387
#     388   def bind_with_trace(self, trace, args, params):
# --> 389     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     391
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     819
#     820   def process_primitive(self, primitive, tracers, params):
# --> 821     return primitive.impl(*tracers, **params)
#     822
#     823   def process_call(self, primitive, f, tracers, params):
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/pjit.py in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1207       in_shardings, out_shardings, None, None)
#    1208   if xla_extension_version >= 169:
# -> 1209     return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1210                         tree_util.default_registry,
#    1211                         _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:

# %%
#Plotting time difference

ellipsoidn_dims = jnp.array(dims)

ellipsoidn_score_tmean = jnp.array([time.average for time in time_score])
ellipsoidn_score_tstd = jnp.array([time.stdev for time in time_bridge])

ellipsoidn_bridge_tmean = jnp.array([time.average for time in time_bridge])
ellipsoidn_bridge_tstd = jnp.array([time.stdev for time in time_bridge])

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.plot(sn_dims, ellipsoidn_score_tmean, color='orange')
ax.plot(sn_dims, ellipsoidn_bridge_tmean, color='blue')
ax.set_xlabel(f'$N$')
ax.set_ylabel(f'$Time$')
ax.grid(True)
ax.fill_between(
    rn_dims,
    jnp.maximum(ellipsoidn_score_tmean - 1.96 * ellipsoidn_score_tstd, jnp.zeros_like(ellipsoidn_score_tmean)),
    jnp.maximum(ellipsoidn_score_tmean + 1.96 * ellipsoidn_score_tstd, jnp.zeros_like(ellipsoidn_score_tmean)),
    color="tab:red",
    alpha=0.5,
)
ax.fill_between(
    dims,
    jnp.maximum(ellipsoidn_bridge_tmean - 1.96 * ellipsoidn_bridge_tstd, jnp.zeros_like(ellipsoidn_bridge_tmean)),
    jnp.maximum(ellipsoidn_bridge_tmean + 1.96 * ellipsoidn_bridge_tstd, jnp.zeros_like(ellipsoidn_bridge_tmean)),
    color="tab:pink",
    alpha=0.5,
)
ax.grid(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/977382752.py in <module>
#      11 fig = plt.figure(figsize=(10,10))
#      12 ax = fig.add_subplot(111)
# ---> 13 ax.plot(sn_dims, sn_score_tmean, color='orange')
#      14 ax.plot(sn_dims, sn_bridge_tmean, color='blue')
#      15 ax.set_xlabel(f'$N$')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (2,)

# %% [markdown]
# # Cylinder

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = Cylinder(params=(1.,jnp.array([0.,0.,1.]),jnp.pi/2.))
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/Cylinder/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

#file_path_s2 = 'scores/Cylinder/s2/'
#state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))
    
    return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Cylinder/s1_' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Cylinder/xs.csv', header=None)
charts = pd.read_csv('Data/Cylinder/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                     step_size=0.01, max_iter=1000)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.135751e+01 | T: ((Array([-0.05872891, -0.04805093], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.024655e+01 | T: ((Array([-0.04898103, -0.03818516], dtype=float32), Array(0.2199283, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 1 | T: 1.024655e+01 | T: (Array([-0.04898103, -0.03818516], dtype=float32), Array(0.2199283, dtype=float32))
# Step 0 | T: 1.135751e+01 | T: ((Array([-0.05872891, -0.04805093], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.024655e+01 | T: ((Array([-0.04898103, -0.03818516], dtype=float32), Array(0.2199283, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 2 | T: 9.303733e+00 | T: ((Array([-0.03971378, -0.02855165], dtype=float32), Array(0.22974525, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 3 | T: 8.501101e+00 | T: ((Array([-0.03118584, -0.01925099], dtype=float32), Array(0.23941708, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 4 | T: 7.815333e+00 | T: ((Array([-0.02365088, -0.0103821 ], dtype=float32), Array(0.24891564, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 5 | T: 7.227013e+00 | T: ((Array([-0.01731015, -0.00203724], dtype=float32), Array(0.25821814, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 6 | T: 6.720035e+00 | T: ((Array([-0.01227468,  0.0057029 ], dtype=float32), Array(0.26730648, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 7 | T: 6.281109e+00 | T: ((Array([-0.00855535,  0.01277333], dtype=float32), Array(0.27616677, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 8 | T: 5.899311e+00 | T: ((Array([-0.00608044,  0.01912744], dtype=float32), Array(0.28478873, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 9 | T: 5.565683e+00 | T: ((Array([-0.00472555,  0.0247381 ], dtype=float32), Array(0.29316527, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 10 | T: 5.272875e+00 | T: ((Array([-0.00434131,  0.02959706], dtype=float32), Array(0.30129188, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 11 | T: 5.014835e+00 | T: ((Array([-0.00477259,  0.03371307], dtype=float32), Array(0.3091664, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 12 | T: 4.786560e+00 | T: ((Array([-0.00586937,  0.03710911], dtype=float32), Array(0.31678858, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 13 | T: 4.583883e+00 | T: ((Array([-0.00749184,  0.03981938], dtype=float32), Array(0.32415977, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 14 | T: 4.403325e+00 | T: ((Array([-0.00951226,  0.04188628], dtype=float32), Array(0.3312827, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 15 | T: 4.241956e+00 | T: ((Array([-0.01181523,  0.04335776], dtype=float32), Array(0.3381612, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 16 | T: 4.097302e+00 | T: ((Array([-0.01429735,  0.04428507], dtype=float32), Array(0.34480003, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 17 | T: 3.967258e+00 | T: ((Array([-0.01686681,  0.04472094], dtype=float32), Array(0.3512047, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 18 | T: 3.850028e+00 | T: ((Array([-0.019443  ,  0.04471825], dtype=float32), Array(0.35738128, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 19 | T: 3.744071e+00 | T: ((Array([-0.02195626,  0.04432902], dtype=float32), Array(0.36333632, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 20 | T: 3.648057e+00 | T: ((Array([-0.02434764,  0.04360365], dtype=float32), Array(0.36907673, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 21 | T: 3.560839e+00 | T: ((Array([-0.02656867,  0.04259044], dtype=float32), Array(0.37460965, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 22 | T: 3.481423e+00 | T: ((Array([-0.02858109,  0.04133523], dtype=float32), Array(0.3799424, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 23 | T: 3.408939e+00 | T: ((Array([-0.03035641,  0.03988122], dtype=float32), Array(0.38508233, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 24 | T: 3.342632e+00 | T: ((Array([-0.03187536,  0.03826877], dtype=float32), Array(0.39003694, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 25 | T: 3.281840e+00 | T: ((Array([-0.03312721,  0.03653536], dtype=float32), Array(0.3948136, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 26 | T: 3.225984e+00 | T: ((Array([-0.03410893,  0.03471555], dtype=float32), Array(0.39941967, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 27 | T: 3.174554e+00 | T: ((Array([-0.03482435,  0.03284099], dtype=float32), Array(0.4038624, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 28 | T: 3.127106e+00 | T: ((Array([-0.03528316,  0.03094042], dtype=float32), Array(0.40814885, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 29 | T: 3.083242e+00 | T: ((Array([-0.03549999,  0.02903973], dtype=float32), Array(0.41228604, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 30 | T: 3.042613e+00 | T: ((Array([-0.03549347,  0.02716201], dtype=float32), Array(0.41628072, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 31 | T: 3.004912e+00 | T: ((Array([-0.03528529,  0.02532761], dtype=float32), Array(0.42013946, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 32 | T: 2.969864e+00 | T: ((Array([-0.03489939,  0.02355424], dtype=float32), Array(0.42386866, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 33 | T: 2.937224e+00 | T: ((Array([-0.03436117,  0.02185707], dtype=float32), Array(0.42747447, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 34 | T: 2.906774e+00 | T: ((Array([-0.03369674,  0.02024881], dtype=float32), Array(0.4309628, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 35 | T: 2.878320e+00 | T: ((Array([-0.03293234,  0.01873988], dtype=float32), Array(0.43433937, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 36 | T: 2.851688e+00 | T: ((Array([-0.03209377,  0.01733846], dtype=float32), Array(0.4376097, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 37 | T: 2.826717e+00 | T: ((Array([-0.03120584,  0.0160507 ], dtype=float32), Array(0.440779, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 38 | T: 2.803270e+00 | T: ((Array([-0.03029205,  0.01488081], dtype=float32), Array(0.4438523, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 39 | T: 2.781216e+00 | T: ((Array([-0.02937414,  0.01383124], dtype=float32), Array(0.44683442, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 40 | T: 2.760442e+00 | T: ((Array([-0.0284719,  0.0129028], dtype=float32), Array(0.44972992, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 41 | T: 2.740840e+00 | T: ((Array([-0.02760291,  0.01209485], dtype=float32), Array(0.45254314, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 42 | T: 2.722318e+00 | T: ((Array([-0.02678237,  0.01140541], dtype=float32), Array(0.45527825, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 43 | T: 2.704790e+00 | T: ((Array([-0.02602306,  0.01083135], dtype=float32), Array(0.4579392, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 44 | T: 2.688178e+00 | T: ((Array([-0.0253353 ,  0.01036852], dtype=float32), Array(0.46052974, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 45 | T: 2.672411e+00 | T: ((Array([-0.0247269 ,  0.01001191], dtype=float32), Array(0.46305338, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 46 | T: 2.657425e+00 | T: ((Array([-0.02420333,  0.00975576], dtype=float32), Array(0.4655135, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 47 | T: 2.643163e+00 | T: ((Array([-0.02376775,  0.00959374], dtype=float32), Array(0.46791327, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 48 | T: 2.629571e+00 | T: ((Array([-0.02342121,  0.00951903], dtype=float32), Array(0.4702557, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 49 | T: 2.616603e+00 | T: ((Array([-0.02316278,  0.0095245 ], dtype=float32), Array(0.47254363, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 50 | T: 2.604213e+00 | T: ((Array([-0.02298979,  0.00960276], dtype=float32), Array(0.47477975, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 51 | T: 2.592365e+00 | T: ((Array([-0.02289804,  0.00974629], dtype=float32), Array(0.4769666, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 52 | T: 2.581020e+00 | T: ((Array([-0.022882  ,  0.00994757], dtype=float32), Array(0.47910655, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 53 | T: 2.570148e+00 | T: ((Array([-0.02293508,  0.0101991 ], dtype=float32), Array(0.48120186, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 54 | T: 2.559716e+00 | T: ((Array([-0.02304988,  0.01049353], dtype=float32), Array(0.48325464, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 55 | T: 2.549699e+00 | T: ((Array([-0.02321837,  0.01082371], dtype=float32), Array(0.4852669, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 56 | T: 2.540071e+00 | T: ((Array([-0.02343213,  0.01118275], dtype=float32), Array(0.48724052, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 57 | T: 2.530809e+00 | T: ((Array([-0.0236826 ,  0.01156408], dtype=float32), Array(0.48917726, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 58 | T: 2.521894e+00 | T: ((Array([-0.02396121,  0.01196148], dtype=float32), Array(0.4910788, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 59 | T: 2.513302e+00 | T: ((Array([-0.0242596 ,  0.01236912], dtype=float32), Array(0.4929467, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 60 | T: 2.505018e+00 | T: ((Array([-0.02456976,  0.0127816 ], dtype=float32), Array(0.49478248, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 61 | T: 2.497025e+00 | T: ((Array([-0.02488418,  0.01319395], dtype=float32), Array(0.49658749, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 62 | T: 2.489305e+00 | T: ((Array([-0.02519593,  0.01360166], dtype=float32), Array(0.49836302, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 63 | T: 2.481846e+00 | T: ((Array([-0.02549877,  0.0140007 ], dtype=float32), Array(0.5001103, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 64 | T: 2.474633e+00 | T: ((Array([-0.02578722,  0.01438748], dtype=float32), Array(0.5018306, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 65 | T: 2.467654e+00 | T: ((Array([-0.0260566 ,  0.01475888], dtype=float32), Array(0.50352484, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 66 | T: 2.460896e+00 | T: ((Array([-0.02630305,  0.01511225], dtype=float32), Array(0.5051941, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 67 | T: 2.454350e+00 | T: ((Array([-0.02652355,  0.01544536], dtype=float32), Array(0.50683945, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 68 | T: 2.448004e+00 | T: ((Array([-0.02671589,  0.01575642], dtype=float32), Array(0.50846165, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 69 | T: 2.441850e+00 | T: ((Array([-0.02687865,  0.01604405], dtype=float32), Array(0.5100616, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 70 | T: 2.435877e+00 | T: ((Array([-0.02701117,  0.01630724], dtype=float32), Array(0.5116402, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 71 | T: 2.430077e+00 | T: ((Array([-0.02711346,  0.01654536], dtype=float32), Array(0.5131981, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 72 | T: 2.424443e+00 | T: ((Array([-0.0271862 ,  0.01675809], dtype=float32), Array(0.514736, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 73 | T: 2.418968e+00 | T: ((Array([-0.02723059,  0.01694545], dtype=float32), Array(0.5162546, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 74 | T: 2.413644e+00 | T: ((Array([-0.02724832,  0.01710772], dtype=float32), Array(0.51775455, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 75 | T: 2.408466e+00 | T: ((Array([-0.02724151,  0.01724543], dtype=float32), Array(0.51923645, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 76 | T: 2.403426e+00 | T: ((Array([-0.02721257,  0.01735934], dtype=float32), Array(0.5207008, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 77 | T: 2.398520e+00 | T: ((Array([-0.02716416,  0.01745041], dtype=float32), Array(0.5221482, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 78 | T: 2.393743e+00 | T: ((Array([-0.02709913,  0.01751974], dtype=float32), Array(0.5235791, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 79 | T: 2.389088e+00 | T: ((Array([-0.02702039,  0.01756859], dtype=float32), Array(0.5249941, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 80 | T: 2.384552e+00 | T: ((Array([-0.02693087,  0.01759833], dtype=float32), Array(0.5263935, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 81 | T: 2.380130e+00 | T: ((Array([-0.02683347,  0.01761041], dtype=float32), Array(0.52777773, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 82 | T: 2.375818e+00 | T: ((Array([-0.02673099,  0.01760635], dtype=float32), Array(0.52914727, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 83 | T: 2.371612e+00 | T: ((Array([-0.02662607,  0.01758769], dtype=float32), Array(0.53050244, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 84 | T: 2.367509e+00 | T: ((Array([-0.02652116,  0.017556  ], dtype=float32), Array(0.5318436, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 85 | T: 2.363504e+00 | T: ((Array([-0.02641848,  0.01751287], dtype=float32), Array(0.5331711, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 86 | T: 2.359595e+00 | T: ((Array([-0.02632   ,  0.01745983], dtype=float32), Array(0.53448534, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 87 | T: 2.355778e+00 | T: ((Array([-0.02622743,  0.01739842], dtype=float32), Array(0.5357865, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 88 | T: 2.352050e+00 | T: ((Array([-0.02614217,  0.0173301 ], dtype=float32), Array(0.537075, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 89 | T: 2.348409e+00 | T: ((Array([-0.02606536,  0.01725628], dtype=float32), Array(0.538351, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 90 | T: 2.344851e+00 | T: ((Array([-0.02599783,  0.01717831], dtype=float32), Array(0.53961486, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 91 | T: 2.341374e+00 | T: ((Array([-0.02594017,  0.01709746], dtype=float32), Array(0.5408668, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 92 | T: 2.337975e+00 | T: ((Array([-0.02589267,  0.01701489], dtype=float32), Array(0.54210705, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 93 | T: 2.334652e+00 | T: ((Array([-0.02585539,  0.01693171], dtype=float32), Array(0.5433358, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 94 | T: 2.331403e+00 | T: ((Array([-0.02582817,  0.01684889], dtype=float32), Array(0.54455334, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 95 | T: 2.328226e+00 | T: ((Array([-0.02581065,  0.01676735], dtype=float32), Array(0.54575986, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 96 | T: 2.325118e+00 | T: ((Array([-0.02580229,  0.01668788], dtype=float32), Array(0.5469555, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 97 | T: 2.322077e+00 | T: ((Array([-0.0258024 ,  0.01661118], dtype=float32), Array(0.5481406, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 98 | T: 2.319102e+00 | T: ((Array([-0.02581019,  0.01653786], dtype=float32), Array(0.5493152, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 99 | T: 2.316190e+00 | T: ((Array([-0.02582476,  0.01646842], dtype=float32), Array(0.55047953, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 99 | T: 2.316190e+00 | T: (Array([-0.02582476,  0.01646842], dtype=float32), Array(0.55047953, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -0.0270 0.0392 )
# T = 0.5400

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0000 0.0000 )
# T = 0.5505

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0475
#  -T error = 0.0105

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/2:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/2:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.02377
#  -T error = 0.0400
# Bridge Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.0505

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # Torus

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = Torus()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
x0[1]
# Out:
# using M.Exp for Logarithm
# Array([0., 0.], dtype=float32)

# %%
file_path = 'scores/Torus/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/Torus/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.emb_dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.emb_dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return to_TMx(M, M.F(y), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t))))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[1], y[1], t)))
    s2_val = ggrady_log(x,y,t)
    s1_proj = jnp.dot(M.invJF((M.F(y), y[1])), s1_val)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_proj,jacfwdx(M.logAbsDet)((y[0],M.F(y))).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: jnp.dot(M.invJF((M.F(y), y[1])), s1.apply(state.params,rng_key, jnp.hstack((M.F(x), M.F(y), t)))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[1],y[1],t)))
    
    return jnp.dot(M.invJF((M.F(y), y[1])), ggrad)

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_263434/1103567372.py in <module>
#       1 file_path = 'scores/Torus/s1_'+ loss_type + '/'
# ----> 2 state = model_loader.load_model(file_path)
#       3
#       4 file_path_s2 = 'scores/Torus/s2/'
#       5 state_s2 = model_loader.load_model(file_path_s2)
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/model_loader.py in load_model(ckpt_dir)
#      34
#      35     file_name = os.path.join(ckpt_dir, "tree.pkl")
# ---> 36     with open(file_name, "rb") as f:
#      37         tree_struct = pickle.load(f)
#      38
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scores/Torus/s1_dsm/tree.pkl'

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Torus/' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Torus/xs.csv', header=None)
charts = pd.read_csv('Data/Torus/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean.initialize(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), 
                                     step_size=0.1, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# Step 0 | T: 1.453338e+01 | T: ((Array([-0.18177876, -0.00945805], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.265824e+01 | T: ((Array([-0.17184542, -0.01500721], dtype=float32), Array(0.219913, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 1 | T: 1.265824e+01 | T: (Array([-0.17184542, -0.01500721], dtype=float32), Array(0.219913, dtype=float32))
# Step 0 | T: 1.453340e+01 | T: ((Array([-0.18177876, -0.00945805], dtype=float32), Array(0.20999993, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 1 | T: 1.265763e+01 | T: ((Array([-0.17184542, -0.015028  ], dtype=float32), Array(0.21991298, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 2 | T: 1.108802e+01 | T: ((Array([-0.16201945, -0.02065388], dtype=float32), Array(0.22969085, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 3 | T: 9.771928e+00 | T: ((Array([-0.15233807, -0.02273714], dtype=float32), Array(0.2392931, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 4 | T: 8.665657e+00 | T: ((Array([-0.14283484, -0.02159458], dtype=float32), Array(0.2486868, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 5 | T: 7.731694e+00 | T: ((Array([-0.13353942, -0.01877476], dtype=float32), Array(0.25784603, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 6 | T: 6.941618e+00 | T: ((Array([-0.12447762, -0.01548404], dtype=float32), Array(0.26675117, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 7 | T: 6.270371e+00 | T: ((Array([-0.11567149, -0.01271017], dtype=float32), Array(0.2753882, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 8 | T: 5.698425e+00 | T: ((Array([-0.10713954, -0.01112683], dtype=float32), Array(0.28374788, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 9 | T: 5.209940e+00 | T: ((Array([-0.09889688, -0.01088306], dtype=float32), Array(0.29182497, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 10 | T: 4.789880e+00 | T: ((Array([-0.09095556, -0.01174235], dtype=float32), Array(0.2996175, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 11 | T: 4.428392e+00 | T: ((Array([-0.08332466, -0.01329946], dtype=float32), Array(0.3071263, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 12 | T: 4.116339e+00 | T: ((Array([-0.07601065, -0.01510678], dtype=float32), Array(0.31435448, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 13 | T: 3.845485e+00 | T: ((Array([-0.06901763, -0.01675476], dtype=float32), Array(0.3213068, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 14 | T: 3.609640e+00 | T: ((Array([-0.06234752, -0.01791202], dtype=float32), Array(0.32798943, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 15 | T: 3.404012e+00 | T: ((Array([-0.05600031, -0.0184004 ], dtype=float32), Array(0.33440974, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 16 | T: 3.223542e+00 | T: ((Array([-0.04997426, -0.01820218], dtype=float32), Array(0.34057578, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 17 | T: 3.065178e+00 | T: ((Array([-0.04426618, -0.01743431], dtype=float32), Array(0.34649625, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 18 | T: 2.925501e+00 | T: ((Array([-0.0388715, -0.0162848], dtype=float32), Array(0.35218027, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 19 | T: 2.801942e+00 | T: ((Array([-0.03378458, -0.01498309], dtype=float32), Array(0.35763717, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 20 | T: 2.692142e+00 | T: ((Array([-0.02899874, -0.0137518 ], dtype=float32), Array(0.36287645, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 21 | T: 2.594517e+00 | T: ((Array([-0.02450654, -0.01278469], dtype=float32), Array(0.36790758, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 22 | T: 2.506560e+00 | T: ((Array([-0.0202998, -0.0122065], dtype=float32), Array(0.37274, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 23 | T: 2.428350e+00 | T: ((Array([-0.01636979, -0.01206261], dtype=float32), Array(0.37738302, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 24 | T: 2.357594e+00 | T: ((Array([-0.01270734, -0.01232953], dtype=float32), Array(0.38184577, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 25 | T: 2.293628e+00 | T: ((Array([-0.00930289, -0.01292171], dtype=float32), Array(0.38613713, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 26 | T: 2.235742e+00 | T: ((Array([-0.00614666, -0.01370466], dtype=float32), Array(0.3902657, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 27 | T: 2.183125e+00 | T: ((Array([-0.00322866, -0.01453952], dtype=float32), Array(0.39423987, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 28 | T: 2.134993e+00 | T: ((Array([-0.0005388 , -0.01529291], dtype=float32), Array(0.39806768, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 29 | T: 2.090705e+00 | T: ((Array([ 0.00193307, -0.01585581], dtype=float32), Array(0.40175685, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 30 | T: 2.050170e+00 | T: ((Array([ 0.00419706, -0.01615573], dtype=float32), Array(0.4053148, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 31 | T: 2.012636e+00 | T: ((Array([ 0.00626325, -0.01617463], dtype=float32), Array(0.4087486, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 32 | T: 1.978205e+00 | T: ((Array([ 0.00814158, -0.01592822], dtype=float32), Array(0.412065, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 33 | T: 1.945994e+00 | T: ((Array([ 0.00984187, -0.01547763], dtype=float32), Array(0.41527048, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 34 | T: 1.915810e+00 | T: ((Array([ 0.01137376, -0.01490612], dtype=float32), Array(0.41837108, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 35 | T: 1.887794e+00 | T: ((Array([ 0.01274668, -0.01430832], dtype=float32), Array(0.42137262, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 36 | T: 1.861552e+00 | T: ((Array([ 0.01396983, -0.01376798], dtype=float32), Array(0.4242806, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 37 | T: 1.837010e+00 | T: ((Array([ 0.01505217, -0.01335713], dtype=float32), Array(0.42710024, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 38 | T: 1.813626e+00 | T: ((Array([ 0.01600238, -0.01313041], dtype=float32), Array(0.42983642, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 39 | T: 1.791643e+00 | T: ((Array([ 0.01682887, -0.01309762], dtype=float32), Array(0.43249378, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 40 | T: 1.770879e+00 | T: ((Array([ 0.01753976, -0.01324071], dtype=float32), Array(0.43507668, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 41 | T: 1.751250e+00 | T: ((Array([ 0.01814289, -0.01352565], dtype=float32), Array(0.43758926, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 42 | T: 1.732166e+00 | T: ((Array([ 0.01864578, -0.01389507], dtype=float32), Array(0.4400353, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 43 | T: 1.714505e+00 | T: ((Array([ 0.01905565, -0.01428853], dtype=float32), Array(0.44241855, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 44 | T: 1.697238e+00 | T: ((Array([ 0.01937941, -0.01464073], dtype=float32), Array(0.44474235, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 45 | T: 1.681140e+00 | T: ((Array([ 0.01962369, -0.01490626], dtype=float32), Array(0.44700995, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 46 | T: 1.665355e+00 | T: ((Array([ 0.01979479, -0.01504882], dtype=float32), Array(0.44922435, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 47 | T: 1.650431e+00 | T: ((Array([ 0.01989871, -0.01506276], dtype=float32), Array(0.45138836, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 48 | T: 1.636099e+00 | T: ((Array([ 0.01994118, -0.01494877], dtype=float32), Array(0.45350465, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 49 | T: 1.622229e+00 | T: ((Array([ 0.0199276 , -0.01473697], dtype=float32), Array(0.4555757, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 50 | T: 1.608997e+00 | T: ((Array([ 0.01986311, -0.01446169], dtype=float32), Array(0.45760387, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 51 | T: 1.596318e+00 | T: ((Array([ 0.01975257, -0.01416761], dtype=float32), Array(0.4595913, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 52 | T: 1.583989e+00 | T: ((Array([ 0.01960056, -0.01389937], dtype=float32), Array(0.46154007, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 53 | T: 1.572088e+00 | T: ((Array([ 0.01941139, -0.01369051], dtype=float32), Array(0.46345207, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 54 | T: 1.560797e+00 | T: ((Array([ 0.01918913, -0.0135701 ], dtype=float32), Array(0.4653291, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 55 | T: 1.549640e+00 | T: ((Array([ 0.01893759, -0.01354981], dtype=float32), Array(0.46717286, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 56 | T: 1.538876e+00 | T: ((Array([ 0.01866033, -0.0136252 ], dtype=float32), Array(0.4689849, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 57 | T: 1.528749e+00 | T: ((Array([ 0.01836071, -0.01377137], dtype=float32), Array(0.4707667, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 58 | T: 1.518717e+00 | T: ((Array([ 0.01804182, -0.01395113], dtype=float32), Array(0.47251964, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 59 | T: 1.508847e+00 | T: ((Array([ 0.01770659, -0.01414127], dtype=float32), Array(0.47424498, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 60 | T: 1.499558e+00 | T: ((Array([ 0.01735769, -0.01431152], dtype=float32), Array(0.47594395, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 61 | T: 1.490479e+00 | T: ((Array([ 0.01699764, -0.01442916], dtype=float32), Array(0.4776177, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 62 | T: 1.481852e+00 | T: ((Array([ 0.01662874, -0.01448383], dtype=float32), Array(0.4792673, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 63 | T: 1.473108e+00 | T: ((Array([ 0.01625312, -0.0144686 ], dtype=float32), Array(0.48089373, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 64 | T: 1.464864e+00 | T: ((Array([ 0.01587276, -0.01439592], dtype=float32), Array(0.4824979, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 65 | T: 1.456973e+00 | T: ((Array([ 0.01548944, -0.01427865], dtype=float32), Array(0.48408073, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 66 | T: 1.449010e+00 | T: ((Array([ 0.01510482, -0.01414147], dtype=float32), Array(0.48564303, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 67 | T: 1.441473e+00 | T: ((Array([ 0.01472039, -0.01400633], dtype=float32), Array(0.48718557, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 68 | T: 1.434119e+00 | T: ((Array([ 0.01433751, -0.01388667], dtype=float32), Array(0.48870906, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 69 | T: 1.426940e+00 | T: ((Array([ 0.01395741, -0.01379656], dtype=float32), Array(0.4902142, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 70 | T: 1.419913e+00 | T: ((Array([ 0.01358121, -0.01374515], dtype=float32), Array(0.4917016, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 71 | T: 1.413188e+00 | T: ((Array([ 0.01320989, -0.0137424 ], dtype=float32), Array(0.4931719, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 72 | T: 1.406323e+00 | T: ((Array([ 0.01284434, -0.01377822], dtype=float32), Array(0.49462563, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 73 | T: 1.400128e+00 | T: ((Array([ 0.01248534, -0.01384501], dtype=float32), Array(0.49606332, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 74 | T: 1.393741e+00 | T: ((Array([ 0.01213358, -0.01392629], dtype=float32), Array(0.4974855, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 75 | T: 1.387634e+00 | T: ((Array([ 0.01178964, -0.01400222], dtype=float32), Array(0.4988926, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 76 | T: 1.381791e+00 | T: ((Array([ 0.01145405, -0.01406551], dtype=float32), Array(0.50028515, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 77 | T: 1.375851e+00 | T: ((Array([ 0.01112724, -0.01411011], dtype=float32), Array(0.50166345, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 78 | T: 1.370249e+00 | T: ((Array([ 0.01080958, -0.01412406], dtype=float32), Array(0.503028, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 79 | T: 1.364747e+00 | T: ((Array([ 0.01050135, -0.0141089 ], dtype=float32), Array(0.5043791, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 80 | T: 1.359370e+00 | T: ((Array([ 0.01020281, -0.0140675 ], dtype=float32), Array(0.50571716, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 81 | T: 1.354099e+00 | T: ((Array([ 0.00991412, -0.01401174], dtype=float32), Array(0.50704247, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 82 | T: 1.348991e+00 | T: ((Array([ 0.00963541, -0.01395295], dtype=float32), Array(0.5083554, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 83 | T: 1.343849e+00 | T: ((Array([ 0.00936676, -0.0138932 ], dtype=float32), Array(0.5096562, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 84 | T: 1.339066e+00 | T: ((Array([ 0.00910821, -0.01384374], dtype=float32), Array(0.5109452, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 85 | T: 1.334323e+00 | T: ((Array([ 0.00885975, -0.01380428], dtype=float32), Array(0.51222265, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 86 | T: 1.329456e+00 | T: ((Array([ 0.00862134, -0.01378656], dtype=float32), Array(0.51348877, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 87 | T: 1.324947e+00 | T: ((Array([ 0.00839291, -0.0137877 ], dtype=float32), Array(0.51474386, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 88 | T: 1.320385e+00 | T: ((Array([ 0.00817436, -0.01380189], dtype=float32), Array(0.5159881, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 89 | T: 1.316251e+00 | T: ((Array([ 0.00796555, -0.01383085], dtype=float32), Array(0.5172218, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 90 | T: 1.311716e+00 | T: ((Array([ 0.00776633, -0.01387029], dtype=float32), Array(0.5184451, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 91 | T: 1.307467e+00 | T: ((Array([ 0.00757653, -0.01390883], dtype=float32), Array(0.51965815, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 92 | T: 1.303365e+00 | T: ((Array([ 0.00739597, -0.01393503], dtype=float32), Array(0.5208612, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 93 | T: 1.299244e+00 | T: ((Array([ 0.00722442, -0.01394909], dtype=float32), Array(0.52205443, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 94 | T: 1.295384e+00 | T: ((Array([ 0.00706168, -0.01395102], dtype=float32), Array(0.523238, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 95 | T: 1.291507e+00 | T: ((Array([ 0.0069075 , -0.01393405], dtype=float32), Array(0.5244121, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 96 | T: 1.287609e+00 | T: ((Array([ 0.00676165, -0.0138993 ], dtype=float32), Array(0.52557683, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 97 | T: 1.284137e+00 | T: ((Array([ 0.00662388, -0.01385681], dtype=float32), Array(0.5267324, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 98 | T: 1.280383e+00 | T: ((Array([ 0.00649394, -0.01381648], dtype=float32), Array(0.52787894, dtype=float32)), Array([0., 0.], dtype=float32))
# Step 99 | T: 1.276822e+00 | T: ((Array([ 0.00637155, -0.01377724], dtype=float32), Array(0.5290166, dtype=float32)), Array([0., 0.], dtype=float32))
# Final 99 | T: 1.276822e+00 | T: (Array([ 0.00637155, -0.01377724], dtype=float32), Array(0.5290166, dtype=float32))

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[1][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.0266 -0.0372 )
# T = 0.5016

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# mu = ( 0.0000 0.0000 )
# T = 0.5290

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0457
#  -T error = 0.0274

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_sm[1][-1])/2:.5f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1])/2:.5f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.02286
#  -T error = 0.0016
# Bridge Diffusion mean:
#  -mean error = 0.00000
#  -T error = 0.0290

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # Hyperbolic Parabolid

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
M = HypParaboloid()
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([0.]*2)
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/HypParaboloid/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

#file_path_s2 = 'scores/HypParaboloid/s2/'
#state_s2 = model_loader.load_model(file_path_s2)
if N<10:
    layers = [50,100,100,50]
elif N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log_ad(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    
    return ggrad

def ggrady_log_score(x,y,t):
    
    ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

if s2_approximation:
    ggrady_log = ggrady_log_score
else:
    ggrady_log = ggrady_log_ad

# %%
grady_log(x0,x0,0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/2994225942.py in <module>
# ----> 1 grady_log(x0,x0,0.5)
#
# /tmp/ipykernel_263434/3353202324.py in grady_log(x, y, t)
#      16 def grady_log(x,y,t):
#      17
# ---> 18     return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
#      19
#      20 def gradt_log(x,y,t):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_263434/3353202324.py in <lambda>(x)
#      10 else:
#      11     layers = [50,100,200,400,400,200,100,50]
# ---> 12 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      13 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      14                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      53         grad_euc = (x1-x2)/t
#      54
# ---> 55         return self.model()(x)+grad_euc
#      56
#      57 @dataclasses.dataclass
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, *args, **kwargs)
#     125         out = layer(out, *args, **kwargs)
#     126       else:
# --> 127         out = layer(out)
#     128     return out
#     129
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, precision)
#     176       stddev = 1. / np.sqrt(self.input_size)
#     177       w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 178     w = hk.get_parameter("w", [input_size, output_size], dtype, init=w_init)
#     179
#     180     out = jnp.dot(inputs, w, precision=precision)
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in wrapped(*args, **kwargs)
#     600   @functools.wraps(f)
#     601   def wrapped(*args, **kwargs):
# --> 602     return wrapped._current(*args, **kwargs)
#     603
#     604   def replace(g):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in get_parameter(name, shape, dtype, init)
#     705
#     706   if param.shape != tuple(shape):
# --> 707     raise ValueError(
#     708         f"{fq_name!r} with retrieved shape {param.shape!r} does not match "
#     709         f"shape={shape!r} dtype={dtype!r}")
#
# ValueError: 'mlp_s1/~model/linear_2/w' with retrieved shape (100, 100) does not match shape=[100, 200] dtype=dtype('float32')

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/HypParaboloid/s1_' + loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel(loss_type)
ax.set_title('Training Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/HypParaboloid/xs.csv', header=None)
charts = pd.read_csv('Data/HypParaboloid/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
grady_log((x0[0],jnp.zeros(3)),(x0[0],jnp.zeros(3)),0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/1993598298.py in <module>
# ----> 1 grady_log((x0[0],jnp.zeros(3)),(x0[0],jnp.zeros(3)),0.5)
#
# /tmp/ipykernel_263434/3353202324.py in grady_log(x, y, t)
#      16 def grady_log(x,y,t):
#      17
# ---> 18     return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
#      19
#      20 def gradt_log(x,y,t):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_263434/3353202324.py in <lambda>(x)
#      10 else:
#      11     layers = [50,100,200,400,400,200,100,50]
# ---> 12 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      13 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      14                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      53         grad_euc = (x1-x2)/t
#      54
# ---> 55         return self.model()(x)+grad_euc
#      56
#      57 @dataclasses.dataclass
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, *args, **kwargs)
#     125         out = layer(out, *args, **kwargs)
#     126       else:
# --> 127         out = layer(out)
#     128     return out
#     129
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, precision)
#     176       stddev = 1. / np.sqrt(self.input_size)
#     177       w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 178     w = hk.get_parameter("w", [input_size, output_size], dtype, init=w_init)
#     179
#     180     out = jnp.dot(inputs, w, precision=precision)
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in wrapped(*args, **kwargs)
#     600   @functools.wraps(f)
#     601   def wrapped(*args, **kwargs):
# --> 602     return wrapped._current(*args, **kwargs)
#     603
#     604   def replace(g):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in get_parameter(name, shape, dtype, init)
#     705
#     706   if param.shape != tuple(shape):
# --> 707     raise ValueError(
#     708         f"{fq_name!r} with retrieved shape {param.shape!r} does not match "
#     709         f"shape={shape!r} dtype={dtype!r}")
#
# ValueError: 'mlp_s1/~model/linear_2/w' with retrieved shape (100, 100) does not match shape=[100, 200] dtype=dtype('float32')

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.001, max_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/93835396.py in <module>
#       1 diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
# ----> 2 mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]),
#       3                                      step_size=0.001, max_iter=1000)
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in <lambda>(X_obs, x0, t, step_size, max_iter)
#      86     elif method == "Gradient":
#      87
# ---> 88         M.sm_dmxt = lambda X_obs, x0, t, step_size=0.1, max_iter=1000: JointGradientDescent(x0,
#      89                                                                                             jnp.array(t),
#      90                                                                                             M,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/optimization/GradientDescent.py in JointGradientDescent(mu_rm, mu_euc, M, grad_fn_rm, grad_fn_euc, step_size_rm, step_size_euc, max_iter, bnds_rm, bnds_euc, max_step)
#     148     ub_rm = bnds_rm[1]
#     149
# --> 150     grad_rm = grad_fn_rm(mu_rm, mu_euc)
#     151     grad_euc = grad_fn_euc(mu_rm, mu_euc)
#     152
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in <lambda>(y, t)
#      89                                                                                             jnp.array(t),
#      90                                                                                             M,
# ---> 91                                                                                             grad_fn_rm = lambda y,t: gradx_loss(X_obs, y, t),
#      92                                                                                             grad_fn_euc = lambda y,t: gradt_loss(X_obs, y, t),
#      93                                                                                             step_size_rm=step_size,
#
#     [... skipping hidden 12 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in gradx_loss(X_obs, y, t)
#      57     def gradx_loss(X_obs:Tuple[Array, Array], y:Tuple[Array,Array],t:Array)->Array:
#      58
# ---> 59         s1 = vmap(lambda x,chart: s1_model((x,chart),y,t))(X_obs[0], X_obs[1])
#      60
#      61         gradx = -jnp.mean(s1, axis=0)
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in <lambda>(x, chart)
#      57     def gradx_loss(X_obs:Tuple[Array, Array], y:Tuple[Array,Array],t:Array)->Array:
#      58
# ---> 59         s1 = vmap(lambda x,chart: s1_model((x,chart),y,t))(X_obs[0], X_obs[1])
#      60
#      61         gradx = -jnp.mean(s1, axis=0)
#
# /tmp/ipykernel_263434/3353202324.py in grady_log(x, y, t)
#      16 def grady_log(x,y,t):
#      17
# ---> 18     return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
#      19
#      20 def gradt_log(x,y,t):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_263434/3353202324.py in <lambda>(x)
#      10 else:
#      11     layers = [50,100,200,400,400,200,100,50]
# ---> 12 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      13 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      14                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      53         grad_euc = (x1-x2)/t
#      54
# ---> 55         return self.model()(x)+grad_euc
#      56
#      57 @dataclasses.dataclass
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, *args, **kwargs)
#     125         out = layer(out, *args, **kwargs)
#     126       else:
# --> 127         out = layer(out)
#     128     return out
#     129
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, precision)
#     176       stddev = 1. / np.sqrt(self.input_size)
#     177       w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 178     w = hk.get_parameter("w", [input_size, output_size], dtype, init=w_init)
#     179
#     180     out = jnp.dot(inputs, w, precision=precision)
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in wrapped(*args, **kwargs)
#     600   @functools.wraps(f)
#     601   def wrapped(*args, **kwargs):
# --> 602     return wrapped._current(*args, **kwargs)
#     603
#     604   def replace(g):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in get_parameter(name, shape, dtype, init)
#     705
#     706   if param.shape != tuple(shape):
# --> 707     raise ValueError(
#     708         f"{fq_name!r} with retrieved shape {param.shape!r} does not match "
#     709         f"shape={shape!r} dtype={dtype!r}")
#
# ValueError: 'mlp_s1/~model/linear_2/w' with retrieved shape (100, 100) does not match shape=[100, 200] dtype=dtype('float32')

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/3771304905.py in <module>
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_263434/3771304905.py in <lambda>(t)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_263434/3771304905.py in <lambda>(x, chart)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log((mu_sm[0][-1], mu_sm[1][-1]), (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
# /tmp/ipykernel_263434/3353202324.py in gradt_log(x, y, t)
#      20 def gradt_log(x,y,t):
#      21
# ---> 22     s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
#      23     s2_val = ggrady_log(x,y,t)
#      24
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_263434/3353202324.py in <lambda>(x)
#      10 else:
#      11     layers = [50,100,200,400,400,200,100,50]
# ---> 12 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      13 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      14                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      53         grad_euc = (x1-x2)/t
#      54
# ---> 55         return self.model()(x)+grad_euc
#      56
#      57 @dataclasses.dataclass
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, *args, **kwargs)
#     125         out = layer(out, *args, **kwargs)
#     126       else:
# --> 127         out = layer(out)
#     128     return out
#     129
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/basic.py in __call__(self, inputs, precision)
#     176       stddev = 1. / np.sqrt(self.input_size)
#     177       w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 178     w = hk.get_parameter("w", [input_size, output_size], dtype, init=w_init)
#     179
#     180     out = jnp.dot(inputs, w, precision=precision)
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in wrapped(*args, **kwargs)
#     600   @functools.wraps(f)
#     601   def wrapped(*args, **kwargs):
# --> 602     return wrapped._current(*args, **kwargs)
#     603
#     604   def replace(g):
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/base.py in get_parameter(name, shape, dtype, init)
#     705
#     706   if param.shape != tuple(shape):
# --> 707     raise ValueError(
#     708         f"{fq_name!r} with retrieved shape {param.shape!r} does not match "
#     709         f"shape={shape!r} dtype={dtype!r}")
#
# ValueError: 'mlp_s1/~model/linear_2/w' with retrieved shape (100, 100) does not match shape=[100, 200] dtype=dtype('float32')

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 140005670970288 was created on line:
#   /home/fmry/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py:42 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_718353/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      81
#      82     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 83             iterative_mle(samples,\
#      84                 neg_log_p_Ts,\
#      85                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      55
#      56     for i in range(num_steps):
# ---> 57         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      58         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      59         if i % 1 == 0:
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      42
#      43         params = get_params(opt_state)
# ---> 44         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      45         opt_state = opt_update(step, grads, opt_state)
#      46         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     133         T = jnp.sum(dts)
#     134
# --> 135         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     136
#     137         # sample
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63     # guide function
#      64     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 65                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      66                                       (1,0))
#      67     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      50             v0 = jnp.zeros(M.dim)
#      51
# ---> 52         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      53
#      54         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( 0.2148 -0.7179 )
# T = 0.7120

# %%
print(f"Bridge Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
print(f"T = {T_bridge[-1]:.4f}")
# Out:
# Bridge Riemannian Diffusion Mean:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/3061874042.py in <module>
#       1 print(f"Bridge Riemannian Diffusion Mean:")
# ----> 2 print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_bridgechart[-1]), ")")
#       3 print(f"T = {T_bridge[-1]:.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
print("The difference between the score and bridge:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(mu_bridgechart[-1]-mu_sm[1][-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-T_sm[-1][0]):.4f}")
# Out:
# The difference between the score and bridge:
# Score Diffusion mean:
#  -mean error = 0.0000
#  -T error = 0.4710

# %%
M.F((mu_sm[0][-1], mu_sm[1][-1]))
# Out:
# Array([  1.0282233,  -3.7317057, -12.868383 ], dtype=float32)

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 3.8708
#  -T error = 0.2000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_202345/3470961726.py in <module>
#       1 print("The Error estimates are:")
#       2 print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# ----> 3 print(f"Bridge Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[1]-mu_bridgechart[-1]):.4f} \n -T error = {jnp.abs(T_bridge[-1]-0.5):.4f}")
#
# NameError: name 'mu_bridgechart' is not defined

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 426 ms ± 7.06 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit M.diffusion_mean(X_obs,num_steps=100)

# %% [markdown]
# # SPDN

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2

# %%
M = SPDN(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([10.]*(N*(N+1)//2))
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/SPDN'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
file_path_s2 = 'scores/SPDN'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
from jax import jacfwd
if N*N<10:
    layers = [50,100,100,50]
elif N*N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    #ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/SPDN'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  370

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/SPDN'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/SPDN'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values)[~jnp.isnan(xs.values).any(axis=1)], jnp.array(charts.values)[~jnp.isnan(xs.values).any(axis=1)])

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.1, max_iter=1000)
# Out:
# /home/fmry/anaconda3/lib/python3.9/site-packages/jax/_src/ops/scatter.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return lax_internal._convert_element_type(out, dtype, weak_type)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 139768308431904 was created on line:
#   /home/fmry/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py:42 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_915229/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      81
#      82     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 83             iterative_mle(samples,\
#      84                 neg_log_p_Ts,\
#      85                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      55
#      56     for i in range(num_steps):
# ---> 57         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      58         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      59         if i % 1 == 0:
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      42
#      43         params = get_params(opt_state)
# ---> 44         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      45         opt_state = opt_update(step, grads, opt_state)
#      46         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     133         T = jnp.sum(dts)
#     134
# --> 135         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     136
#     137         # sample
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63     # guide function
#      64     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 65                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      66                                       (1,0))
#      67     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      50             v0 = jnp.zeros(M.dim)
#      51
# ---> 52         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      53
#      54         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.4984
#  -T error = 0.2010

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 1min 7s ± 2.18 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Sym

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 5

# %%
M = Sym(N=N)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords([10.]*(N*(N+1)//2))
# Out:
# using M.Exp for Logarithm

# %%
file_path = 'scores/Sym'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)
from jax import jacfwd
if N*N<10:
    layers = [50,100,100,50]
elif N*N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    #ggrad = s2.apply(state_s2.params, rng_key, jnp.hstack((x[0],y[0],t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Sym'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  50010

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Sym'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/Sym'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values)[~jnp.isnan(xs.values).any(axis=1)], jnp.array(charts.values)[~jnp.isnan(xs.values).any(axis=1)])

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]), 
                                     step_size=0.001, max_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     262       else:
# --> 263         return cached(config._trace_context(), *args, **kwargs)
#     264
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     255     def cached(_, *args, **kwargs):
# --> 256       return f(*args, **kwargs)
#     257
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_cached(*shapes)
#     153 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 154   return _broadcast_shapes_uncached(*shapes)
#     155
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     169   if result_shape is None:
# --> 170     raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     171   return result_shape
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(5, 5), (25,)]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_263434/93835396.py in <module>
#       1 diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
# ----> 2 mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.3]),
#       3                                      step_size=0.001, max_iter=1000)
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/score_matching/diffusion_mean.py in <lambda>(X_obs, x0, t, step_size, max_iter)
#      86     elif method == "Gradient":
#      87
# ---> 88         M.sm_dmxt = lambda X_obs, x0, t, step_size=0.1, max_iter=1000: JointGradientDescent(x0,
#      89                                                                                             jnp.array(t),
#      90                                                                                             M,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/optimization/GradientDescent.py in JointGradientDescent(mu_rm, mu_euc, M, grad_fn_rm, grad_fn_euc, step_size_rm, step_size_euc, max_iter, bnds_rm, bnds_euc, max_step)
#     151     grad_euc = grad_fn_euc(mu_rm, mu_euc)
#     152
# --> 153     _, out = lax.scan(update, init=(mu_rm, mu_euc, grad_rm, grad_euc), xs=jnp.arange(0,max_iter,1))
#     154
#     155     mu_rm = out[0]
#
#     [... skipping hidden 21 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/optimization/GradientDescent.py in update(carry, idx)
#     122         grad_euc = jnp.clip(grad_euc, min_step/step_size_euc, max_step/step_size_euc)
#     123
# --> 124         mu_rm = M.Exp(mu_rm, -step_size_rm*grad_rm)
#     125         #mu_rm[0] = jnp.clip(mu_rm[0], lb_rm, ub_rm)
#     126
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/Sym.py in <lambda>(x, v)
#      64
#      65         self.Expt = self.StdExpt
# ---> 66         self.Exp = lambda x,v: self.Expt(x,v,t=1.0)
#      67         self.ExpEmbedded = self.ExpEmbedded
#      68         self.Log = self.StdLog
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/Sym.py in StdExpt(self, x, v, t)
#      88         Fv = jnp.dot(self.JF(x),v)
#      89
# ---> 90         w = Fx+Fv
#      91
#      92         return (self.invF((w, w)), w.reshape(-1))
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in op(self, *args)
#     721 def _forward_operator_to_aval(name):
#     722   def op(self, *args):
# --> 723     return getattr(self.aval, f"_{name}")(self, *args)
#     724   return op
#     725
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     254     args = (other, self) if swap else (self, other)
#     255     if isinstance(other, _accepted_binop_types):
# --> 256       return binary_op(*args)
#     257     if isinstance(other, _rejected_binop_types):
#     258       raise TypeError(f"unsupported operand type(s) for {opchar}: "
#
#     [... skipping hidden 12 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/ufuncs.py in fn(x1, x2)
#      94     lax_doc: bool = False) -> BinOp:
#      95   def fn(x1, x2, /):
# ---> 96     x1, x2 = promote_args(numpy_fn.__name__, x1, x2)
#      97     return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#      98   fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/util.py in promote_args(fun_name, *args)
#     355   check_arraylike(fun_name, *args)
#     356   _check_no_float0s(fun_name, *args)
# --> 357   return promote_shapes(fun_name, *promote_dtypes(*args))
#     358
#     359
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/util.py in promote_shapes(fun_name, *args)
#     245         if config.jax_numpy_rank_promotion != "allow":
#     246           _rank_promotion_warning_or_error(fun_name, shapes)
# --> 247         result_rank = len(lax.broadcast_shapes(*shapes))
#     248         return [_broadcast_to(arg, (1,) * (result_rank - len(shp)) + shp)
#     249                 for arg, shp in zip(args, shapes)]
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     168   result_shape = _try_broadcast_shapes(shape_list)
#     169   if result_shape is None:
# --> 170     raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     171   return result_shape
#     172
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(5, 5), (25,)]

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 139768308431904 was created on line:
#   /home/fmry/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py:42 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_915229/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      81
#      82     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 83             iterative_mle(samples,\
#      84                 neg_log_p_Ts,\
#      85                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      55
#      56     for i in range(num_steps):
# ---> 57         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      58         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      59         if i % 1 == 0:
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      42
#      43         params = get_params(opt_state)
# ---> 44         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      45         opt_state = opt_update(step, grads, opt_state)
#      46         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     152     log_p_T = partial(_log_p_T,guided,A,phi)
#     153
# --> 154     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     155                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     156
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     133         T = jnp.sum(dts)
#     134
# --> 135         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     136
#     137         # sample
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      63     # guide function
#      64     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 65                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      66                                       (1,0))
#      67     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Articles/smrdm/GitHub/smrdm/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      50             v0 = jnp.zeros(M.dim)
#      51
# ---> 52         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      53
#      54         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.0089
#  -T error = 0.4960

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 1min 7s ± 2.18 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Landmarks

# %% [markdown]
# ## Defining Manifold and Loading Score

# %%
N = 2

# %%
M = Landmarks(N=N,m=2)
jstoch.Brownian_coords(M)
jstat.diffusion_mean(M)
x0 = M.coords(jnp.vstack((jnp.linspace(-5.0,5.0,M.N),jnp.linspace(5.0,-5.0,M.N))).T.flatten())
x0 = M.coords(jnp.vstack((jnp.linspace(-5.0,5.0,M.N),jnp.zeros(M.N))).T.flatten())
if N >=10:
    with open('../../Data/landmarks/Papilonidae/Papilionidae_landmarks.txt', 'r') as the_file:
        all_data = [line.strip() for line in the_file.readlines()]

        x1 = jnp.array([float(x) for x in all_data[0].split()[2:]])
        x2 = jnp.array([float(x) for x in all_data[1].split()[2:]])

        x0 = M.coords(jnp.vstack((x1[::len(x1)//N],x2[::len(x2)//N])).T.flatten())
# Out:
# using M.Exp for Logarithm

# %%
x0[0].reshape(-1,2)
# Out:
# Array([[-5.,  0.],
#        [ 5.,  0.]], dtype=float32)

# %%
file_path = 'scores/Landmarks'+str(N)+'/s1_'+ loss_type + '/'
state = model_loader.load_model(file_path)

file_path_s2 = 'scores/Landmarks'+str(N)+'/s2/'
state_s2 = model_loader.load_model(file_path_s2)
if 2*N<10:
    layers = [50,100,100,50]
elif 2*N<50:
    layers = [50,100,200,200,100,50]
else:
    layers = [50,100,200,400,400,200,100,50]
s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
                                                dim=M.dim, r = max(M.dim//2,1))(x))
rng_key = jax.random.PRNGKey(2712)
def grady_log(x,y,t):
    
    return s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))

def gradt_log(x,y,t):
    
    s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
    s2_val = ggrady_log(x,y,t)
    
    div = jnp.trace(s2_val)+.5*jnp.dot(s1_val,jacfwdx(M.logAbsDet)(y).squeeze())
    
    return 0.5*(jnp.dot(s1_val, s1_val)+div)

def ggrady_log(x,y,t):
    
    ggrad = jacfwdx(lambda y: s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t))))(y)
    #ggrad = s2.apply(state_s2.params,rng_key, jnp.hstack((x[0], y[0], t)))
    
    return ggrad

# %% [markdown]
# ## Loading Loss

# %%
loss = jnp.load('scores/Landmarks'+str(N)+'/s1_'+ loss_type + '/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  90

# %%
fig = plt.figure(figsize=(8,8))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
loss = jnp.load('scores/Landmarks'+str(N)+'/s2/loss_arrays.npy')
print("Number of Epochs: ", len(loss)*10)
# Out:
# Number of Epochs:  210

# %%
fig = plt.figure(figsize=(10,10))

#R2
ax = fig.add_subplot(1,1,1)
ax.plot(10*jnp.arange(1,len(loss)+1, 1), loss)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.grid(True)

# %%
val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
plt.plot(jnp.linspace(0.2,1,100), val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_359239/2011504933.py in <module>
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_359239/2011504933.py in <lambda>(t)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
#     [... skipping hidden 3 frame]
#
# /tmp/ipykernel_359239/2011504933.py in <lambda>(x, chart)
# ----> 1 val = vmap(lambda t: jnp.mean(vmap(lambda x,chart: gradt_log(x0, (x,chart), t))(X_obs[0],X_obs[1]), axis=0))(jnp.linspace(0.2,1,100))
#       2 plt.plot(jnp.linspace(0.2,1,100), val)
#
# /tmp/ipykernel_359239/1155512290.py in gradt_log(x, y, t)
#      20 def gradt_log(x,y,t):
#      21
# ---> 22     s1_val = s1.apply(state.params,rng_key, jnp.hstack((x[0], y[0], t)))
#      23     s2_val = ggrady_log(x,y,t)
#      24
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, *args, **kwargs)
#     185           "name (e.g. `f.apply(.., state=my_state)`)")
#     186
# --> 187     out, state = f.apply(params, None, *args, **kwargs)
#     188     if state:
#     189       raise base.NonEmptyStateError(
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/transform.py in apply_fn(params, state, rng, *args, **kwargs)
#     455     with base.new_context(params=params, state=state, rng=rng) as ctx:
#     456       try:
# --> 457         out = f(*args, **kwargs)
#     458       except jax.errors.UnexpectedTracerError as e:
#     459         raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#
# /tmp/ipykernel_359239/1155512290.py in <lambda>(x)
#      10 else:
#      11     layers = [50,100,200,400,400,200,100,50]
# ---> 12 s1 = hk.transform(lambda x: models.MLP_s1(dim=M.dim, layers=layers)(x))
#      13 s2 = hk.transform(lambda x: models.MLP_s2(layers_alpha=layers, layers_beta=layers,
#      14                                                 dim=M.dim, r = max(M.dim//2,1))(x))
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in wrapped(self, *args, **kwargs)
#     463           f = jax.named_call(f, name=method_name)
#     464
# --> 465       out = f(*args, **kwargs)
#     466
#     467       # Module names are set in the constructor. If `f` is the constructor then
#
# ~/anaconda3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/anaconda3/lib/python3.9/site-packages/haiku/_src/module.py in run_interceptors(bound_method, method_name, self, orig_class, *args, **kwargs)
#     304   """Runs any method interceptors or the original method."""
#     305   if not interceptor_stack:
# --> 306     return bound_method(*args, **kwargs)
#     307
#     308   ctx = MethodContext(module=self,
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/models/models.py in __call__(self, x)
#      51         t = x_new[-1].reshape(shape)
#      52
# ---> 53         grad_euc = (x1-x2)/t
#      54
#      55         return self.model()(x)+grad_euc
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in op(self, *args)
#     721 def _forward_operator_to_aval(name):
#     722   def op(self, *args):
# --> 723     return getattr(self.aval, f"_{name}")(self, *args)
#     724   return op
#     725
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     254     args = (other, self) if swap else (self, other)
#     255     if isinstance(other, _accepted_binop_types):
# --> 256       return binary_op(*args)
#     257     if isinstance(other, _rejected_binop_types):
#     258       raise TypeError(f"unsupported operand type(s) for {opchar}: "
#
#     [... skipping hidden 12 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/ufuncs.py in <lambda>(x1, x2)
#      80     fn = lambda x1, x2, /: lax_fn(*promote_args_numeric(numpy_fn.__name__, x1, x2))
#      81   else:
# ---> 82     fn = lambda x1, x2, /: lax_fn(*promote_args(numpy_fn.__name__, x1, x2))
#      83   fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#      84   fn = jit(fn, inline=True)
#
#     [... skipping hidden 7 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in broadcasting_shape_rule(name, *avals)
#    1585         result_shape.append(non_1s[0])
#    1586       else:
# -> 1587         raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    1588                         f'{", ".join(map(str, map(tuple, shapes)))}.')
#    1589
#
# TypeError: sub got incompatible shapes for broadcasting: (4,), (3,).

# %% [markdown]
# ## Estimating Diffusion t-Mean

# %%
xs = pd.read_csv('Data/Landmarks'+str(N)+'/xs.csv', header=None)
charts = pd.read_csv('Data/Landmarks'+str(N)+'/chart.csv', header=None)
X_obs = (jnp.array(xs.values), jnp.array(charts.values))

# %%
diffusion_mean(M, s1_model=grady_log, s2_model = gradt_log, method="Gradient")
mu_sm, T_sm, gradx_sm, _ = M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.2]), 
                                    step_size=0.01, max_iter=100)

# %%
# run once to compile
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
# run MLE0
(thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)

mu_bridgex, T_bridge, mu_bridgechart = zip(*mu_bridge)
mu_bridgex, mu_bridghechart = jnp.stack(mu_bridgex), jnp.stack(mu_bridgechart)
T_bridge = jnp.stack(T_bridge)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     140                 try:
# --> 141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/core.py in __array__(self, *args, **kw)
#     610   def __array__(self, *args, **kw):
# --> 611     raise TracerArrayConversionError(self)
#     612
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[].
# This BatchTracer with object id 129078400561776 was created on line:
#   /home/fmry/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/riemannian/Log.py:43 (loss)
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_226173/3884635020.py in <module>
#       1 # run once to compile
# ----> 2 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=2, N=1)
#       3 # run MLE0
#       4 (thetas,chart,log_likelihood,log_likelihoods,mu_bridge) = M.diffusion_mean(X_obs,num_steps=100, N=1)
#       5
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(samples, params, N, num_steps)
#      82
#      83     M.diffusion_mean = lambda samples,params=(x[0]+.1*np.random.normal(size=M.dim),jnp.array(.2,dtype="float32")),N=N,num_steps=80: \
# ---> 84             iterative_mle(samples,\
#      85                 neg_log_p_Ts,\
#      86                 params,params_inds,params_update,x[1],_dts,M,\
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in iterative_mle(obss, neg_log_p_Ts, params, params_inds, params_update, chart, _dts, M, N, step_size, num_steps)
#      56
#      57     for i in range(num_steps):
# ---> 58         (value, opt_state, chart) = step(i, params, opt_state, chart)
#      59         values += (value,); paramss += ((*get_params(opt_state),chart),)
#      60         if i % 1 == 0:
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/iterative_mle.py in step(step, params, opt_state, chart)
#      43
#      44         params = get_params(opt_state)
# ---> 45         value,grads = vg(params[0],chart,obss,dWs(len(obss[0])*N*M.dim,_dts).reshape(-1,_dts.shape[0],N,M.dim),_dts,*params[1:])
#      46         opt_state = opt_update(step, grads, opt_state)
#      47         opt_state,chart = params_update(opt_state, chart)
#
#     [... skipping hidden 8 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(*args)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
#     [... skipping hidden 3 frame]
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in <lambda>(x, chart, w, dW, dts, *ys)
#     153     log_p_T = partial(_log_p_T,guided,A,phi)
#     154
# --> 155     neg_log_p_Ts = lambda *args: -jnp.mean(vmap(lambda x,chart,w,dW,dts,*ys: log_p_T((x,chart),w,dW,dts,*ys),
#     156                                                 (None,None,0,0,None,*((None,)*(len(args)-5))))(*args))
#     157
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/stochastics/guided_process.py in _log_p_T(guided, A, phi, x, v, dW, dts, *ys)
#     134         T = jnp.sum(dts)
#     135
# --> 136         Cxv = jnp.sum(phi(x,M.update_coords(v,x[1])[0],*ys)**2)
#     137
#     138         # sample
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/statistics/diffusion_mean.py in <lambda>(q, v, s)
#      64     # guide function
#      65     phi = lambda q,v,s: jnp.tensordot((1/s)*jnp.linalg.cholesky(M.g(q)).T,
# ---> 66                                       M.Log(q,F_fun((v,q[1]))).flatten(),
#      67                                       (1,0))
#      68     A = lambda x,v,w,s: (s**(-2))*jnp.dot(v,jnp.dot(M.g(x),w))
#
# ~/PhD/Projects/score_diffusion_mean/GitHub/GitHub/score_diffusion_mean/jaxgeometry/manifolds/riemannian/Log.py in shoot(x, y, v0)
#      51             v0 = jnp.zeros(M.dim)
#      52
# ---> 53         res = minimize(lambda w: (loss(x,w,y),dloss(x,w,y)), v0, method=method, jac=True, options={'disp': False, 'maxiter': 100})
#      54
#      55         return (res.x,res.fun)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704     elif meth == 'bfgs':
# --> 705         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706     elif meth == 'newton-cg':
#     707         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1416         maxiter = len(x0) * 200
#    1417
# -> 1418     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1419                                   finite_diff_rel_step=finite_diff_rel_step)
#    1420
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     381     # ScalarFunction caches. Reuse of fun(x) during grad
#     382     # calculation reduces overall function evaluations.
# --> 383     sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     385
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     141                     fx = np.asarray(fx).item()
#     142                 except (TypeError, ValueError) as e:
# --> 143                     raise ValueError(
#     144                         "The user-provided objective function "
#     145                         "must return a scalar value."
#
# ValueError: The user-provided objective function must return a scalar value.

# %%
print(f"Score Matching Riemannian Diffusion Mean:")
print("mu = (", ' '.join("{:.4f}".format(x) for x in mu_sm[0][-1]), ")")
print(f"T = {T_sm[-1][0]:.4f}")
# Out:
# Score Matching Riemannian Diffusion Mean:
# mu = ( -5.0323 -0.0567 4.9516 0.1371 )
# T = 0.5158

# %%
print("The Error estimates are:")
print(f"Score Diffusion mean: \n -mean error = {jnp.linalg.norm(x0[0]-mu_sm[0][-1]):.4f} \n -T error = {jnp.abs(T_sm[-1][0]-0.5):.4f}")
# Out:
# The Error estimates are:
# Score Diffusion mean:
#  -mean error = 0.1594
#  -T error = 0.0158

# %%
# %timeit M.sm_dmxt(X_obs, (X_obs[0][0], X_obs[1][0]), jnp.array([0.1]), step_size=0.01, max_iter=100)
# Out:
# 10.1 s ± 2.39 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
